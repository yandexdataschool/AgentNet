# %%
#experiment name and snapshot folder (used for model persistence)
experiment_setup_name = "research.rl_comparison.a3c.e_greedy"
snapshot_path = "/home/jheuristic/yozhik/agentnet_snapshots/"

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline


#theano imports
#the problem is too simple to be run on GPU. Seriously.
# %env THEANO_FLAGS='device=cpu'
import theano
import theano.tensor as T
floatX = theano.config.floatX

import lasagne
# Out:
# env: THEANO_FLAGS='device=cpu'
# /home/jheuristic/thenv/local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # This tutorial builds above the basic tutorial and shows several advanced tools
# * multi-layer (and in principle, arbitrary) agent memory
# * different reinforcement learning algorithms
# * model persistence
#
# __[todo: add more]__

# %% [markdown]
# # Experiment setup
# * Here we load an experiment environment (description below)
# * Designing one from scratch is explained in later tutorials

# %%
import agentnet.experiments.wikicat as experiment
print experiment.__doc__
# Out:
# This experiment Wikipedia data sample on musicians, scraped via the scripts present in this directory.
# For each musician, we know a number of boolean features (factors) on various topics like
#  * whether or not he/she was active in 1990's, 2000's, etc.
#  * whether or not he/she plays guitar, piano, etc
#  * whether or not he/she was born in 50's, 60's, etc.
#  * what wikipedia categories does he/she belong to
#  etc.
#
#
#
# In the initial moment of time, agent knows nothing about any of them.
# At each turn, agent may decide to
#  - "open" one of the hidden factors.
#    - if the factor turns out to be 1, agent receives +3 reward for Wikipedia categories, +1 for other categories,
#    - Otherwise, the reward equals -1 for Wikipedia categories, -1 for other categores
#    - all these rewards are parameterisable during environment creation
#  - decide to quit session
#    - yields reward of 0 and ends the interaction.
#    - all farther actions will have no effect until next session
#
# It is expected, that in order to maximize it's expected reward, the agent
# will converge to a strategy of polling several key features and then utilizing learned
# dependencies between these factors and other ones. For example, if a particular genre was
# popular during particular decays, it makes sense to poll genres and than "open" the corresponding
# most probable years.
#
# The experiment setup contains a single class WikicatEnvironment that
# implements both BaseEnvironment and BaseObjective.

# %%
#Create an environment with all default parameters
env = experiment.WikicatEnvironment()

# %%
from sklearn.cross_validation import train_test_split
attrs, categories, feature_names = env.get_dataset()

train_attrs,test_attrs,train_cats,test_cats = train_test_split(attrs,categories,test_size=0.99,random_state=32)

print "train size:", train_attrs.shape,train_cats.shape
print "train size:", test_attrs.shape,test_cats.shape

print "features:",feature_names[::20]
# Out:
# train size: (85, 300) (85, 93)
# train size: (8509, 300) (8509, 93)
# features: ['Children:is_known', 'Instruments:vocals', 'Genres:electronic', 'Origin:scotland', 'Genres:jazz', 'Genres:electric', 'Occupation:bassist', 'Instruments:violin', 'Genres:instrumental', 'Occupation:entrepreneur', 'Instruments:mandolin', 'Instruments:vocalist', 'Genres:synthpop', 'decades_active:1990', 'Occupation:remixer', 'category:List_of_musical_artists_from_Japan', 'category:List_of_ambient_music_artists', 'category:List_of_crooners', 'category:List_of_country_music_performers', 'category:List_of_bass_guitarists']

# %%
env.load_random_batch(train_attrs,train_cats,5)

# %% [markdown]
# # agent setup
# * An agent implementation has to contain three parts:
#  * Memory layer(s)
#   * in this case, we train two GRU layers [details below]
#  * Q-values evaluation layers
#   * in this case, a lasagne dense layer based on memory layer
#  * Resolver - acton picker layer
#   * in this case, the resolver has epsilon-greedy policy
#
#
# ### two-layer memory architecture
# We train two memory states:
#   * first one, based on observations,
#   * second one, based on first one;
#
# Note that here we update the second memory layer based on the CURRENT state
# of the first one. Instead, you can try to feed it with a previous state.
#
# The q-values are estimated on a concatenated state, effectively on both memory
# states together, but there is no problem with limiting q-evaluator to only one:
# just pass the correct gru layer as an incoming layer to the q-evaluator.
#
# ### Implementation:
# We concatenate both memories into 1 state to pass it through the session loop.
#
# To perform memory update, we need to slice the concatenated state back into
# two memory states.
#
# We do so by defining an input map function and passing it into agent.
#
# We than concatenate two new states back to form a new memory state.

# %%
from agentnet.resolver import EpsilonGreedyResolver
from agentnet.memory import GRUMemoryLayer
from agentnet.agent import Agent

# %%
import lasagne
n_hid_1=128 #first GRU memory
n_hid_2=64 #second GRU memory


_observation_layer = lasagne.layers.InputLayer([None,env.observation_size],name="obs_input")

_prev_gru1_layer = lasagne.layers.InputLayer([None,n_hid_1],name="prev_gru1_state_input")
_prev_gru2_layer = lasagne.layers.InputLayer([None,n_hid_2],name="prev_gru2_state_input")

#memory
gru1 = GRUMemoryLayer(n_hid_1,
                     _observation_layer,
                     _prev_gru1_layer,
                     name="gru1")

gru2 = GRUMemoryLayer(n_hid_2,
                     gru1,        #note that it takes CURRENT gru1 output as input.
                                  #replacing that with _prev_gru1_state would imply taking previous one.
                     _prev_gru2_layer,
                     name="gru2")

concatenated_memory = lasagne.layers.concat([gru1,gru2])

#policy
n_actions = len(feature_names)


policy_layer = lasagne.layers.DenseLayer(concatenated_memory, #taking both memories. 
                                                        #Replacing with gru1 or gru2 would mean taking one
                                         num_units = n_actions,
                                         nonlinearity=lasagne.nonlinearities.softmax,
                                         name="ActionProbas")

state_value_layer = lasagne.layers.DenseLayer(concatenated_memory,
                                       num_units = 1,
                                       nonlinearity = lasagne.nonlinearities.linear,
                                       name = "Vpredicted")

#resolver
epsilon = theano.shared(np.float32(0.9),"e-greedy.epsilon")

resolver = EpsilonGreedyResolver(policy_layer,epsilon=epsilon,name="resolver")



#we need to define the new input map because concatenated_memory is a ConcatLayer and does not have default one

def custom_input_map(last_hidden,observation):
    """just a function that maps memory states to respective inputs"""
    return {
        _prev_gru1_layer:last_hidden[:,0:n_hid_1],
        _prev_gru2_layer:last_hidden[:,n_hid_1:n_hid_1+n_hid_2],
        _observation_layer:observation
    }

#all together
agent = Agent(concatenated_memory,policy_layer,resolver,input_map=custom_input_map
             )

# %%
#Since it's a single lasagne network, one can get it's weights, output, etc
weights = lasagne.layers.get_all_params([resolver,state_value_layer],trainable=True)
weights
# Out:
# [gru1.W_in_to_updategate,
#  gru1.W_hid_to_updategate,
#  gru1.b_updategate,
#  gru1.W_in_to_resetgate,
#  gru1.W_hid_to_resetgate,
#  gru1.b_resetgate,
#  gru1.W_in_to_hidden_update,
#  gru1.W_hid_to_hidden_update,
#  gru1.b_hidden_update,
#  gru2.W_in_to_updategate,
#  gru2.W_hid_to_updategate,
#  gru2.b_updategate,
#  gru2.W_in_to_resetgate,
#  gru2.W_hid_to_resetgate,
#  gru2.b_resetgate,
#  gru2.W_in_to_hidden_update,
#  gru2.W_hid_to_hidden_update,
#  gru2.b_hidden_update,
#  ActionProbas.W,
#  ActionProbas.b,
#  Vpredicted.W,
#  Vpredicted.b]

# %% [markdown]
# ## Agent setup in detail
# * __Memory layers__
#  * One-step recurrent layer
#      * takes input and one's previous state
#      * returns new memory state
#    * Can be arbitrary lasagne layer
#    * Several one-step recurrent units are implemented in __agentnet.memory__
#    * Note that lasagne's default recurrent networks roll for several steps at once
#      * in other words, __using lasagne recurrent units as memory means recurrence inside recurrence__
#  * Using more than one memory layer is explained in farther tutorials
#
#
# * __Q-values evaluation layer__
#  * Can be arbitrary lasagne network
#  * returns predicted Q-values for each action
#  * Usually depends on memory as an input
#
#
# * __Resolver__ - action picker
#  * Decides on what action is taken
#  * Normally takes Q-values as input
#  * Currently all experiments require integer output
#  * Several resolver layers are implemented in __agentnet.resolver__

# %% [markdown]
# # Interacting with environment
# * an agent has a method that produces symbolic environment interaction sessions
# * interactions result in sequences of observations, actions, q-values,etc
# * one has to pre-define maximum session length.
#  * in this case, environment implements an indicator of whether session has ended by current tick
# * Since this environment also implements Objective methods, it can evaluate rewards for each [batch, time_tick]

# %%
#produce interaction sequences of length <= 10
history = agent.get_sessions(env,session_length=10,
                             batch_size=env.batch_size,
                             additional_output_layers = [state_value_layer])

state_seq,observation_seq,hidden_seq,policy_seq,action_seq,V_seq = history


V_seq = V_seq[:,:,0] #drop n_units dimension since we have 1 neuron only

#get rewards for all actions
rewards_seq = env.get_reward_sequences(state_seq,action_seq)

#get indicator whether session is still active
is_alive_seq = env.get_whether_alive(observation_seq)

# %%
#Let us compile a function that returns all interaction logs
get_history = theano.function([],history+(is_alive_seq,rewards_seq,),mode=theano.compile.mode.FAST_RUN)

# %% [markdown]
# # Evaluating loss function
# * This part is similar to the basic tutorial but for the fact that we use SARSA
#
#
#  #### Get (prediction,reference) pairs

# %%
#get reference Qvalues according to Qlearning algorithm


from agentnet.learning import actor_critic


#gamma - delayed reward coefficient - what fraction of reward is retained if it is obtained one tick later
gamma = theano.shared(np.float32(0.95),name = 'q_learning_gamma')


Vreference = actor_critic.get_state_value_reference(V_seq,rewards_seq,is_alive=is_alive_seq,
                               gamma_or_gammas=gamma,max_n=1)

# %% [markdown]
# #### Define loss functions

# %%
policy_loss = actor_critic.get_objective(policy_seq,V_seq,action_seq,Vreference,is_alive=is_alive_seq)

# %%
from agentnet.utils.mdp import get_action_Qvalues
action_probas = get_action_Qvalues(policy_seq,action_seq)

# %%
#regularize network weights

from lasagne.regularization import regularize_network_params, regularize_layer_params, l2
reg_l2 = (regularize_network_params(resolver,l2) +\
          regularize_layer_params(state_value_layer,l2)
         ) *1e-4

# %%
# - H(p(s,theta)). 

entropy_elwise = - T.sum(policy_seq * T.log(policy_seq),axis=-1)
entropy_reg_elwise = T.maximum(T.log(action_probas),-1e3) * entropy_elwise 

reg_entropy =  T.sum(entropy_reg_elwise*is_alive_seq)/ is_alive_seq.sum() * 1

# %%
loss = policy_loss + reg_l2 + reg_entropy

# %% [markdown]
# #### Compute weight updates

# %%
updates = lasagne.updates.adadelta(loss,
                                             weights,learning_rate=0.05)

# %% [markdown]
# #### Some auxilary evaluation metrics

# %%
mean_session_reward = rewards_seq.sum(axis=1).mean()
#...

# %% [markdown]
# # Compile train and evaluation functions

# %%
train_fun = theano.function([],[loss,mean_session_reward],updates=updates)

evaluation_fun = theano.function([],[loss,policy_loss,reg_l2,reg_entropy,mean_session_reward])

# %% [markdown]
# # session visualization tools
#
#
# * this is a completely optional step of visualizing agent's sessions as chains of actions
# * usually useful to get insight on what worked and what din't
# * in this case, we print strings following pattern
#   * [action_name] ([predicted action qvalue]) -> reward [reference qvalue] | next iteration
#
# * plot shows
#     * time ticks over X, abstract values over Y
#     * bold lines are Qvalues for actions
#     * dots on bold lines represent what actions were taken at each moment of time
#     * dashed lines are agent's hidden state neurons
#     * blue vertical line - session end
#
#
# __Warning! the visualization tools are underdeveloped and only allow simple operations.__
#
# if you found yourself struggling to make it do what you want for 5 minutes, go write your own tool [and contribute it :)]

# %%
from agentnet.display.sessions import print_sessions
get_printables = theano.function([], [
        hidden_seq,policy_seq, action_seq,rewards_seq,policy_seq,is_alive_seq
    ])

def display_sessions(with_plots = False):
        
    hidden_log,qvalues_log,actions_log,reward_log, reference_qv_log, is_alive_log = get_printables()
    
    
    print_sessions(qvalues_log,actions_log,reward_log,
                   is_alive_seq = is_alive_log,
                   #hidden_seq=hidden_log, #do not plot hidden since there's too many actions already
                   reference_qvalues_seq = reference_qv_log,
                   action_names=feature_names,
                   legend = False, #do not show legend since there's too many labeled objects
                  plot_qvalues = with_plots)

# %%
#visualize untrained network performance (which is mostly random)
env.load_random_batch(train_attrs,train_cats,1)
display_sessions(with_plots=True)
# Out:
# session # 0
#  Genres:heavy(qv = 0.00253807101399) -> -1.0(ref = 0.00253807101399) |  Occupation:bandleader(qv = 0.00257543893531) -> -1.0(ref = 0.00257543893531) |  Political party:is_known(qv = 0.00254931487143) -> -1.0(ref = 0.00254931487143) |  Label(s):is_known(qv = 0.00252758827992) -> -1.0(ref = 0.00252758827992) |  Genres:ambient(qv = 0.00292134657502) -> -1.0(ref = 0.00292134657502) |  category:List_of_gospel_musicians(qv = 0.00267725880258) -> -1.0(ref = 0.00267725880258) |  Genres:contemporary(qv = 0.00253664958291) -> -1.0(ref = 0.00253664958291) |  Genres:reggae(qv = 0.00286936829798) -> -1.0(ref = 0.00286936829798) |  last_activity:1989(qv = 0.0023491946049) -> -1.0(ref = 0.0023491946049) |  category:List_of_lead_guitarists(qv = 0.00260843802243) -> 0.0(ref = 0.00260843802243) | reached max session length

# %% [markdown]
# # Training loop

# %%
#tools for model persistence
from agentnet.utils.persistence import save,load
import os

# %%
from agentnet.display import Metrics
score_log = Metrics()

# %%
#starting epoch
epoch_counter = 1

#moving average estimation
alpha = 0.1
ma_reward_current = -7.
ma_reward_greedy = -7.

# %%
n_epochs = 250000
batch_size= 50

for i in range(n_epochs):    
    
    #train
    env.load_random_batch(train_attrs,train_cats,batch_size)
    

    loss,avg_reward = train_fun()
    
    
    
    ##update resolver's epsilon (chance of random action instead of optimal one)
    if epoch_counter%10 ==0:
        current_epsilon =  0.05 + 0.25*np.exp(-epoch_counter/10000.)
        resolver.epsilon.set_value(np.float32(current_epsilon))
    
    
    
    ##record current learning progress and show learning curves
    if epoch_counter%100 ==0:

        ##update learning curves
        full_loss, q_loss, l2_penalty,entropy_penalty, avg_reward_current = evaluation_fun()
        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current
        score_log["expected e-greedy reward"][epoch_counter] = ma_reward_current
        
        
        
        #greedy train
        resolver.epsilon.set_value(0)
        avg_reward_greedy = evaluation_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["expected greedy reward"][epoch_counter] = ma_reward_greedy
        
        
        #back to epsilon-greedy
        resolver.epsilon.set_value(np.float32(current_epsilon))

        print "epoch %i,loss %.5f, epsilon %.5f, rewards: ( e-greedy %.5f, greedy %.5f) "%(
            epoch_counter,full_loss,current_epsilon,ma_reward_current,ma_reward_greedy)
        print "rec %.3f l2 %.3f ent %.3f"%(q_loss,l2_penalty,entropy_penalty)

    if epoch_counter %1000 ==0:
        print "Learning curves:"
        score_log.plot()


        print "Random session examples"
        env.load_random_batch(train_attrs,train_cats,3)
        display_sessions(with_plots=False)
    
    #save snapshot
    if epoch_counter %10000 ==0:
        snap_name = "{}.epoch{}.pcl".format(os.path.join(snapshot_path,experiment_setup_name), epoch_counter)
        save(resolver,snap_name)
        print "saved", snap_name

        
        
    epoch_counter  +=1

    
# Time to drink some coffee!
# Out:
# epoch 100,loss -37.32998, epsilon 0.29751, rewards: ( e-greedy -7.03100, greedy -7.06800)
# rec -2.433 l2 0.262 ent -35.158
# epoch 200,loss -35.85560, epsilon 0.29505, rewards: ( e-greedy -7.08790, greedy -7.15820)
# rec -0.989 l2 0.262 ent -35.128
# epoch 300,loss -34.99989, epsilon 0.29261, rewards: ( e-greedy -7.11611, greedy -7.20738)
# rec -0.098 l2 0.261 ent -35.163
# epoch 400,loss -35.21737, epsilon 0.29020, rewards: ( e-greedy -7.19450, greedy -7.26664)
# rec -0.243 l2 0.261 ent -35.236
# epoch 500,loss -34.63593, epsilon 0.28781, rewards: ( e-greedy -7.20005, greedy -7.25098)
# rec 0.329 l2 0.260 ent -35.225
# epoch 600,loss -34.66868, epsilon 0.28544, rewards: ( e-greedy -7.23304, greedy -7.15388)
# rec 0.360 l2 0.260 ent -35.288
# epoch 700,loss -34.85005, epsilon 0.28310, rewards: ( e-greedy -7.27474, greedy -7.27849)
# rec 0.187 l2 0.259 ent -35.295
# epoch 800,loss -34.76480, epsilon 0.28078, rewards: ( e-greedy -7.29827, greedy -7.41064)
# rec 0.264 l2 0.258 ent -35.287
# epoch 900,loss -35.36010, epsilon 0.27848, rewards: ( e-greedy -7.39044, greedy -7.52958)
# rec -0.329 l2 0.257 ent -35.288
# epoch 1000,loss -34.98134, epsilon 0.27621, rewards: ( e-greedy -7.42640, greedy -7.50862)
# rec 0.105 l2 0.256 ent -35.343
# Learning curves:
# Random session examples
# session # 0
#  Origin:washington(qv = 0.00259731127881) -> 1.0(ref = 0.00259731127881) |  Origin:illinois(qv = 0.00283110560849) -> -1.0(ref = 0.00283110560849) |  Genres:contemporary(qv = 0.00279079191387) -> -1.0(ref = 0.00279079191387) |  Genres:blues(qv = 0.00253267865628) -> -1.0(ref = 0.00253267865628) |  Occupation:educator(qv = 0.00250999350101) -> -1.0(ref = 0.00250999350101) |  Genres:score(qv = 0.00262482091784) -> -1.0(ref = 0.00262482091784) |  Genres:roll(qv = 0.00230211368762) -> -1.0(ref = 0.00230211368762) |  category:List_of_lead_vocalists(qv = 0.00282828346826) -> 3.0(ref = 0.00282828346826) |  Genres:roots(qv = 0.00284768873826) -> -1.0(ref = 0.00284768873826) |  category:List_of_pop_and_rock_pianists(qv = 0.00253199785948) -> 0.0(ref = 0.00253199785948) | reached max session length
# session # 1
#  Origin:washington(qv = 0.00259731127881) -> -1.0(ref = 0.00259731127881) |  decades_active:1970(qv = 0.00273410324007) -> 1.0(ref = 0.00273410324007) |  Genres:soul(qv = 0.00261601782404) -> -1.0(ref = 0.00261601782404) |  category:List_of_Chicago_blues_musicians(qv = 0.00252417288721) -> -1.0(ref = 0.00252417288721) |  Origin:canada(qv = 0.00292131863534) -> -1.0(ref = 0.00292131863534) |  Origin:canada(qv = 0.00289433961734) -> -0.5(ref = 0.00289433961734) |  Genres:roll(qv = 0.0029091052711) -> -1.0(ref = 0.0029091052711) |  end_session_now(qv = 0.0028890920803) -> 0.0(ref = 0.0028890920803) |
#
# session # 2
#  Origin:washington(qv = 0.00259731127881) -> 1.0(ref = 0.00259731127881) |  Genres:acoustic(qv = 0.00243066227995) -> -1.0(ref = 0.00243066227995) |  Genres:power(qv = 0.0026445845142) -> 1.0(ref = 0.0026445845142) |  category:List_of_musicians_from_Quebec(qv = 0.00250898860395) -> -1.0(ref = 0.00250898860395) |  Origin:michigan(qv = 0.00284306053072) -> -1.0(ref = 0.00284306053072) |  category:List_of_Maryland_music_people(qv = 0.00280035915785) -> -1.0(ref = 0.00280035915785) |  first_activity:1968(qv = 0.00260576186702) -> -1.0(ref = 0.00260576186702) |  Genres:jazz(qv = 0.00243179616518) -> -1.0(ref = 0.00243179616518) |  Instruments:organ(qv = 0.0027782432735) -> -1.0(ref = 0.0027782432735) |  Genres:hardcore(qv = 0.00277336267754) -> 0.0(ref = 0.00277336267754) | reached max session length
# epoch 1100,loss -34.97729, epsilon 0.27396, rewards: ( e-greedy -7.46076, greedy -7.43776)
# rec 0.087 l2 0.255 ent -35.319
# epoch 1200,loss -35.31701, epsilon 0.27173, rewards: ( e-greedy -7.51668, greedy -7.39498)
# rec -0.209 l2 0.254 ent -35.363
# epoch 1300,loss -35.32088, epsilon 0.26952, rewards: ( e-greedy -7.55701, greedy -7.38548)
# rec -0.219 l2 0.254 ent -35.355
# epoch 1400,loss -35.31995, epsilon 0.26734, rewards: ( e-greedy -7.59531, greedy -7.45594)
# rec -0.227 l2 0.253 ent -35.346
# epoch 1500,loss -35.14545, epsilon 0.26518, rewards: ( e-greedy -7.61378, greedy -7.43334)
# rec -0.033 l2 0.252 ent -35.365
# epoch 1600,loss -34.86404, epsilon 0.26304, rewards: ( e-greedy -7.57440, greedy -7.35501)
# rec 0.276 l2 0.251 ent -35.391
# epoch 1700,loss -35.17370, epsilon 0.26092, rewards: ( e-greedy -7.59496, greedy -7.47751)
# rec -0.044 l2 0.251 ent -35.381
# epoch 1800,loss -15.76062, epsilon 0.25882, rewards: ( e-greedy -6.99647, greedy -6.72976)
# rec 19.454 l2 0.250 ent -35.465
# epoch 1900,loss -35.57677, epsilon 0.25674, rewards: ( e-greedy -7.11382, greedy -6.88378)
# rec -0.434 l2 0.249 ent -35.392
# epoch 2000,loss -34.75258, epsilon 0.25468, rewards: ( e-greedy -7.12144, greedy -6.86340)
# rec 0.384 l2 0.249 ent -35.385
# Learning curves:
# Random session examples
# session # 0
#  category:List_of_adult_alternative_artists(qv = 0.00255848374218) -> -1.0(ref = 0.00255848374218) |  Origin:south(qv = 0.00271009630524) -> -1.0(ref = 0.00271009630524) |  Genres:r&b(qv = 0.00278836651705) -> 1.0(ref = 0.00278836651705) |  category:List_of_country_music_performers(qv = 0.00259300018661) -> -1.0(ref = 0.00259300018661) |  Genres:chicago(qv = 0.0027589504607) -> -1.0(ref = 0.0027589504607) |  category:List_of_French_singers(qv = 0.00248619285412) -> -1.0(ref = 0.00248619285412) |  Occupation:performer(qv = 0.00276479963213) -> -1.0(ref = 0.00276479963213) |  decades_active:1930(qv = 0.00241094897501) -> -1.0(ref = 0.00241094897501) |  Genres:avant-garde(qv = 0.00273954984732) -> -1.0(ref = 0.00273954984732) |  Genres:hip(qv = 0.00271947379224) -> 0.0(ref = 0.00271947379224) | reached max session length
# session # 1
#  Genres:dance-pop(qv = 0.00257358327508) -> -1.0(ref = 0.00257358327508) |  Occupation:tv(qv = 0.00265646260232) -> -1.0(ref = 0.00265646260232) |  Genres:bop(qv = 0.00276307249442) -> -1.0(ref = 0.00276307249442) |  Origin:us(qv = 0.00274777458981) -> -1.0(ref = 0.00274777458981) |  Instruments:mandolin(qv = 0.00241805263795) -> -1.0(ref = 0.00241805263795) |  Instruments:violin(qv = 0.00276515795849) -> -1.0(ref = 0.00276515795849) |  Chinese name:is_known(qv = 0.00243047135882) -> -1.0(ref = 0.00243047135882) |  Education:is_known(qv = 0.00275268778205) -> -1.0(ref = 0.00275268778205) |  last_activity:2013(qv = 0.00260658864863) -> -1.0(ref = 0.00260658864863) |  category:List_of_pop_and_rock_pianists(qv = 0.00270440313034) -> 0.0(ref = 0.00270440313034) | reached max session length
# session # 2
#  Genres:dance-pop(qv = 0.00257358327508) -> -1.0(ref = 0.00257358327508) |  Website:is_known(qv = 0.00272110733204) -> -1.0(ref = 0.00272110733204) |  category:List_of_Israeli_musical_artists(qv = 0.00276207947172) -> -1.0(ref = 0.00276207947172) |  Genres:bop(qv = 0.00279153301381) -> -1.0(ref = 0.00279153301381) |  Instruments:vocalist(qv = 0.002501957817) -> -1.0(ref = 0.002501957817) |  category:List_of_alternative_rock_artists(qv = 0.00275219953619) -> -1.0(ref = 0.00275219953619) |  Origin:los(qv = 0.00251328712329) -> -1.0(ref = 0.00251328712329) |  Origin:germany(qv = 0.00236866460182) -> -1.0(ref = 0.00236866460182) |  Origin:kingdom(qv = 0.00248172273859) -> -1.0(ref = 0.00248172273859) |  Label(s):is_known(qv = 0.00272295298055) -> 0.0(ref = 0.00272295298055) | reached max session length
# epoch 2100,loss -35.39681, epsilon 0.25265, rewards: ( e-greedy -7.18829, greedy -6.98306)
# rec -0.221 l2 0.248 ent -35.424
# epoch 2200,loss -35.39390, epsilon 0.25063, rewards: ( e-greedy -7.26446, greedy -7.13476)
# rec -0.234 l2 0.247 ent -35.407
# epoch 2300,loss -35.06087, epsilon 0.24863, rewards: ( e-greedy -7.29402, greedy -7.23828)
# rec 0.109 l2 0.247 ent -35.417
# epoch 2400,loss -35.08547, epsilon 0.24666, rewards: ( e-greedy -7.31562, greedy -7.34245)
# rec 0.098 l2 0.246 ent -35.430
# epoch 2500,loss -16.31240, epsilon 0.24470, rewards: ( e-greedy -6.74905, greedy -6.60821)
# rec 18.925 l2 0.246 ent -35.483
# epoch 2600,loss -35.08952, epsilon 0.24276, rewards: ( e-greedy -6.82115, greedy -6.67939)
# rec 0.110 l2 0.245 ent -35.445
# epoch 2700,loss -35.04132, epsilon 0.24084, rewards: ( e-greedy -6.88203, greedy -6.85445)
# rec 0.153 l2 0.244 ent -35.439
# epoch 2800,loss -35.17569, epsilon 0.23895, rewards: ( e-greedy -6.95183, greedy -7.00300)
# rec 0.038 l2 0.244 ent -35.457
# epoch 2900,loss -34.98394, epsilon 0.23707, rewards: ( e-greedy -6.98965, greedy -6.93970)
# rec 0.222 l2 0.243 ent -35.449
# epoch 3000,loss -35.31767, epsilon 0.23520, rewards: ( e-greedy -7.05868, greedy -6.96373)
# rec -0.102 l2 0.243 ent -35.459
# Learning curves:
# Random session examples
# session # 0
#  category:List_of_pop_and_rock_pianists(qv = 0.00256168446504) -> -1.0(ref = 0.00256168446504) |  Genres:chicago(qv = 0.00242336909287) -> -1.0(ref = 0.00242336909287) |  category:List_of_Indian_playback_singers(qv = 0.00254834047519) -> -1.0(ref = 0.00254834047519) |  Instruments:cello(qv = 0.00246804021299) -> -1.0(ref = 0.00246804021299) |  Genres:score(qv = 0.00275435601361) -> -1.0(ref = 0.00275435601361) |  category:List_of_R%26B_musicians(qv = 0.00271023134701) -> -1.0(ref = 0.00271023134701) |  category:List_of_bass_guitarists(qv = 0.0026197868865) -> -1.0(ref = 0.0026197868865) |  Origin:texas(qv = 0.0026827887632) -> -1.0(ref = 0.0026827887632) |  Genres:blues[1](qv = 0.0026965404395) -> -1.0(ref = 0.0026965404395) |  category:List_of_electric_blues_musicians(qv = 0.00268273265101) -> 0.0(ref = 0.00268273265101) | reached max session length
# session # 1
#  category:List_of_pop_and_rock_pianists(qv = 0.00256168446504) -> -1.0(ref = 0.00256168446504) |  category:List_of_lead_vocalists(qv = 0.00269033573568) -> -1.0(ref = 0.00269033573568) |  Genres:garage(qv = 0.00270777661353) -> -1.0(ref = 0.00270777661353) |  first_activity:1995(qv = 0.002699743025) -> -1.0(ref = 0.002699743025) |  decades_active:1970(qv = 0.00272468104959) -> 1.0(ref = 0.00272468104959) |  decades_active:1970(qv = 0.00268684723414) -> -0.5(ref = 0.00268684723414) |  Origin:michigan(qv = 0.00270540546626) -> -1.0(ref = 0.00270540546626) |  Origin:u.s.(qv = 0.0027632098645) -> -1.0(ref = 0.0027632098645) |  Origin:u.s.(qv = 0.00269666174427) -> -0.5(ref = 0.00269666174427) |  category:List_of_hip_hop_musicians(qv = 0.00246784393676) -> 0.0(ref = 0.00246784393676) | reached max session length
# session # 2
#  category:List_of_saxophonists(qv = 0.00238064746372) -> -1.0(ref = 0.00238064746372) |  Occupation:activist(qv = 0.00269319000654) -> -1.0(ref = 0.00269319000654) |  category:List_of_all-female_bands(qv = 0.00273308926262) -> -1.0(ref = 0.00273308926262) |  category:List_of_nicknames_of_jazz_musicians(qv = 0.00272102560848) -> -1.0(ref = 0.00272102560848) |  Genres:metal(qv = 0.00268721207976) -> 1.0(ref = 0.00268721207976) |  category:List_of_folk_musicians(qv = 0.00245873630047) -> -1.0(ref = 0.00245873630047) |  first_activity:2010(qv = 0.00259292731062) -> -1.0(ref = 0.00259292731062) |  category:List_of_bass_guitarists(qv = 0.00268381577916) -> -1.0(ref = 0.00268381577916) |  first_activity:1968(qv = 0.00268639018759) -> -1.0(ref = 0.00268639018759) |  category:List_of_Indian_playback_singers(qv = 0.00268622627482) -> 0.0(ref = 0.00268622627482) | reached max session length
# epoch 3100,loss -35.38499, epsilon 0.23336, rewards: ( e-greedy -7.13081, greedy -7.07836)
# rec -0.181 l2 0.242 ent -35.446
# epoch 3200,loss -30.69926, epsilon 0.23154, rewards: ( e-greedy -6.84973, greedy -6.57052)
# rec 4.542 l2 0.242 ent -35.483
# epoch 3300,loss -35.04028, epsilon 0.22973, rewards: ( e-greedy -6.89276, greedy -6.64747)
# rec 0.172 l2 0.241 ent -35.454
# epoch 3400,loss -34.90707, epsilon 0.22794, rewards: ( e-greedy -6.91348, greedy -6.65972)
# rec 0.336 l2 0.241 ent -35.484
# epoch 3500,loss -35.20586, epsilon 0.22617, rewards: ( e-greedy -6.97714, greedy -6.81375)
# rec 0.029 l2 0.240 ent -35.475
# epoch 3600,loss -35.20072, epsilon 0.22442, rewards: ( e-greedy -7.03542, greedy -6.93638)
# rec 0.040 l2 0.240 ent -35.481
# epoch 3700,loss -33.16392, epsilon 0.22268, rewards: ( e-greedy -6.82688, greedy -6.59774)
# rec 2.073 l2 0.240 ent -35.477
# epoch 3800,loss -34.99273, epsilon 0.22097, rewards: ( e-greedy -6.86619, greedy -6.61796)
# rec 0.252 l2 0.239 ent -35.484
# epoch 3900,loss -35.16699, epsilon 0.21926, rewards: ( e-greedy -6.92257, greedy -6.63217)
# rec 0.069 l2 0.239 ent -35.474
# epoch 4000,loss -35.28376, epsilon 0.21758, rewards: ( e-greedy -6.99532, greedy -6.70295)
# rec -0.053 l2 0.238 ent -35.469
# Learning curves:
# Random session examples
# session # 0
#  Genres:industrial(qv = 0.00255908863619) -> -1.0(ref = 0.00255908863619) |  category:List_of_country_music_performers(qv = 0.00270395330153) -> -1.0(ref = 0.00270395330153) |  Instruments:accordion(qv = 0.00241229427047) -> -1.0(ref = 0.00241229427047) |  Instruments:vocals(qv = 0.00268114148639) -> -1.0(ref = 0.00268114148639) |  Resting place:is_known(qv = 0.00269035156816) -> -1.0(ref = 0.00269035156816) |  Genres:chicago(qv = 0.00269153667614) -> -1.0(ref = 0.00269153667614) |  Genres:world(qv = 0.00268481485546) -> -1.0(ref = 0.00268481485546) |  Origin:san(qv = 0.00265911151655) -> -1.0(ref = 0.00265911151655) |  Genres:world(qv = 0.00265166047029) -> -0.5(ref = 0.00265166047029) |  Instruments:flute(qv = 0.00256649614312) -> 0.0(ref = 0.00256649614312) | reached max session length
# session # 1
#  Genres:industrial(qv = 0.00255908863619) -> -1.0(ref = 0.00255908863619) |  Occupation:presenter(qv = 0.00258716777898) -> -1.0(ref = 0.00258716777898) |  category:List_of_folk_musicians(qv = 0.00271882186644) -> -1.0(ref = 0.00271882186644) |  Genres:gospel(qv = 0.00270630908199) -> -1.0(ref = 0.00270630908199) |  Origin:louisiana(qv = 0.00269663147628) -> -1.0(ref = 0.00269663147628) |  Origin:ontario(qv = 0.00267060683109) -> -1.0(ref = 0.00267060683109) |  Occupation:lyricist(qv = 0.00267791259103) -> -1.0(ref = 0.00267791259103) |  Occupation:drummer(qv = 0.00268677878194) -> -1.0(ref = 0.00268677878194) |  Genres:gangsta(qv = 0.00251802266575) -> -1.0(ref = 0.00251802266575) |  Origin:germany(qv = 0.00265620229766) -> 0.0(ref = 0.00265620229766) | reached max session length
# session # 2
#  Genres:industrial(qv = 0.00255908863619) -> -1.0(ref = 0.00255908863619) |  category:List_of_country_music_performers(qv = 0.00270395330153) -> -1.0(ref = 0.00270395330153) |  Occupation:saxophonist(qv = 0.0025774887763) -> -1.0(ref = 0.0025774887763) |  Genres:alternative(qv = 0.00250853109173) -> -1.0(ref = 0.00250853109173) |  Resting place:is_known(qv = 0.00270670745522) -> -1.0(ref = 0.00270670745522) |  Genres:chicago(qv = 0.00270027667284) -> -1.0(ref = 0.00270027667284) |  Occupation:songwriter(qv = 0.00268770125695) -> -1.0(ref = 0.00268770125695) |  Origin:ontario(qv = 0.00265665375628) -> -1.0(ref = 0.00265665375628) |  Origin:kingdom(qv = 0.00267252046615) -> -1.0(ref = 0.00267252046615) |  category:List_of_female_rock_singers(qv = 0.00254136300646) -> 0.0(ref = 0.00254136300646) | reached max session length
# epoch 4100,loss -35.38938, epsilon 0.21591, rewards: ( e-greedy -7.05978, greedy -6.72766)
# rec -0.128 l2 0.238 ent -35.500
# epoch 4200,loss -35.09501, epsilon 0.21426, rewards: ( e-greedy -7.08381, greedy -6.83089)
# rec 0.153 l2 0.237 ent -35.485
# epoch 4300,loss -35.34387, epsilon 0.21263, rewards: ( e-greedy -7.14342, greedy -6.97380)
# rec -0.087 l2 0.237 ent -35.494
# epoch 4400,loss -35.24527, epsilon 0.21101, rewards: ( e-greedy -7.18008, greedy -7.00642)
# rec 0.014 l2 0.237 ent -35.496
# epoch 4500,loss -34.41468, epsilon 0.20941, rewards: ( e-greedy -7.11107, greedy -6.95978)
# rec 0.838 l2 0.236 ent -35.489
# epoch 4600,loss -29.36277, epsilon 0.20782, rewards: ( e-greedy -6.77097, greedy -6.38780)
# rec 5.911 l2 0.236 ent -35.509
# epoch 4700,loss -34.67733, epsilon 0.20625, rewards: ( e-greedy -6.75887, greedy -6.39802)
# rec 0.589 l2 0.235 ent -35.502
# epoch 4800,loss -35.74120, epsilon 0.20470, rewards: ( e-greedy -6.89898, greedy -6.56822)
# rec -0.478 l2 0.235 ent -35.498
# epoch 4900,loss -35.52835, epsilon 0.20316, rewards: ( e-greedy -6.98008, greedy -6.67740)
# rec -0.262 l2 0.235 ent -35.501
# epoch 5000,loss -35.97327, epsilon 0.20163, rewards: ( e-greedy -7.11808, greedy -6.89366)
# rec -0.700 l2 0.234 ent -35.507
# Learning curves:
# Random session examples
# session # 0
#  Genres:ambient(qv = 0.00253385305405) -> -1.0(ref = 0.00253385305405) |  Occupation:voice(qv = 0.00266328151338) -> -1.0(ref = 0.00266328151338) |  Labels:is_known(qv = 0.00249757035635) -> -1.0(ref = 0.00249757035635) |  Genres:indie(qv = 0.00267453189008) -> -1.0(ref = 0.00267453189008) |  category:List_of_crooners(qv = 0.00266613601707) -> -1.0(ref = 0.00266613601707) |  Residence:is_known(qv = 0.00264501711354) -> -1.0(ref = 0.00264501711354) |  category:List_of_crooners(qv = 0.00266177183948) -> -0.5(ref = 0.00266177183948) |  Genres:bass(qv = 0.00266079511493) -> -1.0(ref = 0.00266079511493) |  Origin:u.s.(qv = 0.00265557039529) -> -1.0(ref = 0.00265557039529) |  Genres:blues[1](qv = 0.00250817695633) -> 0.0(ref = 0.00250817695633) | reached max session length
# session # 1
#  Instruments:trombone(qv = 0.00255596521311) -> -1.0(ref = 0.00255596521311) |  Occupation:tv(qv = 0.00265119271353) -> -1.0(ref = 0.00265119271353) |  category:List_of_Swedes_in_music(qv = 0.00267810630612) -> -1.0(ref = 0.00267810630612) |  Genres:instrumental(qv = 0.00249379314482) -> -1.0(ref = 0.00249379314482) |  category:List_of_Swedes_in_music(qv = 0.00270856800489) -> -0.5(ref = 0.00270856800489) |  Occupation:presenter(qv = 0.00267502176575) -> -1.0(ref = 0.00267502176575) |  category:List_of_pop_and_rock_pianists(qv = 0.00269256834872) -> -1.0(ref = 0.00269256834872) |  category:List_of_female_heavy_metal_singers(qv = 0.00268234475516) -> -1.0(ref = 0.00268234475516) |  Genres:southern(qv = 0.00250883656554) -> -1.0(ref = 0.00250883656554) |  end_session_now(qv = 0.00264305924065) -> 0.0(ref = 0.00264305924065) | reached max session length
# session # 2
#  Occupation:conductor(qv = 0.0025398300495) -> 1.0(ref = 0.0025398300495) |  category:List_of_alternative_rock_artists(qv = 0.00268308399245) -> -1.0(ref = 0.00268308399245) |  Instruments:sampler(qv = 0.0026635476388) -> -1.0(ref = 0.0026635476388) |  category:List_of_Chicago_blues_musicians(qv = 0.00268351426348) -> -1.0(ref = 0.00268351426348) |  first_activity:1959(qv = 0.0025481460616) -> -1.0(ref = 0.0025481460616) |  category:List_of_folk_rock_artists(qv = 0.00268045254052) -> -1.0(ref = 0.00268045254052) |  category:List_of_gospel_musicians(qv = 0.00265882792883) -> -1.0(ref = 0.00265882792883) |  first_activity:2001(qv = 0.00265613337979) -> -1.0(ref = 0.00265613337979) |  Native name:is_known(qv = 0.00250242790207) -> -1.0(ref = 0.00250242790207) |  Occupation:entrepreneur(qv = 0.00265370099805) -> 0.0(ref = 0.00265370099805) | reached max session length
# epoch 5100,loss -35.07856, epsilon 0.20012, rewards: ( e-greedy -7.13527, greedy -7.02129)
# rec 0.196 l2 0.234 ent -35.508
# epoch 5200,loss -35.02748, epsilon 0.19863, rewards: ( e-greedy -7.14474, greedy -7.12016)
# rec 0.239 l2 0.234 ent -35.501
# epoch 5300,loss -34.90645, epsilon 0.19715, rewards: ( e-greedy -7.10927, greedy -7.03815)
# rec 0.367 l2 0.233 ent -35.507
# epoch 5400,loss -34.43720, epsilon 0.19569, rewards: ( e-greedy -7.02734, greedy -6.93833)
# rec 0.844 l2 0.233 ent -35.514
# epoch 5500,loss -14.49236, epsilon 0.19424, rewards: ( e-greedy -6.47161, greedy -6.24450)
# rec 20.845 l2 0.233 ent -35.570
# epoch 5600,loss -35.17850, epsilon 0.19280, rewards: ( e-greedy -6.55145, greedy -6.29005)
# rec 0.110 l2 0.232 ent -35.521
# epoch 5700,loss -33.39246, epsilon 0.19138, rewards: ( e-greedy -6.47330, greedy -5.96904)
# rec 1.884 l2 0.232 ent -35.509
# epoch 5800,loss -35.07693, epsilon 0.18997, rewards: ( e-greedy -6.54597, greedy -6.14214)
# rec 0.205 l2 0.232 ent -35.513
# epoch 5900,loss -35.69391, epsilon 0.18858, rewards: ( e-greedy -6.68137, greedy -6.35293)
# rec -0.394 l2 0.231 ent -35.531
# epoch 6000,loss -34.98910, epsilon 0.18720, rewards: ( e-greedy -6.72224, greedy -6.34563)
# rec 0.291 l2 0.231 ent -35.511
# Learning curves:
# Random session examples
# session # 0
#  first_activity:1965(qv = 0.0025257053785) -> -1.0(ref = 0.0025257053785) |  Occupation:engineer(qv = 0.00265499250963) -> -1.0(ref = 0.00265499250963) |  first_activity:1992(qv = 0.00266108731739) -> -1.0(ref = 0.00266108731739) |  category:List_of_Indian_playback_singers(qv = 0.00266501982696) -> -1.0(ref = 0.00266501982696) |  Origin:us(qv = 0.00265569752082) -> -1.0(ref = 0.00265569752082) |  Origin:us(qv = 0.0026458024513) -> -0.5(ref = 0.0026458024513) |  category:List_of_French_singers(qv = 0.00264795892872) -> -1.0(ref = 0.00264795892872) |  category:List_of_French_singers(qv = 0.00265031005256) -> -0.5(ref = 0.00265031005256) |  Genres:music(qv = 0.00252502947114) -> -1.0(ref = 0.00252502947114) |  Instruments:and(qv = 0.00266799493693) -> 0.0(ref = 0.00266799493693) | reached max session length
# session # 1
#  Origin:texas(qv = 0.00255465041846) -> -1.0(ref = 0.00255465041846) |  category:List_of_classical_pianists(qv = 0.00265004602261) -> -1.0(ref = 0.00265004602261) |  Origin:tennessee(qv = 0.00267005432397) -> -1.0(ref = 0.00267005432397) |  Genres:hard(qv = 0.00267971586436) -> -1.0(ref = 0.00267971586436) |  category:List_of_Indian_playback_singers(qv = 0.00267175748013) -> -1.0(ref = 0.00267175748013) |  Genres:metal(qv = 0.00267775123939) -> -1.0(ref = 0.00267775123939) |  category:List_of_Indian_playback_singers(qv = 0.00266584474593) -> -0.5(ref = 0.00266584474593) |  Genres:metal(qv = 0.00265090656467) -> -0.5(ref = 0.00265090656467) |  category:List_of_Indian_playback_singers(qv = 0.00265729287639) -> -0.5(ref = 0.00265729287639) |  end_session_now(qv = 0.00265651755035) -> 0.0(ref = 0.00265651755035) | reached max session length
# session # 2
#  Genres:progressive(qv = 0.00253837928176) -> -1.0(ref = 0.00253837928176) |  Occupation:musician(qv = 0.00264678359963) -> 1.0(ref = 0.00264678359963) |  Genres:gospel(qv = 0.00269248452969) -> -1.0(ref = 0.00269248452969) |  category:List_of_R%26B_musicians(qv = 0.00266712298617) -> -1.0(ref = 0.00266712298617) |  Genres:post-punk(qv = 0.00264625018463) -> -1.0(ref = 0.00264625018463) |  category:List_of_tenors_in_non-classical_music(qv = 0.00251765339635) -> -1.0(ref = 0.00251765339635) |  Origin:norway(qv = 0.00263835536316) -> -1.0(ref = 0.00263835536316) |  Occupation:author(qv = 0.00262790988199) -> -1.0(ref = 0.00262790988199) |  category:List_of_country_music_performers(qv = 0.00256007793359) -> -1.0(ref = 0.00256007793359) |  Occupation:and(qv = 0.00257081631571) -> 0.0(ref = 0.00257081631571) | reached max session length
# epoch 6100,loss -34.72666, epsilon 0.18584, rewards: ( e-greedy -6.74201, greedy -6.35507)
# rec 0.560 l2 0.231 ent -35.517
# epoch 6200,loss -35.41264, epsilon 0.18449, rewards: ( e-greedy -6.82481, greedy -6.46356)
# rec -0.127 l2 0.231 ent -35.516
# epoch 6300,loss -35.05376, epsilon 0.18315, rewards: ( e-greedy -6.87133, greedy -6.65421)
# rec 0.234 l2 0.230 ent -35.518
# epoch 6400,loss -35.52597, epsilon 0.18182, rewards: ( e-greedy -6.96820, greedy -6.87479)
# rec -0.220 l2 0.230 ent -35.536
# epoch 6500,loss -35.72351, epsilon 0.18051, rewards: ( e-greedy -7.07138, greedy -6.98031)
# rec -0.417 l2 0.230 ent -35.536
# epoch 6600,loss -35.36459, epsilon 0.17921, rewards: ( e-greedy -7.12124, greedy -7.06228)
# rec -0.068 l2 0.229 ent -35.526
# epoch 6700,loss -34.99551, epsilon 0.17793, rewards: ( e-greedy -7.12812, greedy -7.04905)
# rec 0.309 l2 0.229 ent -35.533
# epoch 6800,loss -34.71127, epsilon 0.17665, rewards: ( e-greedy -7.09030, greedy -6.96014)
# rec 0.569 l2 0.229 ent -35.509

# %%
T.zeros()

# %%
np.sum(Vreference.eval() - V_seq.eval())

# %% [markdown]
# # Evaluating results

# %%
score_log.plot("final")

# %%
print "Random session examples"
env.load_random_batch(train_attrs,train_cats,10)
display_sessions(with_plots=True)
