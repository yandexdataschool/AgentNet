# %%
#experiment name and snapshot folder (used for model persistence)
experiment_setup_name = "research.rl_comparison.a3c.3_step.larger.wikicat_extended"
snapshot_path = "/home/jheuristic/yozhik/agentnet_snapshots/"

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline


#theano imports
#the problem is too simple to be run on GPU. Seriously.
# %env THEANO_FLAGS='device=gpu2'
import lasagne

import theano
import theano.tensor as T
floatX = theano.config.floatX
# Out:
# env: THEANO_FLAGS='device=gpu2'
# Using gpu device 2: Tesla K40m (CNMeM is disabled, CuDNN 4004)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # This tutorial builds above the basic tutorial and shows several advanced tools
# * multi-layer (and in principle, arbitrary) agent memory
# * different reinforcement learning algorithms
# * model persistence
#
# __[todo: add more]__

# %% [markdown]
# # Experiment setup
# * Here we load an experiment environment (description below)
# * Designing one from scratch is explained in later tutorials

# %%
import agentnet.experiments.wikicat as experiment
print experiment.__doc__
# Out:
# This experiment Wikipedia data sample on musicians, scraped via the scripts present in this directory.
# For each musician, we know a number of boolean features (factors) on various topics like
#  * whether or not he/she was active in 1990's, 2000's, etc.
#  * whether or not he/she plays guitar, piano, etc
#  * whether or not he/she was born in 50's, 60's, etc.
#  * what wikipedia categories does he/she belong to
#  etc.
#
#
#
# In the initial moment of time, agent knows nothing about any of them.
# At each turn, agent may decide to
#  - "open" one of the hidden factors.
#    - if the factor turns out to be 1, agent receives +3 reward for Wikipedia categories, +1 for other categories,
#    - Otherwise, the reward equals -1 for Wikipedia categories, -1 for other categores
#    - all these rewards are parameterisable during environment creation
#  - decide to quit session
#    - yields reward of 0 and ends the interaction.
#    - all farther actions will have no effect until next session
#
# It is expected, that in order to maximize it's expected reward, the agent
# will converge to a strategy of polling several key features and then utilizing learned
# dependencies between these factors and other ones. For example, if a particular genre was
# popular during particular decays, it makes sense to poll genres and than "open" the corresponding
# most probable years.
#
# The experiment setup contains a single class WikicatEnvironment that
# implements both BaseEnvironment and BaseObjective.

# %%
#Create an environment with all default parameters
from collections import defaultdict

rewards_dict={'category_positive': 5, 'attribute_positive': 0.1, 'attribute_negative': -0.1, 'end_action': 0, 'end_action_if_no_category_predicted': -5, 'repeated_poll': -0.1, 'category_negative': -0.1}

env = experiment.WikicatEnvironment(rewards=rewards_dict)

# %%
from sklearn.cross_validation import train_test_split
attrs, categories, feature_names = env.get_dataset(min_occurences=3)

train_attrs,test_attrs,train_cats,test_cats = train_test_split(attrs,categories,train_size=0.9,random_state=32)

print "train size:", train_attrs.shape,train_cats.shape
print "test size:", test_attrs.shape,test_cats.shape

print "features:",feature_names[::20]
# Out:
# train size: (19156, 300) (19156, 93)
# test size: (2129, 300) (2129, 93)
# features: ['Children:is_known', 'Instruments:vocals', 'Genres:electronic', 'Origin:scotland', 'Genres:jazz', 'Genres:electric', 'Occupation:bassist', 'Instruments:violin', 'Genres:instrumental', 'Occupation:entrepreneur', 'Instruments:mandolin', 'Instruments:vocalist', 'Genres:synthpop', 'decades_active:1990', 'Occupation:remixer', 'category:List_of_musical_artists_from_Japan', 'category:List_of_ambient_music_artists', 'category:List_of_crooners', 'category:List_of_country_music_performers', 'category:List_of_bass_guitarists']

# %%
env.load_random_batch(train_attrs,train_cats,5)

# %% [markdown]
# # agent setup
# * An agent implementation has to contain three parts:
#  * Memory layer(s)
#   * in this case, we train two GRU layers [details below]
#  * Q-values evaluation layers
#   * in this case, a lasagne dense layer based on memory layer
#  * Resolver - acton picker layer
#   * in this case, the resolver has epsilon-greedy policy
#
#
# ### two-layer memory architecture
# We train two memory states:
#   * first one, based on observations,
#   * second one, based on first one;
#
# Note that here we update the second memory layer based on the CURRENT state
# of the first one. Instead, you can try to feed it with a previous state.
#
# The q-values are estimated on a concatenated state, effectively on both memory
# states together, but there is no problem with limiting q-evaluator to only one:
# just pass the correct gru layer as an incoming layer to the q-evaluator.
#
# ### Implementation:
# We concatenate both memories into 1 state to pass it through the session loop.
#
# To perform memory update, we need to slice the concatenated state back into
# two memory states.
#
# We do so by defining an input map function and passing it into agent.
#
# We than concatenate two new states back to form a new memory state.

# %%
from agentnet.resolver import ProbablisticResolver
from agentnet.memory import GRUMemoryLayer
from agentnet.agent import Agent

# %%
import lasagne
n_hid_1=512 #first GRU memory
n_hid_2=512 #second GRU memory


_observation_layer = lasagne.layers.InputLayer([None,env.observation_size],name="obs_input")

_prev_gru1_layer = lasagne.layers.InputLayer([None,n_hid_1],name="prev_gru1_state_input")
_prev_gru2_layer = lasagne.layers.InputLayer([None,n_hid_2],name="prev_gru2_state_input")

#memory
gru1 = GRUMemoryLayer(n_hid_1,
                     _observation_layer,
                     _prev_gru1_layer,
                     name="gru1")

gru2 = GRUMemoryLayer(n_hid_2,
                     gru1,        #note that it takes CURRENT gru1 output as input.
                                  #replacing that with _prev_gru1_state would imply taking previous one.
                     _prev_gru2_layer,
                     name="gru2")

concatenated_memory = lasagne.layers.concat([gru1,gru2])

#policy
n_actions = len(feature_names)



smoothing = theano.shared(np.float32(0),"laplacian_smoothing")

def smooth_softmax(x):
    p = lasagne.nonlinearities.softmax(x)
    return (p + smoothing) / (1 + smoothing*n_actions )


policy_layer = lasagne.layers.DenseLayer(concatenated_memory, #taking both memories. 
                                                        #Replacing with gru1 or gru2 would mean taking one
                                         num_units = n_actions,
                                         nonlinearity=smooth_softmax,
                                         name="policy_original")


state_value_layer = lasagne.layers.DenseLayer(concatenated_memory,
                                       num_units = 1,
                                       nonlinearity = lasagne.nonlinearities.linear,
                                       name = "Vpredicted")

#resolver


resolver = ProbablisticResolver(policy_layer,assume_normalized=True,name="resolver")



#we need to define the new input map because concatenated_memory is a ConcatLayer, not MemoryLayer and so
# it does not have default input map

def custom_input_map(last_hidden,observation):
    """just a function that maps memory states to respective inputs"""
    return {
        _prev_gru1_layer:last_hidden[:,0:n_hid_1],
        _prev_gru2_layer:last_hidden[:,n_hid_1:n_hid_1+n_hid_2],
        _observation_layer:observation
    }

#all together
agent = Agent(concatenated_memory,policy_layer,resolver,input_map=custom_input_map
             )

# %%
#Since it's a single lasagne network, one can get it's weights, output, etc
weights = lasagne.layers.get_all_params([resolver,state_value_layer],trainable=True)
weights
# Out:
# [gru1.W_in_to_updategate,
#  gru1.W_hid_to_updategate,
#  gru1.b_updategate,
#  gru1.W_in_to_resetgate,
#  gru1.W_hid_to_resetgate,
#  gru1.b_resetgate,
#  gru1.W_in_to_hidden_update,
#  gru1.W_hid_to_hidden_update,
#  gru1.b_hidden_update,
#  gru2.W_in_to_updategate,
#  gru2.W_hid_to_updategate,
#  gru2.b_updategate,
#  gru2.W_in_to_resetgate,
#  gru2.W_hid_to_resetgate,
#  gru2.b_resetgate,
#  gru2.W_in_to_hidden_update,
#  gru2.W_hid_to_hidden_update,
#  gru2.b_hidden_update,
#  policy_original.W,
#  policy_original.b,
#  Vpredicted.W,
#  Vpredicted.b]

# %% [markdown]
# ## Agent setup in detail
# * __Memory layers__
#  * One-step recurrent layer
#      * takes input and one's previous state
#      * returns new memory state
#    * Can be arbitrary lasagne layer
#    * Several one-step recurrent units are implemented in __agentnet.memory__
#    * Note that lasagne's default recurrent networks roll for several steps at once
#      * in other words, __using lasagne recurrent units as memory means recurrence inside recurrence__
#  * Using more than one memory layer is explained in farther tutorials
#
#
# * __Q-values evaluation layer__
#  * Can be arbitrary lasagne network
#  * returns predicted Q-values for each action
#  * Usually depends on memory as an input
#
#
# * __Resolver__ - action picker
#  * Decides on what action is taken
#  * Normally takes Q-values as input
#  * Currently all experiments require integer output
#  * Several resolver layers are implemented in __agentnet.resolver__

# %% [markdown]
# # Interacting with environment
# * an agent has a method that produces symbolic environment interaction sessions
# * interactions result in sequences of observations, actions, q-values,etc
# * one has to pre-define maximum session length.
#  * in this case, environment implements an indicator of whether session has ended by current tick
# * Since this environment also implements Objective methods, it can evaluate rewards for each [batch, time_tick]

# %%
#produce interaction sequences of length <= 25
history = agent.get_sessions(env,session_length=25,
                             batch_size=env.batch_size,
                             additional_output_layers = [state_value_layer],
                             )

state_seq,observation_seq,hidden_seq,policy_seq,action_seq,V_seq = history


V_seq = V_seq[:,:,0] #drop n_units dimension since we have 1 neuron only

#get rewards for all actions
rewards_seq = env.get_reward_sequences(state_seq,action_seq)

#get indicator whether session is still active
is_alive_seq = env.get_whether_alive(observation_seq)

# %%
#Let us compile a function that returns all interaction logs
get_history = theano.function([],history+(is_alive_seq,rewards_seq,),mode=theano.compile.mode.FAST_RUN)

# %% [markdown]
# # Evaluating loss function
# * This part is similar to the basic tutorial but for the fact that we use SARSA
#
#
#  #### Get (prediction,reference) pairs

# %%
#get reference Qvalues according to Qlearning algorithm


from agentnet.learning import a2c_n_step as  actor_critic


#gamma - delayed reward coefficient - what fraction of reward is retained if it is obtained one tick later
gamma = theano.shared(np.float32(0.95),name = 'q_learning_gamma')


Vreference = actor_critic.get_state_value_reference(V_seq,rewards_seq,is_alive=is_alive_seq,
                               gamma_or_gammas=gamma,n_steps=3)

# %% [markdown]
# #### Define loss functions

# %%
elwise_policy_loss = actor_critic._get_objective(policy_seq,V_seq,action_seq,Vreference,is_alive=is_alive_seq)

policy_loss = elwise_policy_loss.sum()/ is_alive_seq.sum()

# %%
from agentnet.utils.mdp import get_action_Qvalues
action_probas = get_action_Qvalues(policy_seq,action_seq)

# %%
#regularize network weights

from lasagne.regularization import regularize_network_params, regularize_layer_params, l2
reg_l2 = (regularize_network_params(resolver,l2) +\
          regularize_layer_params(state_value_layer,l2)
         ) *1e-4

# %%
# - H(p(s,theta)). 

entropy_elwise = - T.sum(policy_seq * T.log(policy_seq),axis=-1)
entropy_reg_elwise = T.maximum(T.log(action_probas),-1e3) * entropy_elwise 

reg_entropy =  T.sum(entropy_reg_elwise*is_alive_seq)/ is_alive_seq.sum() * 0.05

# %%
loss = policy_loss + reg_l2 + reg_entropy

# %% [markdown]
# #### Compute weight updates

# %%
updates = lasagne.updates.adadelta(loss,
                                             weights,learning_rate=0.05)

# %% [markdown]
# #### Some auxilary evaluation metrics

# %%
mean_session_reward = rewards_seq.sum(axis=1).mean()
#...

# %% [markdown]
# # Compile train and evaluation functions

# %%
train_fun = theano.function([],[loss,mean_session_reward],updates=updates)

evaluation_fun = theano.function([],[loss,policy_loss,reg_l2,reg_entropy,mean_session_reward])

# %% [markdown]
# # session visualization tools
#
#
# * this is a completely optional step of visualizing agent's sessions as chains of actions
# * usually useful to get insight on what worked and what din't
# * in this case, we print strings following pattern
#   * [action_name] ([predicted action qvalue]) -> reward [reference qvalue] | next iteration
#
# * plot shows
#     * time ticks over X, abstract values over Y
#     * bold lines are Qvalues for actions
#     * dots on bold lines represent what actions were taken at each moment of time
#     * dashed lines are agent's hidden state neurons
#     * blue vertical line - session end
#
#
# __Warning! the visualization tools are underdeveloped and only allow simple operations.__
#
# if you found yourself struggling to make it do what you want for 5 minutes, go write your own tool [and contribute it :)]

# %%
from agentnet.display.sessions import print_sessions
get_printables = theano.function([], [
        hidden_seq,policy_seq, action_seq,rewards_seq,policy_seq,is_alive_seq
    ])

def display_sessions(with_plots = False):
        
    hidden_log,qvalues_log,actions_log,reward_log, reference_qv_log, is_alive_log = get_printables()
    
    
    print_sessions(qvalues_log,actions_log,reward_log,
                   is_alive_seq = is_alive_log,
                   #hidden_seq=hidden_log, #do not plot hidden since there's too many actions already
                   reference_policy_seq = reference_qv_log,
                   action_names=feature_names,
                   legend = False, #do not show legend since there's too many labeled objects
                  plot_policy = with_plots)

# %%
#visualize untrained network performance (which is mostly random)
env.load_random_batch(train_attrs,train_cats,1)
display_sessions(with_plots=True)
# Out:
# session # 0
#  Genres:wave(qv = 0.00253807101399) -> -0.10000000149(ref = 0.00253807101399) |  Genres:traditional(qv = 0.00260106101632) -> -0.10000000149(ref = 0.00260106101632) |  Occupation:educator(qv = 0.0022395204287) -> -0.10000000149(ref = 0.0022395204287) |  Origin:states(qv = 0.00269995233975) -> -0.10000000149(ref = 0.00269995233975) |  Instruments:vocalist(qv = 0.00246227439493) -> -0.10000000149(ref = 0.00246227439493) |  Genres:metal(qv = 0.00310136354528) -> -0.10000000149(ref = 0.00310136354528) |  Genres:melodic(qv = 0.00378402974457) -> -0.10000000149(ref = 0.00378402974457) |  Genres:folk(qv = 0.00342301395722) -> -0.10000000149(ref = 0.00342301395722) |  category:List_of_child_music_prodigies(qv = 0.00153743324336) -> -0.10000000149(ref = 0.00153743324336) |  Genres:jazz(qv = 0.00187608483247) -> -0.10000000149(ref = 0.00187608483247) |  Genres:chicago(qv = 0.00241292337887) -> -0.10000000149(ref = 0.00241292337887) |  category:List_of_jazz_drummers(qv = 0.00208563660271) -> -0.10000000149(ref = 0.00208563660271) |  Genres:rap(qv = 0.00377501151524) -> -0.10000000149(ref = 0.00377501151524) |  category:List_of_video_game_musicians(qv = 0.00342718930915) -> -0.10000000149(ref = 0.00342718930915) |  category:List_of_slide_guitarists(qv = 0.00406587263569) -> -0.10000000149(ref = 0.00406587263569) |  last_activity:2004(qv = 0.00494703091681) -> -0.10000000149(ref = 0.00494703091681) |  Occupation:personality(qv = 0.00329784560017) -> -0.10000000149(ref = 0.00329784560017) |  Origin:korea(qv = 0.00277958414517) -> -0.10000000149(ref = 0.00277958414517) |  Occupation:bandleader(qv = 0.00391771970317) -> -0.10000000149(ref = 0.00391771970317) |  Instruments:acoustic(qv = 0.004130769521) -> -0.10000000149(ref = 0.004130769521) |  first_activity:1983(qv = 0.00517397746444) -> -0.10000000149(ref = 0.00517397746444) |  Instruments:synthesizer(qv = 0.00247526401654) -> -0.10000000149(ref = 0.00247526401654) |  first_activity:1992(qv = 0.00834988150746) -> -0.10000000149(ref = 0.00834988150746) |  Genres:rockabilly(qv = 0.00307190511376) -> -0.10000000149(ref = 0.00307190511376) |  Instruments:synthesizer(qv = 0.00496335374191) -> -5.0(ref = 0.00496335374191) | reached max session length

# %%
smoothing.set_value(0.10)

# %% [markdown]
# # Training loop

# %%
#tools for model persistence
from agentnet.utils.persistence import save,load
import os

# %%
from agentnet.display import Metrics
score_log = Metrics()

# %%
#starting epoch
epoch_counter = 1

#moving average estimation
alpha = 0.1
ma_reward_current = -7.
ma_reward_greedy = -7.

# %%
n_epochs = 1000000
batch_size= 50

for i in range(n_epochs):    
    
    #train
    env.load_random_batch(train_attrs,train_cats,batch_size)
    

    loss,avg_reward = train_fun()
    
    
    
    #update resolver's "greediness"
    if epoch_counter%10 ==0:
        current_smoothing =  0.01*np.exp(-epoch_counter/100000.)
        smoothing.set_value(np.float32(current_smoothing))
    
    
    
    ##record current learning progress and show learning curves
    if epoch_counter%100 ==0:

        ##update learning curves
        full_loss, q_loss, l2_penalty,entropy_penalty, avg_reward_current = evaluation_fun()
        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current
        score_log["expected reward with smoothed policy"][epoch_counter] = ma_reward_current
        
        
        
        #greedy train
        smoothing.set_value(0)

        avg_reward_greedy = evaluation_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["expected reward with actual policy"][epoch_counter] = ma_reward_greedy
        
        
        #back to less greedy
        smoothing.set_value(np.float32(current_smoothing))

        print "epoch %i,loss %.5f, smoothing %.5f, rewards: ( in_train %.5f, greedy %.5f) "%(
            epoch_counter,full_loss,current_smoothing,ma_reward_current,ma_reward_greedy)
        print "rec %.3f l2 %.3f ent %.3f"%(q_loss,l2_penalty,entropy_penalty)

    if epoch_counter %1000 ==0:
        print "Learning curves:"
        score_log.plot()


        print "Random session examples"
        env.load_random_batch(train_attrs,train_cats,3)
        display_sessions(with_plots=False)
    
    #save snapshot
    if epoch_counter %10000 ==0:
        snap_name = "{}.epoch{}.pcl".format(os.path.join(snapshot_path,experiment_setup_name), epoch_counter)
        save(resolver,snap_name)
        print "saved", snap_name

        
        
    epoch_counter  +=1

    
# Time to drink some coffee!
# Out:
# epoch 142600,loss -0.67516, smoothing 0.00240, rewards: ( in_train -5.88131, greedy -5.71030)
# rec 0.874 l2 0.227 ent -1.776

# %% [markdown]
# # Evaluating results

# %%
score_log.plot("final")

# %%
print "Random session examples"
env.load_random_batch(train_attrs,train_cats,10)
display_sessions(with_plots=True)
# Out:
# Random session examples
# session # 0
#  Origin:texas(qv = 0.00234468863346) -> -0.10000000149(ref = 0.00234468863346) |  category:List_of_musicians_who_play_left-handed(qv = 0.00295710097998) -> -0.10000000149(ref = 0.00295710097998) |  Occupation:remixer(qv = 0.00212797475979) -> -0.10000000149(ref = 0.00212797475979) |  Genres:techno(qv = 0.00230424641632) -> -0.10000000149(ref = 0.00230424641632) |  Occupation:actor(qv = 0.00233068712987) -> -0.10000000149(ref = 0.00233068712987) |  Height:is_known(qv = 0.00224452838302) -> -0.10000000149(ref = 0.00224452838302) |  Genres:soul(qv = 0.00230972794816) -> -0.10000000149(ref = 0.00230972794816) |  category:List_of_bass_guitarists(qv = 0.00653041200712) -> -0.10000000149(ref = 0.00653041200712) |  category:List_of_Christian_hip_hop_and_rap_artists(qv = 0.00266803521663) -> -0.10000000149(ref = 0.00266803521663) |  last_activity:2004(qv = 0.00233942596242) -> -0.10000000149(ref = 0.00233942596242) |  Genres:indie(qv = 0.00230198050849) -> -0.10000000149(ref = 0.00230198050849) |  Origin:new(qv = 0.00256351963617) -> -0.10000000149(ref = 0.00256351963617) |  decades_active:1940(qv = 0.00264061661437) -> -0.10000000149(ref = 0.00264061661437) |  Cause of death:is_known(qv = 0.00214914348908) -> -0.10000000149(ref = 0.00214914348908) |  Origin:usa(qv = 0.00221070530824) -> -0.10000000149(ref = 0.00221070530824) |  first_activity:1959(qv = 0.00226089335047) -> -0.10000000149(ref = 0.00226089335047) |  Genres:roll(qv = 0.002334859455) -> -0.10000000149(ref = 0.002334859455) |  Label(s):is_known(qv = 0.00219082925469) -> -0.10000000149(ref = 0.00219082925469) |  Instruments:ukulele(qv = 0.00282815727405) -> -0.10000000149(ref = 0.00282815727405) |  Origin:canada(qv = 0.00260111899115) -> -0.10000000149(ref = 0.00260111899115) |  Genres:americana(qv = 0.00242672348395) -> -0.10000000149(ref = 0.00242672348395) |  Instruments:voice(qv = 0.00223230267875) -> -0.10000000149(ref = 0.00223230267875) |  Occupation:host(qv = 0.00205057486892) -> -0.10000000149(ref = 0.00205057486892) |  decades_active:1950(qv = 0.00212684040889) -> -0.10000000149(ref = 0.00212684040889) |  Genres:reggae(qv = 0.00241532432847) -> -5.0(ref = 0.00241532432847) | reached max session length
# session # 1
#  category:List_of_guitarists(qv = 0.005600345321) -> -0.10000000149(ref = 0.005600345321) |  Occupation:director(qv = 0.00224905088544) -> -0.10000000149(ref = 0.00224905088544) |  category:List_of_band_name_etymologies(qv = 0.00252248882316) -> -0.10000000149(ref = 0.00252248882316) |  Origin:michigan(qv = 0.00225264928304) -> -0.10000000149(ref = 0.00225264928304) |  decades_active:1930(qv = 0.00239067291841) -> -0.10000000149(ref = 0.00239067291841) |  Genres:experimental(qv = 0.00217628502287) -> -0.10000000149(ref = 0.00217628502287) |  category:List_of_individual_K-pop_artists(qv = 0.00275849341415) -> -0.10000000149(ref = 0.00275849341415) |  last_activity:2004(qv = 0.00231514545158) -> -0.10000000149(ref = 0.00231514545158) |  Genres:southern(qv = 0.00215052766725) -> -0.10000000149(ref = 0.00215052766725) |  Origin:korea(qv = 0.00215387833305) -> -0.10000000149(ref = 0.00215387833305) |  category:List_of_adult_alternative_artists(qv = 0.00241646193899) -> -0.10000000149(ref = 0.00241646193899) |  Origin:angeles(qv = 0.00216017500497) -> -0.10000000149(ref = 0.00216017500497) |  Genres:americana(qv = 0.00247330381535) -> -0.10000000149(ref = 0.00247330381535) |  Genres:and(qv = 0.00248700822704) -> -0.10000000149(ref = 0.00248700822704) |  Occupation:television(qv = 0.00215074256994) -> -0.10000000149(ref = 0.00215074256994) |  Origin:canada(qv = 0.00259141740389) -> -0.10000000149(ref = 0.00259141740389) |  Religion:is_known(qv = 0.00219324836507) -> -0.10000000149(ref = 0.00219324836507) |  category:List_of_guitarists(qv = 0.0129991397262) -> -0.10000000149(ref = 0.0129991397262) |  Instruments:piano(qv = 0.00232448522002) -> -0.10000000149(ref = 0.00232448522002) |  decades_active:1930(qv = 0.00241240602918) -> -0.10000000149(ref = 0.00241240602918) |  Occupation:arranger(qv = 0.00233727809973) -> -0.10000000149(ref = 0.00233727809973) |  Genres:fusion(qv = 0.00233220285736) -> -0.10000000149(ref = 0.00233220285736) |  Origin:germany(qv = 0.00211974256672) -> -0.10000000149(ref = 0.00211974256672) |  category:List_of_bands_with_more_than_one_lead_vocalist(qv = 0.00240303343162) -> -0.10000000149(ref = 0.00240303343162) |  Genres:blues(qv = 0.00224501709454) -> -5.0(ref = 0.00224501709454) | reached max session length
# session # 2
#  first_activity:2004(qv = 0.00241526402533) -> -0.10000000149(ref = 0.00241526402533) |  last_activity:2004(qv = 0.0023242929019) -> -0.10000000149(ref = 0.0023242929019) |  category:List_of_rhythm_guitarists(qv = 0.00279686483555) -> -0.10000000149(ref = 0.00279686483555) |  Occupation:presenter(qv = 0.0022375092376) -> -0.10000000149(ref = 0.0022375092376) |  Genres:synthpop(qv = 0.00239461427554) -> -0.10000000149(ref = 0.00239461427554) |  Origin:angeles(qv = 0.00218183849938) -> -0.10000000149(ref = 0.00218183849938) |  category:List_of_Swedes_in_music(qv = 0.00283733871765) -> -0.10000000149(ref = 0.00283733871765) |  Instruments:vocal(qv = 0.00219535827637) -> -0.10000000149(ref = 0.00219535827637) |  last_activity:2010(qv = 0.00224451790564) -> -0.10000000149(ref = 0.00224451790564) |  first_activity:2007(qv = 0.00228204275481) -> 0.10000000149(ref = 0.00228204275481) |  Occupation:multi-instrumentalist(qv = 0.00213578389958) -> -0.10000000149(ref = 0.00213578389958) |  first_activity:1956(qv = 0.00220425380394) -> -0.10000000149(ref = 0.00220425380394) |  category:List_of_Latin_pop_artists(qv = 0.00340808718465) -> -0.10000000149(ref = 0.00340808718465) |  Origin:michigan(qv = 0.00213668285869) -> -0.10000000149(ref = 0.00213668285869) |  Origin:san(qv = 0.00242927717045) -> -0.10000000149(ref = 0.00242927717045) |  Instruments:flute(qv = 0.00214687851258) -> -0.10000000149(ref = 0.00214687851258) |  Origin:london(qv = 0.00216593733057) -> -0.10000000149(ref = 0.00216593733057) |  category:List_of_Asian-American_hip_hop_musicians(qv = 0.00295603182167) -> -0.10000000149(ref = 0.00295603182167) |  Birth name:is_known(qv = 0.00338026694953) -> 0.10000000149(ref = 0.00338026694953) |  Genres:reggae(qv = 0.002288821619) -> -0.10000000149(ref = 0.002288821619) |  Genres:ska(qv = 0.00189071439672) -> -0.10000000149(ref = 0.00189071439672) |  Genres:experimental(qv = 0.00212448067032) -> -0.10000000149(ref = 0.00212448067032) |  decades_active:1950(qv = 0.00209201429971) -> -0.10000000149(ref = 0.00209201429971) |  category:List_of_jazz_vocalists(qv = 0.00302236853167) -> -0.10000000149(ref = 0.00302236853167) |  Instruments:trumpet(qv = 0.00205059093423) -> -5.0(ref = 0.00205059093423) | reached max session length
# session # 3
#  Genres:metal(qv = 0.00242375349626) -> -0.10000000149(ref = 0.00242375349626) |  Genres:nu(qv = 0.00237688631751) -> -0.10000000149(ref = 0.00237688631751) |  Origin:u.s.(qv = 0.00237241573632) -> -0.10000000149(ref = 0.00237241573632) |  Genres:progressive(qv = 0.00241421232931) -> -0.10000000149(ref = 0.00241421232931) |  category:List_of_tenors_in_non-classical_music(qv = 0.00231800065376) -> -0.10000000149(ref = 0.00231800065376) |  Genres:electropop(qv = 0.00236221868545) -> -0.10000000149(ref = 0.00236221868545) |  category:List_of_singer-songwriters(qv = 0.0124773504212) -> -0.10000000149(ref = 0.0124773504212) |  category:List_of_bass_guitarists(qv = 0.00624362146482) -> -0.10000000149(ref = 0.00624362146482) |  category:List_of_soft_rock_artists_and_songs(qv = 0.00278252852149) -> -0.10000000149(ref = 0.00278252852149) |  Genres:southern(qv = 0.00215441989712) -> -0.10000000149(ref = 0.00215441989712) |  Occupation:film(qv = 0.00229806546122) -> 0.10000000149(ref = 0.00229806546122) |  category:List_of_lead_vocalists(qv = 0.0101722124964) -> -0.10000000149(ref = 0.0101722124964) |  category:List_of_Brazilian_musicians(qv = 0.00276951724663) -> -0.10000000149(ref = 0.00276951724663) |  Genres:ska(qv = 0.00191312655807) -> -0.10000000149(ref = 0.00191312655807) |  last_activity:1980(qv = 0.00234058313072) -> -0.10000000149(ref = 0.00234058313072) |  category:List_of_singer-songwriters(qv = 0.0232641398907) -> -0.10000000149(ref = 0.0232641398907) |  Instruments:trombone(qv = 0.00239102495834) -> -0.10000000149(ref = 0.00239102495834) |  first_activity:1950(qv = 0.00233584549278) -> -0.10000000149(ref = 0.00233584549278) |  Alma mater:is_known(qv = 0.00215051718988) -> -0.10000000149(ref = 0.00215051718988) |  Genres:r&b(qv = 0.00259945075959) -> -0.10000000149(ref = 0.00259945075959) |  Genres:acoustic(qv = 0.00264212489128) -> -0.10000000149(ref = 0.00264212489128) |  last_activity:2001(qv = 0.00220973719843) -> -0.10000000149(ref = 0.00220973719843) |  Genres:ska(qv = 0.00203514820896) -> -0.10000000149(ref = 0.00203514820896) |  Origin:australia(qv = 0.00231047836132) -> -0.10000000149(ref = 0.00231047836132) |  Instruments:synthesizer(qv = 0.00207127048634) -> -5.0(ref = 0.00207127048634) | reached max session length
# session # 4
#  Partner(s):is_known(qv = 0.00234815035947) -> -0.10000000149(ref = 0.00234815035947) |  decades_active:before_1920(qv = 0.00230383151211) -> -0.10000000149(ref = 0.00230383151211) |  Occupation:director(qv = 0.00222956715152) -> -0.10000000149(ref = 0.00222956715152) |  category:List_of_soft_rock_artists_and_songs(qv = 0.00262814410962) -> -0.10000000149(ref = 0.00262814410962) |  Occupation:host(qv = 0.00221511628479) -> -0.10000000149(ref = 0.00221511628479) |  Genres:k-pop(qv = 0.00218703877181) -> -0.10000000149(ref = 0.00218703877181) |  category:List_of_female_rock_singers(qv = 0.00342425168492) -> -0.10000000149(ref = 0.00342425168492) |  Genres:bluegrass(qv = 0.00213527213782) -> -0.10000000149(ref = 0.00213527213782) |  Genres:rock(qv = 0.00295199989341) -> -0.10000000149(ref = 0.00295199989341) |  last_activity:2013(qv = 0.00247374060564) -> -0.10000000149(ref = 0.00247374060564) |  category:List_of_roots_reggae_artists(qv = 0.00248518283479) -> -0.10000000149(ref = 0.00248518283479) |  Occupation:rapper(qv = 0.00227063661441) -> -0.10000000149(ref = 0.00227063661441) |  decades_active:2000(qv = 0.00346622383222) -> -0.10000000149(ref = 0.00346622383222) |  category:List_of_Indian_playback_singers(qv = 0.00247706193477) -> -0.10000000149(ref = 0.00247706193477) |  Genres:post-punk(qv = 0.00221538427286) -> -0.10000000149(ref = 0.00221538427286) |  category:List_of_crooners(qv = 0.00252263923176) -> -0.10000000149(ref = 0.00252263923176) |  last_activity:1992(qv = 0.00220140814781) -> -0.10000000149(ref = 0.00220140814781) |  decades_active:1930(qv = 0.00238478858955) -> -0.10000000149(ref = 0.00238478858955) |  Occupation:director(qv = 0.00222609750926) -> -0.10000000149(ref = 0.00222609750926) |  Instruments:bass(qv = 0.00245543406345) -> -0.10000000149(ref = 0.00245543406345) |  Occupation:model(qv = 0.00212310743518) -> -0.10000000149(ref = 0.00212310743518) |  category:List_of_drummers(qv = 0.00618511810899) -> -0.10000000149(ref = 0.00618511810899) |  category:List_of_musical_artists_from_Japan(qv = 0.00264223502018) -> -0.10000000149(ref = 0.00264223502018) |  Instruments:harmonica(qv = 0.00248749065213) -> -0.10000000149(ref = 0.00248749065213) |  Genres:metal(qv = 0.00244871061295) -> -5.0(ref = 0.00244871061295) | reached max session length
# session # 5
#  Genres:gothic(qv = 0.00229684333317) -> -0.10000000149(ref = 0.00229684333317) |  category:List_of_musicians_from_Quebec(qv = 0.00264485389926) -> -0.10000000149(ref = 0.00264485389926) |  Genres:instrumental(qv = 0.00226462655701) -> -0.10000000149(ref = 0.00226462655701) |  Genres:black(qv = 0.00218460615724) -> -0.10000000149(ref = 0.00218460615724) |  Genres:folk(qv = 0.00236780382693) -> -0.10000000149(ref = 0.00236780382693) |  category:List_of_guitarists(qv = 0.010575350374) -> -0.10000000149(ref = 0.010575350374) |  category:List_of_rhythm_guitarists(qv = 0.00282965134829) -> -0.10000000149(ref = 0.00282965134829) |  Genres:[1](qv = 0.00239756773226) -> -0.10000000149(ref = 0.00239756773226) |  category:List_of_jazz_pianists(qv = 0.00400539999828) -> -0.10000000149(ref = 0.00400539999828) |  Children:is_known(qv = 0.00262587773614) -> -0.10000000149(ref = 0.00262587773614) |  category:List_of_music_arrangers(qv = 0.00240988633595) -> -0.10000000149(ref = 0.00240988633595) |  Instruments:trombone(qv = 0.00245433137752) -> -0.10000000149(ref = 0.00245433137752) |  Occupation:educator(qv = 0.00216117408127) -> -0.10000000149(ref = 0.00216117408127) |  Occupation:engineer(qv = 0.00227874936536) -> -0.10000000149(ref = 0.00227874936536) |  category:List_of_singer-songwriters(qv = 0.0165811236948) -> -0.10000000149(ref = 0.0165811236948) |  Occupation:author(qv = 0.00234779971652) -> -0.10000000149(ref = 0.00234779971652) |  first_activity:1947(qv = 0.00233794772066) -> -0.10000000149(ref = 0.00233794772066) |  category:List_of_lead_vocalists(qv = 0.010262244381) -> -0.10000000149(ref = 0.010262244381) |  last_activity:1980(qv = 0.00220385147259) -> -0.10000000149(ref = 0.00220385147259) |  Origin:california(qv = 0.00247626029886) -> -0.10000000149(ref = 0.00247626029886) |  category:List_of_jazz_vocalists(qv = 0.00355421938002) -> -0.10000000149(ref = 0.00355421938002) |  Origin:states(qv = 0.00231065694243) -> -0.10000000149(ref = 0.00231065694243) |  Occupation:vocalist(qv = 0.0021211092826) -> -0.10000000149(ref = 0.0021211092826) |  Instruments:vocal(qv = 0.00211014226079) -> -0.10000000149(ref = 0.00211014226079) |  Origin:korea(qv = 0.00217951415107) -> -5.0(ref = 0.00217951415107) | reached max session length
# session # 6
#  Education:is_known(qv = 0.00234037474729) -> -0.10000000149(ref = 0.00234037474729) |  Genres:rhythm(qv = 0.00220626569353) -> -0.10000000149(ref = 0.00220626569353) |  Genres:gothic(qv = 0.0022217486985) -> -0.10000000149(ref = 0.0022217486985) |  Instruments:synthesizers(qv = 0.00226822099648) -> -0.10000000149(ref = 0.00226822099648) |  Occupation:artist(qv = 0.00223562680185) -> -0.10000000149(ref = 0.00223562680185) |  decades_active:1930(qv = 0.00238085002638) -> -0.10000000149(ref = 0.00238085002638) |  Genres:soft(qv = 0.00225845118985) -> -0.10000000149(ref = 0.00225845118985) |  Occupation:record(qv = 0.00225589051843) -> -0.10000000149(ref = 0.00225589051843) |  category:List_of_tenors_in_non-classical_music(qv = 0.00229646149091) -> -0.10000000149(ref = 0.00229646149091) |  Instruments:singing(qv = 0.00233676633798) -> -0.10000000149(ref = 0.00233676633798) |  Labels:is_known(qv = 0.0034150024876) -> -0.10000000149(ref = 0.0034150024876) |  Home town:is_known(qv = 0.00222995015793) -> -0.10000000149(ref = 0.00222995015793) |  Instruments:organ(qv = 0.00225283228792) -> -0.10000000149(ref = 0.00225283228792) |  Occupation:artist(qv = 0.00198729312979) -> -0.10000000149(ref = 0.00198729312979) |  Instruments:mandolin(qv = 0.00235401839018) -> -0.10000000149(ref = 0.00235401839018) |  category:List_of_Scottish_musicians(qv = 0.00264286436141) -> -0.10000000149(ref = 0.00264286436141) |  first_activity:1950(qv = 0.00228683231398) -> -0.10000000149(ref = 0.00228683231398) |  category:List_of_singer-songwriters(qv = 0.0193247105926) -> -0.10000000149(ref = 0.0193247105926) |  Occupation:radio(qv = 0.0025110472925) -> -0.10000000149(ref = 0.0025110472925) |  Occupation:engineer(qv = 0.00218925462104) -> -0.10000000149(ref = 0.00218925462104) |  Genres:adult(qv = 0.00208993186243) -> -0.10000000149(ref = 0.00208993186243) |  category:List_of_musicians_who_play_left-handed(qv = 0.00322245480493) -> -0.10000000149(ref = 0.00322245480493) |  last_activity:still_active(qv = 0.00280381576158) -> 0.10000000149(ref = 0.00280381576158) |  category:List_of_bands_with_more_than_one_lead_vocalist(qv = 0.00243318243884) -> -0.10000000149(ref = 0.00243318243884) |  Resting place:is_known(qv = 0.00226220418699) -> -5.0(ref = 0.00226220418699) | reached max session length
# session # 7
#  Genres:and(qv = 0.00233554723673) -> 0.10000000149(ref = 0.00233554723673) |  Origin:us(qv = 0.00234168884344) -> -0.10000000149(ref = 0.00234168884344) |  category:List_of_electric_blues_musicians(qv = 0.00244149845093) -> 5.0(ref = 0.00244149845093) |  category:List_of_Indian_film_music_directors(qv = 0.00259924889542) -> -0.10000000149(ref = 0.00259924889542) |  Genres:west(qv = 0.00232300814241) -> -0.10000000149(ref = 0.00232300814241) |  category:List_of_soul_musicians(qv = 0.00374382990412) -> -0.10000000149(ref = 0.00374382990412) |  category:List_of_bass_guitarists(qv = 0.00647771218792) -> -0.10000000149(ref = 0.00647771218792) |  category:List_of_jazz_vocalists(qv = 0.00361799937673) -> -0.10000000149(ref = 0.00361799937673) |  category:List_of_jazz_fusion_musicians(qv = 0.00321917049587) -> -0.10000000149(ref = 0.00321917049587) |  Instruments:cello(qv = 0.0021958022844) -> -0.10000000149(ref = 0.0021958022844) |  Genres:band(qv = 0.00239333091304) -> -0.10000000149(ref = 0.00239333091304) |  first_activity:2007(qv = 0.00223609269597) -> -0.10000000149(ref = 0.00223609269597) |  Origin:tennessee(qv = 0.00222799996845) -> -0.10000000149(ref = 0.00222799996845) |  category:List_of_drummers(qv = 0.00437302840874) -> -0.10000000149(ref = 0.00437302840874) |  category:List_of_lead_vocalists(qv = 0.00783944968134) -> -0.10000000149(ref = 0.00783944968134) |  Genres:pop(qv = 0.00251618004404) -> -0.10000000149(ref = 0.00251618004404) |  decades_active:1930(qv = 0.00223608780652) -> -0.10000000149(ref = 0.00223608780652) |  category:List_of_jazz_bassists(qv = 0.00287913787179) -> -0.10000000149(ref = 0.00287913787179) |  Genres:urban(qv = 0.00227231741883) -> -0.10000000149(ref = 0.00227231741883) |  Genres:mandopop(qv = 0.00225182366557) -> -0.10000000149(ref = 0.00225182366557) |  Occupation:director(qv = 0.00218959455378) -> -0.10000000149(ref = 0.00218959455378) |  decades_active:before_1920(qv = 0.00233010738157) -> -0.10000000149(ref = 0.00233010738157) |  Genres:mandopop(qv = 0.00232533784583) -> -0.10000000149(ref = 0.00232533784583) |  Occupation:producer(qv = 0.00261319754645) -> 0.10000000149(ref = 0.00261319754645) |  Genres:industrial(qv = 0.00227532419376) -> 0.0(ref = 0.00227532419376) | reached max session length
# session # 8
#  category:List_of_soul_musicians(qv = 0.00306979403831) -> -0.10000000149(ref = 0.00306979403831) |  Genres:industrial(qv = 0.00227519008331) -> -0.10000000149(ref = 0.00227519008331) |  category:List_of_African_musicians(qv = 0.00240784231573) -> 5.0(ref = 0.00240784231573) |  Origin:texas(qv = 0.00233606924303) -> -0.10000000149(ref = 0.00233606924303) |  category:List_of_bass_guitarists(qv = 0.00709664495662) -> -0.10000000149(ref = 0.00709664495662) |  Occupation:comedian(qv = 0.00205058441497) -> -0.10000000149(ref = 0.00205058441497) |  first_activity:1950(qv = 0.00221433397382) -> -0.10000000149(ref = 0.00221433397382) |  category:List_of_country_performers_by_era(qv = 0.00400572177023) -> -0.10000000149(ref = 0.00400572177023) |  Origin:california(qv = 0.00241878023371) -> -0.10000000149(ref = 0.00241878023371) |  Genres:wave(qv = 0.0022346128244) -> -0.10000000149(ref = 0.0022346128244) |  first_activity:2004(qv = 0.00232305889949) -> -0.10000000149(ref = 0.00232305889949) |  Genres:electropop(qv = 0.00231989566237) -> -0.10000000149(ref = 0.00231989566237) |  category:List_of_female_rock_singers(qv = 0.00436052586883) -> -0.10000000149(ref = 0.00436052586883) |  category:List_of_ambient_music_artists(qv = 0.00256373826414) -> -0.10000000149(ref = 0.00256373826414) |  Genres:experimental(qv = 0.00224041519687) -> -0.10000000149(ref = 0.00224041519687) |  Label(s):is_known(qv = 0.0023225969635) -> -0.10000000149(ref = 0.0023225969635) |  last_activity:2007(qv = 0.00230232230388) -> -0.10000000149(ref = 0.00230232230388) |  category:List_of_jazz_fusion_musicians(qv = 0.00319522037171) -> -0.10000000149(ref = 0.00319522037171) |  Website:is_known(qv = 0.00343396887183) -> 0.10000000149(ref = 0.00343396887183) |  Native name:is_known(qv = 0.00245425361209) -> -0.10000000149(ref = 0.00245425361209) |  last_activity:2007(qv = 0.00232594995759) -> -0.10000000149(ref = 0.00232594995759) |  Genres:coast(qv = 0.00227569486015) -> -0.10000000149(ref = 0.00227569486015) |  Instruments:accordion(qv = 0.00228776759468) -> -0.10000000149(ref = 0.00228776759468) |  category:List_of_new-age_music_artists(qv = 0.0024982385803) -> -0.10000000149(ref = 0.0024982385803) |  Instruments:keyboard(qv = 0.00237435451709) -> 0.0(ref = 0.00237435451709) | reached max session length
# session # 9
#  Genres:big(qv = 0.0023669837974) -> -0.10000000149(ref = 0.0023669837974) |  category:List_of_female_heavy_metal_singers(qv = 0.00253944727592) -> -0.10000000149(ref = 0.00253944727592) |  Origin:united(qv = 0.00264169438742) -> -0.10000000149(ref = 0.00264169438742) |  category:List_of_bass_guitarists(qv = 0.00668449373916) -> -0.10000000149(ref = 0.00668449373916) |  category:List_of_adult_alternative_artists(qv = 0.00239021051675) -> -0.10000000149(ref = 0.00239021051675) |  category:List_of_R%26B_musicians(qv = 0.00368085084483) -> -0.10000000149(ref = 0.00368085084483) |  Instruments:cello(qv = 0.00234485091642) -> -0.10000000149(ref = 0.00234485091642) |  Genres:folk(qv = 0.00233174115419) -> -0.10000000149(ref = 0.00233174115419) |  Occupation:television(qv = 0.002261784859) -> -0.10000000149(ref = 0.002261784859) |  Partner(s):is_known(qv = 0.00233860686421) -> -0.10000000149(ref = 0.00233860686421) |  Genres:experimental(qv = 0.0021676402539) -> -0.10000000149(ref = 0.0021676402539) |  category:List_of_Maryland_music_people(qv = 0.00301647488959) -> -0.10000000149(ref = 0.00301647488959) |  decades_active:1980(qv = 0.00290151801892) -> 0.10000000149(ref = 0.00290151801892) |  Genres:west(qv = 0.00233661080711) -> -0.10000000149(ref = 0.00233661080711) |  Origin:kingdom(qv = 0.00216572009958) -> -0.10000000149(ref = 0.00216572009958) |  Rank:is_known(qv = 0.00238762283698) -> -0.10000000149(ref = 0.00238762283698) |  Genres:melodic(qv = 0.00198039924726) -> -0.10000000149(ref = 0.00198039924726) |  Religion:is_known(qv = 0.00216056522913) -> -0.10000000149(ref = 0.00216056522913) |  Genres:big(qv = 0.00232772924937) -> -0.10000000149(ref = 0.00232772924937) |  category:List_of_slide_guitarists(qv = 0.00266732135788) -> -0.10000000149(ref = 0.00266732135788) |  Instruments:bass(qv = 0.00247802911326) -> -0.10000000149(ref = 0.00247802911326) |  category:List_of_Dutch_musicians(qv = 0.00266151269898) -> -0.10000000149(ref = 0.00266151269898) |  Genres:death(qv = 0.00213466840796) -> -0.10000000149(ref = 0.00213466840796) |  category:List_of_hip_hop_musicians(qv = 0.00382811739109) -> -0.10000000149(ref = 0.00382811739109) |  Genres:bass(qv = 0.00243181060068) -> -5.0(ref = 0.00243181060068) | reached max session length
