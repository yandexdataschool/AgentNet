# %%
#experiment name and snapshot folder (used for model persistence)
experiment_setup_name = "research.rl_comparison.n_step_qlearning"
snapshot_path = "/home/jheuristic/yozhik/agentnet_snapshots/"

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline


#theano imports
#the problem is too simple to be run on GPU. Seriously.
# %env THEANO_FLAGS='device=cpu'
import theano
import theano.tensor as T
floatX = theano.config.floatX

import lasagne
# Out:
# env: THEANO_FLAGS='device=cpu'
# /home/jheuristic/thenv/local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # This tutorial builds above the basic tutorial and shows several advanced tools
# * multi-layer (and in principle, arbitrary) agent memory
# * different reinforcement learning algorithms
# * model persistence
#
# __[todo: add more]__

# %% [markdown]
# # Experiment setup
# * Here we load an experiment environment (description below)
# * Designing one from scratch is explained in later tutorials

# %%
import agentnet.experiments.wikicat as experiment
print experiment.__doc__
# Out:
# This experiment Wikipedia data sample on musicians, scraped via the scripts present in this directory.
# For each musician, we know a number of boolean features (factors) on various topics like
#  * whether or not he/she was active in 1990's, 2000's, etc.
#  * whether or not he/she plays guitar, piano, etc
#  * whether or not he/she was born in 50's, 60's, etc.
#  * what wikipedia categories does he/she belong to
#  etc.
#
#
#
# In the initial moment of time, agent knows nothing about any of them.
# At each turn, agent may decide to
#  - "open" one of the hidden factors.
#    - if the factor turns out to be 1, agent receives +3 reward for Wikipedia categories, +1 for other categories,
#    - Otherwise, the reward equals -1 for Wikipedia categories, -1 for other categores
#    - all these rewards are parameterisable during environment creation
#  - decide to quit session
#    - yields reward of 0 and ends the interaction.
#    - all farther actions will have no effect until next session
#
# It is expected, that in order to maximize it's expected reward, the agent
# will converge to a strategy of polling several key features and then utilizing learned
# dependencies between these factors and other ones. For example, if a particular genre was
# popular during particular decays, it makes sense to poll genres and than "open" the corresponding
# most probable years.
#
# The experiment setup contains a single class WikicatEnvironment that
# implements both BaseEnvironment and BaseObjective.

# %%
#Create an environment with all default parameters
env = experiment.WikicatEnvironment()

# %%
from sklearn.cross_validation import train_test_split
attrs, categories, feature_names = env.get_dataset()

train_attrs,test_attrs,train_cats,test_cats = train_test_split(attrs,categories,test_size=0.99,random_state=32)

print "train size:", train_attrs.shape,train_cats.shape
print "train size:", test_attrs.shape,test_cats.shape

print "features:",feature_names[::20]
# Out:
# train size: (85, 300) (85, 93)
# train size: (8509, 300) (8509, 93)
# features: ['Children:is_known', 'Instruments:vocals', 'Genres:electronic', 'Origin:scotland', 'Genres:jazz', 'Genres:electric', 'Occupation:bassist', 'Instruments:violin', 'Genres:instrumental', 'Occupation:entrepreneur', 'Instruments:mandolin', 'Instruments:vocalist', 'Genres:synthpop', 'decades_active:1990', 'Occupation:remixer', 'category:List_of_musical_artists_from_Japan', 'category:List_of_ambient_music_artists', 'category:List_of_crooners', 'category:List_of_country_music_performers', 'category:List_of_bass_guitarists']

# %%
env.load_random_batch(train_attrs,train_cats,5)

# %% [markdown]
# # agent setup
# * An agent implementation has to contain three parts:
#  * Memory layer(s)
#   * in this case, we train two GRU layers [details below]
#  * Q-values evaluation layers
#   * in this case, a lasagne dense layer based on memory layer
#  * Resolver - acton picker layer
#   * in this case, the resolver has epsilon-greedy policy
#
#
# ### two-layer memory architecture
# We train two memory states:
#   * first one, based on observations,
#   * second one, based on first one;
#
# Note that here we update the second memory layer based on the CURRENT state
# of the first one. Instead, you can try to feed it with a previous state.
#
# The q-values are estimated on a concatenated state, effectively on both memory
# states together, but there is no problem with limiting q-evaluator to only one:
# just pass the correct gru layer as an incoming layer to the q-evaluator.
#
# ### Implementation:
# We concatenate both memories into 1 state to pass it through the session loop.
#
# To perform memory update, we need to slice the concatenated state back into
# two memory states.
#
# We do so by defining an input map function and passing it into agent.
#
# We than concatenate two new states back to form a new memory state.

# %%
from agentnet.resolver import EpsilonGreedyResolver
from agentnet.memory import GRUMemoryLayer
from agentnet.agent import Agent

# %%
import lasagne
n_hid_1=128 #first GRU memory
n_hid_2=64 #second GRU memory


_observation_layer = lasagne.layers.InputLayer([None,env.observation_size],name="obs_input")

_prev_gru1_layer = lasagne.layers.InputLayer([None,n_hid_1],name="prev_gru1_state_input")
_prev_gru2_layer = lasagne.layers.InputLayer([None,n_hid_2],name="prev_gru2_state_input")

#memory
gru1 = GRUMemoryLayer(n_hid_1,
                     _observation_layer,
                     _prev_gru1_layer,
                     name="gru1")

gru2 = GRUMemoryLayer(n_hid_2,
                     gru1,        #note that it takes CURRENT gru1 output as input.
                                  #replacing that with _prev_gru1_state would imply taking previous one.
                     _prev_gru2_layer,
                     name="gru2")

concatenated_memory = lasagne.layers.concat([gru1,gru2])

#q_eval
n_actions = len(feature_names)
q_eval = lasagne.layers.DenseLayer(concatenated_memory, #taking both memories. 
                                                        #Replacing with gru1 or gru2 would mean taking one
                                   num_units = n_actions,
                                   nonlinearity=lasagne.nonlinearities.linear,name="QEvaluator")
#resolver
epsilon = theano.shared(np.float32(0.9),"e-greedy.epsilon")

resolver = EpsilonGreedyResolver(q_eval,epsilon=epsilon,name="resolver")



#we need to define the new input map because concatenated_memory is a ConcatLayer and does not have default one

def custom_input_map(last_hidden,observation):
    """just a function that maps memory states to respective inputs"""
    return {
        _prev_gru1_layer:last_hidden[:,0:n_hid_1],
        _prev_gru2_layer:last_hidden[:,n_hid_1:n_hid_1+n_hid_2],
        _observation_layer:observation
    }

#all together
agent = Agent(concatenated_memory,q_eval,resolver,input_map=custom_input_map
             )

# %%
#Since it's a single lasagne network, one can get it's weights, output, etc
weights = lasagne.layers.get_all_params(resolver,trainable=True)
weights
# Out:
# [gru1.W_in_to_updategate,
#  gru1.W_hid_to_updategate,
#  gru1.b_updategate,
#  gru1.W_in_to_resetgate,
#  gru1.W_hid_to_resetgate,
#  gru1.b_resetgate,
#  gru1.W_in_to_hidden_update,
#  gru1.W_hid_to_hidden_update,
#  gru1.b_hidden_update,
#  gru2.W_in_to_updategate,
#  gru2.W_hid_to_updategate,
#  gru2.b_updategate,
#  gru2.W_in_to_resetgate,
#  gru2.W_hid_to_resetgate,
#  gru2.b_resetgate,
#  gru2.W_in_to_hidden_update,
#  gru2.W_hid_to_hidden_update,
#  gru2.b_hidden_update,
#  QEvaluator.W,
#  QEvaluator.b]

# %% [markdown]
# ## Agent setup in detail
# * __Memory layers__
#  * One-step recurrent layer
#      * takes input and one's previous state
#      * returns new memory state
#    * Can be arbitrary lasagne layer
#    * Several one-step recurrent units are implemented in __agentnet.memory__
#    * Note that lasagne's default recurrent networks roll for several steps at once
#      * in other words, __using lasagne recurrent units as memory means recurrence inside recurrence__
#  * Using more than one memory layer is explained in farther tutorials
#
#
# * __Q-values evaluation layer__
#  * Can be arbitrary lasagne network
#  * returns predicted Q-values for each action
#  * Usually depends on memory as an input
#
#
# * __Resolver__ - action picker
#  * Decides on what action is taken
#  * Normally takes Q-values as input
#  * Currently all experiments require integer output
#  * Several resolver layers are implemented in __agentnet.resolver__

# %% [markdown]
# # Interacting with environment
# * an agent has a method that produces symbolic environment interaction sessions
# * interactions result in sequences of observations, actions, q-values,etc
# * one has to pre-define maximum session length.
#  * in this case, environment implements an indicator of whether session has ended by current tick
# * Since this environment also implements Objective methods, it can evaluate rewards for each [batch, time_tick]

# %%
#produce interaction sequences of length <= 10
history = agent.get_sessions(env,session_length=10,
                       batch_size=env.batch_size,)

state_seq,observation_seq,hidden_seq,qvalues_seq,action_seq = history

#get rewards for all actions
rewards_seq = env.get_reward_sequences(state_seq,action_seq)

#get indicator whether session is still active
is_alive_seq = env.get_whether_alive(observation_seq)

# %%
#Let us compile a function that returns all interaction logs
get_history = theano.function([],history+(is_alive_seq,rewards_seq,),mode=theano.compile.mode.FAST_RUN)

# %% [markdown]
# # Evaluating loss function
# * This part is similar to the basic tutorial but for the fact that we use SARSA
#
#
#  #### Get (prediction,reference) pairs

# %%
#get reference Qvalues according to Qlearning algorithm


from agentnet.learning import n_step


#gamma - delayed reward coefficient - what fraction of reward is retained if it is obtained one tick later
gamma = theano.shared(np.float32(0.95),name = 'q_learning_gamma')


reference_Qvalues = n_step.get_reference(
    qvalues_seq,action_seq,rewards_seq,
    is_alive= is_alive_seq,
    max_n = 3,
    gamma_or_gammas=gamma,
)

# %%
#zero-out future rewards at session end
#from agentnet.utils.mdp import get_end_indicator

#end_action_ids = get_end_indicator(is_alive_seq).nonzero()

# "set reference Qvalues at end action ids to just the immediate rewards"
#reference_Qvalues = T.set_subtensor(reference_Qvalues[end_action_ids],
#                                    rewards_seq[end_action_ids])

# %%
#prevent gradient updates over reference Qvalues (since they depend on predicted Qvalues)
from agentnet.utils import consider_constant
reference_Qvalues = consider_constant(reference_Qvalues)

# %%
from agentnet.utils.mdp import get_action_Qvalues
action_Qvalues = get_action_Qvalues(qvalues_seq,action_seq)

# %% [markdown]
# #### Define loss functions

# %%
#tensor of elementwise squared errors
squared_error = lasagne.objectives.squared_error(reference_Qvalues,action_Qvalues)

#zero-out ticks after session ended
squared_error = squared_error * is_alive_seq

#compute average of squared error sums per session
mse_loss = squared_error.sum() / is_alive_seq.sum()

# %%
#regularize network weights

from lasagne.regularization import regularize_network_params, l2
reg_l2 = regularize_network_params(resolver,l2)*10**-4

# %%
loss = mse_loss + reg_l2

# %% [markdown]
# #### Compute weight updates

# %%
updates = lasagne.updates.adadelta(loss,
                                             weights,learning_rate=0.05)

# %% [markdown]
# #### Some auxilary evaluation metrics

# %%
mean_session_reward = rewards_seq.sum(axis=1).mean()
#...

# %% [markdown]
# # Compile train and evaluation functions

# %%
train_fun = theano.function([],[loss,mean_session_reward],updates=updates)

evaluation_fun = theano.function([],[loss,mse_loss,reg_l2,mean_session_reward])

# %% [markdown]
# # session visualization tools
#
#
# * this is a completely optional step of visualizing agent's sessions as chains of actions
# * usually useful to get insight on what worked and what din't
# * in this case, we print strings following pattern
#   * [action_name] ([predicted action qvalue]) -> reward [reference qvalue] | next iteration
#
# * plot shows
#     * time ticks over X, abstract values over Y
#     * bold lines are Qvalues for actions
#     * dots on bold lines represent what actions were taken at each moment of time
#     * dashed lines are agent's hidden state neurons
#     * blue vertical line - session end
#
#
# __Warning! the visualization tools are underdeveloped and only allow simple operations.__
#
# if you found yourself struggling to make it do what you want for 5 minutes, go write your own tool [and contribute it :)]

# %%
from agentnet.display.sessions import print_sessions
get_printables = theano.function([], [
        hidden_seq,qvalues_seq, action_seq,rewards_seq,reference_Qvalues,is_alive_seq
    ])

def display_sessions(with_plots = False):
        
    hidden_log,qvalues_log,actions_log,reward_log, reference_qv_log, is_alive_log = get_printables()
    
    
    print_sessions(qvalues_log,actions_log,reward_log,
                   is_alive_seq = is_alive_log,
                   #hidden_seq=hidden_log, #do not plot hidden since there's too many actions already
                   reference_qvalues_seq = reference_qv_log,
                   action_names=feature_names,
                   legend = False, #do not show legend since there's too many labeled objects
                  plot_qvalues = with_plots)

# %%
#visualize untrained network performance (which is mostly random)
env.load_random_batch(train_attrs,train_cats,1)
display_sessions(with_plots=True)
# Out:
# session # 0
#  Genres:heavy(qv = 0.0) -> -1.0(ref = -0.88395434618) |  Occupation:bandleader(qv = 0.0202210340649) -> -1.0(ref = -2.73273468018) |  Political party:is_known(qv = -0.0245008580387) -> -1.0(ref = -1.82393121719) |  Label(s):is_known(qv = -0.0199603009969) -> -1.0(ref = -0.867295980453) |  category:List_of_individual_K-pop_artists(qv = 0.139688432217) -> -1.0(ref = -2.72636556625) |  category:List_of_gospel_musicians(qv = 0.0755145028234) -> -1.0(ref = -1.81722676754) |  Genres:contemporary(qv = 0.0477731898427) -> -1.0(ref = -0.860238730907) |  decades_active:before_1920(qv = 0.147117123008) -> -1.0(ref = -1.95000004768) |  last_activity:1989(qv = -0.00116212666035) -> -1.0(ref = -1.0) |  category:List_of_lead_guitarists(qv = -0.0125867938623) -> 0.0(ref = 0.0) | reached max session length

# %% [markdown]
# # Training loop

# %%
#tools for model persistence
from agentnet.utils.persistence import save,load
import os

# %%
from agentnet.display import Metrics
score_log = Metrics()

# %%
#starting epoch
epoch_counter = 1

#moving average estimation
alpha = 0.1
ma_reward_current = -7.
ma_reward_greedy = -7.

# %%
n_epochs = 250000
batch_size= 50

for i in range(n_epochs):    
    
    #train
    env.load_random_batch(train_attrs,train_cats,batch_size)
    loss,avg_reward = train_fun()
    
    
    
    ##update resolver's epsilon (chance of random action instead of optimal one)
    if epoch_counter%10 ==0:
        current_epsilon =  0.05 + 0.95*np.exp(-epoch_counter/10000.)
        resolver.epsilon.set_value(np.float32(current_epsilon))
    
    
    
    ##record current learning progress and show learning curves
    if epoch_counter%100 ==0:

        ##update learning curves
        full_loss, q_loss, l2_penalty, avg_reward_current = evaluation_fun()
        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current
        score_log["expected e-greedy reward"][epoch_counter] = ma_reward_current
        
        
        
        #greedy train
        resolver.epsilon.set_value(0)
        avg_reward_greedy = evaluation_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["expected greedy reward"][epoch_counter] = ma_reward_greedy
        
        
        #back to epsilon-greedy
        resolver.epsilon.set_value(np.float32(current_epsilon))

        print "epoch %i,loss %.5f, epsilon %.5f, rewards: ( e-greedy %.5f, greedy %.5f) "%(
            epoch_counter,full_loss,current_epsilon,ma_reward_current,ma_reward_greedy)
        print "rec %.3f reg %.3f"%(q_loss,l2_penalty)

    if epoch_counter %1000 ==0:
        print "Learning curves:"
        score_log.plot()


        print "Random session examples"
        env.load_random_batch(train_attrs,train_cats,3)
        display_sessions(with_plots=False)
    
    #save snapshot
    if epoch_counter %10000 ==0:
        snap_name = "{}.epoch{}.pcl".format(os.path.join(snapshot_path,experiment_setup_name), epoch_counter)
        save(resolver,snap_name)
        print "saved", snap_name

        
        
    epoch_counter  +=1

    
# Time to drink some coffee!
# Out:
# epoch 8200,loss 1.22858, epsilon 0.46841, rewards: ( e-greedy -1.87301, greedy 2.31345)
# rec 0.999 reg 0.230
# epoch 8300,loss 1.24705, epsilon 0.46425, rewards: ( e-greedy -1.76571, greedy 2.43111)
# rec 1.017 reg 0.230
# epoch 8400,loss 1.41613, epsilon 0.46012, rewards: ( e-greedy -1.68714, greedy 2.47499)
# rec 1.187 reg 0.229
# epoch 8500,loss 1.40225, epsilon 0.45604, rewards: ( e-greedy -1.54542, greedy 2.60650)
# rec 1.173 reg 0.229
# epoch 8600,loss 1.54479, epsilon 0.45200, rewards: ( e-greedy -1.48688, greedy 2.61685)
# rec 1.316 reg 0.229
# epoch 8700,loss 1.25319, epsilon 0.44800, rewards: ( e-greedy -1.45219, greedy 2.61716)
# rec 1.025 reg 0.228
# epoch 8800,loss 1.55732, epsilon 0.44404, rewards: ( e-greedy -1.34197, greedy 2.62744)
# rec 1.330 reg 0.228
# epoch 8900,loss 1.51435, epsilon 0.44012, rewards: ( e-greedy -1.31778, greedy 2.59770)
# rec 1.287 reg 0.227
# epoch 9000,loss 1.53829, epsilon 0.43624, rewards: ( e-greedy -1.24500, greedy 2.65393)
# rec 1.311 reg 0.227
# Learning curves:
# Random session examples
# session # 0
#  Origin:germany(qv = -0.567878186703) -> -1.0(ref = -0.0707848668098) |  category:List_of_saxophonists(qv = -0.683553814888) -> -1.0(ref = -2.23650407791) |  category:List_of_Indian_playback_singers(qv = -0.541368961334) -> -1.0(ref = -1.30158317089) |  Genres:art(qv = -0.714842319489) -> -1.0(ref = -0.317456007004) |  decades_active:2010(qv = 0.718467354774) -> 1.0(ref = 1.33442902565) |  category:List_of_house_music_artists(qv = -0.517006993294) -> -1.0(ref = 0.35203063488) |  decades_active:2000(qv = 1.0755289793) -> 1.0(ref = 1.42319011688) |  Origin:ontario(qv = -0.973101437092) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.309895396233) -> 1.0(ref = 1.0) |  first_activity:2001(qv = -0.0991583019495) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 1.28988075256) -> 1.0(ref = 2.00186443329) |  category:List_of_folk_musicians(qv = -0.483907163143) -> -1.0(ref = -0.272760987282) |  Genres:[1](qv = -0.446717232466) -> -1.0(ref = 0.765514731407) |  decades_active:2010(qv = 1.35034239292) -> 1.0(ref = 1.85843658447) |  last_activity:still_active(qv = 0.903617441654) -> 1.0(ref = 3.05089449883) |  decades_active:2000(qv = 1.32853662968) -> 1.0(ref = 2.15883636475) |  Labels:is_known(qv = 0.678943097591) -> 1.0(ref = 1.2198278904) |  Website:is_known(qv = 0.2313978374) -> 1.0(ref = 0.0500000119209) |  Birth name:is_known(qv = 0.296996891499) -> -1.0(ref = -1.0) |  Instruments:trombone(qv = -0.0386644937098) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 1.28988075256) -> 1.0(ref = 2.00186443329) |  Genres:ska(qv = -0.395404368639) -> -1.0(ref = -0.302575826645) |  Genres:experimental(qv = -0.410495638847) -> -1.0(ref = 0.734130740166) |  decades_active:2010(qv = 1.29241323471) -> 1.0(ref = 1.82540082932) |  last_activity:still_active(qv = 0.868843019009) -> 1.0(ref = 3.06356954575) |  decades_active:2000(qv = 1.34042704105) -> 1.0(ref = 2.17217850685) |  Labels:is_known(qv = 0.694227099419) -> 1.0(ref = 1.23387217522) |  category:List_of_Asian-American_hip_hop_musicians(qv = -0.906857967377) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.339318454266) -> 1.0(ref = 1.0) |  Genres:power(qv = 0.0690446048975) -> 0.0(ref = 0.0) | reached max session length
# epoch 9100,loss 1.55388, epsilon 0.43240, rewards: ( e-greedy -1.28150, greedy 2.59054)
# rec 1.327 reg 0.227
# epoch 9200,loss 1.40727, epsilon 0.42859, rewards: ( e-greedy -1.21035, greedy 2.61548)
# rec 1.181 reg 0.226
# epoch 9300,loss 1.35445, epsilon 0.42483, rewards: ( e-greedy -1.13331, greedy 2.71094)
# rec 1.129 reg 0.226
# epoch 9400,loss 1.38459, epsilon 0.42110, rewards: ( e-greedy -1.10298, greedy 2.79384)
# rec 1.159 reg 0.226
# epoch 9500,loss 1.40095, epsilon 0.41740, rewards: ( e-greedy -0.97868, greedy 2.82546)
# rec 1.176 reg 0.225
# epoch 9600,loss 1.42868, epsilon 0.41375, rewards: ( e-greedy -0.85082, greedy 2.88891)
# rec 1.204 reg 0.225
# epoch 9700,loss 1.42448, epsilon 0.41013, rewards: ( e-greedy -0.75273, greedy 2.94402)
# rec 1.200 reg 0.224
# epoch 9800,loss 1.52029, epsilon 0.40655, rewards: ( e-greedy -0.72646, greedy 2.96462)
# rec 1.296 reg 0.224
# epoch 9900,loss 1.66071, epsilon 0.40300, rewards: ( e-greedy -0.69281, greedy 2.97016)
# rec 1.437 reg 0.224
# epoch 10000,loss 1.46525, epsilon 0.39949, rewards: ( e-greedy -0.69553, greedy 2.92814)
# rec 1.242 reg 0.223
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 1.49559342861) -> 1.0(ref = 2.22109603882) |  category:List_of_new-age_music_artists(qv = -0.263576030731) -> -1.0(ref = 0.0746533870697) |  Cause of death:is_known(qv = -0.300977945328) -> -1.0(ref = 1.13121414185) |  decades_active:2010(qv = 1.84726154804) -> 1.0(ref = 2.24338340759) |  last_activity:still_active(qv = 1.3088247776) -> -1.0(ref = 1.05459809303) |  decades_active:2000(qv = 1.1668266058) -> 1.0(ref = 2.16273498535) |  Labels:is_known(qv = 0.685388624668) -> 1.0(ref = 1.22393155098) |  Website:is_known(qv = 0.235717460513) -> -1.0(ref = -1.95000004768) |  Origin:los(qv = -0.879707455635) -> -1.0(ref = -1.0) |  end_session_now(qv = 0.00018803216517) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 1.49559342861) -> 1.0(ref = 2.22109603882) |  Origin:tennessee(qv = -0.20375905931) -> -1.0(ref = -0.0660357475281) |  decades_active:2010(qv = 1.56679606438) -> 1.0(ref = 0.983120262623) |  Genres:black(qv = -0.274979233742) -> -1.0(ref = -0.0177681446075) |  decades_active:2000(qv = 1.03392827511) -> 1.0(ref = 1.17588579655) |  category:List_of_band_name_etymologies(qv = -0.354234993458) -> -1.0(ref = 0.185142993927) |  Labels:is_known(qv = 0.468886762857) -> 1.0(ref = 1.24751901627) |  first_activity:1995(qv = -0.787087798119) -> -1.0(ref = -1.95000004768) |  category:List_of_South_Korean_musicians(qv = -0.815840303898) -> -1.0(ref = -1.0) |  Instruments:vocal(qv = -0.0545900799334) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 1.4955933094) -> 1.0(ref = 2.22109651566) |  Resting place:is_known(qv = -0.325766772032) -> -1.0(ref = -0.0458669066429) |  category:List_of_clarinetists(qv = -0.321721613407) -> -1.0(ref = 1.00435066223) |  decades_active:2010(qv = 1.74502825737) -> 1.0(ref = 2.10984277725) |  last_activity:still_active(qv = 1.16825568676) -> 1.0(ref = 3.15739989281) |  decades_active:2000(qv = 1.4351555109) -> 1.0(ref = 2.27094721794) |  Labels:is_known(qv = 0.851170897484) -> 1.0(ref = 1.3378392458) |  Website:is_known(qv = 0.355620265007) -> 1.0(ref = 1.95000004768) |  Birth name:is_known(qv = 0.411208719015) -> 1.0(ref = 1.0) |  Genres:instrumental(qv = -0.218316212296) -> 0.0(ref = 0.0) | reached max session length
# saved /home/jheuristic/yozhik/agentnet_snapshots/research.rl_comparison.qlearning.epoch10000.pcl
# epoch 10100,loss 1.37951, epsilon 0.39601, rewards: ( e-greedy -0.59598, greedy 3.05133)
# rec 1.157 reg 0.223
# epoch 10200,loss 1.63567, epsilon 0.39257, rewards: ( e-greedy -0.59838, greedy 2.97619)
# rec 1.413 reg 0.223
# epoch 10300,loss 1.39222, epsilon 0.38916, rewards: ( e-greedy -0.56654, greedy 2.95557)
# rec 1.170 reg 0.222
# epoch 10400,loss 1.56295, epsilon 0.38578, rewards: ( e-greedy -0.50789, greedy 2.96902)
# rec 1.341 reg 0.222
# epoch 10500,loss 1.57039, epsilon 0.38244, rewards: ( e-greedy -0.43010, greedy 3.01112)
# rec 1.349 reg 0.221
# epoch 10600,loss 1.53799, epsilon 0.37913, rewards: ( e-greedy -0.38709, greedy 3.02400)
# rec 1.317 reg 0.221
# epoch 10700,loss 1.34609, epsilon 0.37586, rewards: ( e-greedy -0.29738, greedy 3.04660)
# rec 1.125 reg 0.221
# epoch 10800,loss 1.45736, epsilon 0.37262, rewards: ( e-greedy -0.28164, greedy 3.05694)
# rec 1.237 reg 0.220
# epoch 10900,loss 1.74769, epsilon 0.36941, rewards: ( e-greedy -0.32248, greedy 2.94325)
# rec 1.528 reg 0.220
# epoch 11000,loss 1.62197, epsilon 0.36623, rewards: ( e-greedy -0.26623, greedy 2.95392)
# rec 1.402 reg 0.220
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 1.71700298786) -> 1.0(ref = 2.42947483063) |  decades_active:2010(qv = 1.14768362045) -> 1.0(ref = 0.418789982796) |  Instruments:harmonica(qv = -0.202213287354) -> -1.0(ref = -0.611800014973) |  decades_active:2010(qv = 1.21228301525) -> -0.5(ref = 0.408631563187) |  Genres:indie(qv = 0.00450593605638) -> -1.0(ref = 1.13607168198) |  decades_active:2000(qv = 1.20004951954) -> 1.0(ref = 2.24849653244) |  Labels:is_known(qv = 0.701024055481) -> 1.0(ref = 1.31420683861) |  Website:is_known(qv = 0.330744087696) -> 1.0(ref = 1.95000004768) |  Birth name:is_known(qv = 0.273505479097) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.0240463353693) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Instruments:and(qv = -0.226605057716) -> -1.0(ref = 0.513518452644) |  Occupation:bassist(qv = -0.270155698061) -> -1.0(ref = 1.89675569534) |  decades_active:2010(qv = 1.57971394062) -> 1.0(ref = 3.04921650887) |  last_activity:still_active(qv = 1.73173463345) -> 1.0(ref = 2.15707015991) |  decades_active:2000(qv = 1.21796858311) -> 1.0(ref = 1.16463756561) |  first_activity:1956(qv = -0.469545394182) -> -1.0(ref = 0.173302650452) |  Labels:is_known(qv = 0.53392124176) -> 1.0(ref = 1.23505544662) |  Genres:symphonic(qv = -0.901889979839) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.237121701241) -> 1.0(ref = 1.0) |  end_session_now(qv = -0.00352128222585) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 1.71700310707) -> 1.0(ref = 2.42947483063) |  Occupation:saxophonist(qv = -0.204086571932) -> -1.0(ref = -0.22278624773) |  decades_active:2010(qv = 1.76163852215) -> 1.0(ref = 0.818119764328) |  Genres:glam(qv = -0.0847924277186) -> -1.0(ref = -0.191452860832) |  decades_active:2000(qv = 0.851102232933) -> 1.0(ref = -0.829617977142) |  Labels:is_known(qv = 0.639907479286) -> -1.0(ref = -1.92591369152) |  Website:is_known(qv = 0.15578339994) -> -1.0(ref = -0.974645972252) |  category:List_of_Scottish_musicians(qv = -0.79742872715) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.177118465304) -> 1.0(ref = 1.0) |  end_session_now(qv = -0.0126247368753) -> 0.0(ref = 0.0) | reached max session length
# epoch 11100,loss 1.64826, epsilon 0.36308, rewards: ( e-greedy -0.26161, greedy 2.98153)
# rec 1.429 reg 0.219
# epoch 11200,loss 1.62582, epsilon 0.35997, rewards: ( e-greedy -0.26545, greedy 3.00338)
# rec 1.407 reg 0.219
# epoch 11300,loss 1.47323, epsilon 0.35688, rewards: ( e-greedy -0.28990, greedy 2.98204)
# rec 1.255 reg 0.219
# epoch 11400,loss 1.37030, epsilon 0.35383, rewards: ( e-greedy -0.22891, greedy 3.07584)
# rec 1.152 reg 0.218
# epoch 11500,loss 1.59851, epsilon 0.35080, rewards: ( e-greedy -0.15402, greedy 3.10525)
# rec 1.380 reg 0.218
# epoch 11600,loss 1.35276, epsilon 0.34781, rewards: ( e-greedy -0.10562, greedy 3.13673)
# rec 1.135 reg 0.218
# epoch 11700,loss 1.42712, epsilon 0.34485, rewards: ( e-greedy -0.08606, greedy 3.19105)
# rec 1.210 reg 0.217
# epoch 11800,loss 1.61714, epsilon 0.34191, rewards: ( e-greedy -0.05245, greedy 3.16395)
# rec 1.400 reg 0.217
# epoch 11900,loss 1.71821, epsilon 0.33901, rewards: ( e-greedy -0.06421, greedy 3.13555)
# rec 1.501 reg 0.217
# epoch 12000,loss 1.66406, epsilon 0.33613, rewards: ( e-greedy 0.05821, greedy 3.19200)
# rec 1.448 reg 0.216
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 1.91442537308) -> -1.0(ref = -0.298970460892) |  decades_active:1990(qv = 0.737925827503) -> -0.5(ref = -0.457963854074) |  Birth name:is_known(qv = 0.63325124979) -> 1.0(ref = 0.0442485809326) |  last_activity:still_active(qv = 0.420230776072) -> -1.0(ref = -1.00605416298) |  end_session_now(qv = -0.00637276284397) -> 0.0(ref = 0.0) |
#
# session # 1
#  category:List_of_Iranian_musicians(qv = -0.17494738102) -> -1.0(ref = 0.740473508835) |  decades_active:1990(qv = 1.832077384) -> -1.0(ref = 1.75744748116) |  decades_active:2010(qv = 1.0951167345) -> 1.0(ref = 2.90257620811) |  last_activity:still_active(qv = 1.41437983513) -> 1.0(ref = 2.00271177292) |  decades_active:2000(qv = 1.05548608303) -> 1.0(ref = 2.99785280228) |  Labels:is_known(qv = 0.615309655666) -> 1.0(ref = 2.10300302505) |  Website:is_known(qv = 0.3439476192) -> 1.0(ref = 1.16105592251) |  category:List_of_classical_pianists(qv = -0.900235950947) -> -1.0(ref = -1.95000004768) |  Genres:rhythm(qv = -0.654579520226) -> -1.0(ref = -1.0) |  Occupation:director(qv = -0.474500477314) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 1.91442513466) -> 1.0(ref = 2.61375045776) |  last_activity:still_active(qv = 1.69868469238) -> -1.0(ref = -1.00416266918) |  decades_active:2010(qv = 0.91886806488) -> -1.0(ref = -0.00438171625137) |  Birth name:is_known(qv = 0.244605854154) -> 1.0(ref = 1.04801928997) |  Instruments:alto(qv = -0.290037125349) -> -1.0(ref = -2.79722738266) |  Instruments:electric(qv = -0.725170373917) -> -1.0(ref = -1.89181828499) |  Labels:is_known(qv = 0.165098413825) -> -1.0(ref = -0.938756167889) |  Birth name:is_known(qv = 0.0644672140479) -> -0.5(ref = -0.5) |  end_session_now(qv = -0.00877010636032) -> 0.0(ref = 0.0) |
#
# epoch 12100,loss 1.55884, epsilon 0.33329, rewards: ( e-greedy 0.15739, greedy 3.21380)
# rec 1.343 reg 0.216
# epoch 12200,loss 1.61280, epsilon 0.33047, rewards: ( e-greedy 0.18165, greedy 3.28842)
# rec 1.397 reg 0.216
# epoch 12300,loss 1.67654, epsilon 0.32768, rewards: ( e-greedy 0.22149, greedy 3.26658)
# rec 1.461 reg 0.215
# epoch 12400,loss 1.81444, epsilon 0.32492, rewards: ( e-greedy 0.22834, greedy 3.20492)
# rec 1.599 reg 0.215
# epoch 12500,loss 1.48483, epsilon 0.32218, rewards: ( e-greedy 0.24751, greedy 3.18143)
# rec 1.270 reg 0.215
# epoch 12600,loss 1.53279, epsilon 0.31947, rewards: ( e-greedy 0.29975, greedy 3.21528)
# rec 1.318 reg 0.215
# epoch 12700,loss 1.81470, epsilon 0.31679, rewards: ( e-greedy 0.29278, greedy 3.19376)
# rec 1.600 reg 0.214
# epoch 12800,loss 1.64008, epsilon 0.31414, rewards: ( e-greedy 0.41450, greedy 3.27838)
# rec 1.426 reg 0.214
# epoch 12900,loss 1.64835, epsilon 0.31151, rewards: ( e-greedy 0.42205, greedy 3.32254)
# rec 1.435 reg 0.214
# epoch 13000,loss 1.65151, epsilon 0.30891, rewards: ( e-greedy 0.48585, greedy 3.40329)
# rec 1.438 reg 0.213
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 2.13358926773) -> 1.0(ref = 3.01932549477) |  last_activity:still_active(qv = 2.12560582161) -> 1.0(ref = 2.46387004852) |  decades_active:2010(qv = 2.34606313705) -> 1.0(ref = 1.54091572762) |  category:List_of_deaths_in_rock_and_roll(qv = 0.448329001665) -> -1.0(ref = 0.569385051727) |  decades_active:2000(qv = 1.65198433399) -> 1.0(ref = 1.20519506931) |  Labels:is_known(qv = 0.958487927914) -> 1.0(ref = 0.2159948349) |  Occupation:activist(qv = -0.774418652058) -> -1.0(ref = -0.825268626213) |  decades_active:1980(qv = 0.183927774429) -> 1.0(ref = 0.0500000119209) |  Instruments:flute(qv = -0.551280260086) -> -1.0(ref = -1.0) |  Origin:city(qv = -0.400517553091) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Genres:bop(qv = 0.00254018977284) -> -1.0(ref = 0.798209667206) |  Genres:art(qv = -0.067293100059) -> -1.0(ref = 2.20815753937) |  decades_active:2010(qv = 1.82564115524) -> 1.0(ref = 3.37700796127) |  last_activity:still_active(qv = 2.19705176353) -> 1.0(ref = 2.5021135807) |  decades_active:2000(qv = 1.58117222786) -> 1.0(ref = 3.03812003136) |  Labels:is_known(qv = 0.871619164944) -> 1.0(ref = 2.14538955688) |  Website:is_known(qv = 0.645336329937) -> 1.0(ref = 1.20567333698) |  decades_active:1980(qv = 0.216498211026) -> 1.0(ref = 1.95000004768) |  Birth name:is_known(qv = 0.390335947275) -> 1.0(ref = 1.0) |  category:List_of_bands_with_more_than_one_lead_vocalist(qv = -0.381860822439) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 2.13358950615) -> 1.0(ref = 3.01932549477) |  last_activity:still_active(qv = 2.12560582161) -> -1.0(ref = -1.00632619858) |  decades_active:2010(qv = 1.25076448917) -> -1.0(ref = -0.00665920972824) |  decades_active:2000(qv = 0.105383239686) -> 1.0(ref = 1.04562187195) |  end_session_now(qv = 0.0480230338871) -> 0.0(ref = 0.0) |
#
# epoch 13100,loss 1.76297, epsilon 0.30633, rewards: ( e-greedy 0.53726, greedy 3.44496)
# rec 1.550 reg 0.213
# epoch 13200,loss 1.64325, epsilon 0.30378, rewards: ( e-greedy 0.55154, greedy 3.49046)
# rec 1.431 reg 0.213
# epoch 13300,loss 1.79423, epsilon 0.30125, rewards: ( e-greedy 0.58238, greedy 3.47042)
# rec 1.582 reg 0.212
# epoch 13400,loss 1.64412, epsilon 0.29875, rewards: ( e-greedy 0.59514, greedy 3.46238)
# rec 1.432 reg 0.212
# epoch 13500,loss 1.86288, epsilon 0.29628, rewards: ( e-greedy 0.62163, greedy 3.44014)
# rec 1.651 reg 0.212
# epoch 13600,loss 1.77830, epsilon 0.29383, rewards: ( e-greedy 0.61647, greedy 3.46512)
# rec 1.567 reg 0.211
# epoch 13700,loss 1.58273, epsilon 0.29140, rewards: ( e-greedy 0.76982, greedy 3.65061)
# rec 1.372 reg 0.211
# epoch 13800,loss 1.82347, epsilon 0.28900, rewards: ( e-greedy 0.82084, greedy 3.68355)
# rec 1.613 reg 0.211
# epoch 13900,loss 1.58994, epsilon 0.28662, rewards: ( e-greedy 0.84375, greedy 3.68820)
# rec 1.379 reg 0.211
# epoch 14000,loss 1.63074, epsilon 0.28427, rewards: ( e-greedy 0.87738, greedy 3.75738)
# rec 1.421 reg 0.210
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 2.21320295334) -> 1.0(ref = 3.07746505737) |  last_activity:still_active(qv = 2.18680524826) -> -1.0(ref = 0.882299900055) |  decades_active:2010(qv = 1.06999588013) -> -1.0(ref = 1.9813683033) |  category:List_of_deaths_in_rock_and_roll(qv = 0.309117019176) -> 3.0(ref = 3.13828253746) |  Genres:j-pop(qv = -0.354724138975) -> -1.0(ref = -0.911874055862) |  Genres:dancehall(qv = -0.49792817235) -> -1.0(ref = 0.0927641391754) |  Labels:is_known(qv = 0.52609205246) -> 1.0(ref = 1.15027809143) |  Website:is_known(qv = 0.158187419176) -> 1.0(ref = 0.0500000119209) |  Birth name:is_known(qv = 0.331049144268) -> -1.0(ref = -1.0) |  end_session_now(qv = 0.0180443990976) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Occupation:conductor(qv = 0.0653726756573) -> -1.0(ref = 0.92305791378) |  decades_active:1990(qv = 2.02427148819) -> -1.0(ref = -2.85991382599) |  decades_active:2010(qv = 0.781377434731) -> -1.0(ref = -1.95780420303) |  category:List_of_deaths_in_rock_and_roll(qv = 0.221405461431) -> -1.0(ref = -1.00821495056) |  Instruments:harmonica(qv = -0.56086230278) -> -1.0(ref = -2.84941530228) |  Labels:is_known(qv = 0.093193590641) -> -1.0(ref = -1.94675302505) |  Genres:gospel(qv = -1.02591109276) -> -1.0(ref = -0.996582210064) |  end_session_now(qv = 0.0035976562649) -> 0.0(ref = 0.0) |
#
# session # 2
#  decades_active:1990(qv = 2.21320319176) -> 1.0(ref = 3.07746505737) |  last_activity:still_active(qv = 2.18680524826) -> -1.0(ref = -2.83240461349) |  decades_active:2010(qv = 1.06999564171) -> -1.0(ref = -1.9288469553) |  category:List_of_deaths_in_rock_and_roll(qv = 0.30911692977) -> -1.0(ref = -0.977733671665) |  end_session_now(qv = 0.023438224569) -> 0.0(ref = 0.0) |
#
# epoch 14100,loss 1.77124, epsilon 0.28194, rewards: ( e-greedy 0.86864, greedy 3.76464)
# rec 1.561 reg 0.210
# epoch 14200,loss 1.65871, epsilon 0.27963, rewards: ( e-greedy 0.93378, greedy 3.80617)
# rec 1.449 reg 0.210
# epoch 14300,loss 1.66352, epsilon 0.27734, rewards: ( e-greedy 1.01840, greedy 3.78656)
# rec 1.454 reg 0.209
# epoch 14400,loss 1.65660, epsilon 0.27508, rewards: ( e-greedy 1.05956, greedy 3.80990)
# rec 1.448 reg 0.209
# epoch 14500,loss 1.70723, epsilon 0.27284, rewards: ( e-greedy 1.15860, greedy 3.86491)
# rec 1.499 reg 0.209
# epoch 14600,loss 1.90975, epsilon 0.27062, rewards: ( e-greedy 1.10874, greedy 3.82642)
# rec 1.701 reg 0.208
# epoch 14700,loss 1.56558, epsilon 0.26843, rewards: ( e-greedy 1.21487, greedy 3.93978)
# rec 1.357 reg 0.208
# epoch 14800,loss 1.49882, epsilon 0.26626, rewards: ( e-greedy 1.34338, greedy 4.02880)
# rec 1.291 reg 0.208
# epoch 14900,loss 1.52418, epsilon 0.26410, rewards: ( e-greedy 1.41204, greedy 4.02492)
# rec 1.317 reg 0.207
# epoch 15000,loss 1.48139, epsilon 0.26197, rewards: ( e-greedy 1.50784, greedy 4.13943)
# rec 1.274 reg 0.207
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 2.4039747715) -> 1.0(ref = 3.2249288559) |  last_activity:still_active(qv = 2.34203028679) -> -1.0(ref = 1.09377193451) |  decades_active:2010(qv = 1.26668930054) -> -1.0(ref = 2.20397043228) |  category:List_of_deaths_in_rock_and_roll(qv = 0.401078999043) -> 3.0(ref = 3.37260055542) |  decades_active:2000(qv = 0.392211019993) -> -1.0(ref = 1.00746035576) |  Labels:is_known(qv = 0.404608100653) -> 1.0(ref = 2.11311626434) |  Instruments:guitar(qv = 0.097811833024) -> 1.0(ref = 1.17170131207) |  Awards:is_known(qv = -0.966612100601) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.151822969317) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.00094105489552) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Occupation:director(qv = 0.124693311751) -> -1.0(ref = 1.07456970215) |  decades_active:1990(qv = 2.18375754356) -> -1.0(ref = -2.88151955605) |  Website:is_known(qv = 0.888100445271) -> -1.0(ref = -1.98054695129) |  Occupation:and(qv = 0.173240721226) -> -1.0(ref = -1.0321546793) |  Origin:ontario(qv = -0.228365674615) -> -1.0(ref = -2.85283565521) |  Labels:is_known(qv = 0.158603101969) -> -1.0(ref = -1.95035338402) |  Instruments:vocals(qv = -0.0207715686411) -> -1.0(ref = -1.00037205219) |  Birth name:is_known(qv = -0.000391688197851) -> -1.0(ref = -1.0) |  end_session_now(qv = -0.00382842682302) -> 0.0(ref = 0.0) |
#
# session # 2
#  decades_active:1990(qv = 2.4039747715) -> -1.0(ref = -0.041234433651) |  Website:is_known(qv = 1.00922691822) -> 1.0(ref = 2.22416830063) |  decades_active:2010(qv = 1.80228841305) -> 1.0(ref = 1.28859817982) |  Genres:symphonic(qv = 0.438920229673) -> -1.0(ref = 0.303787589073) |  decades_active:2000(qv = 1.37240803242) -> 1.0(ref = 1.63755536079) |  Labels:is_known(qv = 0.779491961002) -> 1.0(ref = 0.671110868454) |  Website:is_known(qv = 0.464492112398) -> -0.5(ref = -0.346199095249) |  Origin:ontario(qv = -0.814869999886) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.271208286285) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.00171040929854) -> 0.0(ref = 0.0) | reached max session length
# epoch 15100,loss 1.43897, epsilon 0.25986, rewards: ( e-greedy 1.49806, greedy 4.15549)
# rec 1.232 reg 0.207
# epoch 15200,loss 1.95809, epsilon 0.25778, rewards: ( e-greedy 1.45125, greedy 4.02894)
# rec 1.752 reg 0.207
# epoch 15300,loss 1.67562, epsilon 0.25571, rewards: ( e-greedy 1.43612, greedy 3.99504)
# rec 1.469 reg 0.206
# epoch 15400,loss 1.29406, epsilon 0.25366, rewards: ( e-greedy 1.56751, greedy 4.07254)
# rec 1.088 reg 0.206
# epoch 15500,loss 1.70713, epsilon 0.25164, rewards: ( e-greedy 1.54476, greedy 3.97829)
# rec 1.501 reg 0.206
# epoch 15600,loss 1.74985, epsilon 0.24963, rewards: ( e-greedy 1.56328, greedy 3.98146)
# rec 1.545 reg 0.205
# epoch 15700,loss 1.60115, epsilon 0.24764, rewards: ( e-greedy 1.56996, greedy 3.96031)
# rec 1.396 reg 0.205
# epoch 15800,loss 1.71956, epsilon 0.24568, rewards: ( e-greedy 1.56296, greedy 3.97028)
# rec 1.515 reg 0.205
# epoch 15900,loss 1.68398, epsilon 0.24373, rewards: ( e-greedy 1.52866, greedy 3.93325)
# rec 1.480 reg 0.204
# epoch 16000,loss 1.40281, epsilon 0.24180, rewards: ( e-greedy 1.65080, greedy 4.04193)
# rec 1.199 reg 0.204
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 2.60499644279) -> -1.0(ref = 0.113341331482) |  Website:is_known(qv = 1.17193830013) -> -1.0(ref = -1.47500002384) |  Website:is_known(qv = 0.340186417103) -> -0.5(ref = -0.5) |  end_session_now(qv = 0.00426820479333) -> 0.0(ref = 0.0) |
#
# session # 1
#  Genres:trance(qv = 0.317501187325) -> -1.0(ref = 1.42426490784) |  decades_active:1990(qv = 2.55185770988) -> 1.0(ref = 3.06501531601) |  last_activity:still_active(qv = 2.48419713974) -> 1.0(ref = 2.17370033264) |  Genres:swing(qv = 0.812566578388) -> -1.0(ref = 1.23547387123) |  decades_active:2010(qv = 2.35313034058) -> 1.0(ref = 1.88703489304) |  Genres:free(qv = 0.230460822582) -> -1.0(ref = 0.933720946312) |  decades_active:2000(qv = 2.18343257904) -> 1.0(ref = 2.03549575806) |  Origin:france(qv = -0.706800878048) -> -1.0(ref = -0.0500000119209) |  Labels:is_known(qv = 0.500782549381) -> 1.0(ref = 1.0) |  Occupation:musician(qv = 0.0311673115939) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 2.60499596596) -> 1.0(ref = 3.37293505669) |  last_activity:still_active(qv = 2.49782633781) -> -1.0(ref = -2.64699268341) |  Website:is_known(qv = 1.33919453621) -> -1.0(ref = -1.73367667198) |  category:List_of_C-pop_artists(qv = 0.156561791897) -> -1.0(ref = -0.772291243076) |  Instruments:singing(qv = -0.337781250477) -> -1.0(ref = -2.72355270386) |  Labels:is_known(qv = 0.470420837402) -> -1.0(ref = -1.81426584721) |  Instruments:vocals(qv = 0.109882794321) -> -1.0(ref = -0.857121944427) |  Birth name:is_known(qv = 0.15039794147) -> 1.0(ref = 1.0) |  end_session_now(qv = -0.00259796716273) -> 0.0(ref = 0.0) |
#
# epoch 16100,loss 1.42482, epsilon 0.23989, rewards: ( e-greedy 1.72972, greedy 4.10073)
# rec 1.221 reg 0.204
# epoch 16200,loss 1.81501, epsilon 0.23800, rewards: ( e-greedy 1.76575, greedy 4.11866)
# rec 1.611 reg 0.204
# epoch 16300,loss 1.68684, epsilon 0.23613, rewards: ( e-greedy 1.74317, greedy 4.08879)
# rec 1.484 reg 0.203
# epoch 16400,loss 1.78249, epsilon 0.23428, rewards: ( e-greedy 1.77285, greedy 4.10192)
# rec 1.580 reg 0.203
# epoch 16500,loss 1.76344, epsilon 0.23245, rewards: ( e-greedy 1.79657, greedy 4.14872)
# rec 1.561 reg 0.203
# epoch 16600,loss 1.58482, epsilon 0.23063, rewards: ( e-greedy 1.84291, greedy 4.16185)
# rec 1.382 reg 0.202
# epoch 16700,loss 1.40799, epsilon 0.22883, rewards: ( e-greedy 1.91162, greedy 4.24667)
# rec 1.206 reg 0.202
# epoch 16800,loss 1.62631, epsilon 0.22706, rewards: ( e-greedy 1.88446, greedy 4.20100)
# rec 1.425 reg 0.202
# epoch 16900,loss 1.56792, epsilon 0.22529, rewards: ( e-greedy 1.90401, greedy 4.18690)
# rec 1.366 reg 0.202
# epoch 17000,loss 1.69764, epsilon 0.22355, rewards: ( e-greedy 1.91061, greedy 4.19821)
# rec 1.496 reg 0.201
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 2.59329104424) -> -1.0(ref = -0.0495968461037) |  Website:is_known(qv = 1.00042438507) -> 1.0(ref = 3.98610568047) |  decades_active:2010(qv = 1.69263553619) -> 1.0(ref = 3.14326930046) |  last_activity:still_active(qv = 2.24812221527) -> 1.0(ref = 2.25607299805) |  decades_active:2000(qv = 1.3221821785) -> 1.0(ref = 1.23136615753) |  category:List_of_jazz_vocalists(qv = -0.256240725517) -> -1.0(ref = 0.243543386459) |  Labels:is_known(qv = 0.865329921246) -> 1.0(ref = 1.30899310112) |  Birth name:is_known(qv = 0.325255870819) -> 1.0(ref = 0.0500000119209) |  Instruments:vocals(qv = 0.130645692348) -> -1.0(ref = -1.0) |  Instruments:electric(qv = -0.42627838254) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 2.59329104424) -> -1.0(ref = -0.0495968461037) |  Website:is_known(qv = 1.00042438507) -> 1.0(ref = 3.98610568047) |  decades_active:2010(qv = 1.69263553619) -> 1.0(ref = 3.14326930046) |  last_activity:still_active(qv = 2.24812221527) -> 1.0(ref = 2.25607299805) |  decades_active:2000(qv = 1.3221821785) -> 1.0(ref = 3.08627176285) |  Labels:is_known(qv = 0.701265752316) -> 1.0(ref = 2.19607567787) |  Instruments:vocals(qv = 0.388496220112) -> 1.0(ref = 1.25902700424) |  Birth name:is_known(qv = 0.272660046816) -> 1.0(ref = 0.524999976158) |  Instruments:vocals(qv = 0.0445105805993) -> -0.5(ref = -0.5) |  end_session_now(qv = -0.0180923976004) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 2.59329128265) -> 1.0(ref = 3.45583200455) |  last_activity:still_active(qv = 2.58508634567) -> 1.0(ref = 2.5000295639) |  decades_active:2010(qv = 2.58211064339) -> 1.0(ref = 1.57897853851) |  category:List_of_soft_rock_artists_and_songs(qv = 0.965194702148) -> -1.0(ref = 0.609451055527) |  Genres:rockabilly(qv = 0.257268726826) -> -1.0(ref = 1.25598597527) |  decades_active:2000(qv = 1.70791351795) -> 1.0(ref = 2.37472200394) |  Labels:is_known(qv = 1.08494317532) -> 1.0(ref = 1.44707596302) |  Website:is_known(qv = 0.470606297255) -> 1.0(ref = 1.95000004768) |  Birth name:is_known(qv = 0.398926854134) -> 1.0(ref = 1.0) |  end_session_now(qv = -0.00999245420098) -> 0.0(ref = 0.0) | reached max session length
# epoch 17100,loss 1.71969, epsilon 0.22182, rewards: ( e-greedy 1.88255, greedy 4.16939)
# rec 1.519 reg 0.201
# epoch 17200,loss 1.79107, epsilon 0.22011, rewards: ( e-greedy 1.85430, greedy 4.16045)
# rec 1.590 reg 0.201
# epoch 17300,loss 1.84305, epsilon 0.21842, rewards: ( e-greedy 1.77987, greedy 4.04740)
# rec 1.643 reg 0.200
# epoch 17400,loss 1.91068, epsilon 0.21674, rewards: ( e-greedy 1.75088, greedy 3.95066)
# rec 1.711 reg 0.200
# epoch 17500,loss 1.52134, epsilon 0.21509, rewards: ( e-greedy 1.82979, greedy 4.04560)
# rec 1.322 reg 0.200
# epoch 17600,loss 2.12227, epsilon 0.21344, rewards: ( e-greedy 1.75981, greedy 3.92804)
# rec 1.923 reg 0.200
# epoch 17700,loss 1.63663, epsilon 0.21182, rewards: ( e-greedy 1.80683, greedy 3.95823)
# rec 1.437 reg 0.199
# epoch 17800,loss 1.43797, epsilon 0.21021, rewards: ( e-greedy 1.92315, greedy 4.03041)
# rec 1.239 reg 0.199
# epoch 17900,loss 1.54062, epsilon 0.20861, rewards: ( e-greedy 1.95883, greedy 4.06437)
# rec 1.342 reg 0.199
# epoch 18000,loss 1.81075, epsilon 0.20703, rewards: ( e-greedy 1.98295, greedy 4.06393)
# rec 1.612 reg 0.198
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 2.77493596077) -> -1.0(ref = 0.105249881744) |  Website:is_known(qv = 1.1634209156) -> 1.0(ref = 4.05912685394) |  decades_active:2010(qv = 1.77030992508) -> 1.0(ref = 3.2201333046) |  last_activity:still_active(qv = 2.26305317879) -> 1.0(ref = 2.33698248863) |  decades_active:2000(qv = 1.40735006332) -> 1.0(ref = -0.558806419373) |  Other names:is_known(qv = -0.215697795153) -> -1.0(ref = -1.64084887505) |  Labels:is_known(qv = 0.964891374111) -> -1.0(ref = -0.674577713013) |  Occupation:educator(qv = -0.879997491837) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.371452003717) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.00548105686903) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 2.77493596077) -> 1.0(ref = 3.61224222183) |  last_activity:still_active(qv = 2.74972867966) -> -1.0(ref = 1.40916013718) |  decades_active:2010(qv = 1.61393654346) -> -1.0(ref = 2.53595805168) |  category:List_of_deaths_in_rock_and_roll(qv = 1.26939129829) -> 3.0(ref = 3.72206115723) |  decades_active:2000(qv = 0.760064542294) -> -1.0(ref = 1.09834074974) |  Labels:is_known(qv = 0.643018364906) -> 1.0(ref = 2.20877981186) |  Instruments:vocals(qv = 0.238670870662) -> 1.0(ref = 1.27239990234) |  Birth name:is_known(qv = 0.286736696959) -> 1.0(ref = 0.0500000119209) |  category:List_of_girl_groups(qv = -0.537512600422) -> -1.0(ref = -1.0) |  Genres:melodic(qv = -0.427008271217) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 2.77493572235) -> 1.0(ref = 3.61224198341) |  last_activity:still_active(qv = 2.74972844124) -> 1.0(ref = 3.826141119) |  decades_active:2010(qv = 2.71522283554) -> 1.0(ref = 2.97488546371) |  decades_active:2000(qv = 2.10558223724) -> 1.0(ref = 2.0788269043) |  decades_active:1980(qv = 1.13560736179) -> -1.0(ref = -0.711521446705) |  Labels:is_known(qv = 1.01070892811) -> 1.0(ref = 0.303661644459) |  Website:is_known(qv = 0.512028455734) -> -1.0(ref = -0.732987761497) |  Birth name:is_known(qv = 0.281065493822) -> -1.0(ref = -1.95000004768) |  category:List_of_individual_K-pop_artists(qv = -0.66318321228) -> -1.0(ref = -1.0) |  end_session_now(qv = -0.0149790495634) -> 0.0(ref = 0.0) | reached max session length
# epoch 18100,loss 1.58274, epsilon 0.20547, rewards: ( e-greedy 2.03165, greedy 4.08754)
# rec 1.385 reg 0.198
# epoch 18200,loss 1.55869, epsilon 0.20392, rewards: ( e-greedy 2.08749, greedy 4.12279)
# rec 1.361 reg 0.198
# epoch 18300,loss 1.70316, epsilon 0.20239, rewards: ( e-greedy 2.16474, greedy 4.12151)
# rec 1.506 reg 0.197
# epoch 18400,loss 1.75684, epsilon 0.20088, rewards: ( e-greedy 2.14927, greedy 4.11536)
# rec 1.560 reg 0.197
# epoch 18500,loss 2.15153, epsilon 0.19938, rewards: ( e-greedy 2.09034, greedy 4.08782)
# rec 1.955 reg 0.197
# epoch 18600,loss 1.68650, epsilon 0.19789, rewards: ( e-greedy 2.11031, greedy 4.10804)
# rec 1.490 reg 0.197
# epoch 18700,loss 1.65774, epsilon 0.19642, rewards: ( e-greedy 2.13228, greedy 4.07623)
# rec 1.461 reg 0.196
# epoch 18800,loss 1.74222, epsilon 0.19496, rewards: ( e-greedy 2.10105, greedy 4.01261)
# rec 1.546 reg 0.196
# epoch 18900,loss 1.71547, epsilon 0.19352, rewards: ( e-greedy 2.04594, greedy 3.97335)
# rec 1.520 reg 0.196
# epoch 19000,loss 1.76067, epsilon 0.19209, rewards: ( e-greedy 2.08035, greedy 3.92202)
# rec 1.565 reg 0.195
# Learning curves:
# Random session examples
# session # 0
#  Genres:and(qv = 0.638267099857) -> -1.0(ref = 1.47433328629) |  decades_active:1990(qv = 2.60456132889) -> 1.0(ref = 4.34820556641) |  last_activity:still_active(qv = 2.57199382782) -> 1.0(ref = 3.52442669868) |  decades_active:2010(qv = 2.64786028862) -> 1.0(ref = 2.65729141235) |  decades_active:2000(qv = 1.74451732635) -> 1.0(ref = 3.2589225769) |  decades_active:1980(qv = 0.991284370422) -> 1.0(ref = 2.37781333923) |  Labels:is_known(qv = 0.971446216106) -> 1.0(ref = 1.45032978058) |  Website:is_known(qv = 0.474031299353) -> 1.0(ref = 0.0500000119209) |  Children:is_known(qv = -0.609630823135) -> -1.0(ref = -1.0) |  category:List_of_Brazilian_musicians(qv = -0.356626480818) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 2.81848335266) -> 1.0(ref = 3.61810088158) |  last_activity:still_active(qv = 2.75589561462) -> -1.0(ref = 1.59295964241) |  decades_active:2010(qv = 1.52757287025) -> 1.0(ref = 2.72943115234) |  decades_active:2000(qv = 1.38786005974) -> 1.0(ref = 1.82045376301) |  Ethnicity:is_known(qv = -0.412046551704) -> -1.0(ref = -2.4276676178) |  category:List_of_folk_rock_artists(qv = -0.71773070097) -> -1.0(ref = -1.50280809402) |  category:List_of_crooners(qv = -0.798614501953) -> -1.0(ref = -0.52927172184) |  category:List_of_pop_and_rock_pianists(qv = -0.927115499973) -> -1.0(ref = -1.0) |  end_session_now(qv = 0.0471764095128) -> 0.0(ref = 0.0) |
#
# session # 2
#  category:List_of_Dutch_musicians(qv = 0.547563672066) -> -1.0(ref = 1.50439143181) |  decades_active:1990(qv = 2.6362016201) -> -1.0(ref = 2.36450147629) |  Website:is_known(qv = 1.10297369957) -> 1.0(ref = 3.54158043861) |  decades_active:2010(qv = 1.32874894142) -> 1.0(ref = 2.67534780502) |  last_activity:still_active(qv = 1.76352405548) -> 1.0(ref = 3.1334104538) |  decades_active:2000(qv = 1.07344567776) -> 1.0(ref = 2.24569535255) |  Labels:is_known(qv = 0.646016776562) -> 1.0(ref = 1.31125831604) |  Birth name:is_known(qv = 0.327640324831) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.0196376256645) -> 0.0(ref = 0.0) |
#
# epoch 19100,loss 1.75281, epsilon 0.19068, rewards: ( e-greedy 2.09531, greedy 3.95781)
# rec 1.558 reg 0.195
# epoch 19200,loss 1.66134, epsilon 0.18928, rewards: ( e-greedy 2.12378, greedy 3.93403)
# rec 1.467 reg 0.195
# epoch 19300,loss 1.82123, epsilon 0.18789, rewards: ( e-greedy 2.07640, greedy 3.90963)
# rec 1.627 reg 0.195
# epoch 19400,loss 1.50724, epsilon 0.18652, rewards: ( e-greedy 2.13176, greedy 3.97467)
# rec 1.313 reg 0.194
# epoch 19500,loss 1.82215, epsilon 0.18516, rewards: ( e-greedy 2.18659, greedy 4.05920)
# rec 1.628 reg 0.194
# epoch 19600,loss 1.39831, epsilon 0.18382, rewards: ( e-greedy 2.33393, greedy 4.18528)
# rec 1.205 reg 0.194
# epoch 19700,loss 1.48966, epsilon 0.18248, rewards: ( e-greedy 2.31754, greedy 4.18475)
# rec 1.296 reg 0.193
# epoch 19800,loss 1.52666, epsilon 0.18117, rewards: ( e-greedy 2.36878, greedy 4.26728)
# rec 1.334 reg 0.193
# epoch 19900,loss 1.67766, epsilon 0.17986, rewards: ( e-greedy 2.36590, greedy 4.22055)
# rec 1.485 reg 0.193
# epoch 20000,loss 1.30530, epsilon 0.17857, rewards: ( e-greedy 2.47031, greedy 4.32249)
# rec 1.113 reg 0.193
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 3.04653930664) -> 1.0(ref = 3.88635492325) |  last_activity:still_active(qv = 3.03826832771) -> -1.0(ref = -2.02971053123) |  decades_active:2010(qv = 1.78971016407) -> -1.0(ref = -1.08390581608) |  category:List_of_Asian-American_hip_hop_musicians(qv = 0.146519422531) -> -1.0(ref = -0.0883218646049) |  category:List_of_deaths_in_rock_and_roll(qv = 0.959661185741) -> 3.0(ref = 5.09818172455) |  Labels:is_known(qv = 0.517676949501) -> 1.0(ref = 2.20861244202) |  Instruments:vocals(qv = 0.434676527977) -> 1.0(ref = 1.27222371101) |  Birth name:is_known(qv = 0.286551356316) -> 1.0(ref = 1.95000004768) |  Genres:rock(qv = 0.0546013750136) -> 1.0(ref = 1.0) |  first_activity:1965(qv = 0.00902404263616) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Origin:london(qv = 0.787432789803) -> -1.0(ref = 1.71480488777) |  decades_active:1990(qv = 2.85768938065) -> 1.0(ref = 3.29217410088) |  last_activity:still_active(qv = 3.04406285286) -> 1.0(ref = 2.41281485558) |  Genres:big(qv = 1.37989127636) -> -1.0(ref = 1.48717355728) |  Instruments:and(qv = 0.770939469337) -> -1.0(ref = 0.408841371536) |  decades_active:2010(qv = 2.32906579971) -> 1.0(ref = 1.48299098015) |  Origin:jamaica(qv = 0.105614706874) -> -1.0(ref = 0.50841152668) |  decades_active:2000(qv = 1.58780157566) -> 1.0(ref = 1.95000004768) |  Labels:is_known(qv = 0.665235161781) -> 1.0(ref = 1.0) |  Genres:rock(qv = 0.200015977025) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 3.0465388298) -> -1.0(ref = 0.333624720573) |  category:List_of_J-pop_artists(qv = 0.764252781868) -> -1.0(ref = 2.23271298409) |  decades_active:2010(qv = 0.910432338715) -> 1.0(ref = 3.40285587311) |  last_activity:still_active(qv = 2.06686687469) -> 1.0(ref = 2.52932190895) |  decades_active:2000(qv = 1.6098126173) -> 1.0(ref = 1.31702232361) |  Labels:is_known(qv = 0.715474903584) -> 1.0(ref = 0.333707749844) |  category:List_of_new-age_music_artists(qv = -0.615667939186) -> -1.0(ref = -0.701360285282) |  Birth name:is_known(qv = 0.314357608557) -> -1.0(ref = -1.95000004768) |  first_activity:1974(qv = -0.680527508259) -> -1.0(ref = -1.0) |  end_session_now(qv = 0.0480401068926) -> 0.0(ref = 0.0) | reached max session length
# saved /home/jheuristic/yozhik/agentnet_snapshots/research.rl_comparison.qlearning.epoch20000.pcl
# epoch 20100,loss 1.77527, epsilon 0.17729, rewards: ( e-greedy 2.40628, greedy 4.21724)
# rec 1.583 reg 0.192
# epoch 20200,loss 1.36010, epsilon 0.17602, rewards: ( e-greedy 2.52065, greedy 4.28852)
# rec 1.168 reg 0.192
# epoch 20300,loss 1.73927, epsilon 0.17477, rewards: ( e-greedy 2.49259, greedy 4.24867)
# rec 1.548 reg 0.192
# epoch 20400,loss 1.42732, epsilon 0.17353, rewards: ( e-greedy 2.49733, greedy 4.22180)
# rec 1.236 reg 0.191
# epoch 20500,loss 1.54140, epsilon 0.17230, rewards: ( e-greedy 2.54960, greedy 4.29562)
# rec 1.350 reg 0.191
# epoch 20600,loss 1.70600, epsilon 0.17108, rewards: ( e-greedy 2.47564, greedy 4.17906)
# rec 1.515 reg 0.191
# epoch 20700,loss 1.67467, epsilon 0.16988, rewards: ( e-greedy 2.51207, greedy 4.19015)
# rec 1.484 reg 0.191
# epoch 20800,loss 1.46122, epsilon 0.16868, rewards: ( e-greedy 2.52787, greedy 4.20014)
# rec 1.271 reg 0.190
# epoch 20900,loss 1.56210, epsilon 0.16750, rewards: ( e-greedy 2.54908, greedy 4.22112)
# rec 1.372 reg 0.190
# epoch 21000,loss 1.44248, epsilon 0.16633, rewards: ( e-greedy 2.54717, greedy 4.14101)
# rec 1.253 reg 0.190
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 3.04762077332) -> 1.0(ref = 3.93817257881) |  last_activity:still_active(qv = 3.0928132534) -> 1.0(ref = 2.74019932747) |  decades_active:2010(qv = 2.86590075493) -> 1.0(ref = 1.83178877831) |  Genres:symphonic(qv = 0.907210826874) -> -1.0(ref = 0.8755671978) |  decades_active:2000(qv = 1.97428131104) -> 1.0(ref = 3.30283021927) |  decades_active:1980(qv = 1.10041034222) -> 1.0(ref = 2.42403173447) |  Labels:is_known(qv = 0.970673382282) -> 1.0(ref = 1.49898076057) |  Website:is_known(qv = 0.52524292469) -> 1.0(ref = 1.95000004768) |  Birth name:is_known(qv = 0.295161873102) -> 1.0(ref = 1.0) |  end_session_now(qv = -0.0165057629347) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 3.04762077332) -> 1.0(ref = 3.93817257881) |  last_activity:still_active(qv = 3.0928132534) -> -1.0(ref = 1.48115897179) |  decades_active:2010(qv = 1.86270809174) -> -1.0(ref = 2.61174631119) |  category:List_of_deaths_in_rock_and_roll(qv = 1.88562035561) -> 3.0(ref = 3.80183815956) |  Occupation:bandleader(qv = -0.267998963594) -> -1.0(ref = 1.04185009003) |  Labels:is_known(qv = 0.68349480629) -> 1.0(ref = 2.14931583405) |  Instruments:vocals(qv = 0.312718957663) -> 1.0(ref = 1.20980608463) |  Birth name:is_known(qv = 0.220848470926) -> 1.0(ref = 0.0500000119209) |  Occupation:dancer(qv = -0.619129478931) -> -1.0(ref = -1.0) |  end_session_now(qv = -0.0123785892501) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 3.04762077332) -> 1.0(ref = 3.93817281723) |  last_activity:still_active(qv = 3.09281349182) -> 1.0(ref = 2.59857964516) |  Genres:contemporary(qv = 1.39603054523) -> -1.0(ref = 1.68271541595) |  decades_active:2010(qv = 2.68577194214) -> 1.0(ref = 2.82391095161) |  Genres:k-pop(qv = 0.519366204739) -> -1.0(ref = 1.25269031525) |  decades_active:2000(qv = 1.86234951019) -> 1.0(ref = 2.37125301361) |  Labels:is_known(qv = 1.11042678356) -> 1.0(ref = 1.44342422485) |  Website:is_known(qv = 0.466762304306) -> 1.0(ref = 1.95000004768) |  Birth name:is_known(qv = 0.305836647749) -> 1.0(ref = 1.0) |  end_session_now(qv = -0.00880745146424) -> 0.0(ref = 0.0) | reached max session length
# epoch 21100,loss 1.46255, epsilon 0.16518, rewards: ( e-greedy 2.62045, greedy 4.16791)
# rec 1.273 reg 0.189
# epoch 21200,loss 1.23270, epsilon 0.16403, rewards: ( e-greedy 2.67941, greedy 4.20412)
# rec 1.044 reg 0.189
# epoch 21300,loss 1.90785, epsilon 0.16290, rewards: ( e-greedy 2.60547, greedy 4.11071)
# rec 1.719 reg 0.189
# epoch 21400,loss 1.54740, epsilon 0.16177, rewards: ( e-greedy 2.67892, greedy 4.18264)
# rec 1.359 reg 0.189
# epoch 21500,loss 1.45986, epsilon 0.16066, rewards: ( e-greedy 2.67903, greedy 4.17737)
# rec 1.271 reg 0.188
# epoch 21600,loss 1.50463, epsilon 0.15956, rewards: ( e-greedy 2.76413, greedy 4.24264)
# rec 1.317 reg 0.188
# epoch 21700,loss 1.62118, epsilon 0.15847, rewards: ( e-greedy 2.75671, greedy 4.24237)
# rec 1.433 reg 0.188
# epoch 21800,loss 1.39411, epsilon 0.15739, rewards: ( e-greedy 2.86604, greedy 4.34113)
# rec 1.207 reg 0.188
# epoch 21900,loss 1.31889, epsilon 0.15632, rewards: ( e-greedy 2.88344, greedy 4.36502)
# rec 1.132 reg 0.187
# epoch 22000,loss 1.22609, epsilon 0.15526, rewards: ( e-greedy 2.96209, greedy 4.45952)
# rec 1.039 reg 0.187
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 3.1590321064) -> 1.0(ref = 3.93885540962) |  last_activity:still_active(qv = 3.09353208542) -> 1.0(ref = 3.91781759262) |  decades_active:2010(qv = 3.02711176872) -> 1.0(ref = 3.07138705254) |  decades_active:2000(qv = 2.23811244965) -> 1.0(ref = 2.18040752411) |  decades_active:1980(qv = 1.24253439903) -> 1.0(ref = 3.18787837029) |  Labels:is_known(qv = 1.20228946209) -> 1.0(ref = 2.30303001404) |  Website:is_known(qv = 0.915703654289) -> 1.0(ref = 1.37161040306) |  Birth name:is_known(qv = 0.391168892384) -> 1.0(ref = 1.95000004768) |  Genres:rock(qv = 0.193452626467) -> 1.0(ref = 1.0) |  category:List_of_band_name_etymologies(qv = 0.0311719141901) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 3.1590321064) -> 1.0(ref = 3.93885540962) |  last_activity:still_active(qv = 3.09353208542) -> -1.0(ref = 2.1122367382) |  decades_active:2010(qv = 2.18137121201) -> 1.0(ref = 3.2760386467) |  decades_active:2000(qv = 2.0370285511) -> 1.0(ref = 2.39583015442) |  category:List_of_deaths_in_rock_and_roll(qv = 1.46929490566) -> 3.0(ref = 4.8632106781) |  Labels:is_known(qv = 0.902295231819) -> 1.0(ref = 1.96127462387) |  Birth name:is_known(qv = 0.483543336391) -> 1.0(ref = 1.01186800003) |  Genres:rock(qv = 0.0124926641583) -> 1.0(ref = 0.0500000119209) |  Instruments:synthesizers(qv = -0.594794213772) -> -1.0(ref = -1.0) |  first_activity:1971(qv = -0.0750871002674) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 3.15903234482) -> 1.0(ref = 3.93885445595) |  last_activity:still_active(qv = 3.09353113174) -> 1.0(ref = 3.9178173542) |  decades_active:2010(qv = 3.02711176872) -> 1.0(ref = 3.07138681412) |  decades_active:2000(qv = 2.23811268806) -> 1.0(ref = 2.18040728569) |  decades_active:1980(qv = 1.2425340414) -> 1.0(ref = -0.145151138306) |  first_activity:1983(qv = -0.138428330421) -> -1.0(ref = -1.20542228222) |  Instruments:banjo(qv = -0.118631854653) -> -1.0(ref = -0.216234028339) |  Labels:is_known(qv = 0.825016796589) -> 1.0(ref = 0.0500000119209) |  Origin:pennsylvania(qv = -0.578982412815) -> -1.0(ref = -1.0) |  category:List_of_musical_artists_from_Japan(qv = -0.320558726788) -> 0.0(ref = 0.0) | reached max session length
# epoch 22100,loss 1.51448, epsilon 0.15422, rewards: ( e-greedy 2.95688, greedy 4.45857)
# rec 1.328 reg 0.187
# epoch 22200,loss 1.27069, epsilon 0.15318, rewards: ( e-greedy 2.98320, greedy 4.48371)
# rec 1.084 reg 0.187
# epoch 22300,loss 1.58248, epsilon 0.15215, rewards: ( e-greedy 2.95388, greedy 4.49134)
# rec 1.396 reg 0.186
# epoch 22400,loss 1.72067, epsilon 0.15114, rewards: ( e-greedy 3.02549, greedy 4.51321)
# rec 1.535 reg 0.186
# epoch 22500,loss 1.55839, epsilon 0.15013, rewards: ( e-greedy 3.03394, greedy 4.55989)
# rec 1.373 reg 0.186
# epoch 22600,loss 1.57160, epsilon 0.14913, rewards: ( e-greedy 3.03355, greedy 4.55790)
# rec 1.386 reg 0.185
# epoch 22700,loss 1.68386, epsilon 0.14815, rewards: ( e-greedy 3.02219, greedy 4.48911)
# rec 1.499 reg 0.185
# epoch 22800,loss 1.77921, epsilon 0.14717, rewards: ( e-greedy 2.96897, greedy 4.45620)
# rec 1.594 reg 0.185
# epoch 22900,loss 1.58010, epsilon 0.14620, rewards: ( e-greedy 2.94208, greedy 4.43358)
# rec 1.396 reg 0.185
# epoch 23000,loss 1.69713, epsilon 0.14525, rewards: ( e-greedy 2.94787, greedy 4.42322)
# rec 1.513 reg 0.184
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 3.19379377365) -> 1.0(ref = 4.11578941345) |  last_activity:still_active(qv = 3.27977800369) -> -1.0(ref = 2.32233905792) |  decades_active:2010(qv = 2.43041443825) -> 1.0(ref = 3.49719905853) |  decades_active:2000(qv = 2.41851139069) -> 1.0(ref = 2.62863063812) |  category:List_of_deaths_in_rock_and_roll(qv = 1.71434807777) -> 3.0(ref = 2.96310734749) |  Labels:is_known(qv = 0.961136519909) -> -1.0(ref = -0.0388342738152) |  Birth name:is_known(qv = 0.577607393265) -> 1.0(ref = 1.0117534399) |  end_session_now(qv = 0.0123720448464) -> 0.0(ref = 0.0) |
#
# session # 1
#  decades_active:1990(qv = 3.19379377365) -> 1.0(ref = 4.11578941345) |  last_activity:still_active(qv = 3.27977800369) -> 1.0(ref = 4.11668729782) |  decades_active:2010(qv = 3.13893580437) -> 1.0(ref = 3.28072357178) |  decades_active:2000(qv = 2.43254375458) -> 1.0(ref = 2.40076160431) |  category:List_of_soft_rock_artists_and_songs(qv = 0.216456517577) -> -1.0(ref = -0.548329770565) |  Labels:is_known(qv = 1.32275342941) -> 1.0(ref = 0.475442349911) |  Genres:electropop(qv = -0.437561869621) -> -1.0(ref = -0.552165985107) |  Genres:rhythm(qv = -0.703472197056) -> -1.0(ref = -1.95000004768) |  Origin:san(qv = -0.617715537548) -> -1.0(ref = -1.0) |  end_session_now(qv = 0.0130696315318) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 3.19379329681) -> 1.0(ref = 4.11578845978) |  last_activity:still_active(qv = 3.27977752686) -> 1.0(ref = 4.11668729782) |  decades_active:2010(qv = 3.13893532753) -> 1.0(ref = 3.28072357178) |  decades_active:2000(qv = 2.43254375458) -> 1.0(ref = 2.40076160431) |  decades_active:1980(qv = 1.47448587418) -> 1.0(ref = 1.36606705189) |  Labels:is_known(qv = 1.31214404106) -> 1.0(ref = 0.385333716869) |  Website:is_known(qv = 1.00455617905) -> -1.0(ref = -0.647017121315) |  Resting place:is_known(qv = -0.849119126797) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.163424685597) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.011276466772) -> 0.0(ref = 0.0) | reached max session length
# epoch 23100,loss 1.30452, epsilon 0.14430, rewards: ( e-greedy 3.00408, greedy 4.46690)
# rec 1.120 reg 0.184
# epoch 23200,loss 1.50205, epsilon 0.14336, rewards: ( e-greedy 3.09667, greedy 4.49421)
# rec 1.318 reg 0.184
# epoch 23300,loss 1.52852, epsilon 0.14243, rewards: ( e-greedy 3.15701, greedy 4.55979)
# rec 1.345 reg 0.184
# epoch 23400,loss 1.52613, epsilon 0.14151, rewards: ( e-greedy 3.15430, greedy 4.55381)
# rec 1.343 reg 0.183
# epoch 23500,loss 1.48259, epsilon 0.14060, rewards: ( e-greedy 3.16587, greedy 4.54843)
# rec 1.300 reg 0.183
# epoch 23600,loss 1.49163, epsilon 0.13970, rewards: ( e-greedy 3.15429, greedy 4.49558)
# rec 1.309 reg 0.183
# epoch 23700,loss 1.60363, epsilon 0.13881, rewards: ( e-greedy 3.15886, greedy 4.48103)
# rec 1.421 reg 0.182
# epoch 23800,loss 1.52145, epsilon 0.13792, rewards: ( e-greedy 3.14297, greedy 4.48992)
# rec 1.339 reg 0.182
# epoch 23900,loss 1.59881, epsilon 0.13705, rewards: ( e-greedy 3.10368, greedy 4.46493)
# rec 1.417 reg 0.182
# epoch 24000,loss 1.56902, epsilon 0.13618, rewards: ( e-greedy 3.12231, greedy 4.47744)
# rec 1.387 reg 0.182
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 3.2097492218) -> 1.0(ref = 4.07021284103) |  last_activity:still_active(qv = 3.23180294037) -> 1.0(ref = 1.5436258316) |  Instruments:keyboards(qv = 2.05221939087) -> -1.0(ref = 0.572237730026) |  category:List_of_C-pop_artists(qv = 1.35395371914) -> -1.0(ref = 1.65498709679) |  decades_active:2010(qv = 2.79472327232) -> 1.0(ref = 1.8068857193) |  decades_active:2000(qv = 1.96799600124) -> 1.0(ref = 0.849353313446) |  Genres:classical(qv = -0.219736412168) -> -1.0(ref = -0.158575475216) |  Labels:is_known(qv = 0.885710060596) -> 1.0(ref = 1.95000004768) |  Website:is_known(qv = 0.555993855) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.00302370730788) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 3.2097492218) -> -1.0(ref = 0.807464599609) |  Genres:indie(qv = 1.15864181519) -> -1.0(ref = -2.81819391251) |  Website:is_known(qv = 1.34480202198) -> -1.0(ref = -1.91388845444) |  decades_active:2010(qv = 0.363015681505) -> -1.0(ref = -0.961987793446) |  end_session_now(qv = 0.0400128364563) -> 0.0(ref = 0.0) |
#
# session # 2
#  decades_active:1990(qv = 3.20974969864) -> -1.0(ref = 0.807464599609) |  Website:is_known(qv = 1.90259432793) -> 1.0(ref = 1.68897676468) |  decades_active:2010(qv = 2.39705252647) -> -1.0(ref = 0.72523868084) |  Instruments:piano(qv = 0.632204174995) -> 1.0(ref = 1.81604075432) |  Instruments:vocals(qv = 0.858990192413) -> 1.0(ref = 1.49428367615) |  Labels:is_known(qv = 0.506514012814) -> 1.0(ref = 0.520298600197) |  Website:is_known(qv = 0.155671536922) -> -0.5(ref = -0.504948854446) |  Birth name:is_known(qv = -0.00520928949118) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.018997207284) -> 0.0(ref = 0.0) |
#
# epoch 24100,loss 1.47904, epsilon 0.13532, rewards: ( e-greedy 3.15808, greedy 4.49169)
# rec 1.298 reg 0.181
# epoch 24200,loss 1.49727, epsilon 0.13448, rewards: ( e-greedy 3.16327, greedy 4.49352)
# rec 1.316 reg 0.181
# epoch 24300,loss 1.47655, epsilon 0.13363, rewards: ( e-greedy 3.09294, greedy 4.46317)
# rec 1.296 reg 0.181
# epoch 24400,loss 1.58415, epsilon 0.13280, rewards: ( e-greedy 3.12065, greedy 4.47186)
# rec 1.404 reg 0.181
# epoch 24500,loss 1.34628, epsilon 0.13198, rewards: ( e-greedy 3.08058, greedy 4.44767)
# rec 1.166 reg 0.180
# epoch 24600,loss 1.66171, epsilon 0.13116, rewards: ( e-greedy 3.03852, greedy 4.39090)
# rec 1.482 reg 0.180
# epoch 24700,loss 1.54651, epsilon 0.13036, rewards: ( e-greedy 2.97567, greedy 4.29381)
# rec 1.367 reg 0.180
# epoch 24800,loss 1.57884, epsilon 0.12956, rewards: ( e-greedy 3.04311, greedy 4.32543)
# rec 1.399 reg 0.179
# epoch 24900,loss 1.65911, epsilon 0.12876, rewards: ( e-greedy 3.13479, greedy 4.37689)
# rec 1.480 reg 0.179
# epoch 25000,loss 1.48600, epsilon 0.12798, rewards: ( e-greedy 3.11832, greedy 4.37120)
# rec 1.307 reg 0.179
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 3.37638425827) -> 1.0(ref = 4.19335746765) |  last_activity:still_active(qv = 3.36142897606) -> 1.0(ref = 4.14748477936) |  decades_active:2010(qv = 3.16173291206) -> 1.0(ref = 3.3131415844) |  decades_active:2000(qv = 2.46254277229) -> 1.0(ref = 2.4348859787) |  decades_active:1980(qv = 1.51040625572) -> -1.0(ref = 0.976586937904) |  Labels:is_known(qv = 1.35546457767) -> 1.0(ref = 2.08061790466) |  Birth name:is_known(qv = 0.650164425373) -> 1.0(ref = 1.13749265671) |  Instruments:organ(qv = -0.814989686012) -> -1.0(ref = -1.47500002384) |  Birth name:is_known(qv = -0.0116333141923) -> -0.5(ref = -0.5) |  end_session_now(qv = -0.0159592740238) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 3.37638425827) -> 1.0(ref = 4.19335746765) |  last_activity:still_active(qv = 3.36142897606) -> -1.0(ref = 1.55066418648) |  decades_active:2010(qv = 2.53152036667) -> -1.0(ref = 2.68490958214) |  category:List_of_deaths_in_rock_and_roll(qv = 2.35502958298) -> 3.0(ref = 3.87885212898) |  decades_active:2000(qv = 0.925107479095) -> 1.0(ref = 1.05085754395) |  Labels:is_known(qv = 0.882954597473) -> 1.0(ref = 0.0535342693329) |  Birth name:is_known(qv = 0.591241419315) -> -1.0(ref = -0.996279716492) |  end_session_now(qv = 0.00391606148332) -> 0.0(ref = 0.0) |
#
# session # 2
#  decades_active:1990(qv = 3.37638473511) -> 1.0(ref = 4.19335746765) |  last_activity:still_active(qv = 3.36142921448) -> 1.0(ref = 4.14748477936) |  decades_active:2010(qv = 3.1617333889) -> 1.0(ref = 3.3131415844) |  decades_active:2000(qv = 2.46254301071) -> 1.0(ref = 2.4348859787) |  decades_active:1980(qv = 1.51040637493) -> 1.0(ref = -0.83059322834) |  Labels:is_known(qv = 1.32184350491) -> -1.0(ref = -1.92694020271) |  Birth name:is_known(qv = 0.731424152851) -> -1.0(ref = -0.975726544857) |  Labels:is_known(qv = 0.0255510285497) -> -0.5(ref = -0.975000023842) |  Birth name:is_known(qv = 0.026533447206) -> -0.5(ref = -0.5) |  end_session_now(qv = 0.000815904699266) -> 0.0(ref = 0.0) | reached max session length
# epoch 25100,loss 1.36511, epsilon 0.12720, rewards: ( e-greedy 3.12848, greedy 4.40308)
# rec 1.186 reg 0.179
# epoch 25200,loss 1.28635, epsilon 0.12644, rewards: ( e-greedy 3.14864, greedy 4.43977)
# rec 1.108 reg 0.178
# epoch 25300,loss 1.41294, epsilon 0.12568, rewards: ( e-greedy 3.11377, greedy 4.42779)
# rec 1.235 reg 0.178
# epoch 25400,loss 1.49261, epsilon 0.12492, rewards: ( e-greedy 3.17639, greedy 4.48501)
# rec 1.315 reg 0.178
# epoch 25500,loss 1.44417, epsilon 0.12418, rewards: ( e-greedy 3.20276, greedy 4.54851)
# rec 1.267 reg 0.178
# epoch 25600,loss 1.45687, epsilon 0.12344, rewards: ( e-greedy 3.24648, greedy 4.62466)
# rec 1.279 reg 0.177
# epoch 25700,loss 1.48740, epsilon 0.12271, rewards: ( e-greedy 3.22683, greedy 4.61920)
# rec 1.310 reg 0.177
# epoch 25800,loss 1.37949, epsilon 0.12199, rewards: ( e-greedy 3.26915, greedy 4.66728)
# rec 1.203 reg 0.177
# epoch 25900,loss 1.67042, epsilon 0.12127, rewards: ( e-greedy 3.31023, greedy 4.68655)
# rec 1.494 reg 0.177
# epoch 26000,loss 1.52819, epsilon 0.12056, rewards: ( e-greedy 3.31621, greedy 4.70889)
# rec 1.352 reg 0.176
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 3.32749319077) -> -1.0(ref = 0.905128836632) |  Website:is_known(qv = 2.00539875031) -> -1.0(ref = -0.731148302555) |  Occupation:musician(qv = 0.785576820374) -> 1.0(ref = 0.28300178051) |  Instruments:trumpet(qv = -0.120034322143) -> -1.0(ref = -0.754734992981) |  category:List_of_drummers(qv = 0.258173704147) -> -1.0(ref = 0.877057313919) |  Labels:is_known(qv = 0.413795381784) -> 1.0(ref = 1.97584986687) |  Occupation:songwriter(qv = 0.0781989097595) -> 1.0(ref = 1.02721047401) |  Birth name:is_known(qv = 0.028642591089) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.0043643116951) -> 0.0(ref = 0.0) |
#
# session # 1
#  decades_active:1990(qv = 3.32749319077) -> -1.0(ref = 0.905128836632) |  last_activity:1992(qv = 1.1360168457) -> -1.0(ref = 3.12525510788) |  Occupation:musician(qv = 1.53211963177) -> 1.0(ref = 4.34237384796) |  decades_active:2010(qv = 2.34690070152) -> 1.0(ref = 3.51828861237) |  last_activity:still_active(qv = 2.65083026886) -> 1.0(ref = 1.4663528204) |  decades_active:2000(qv = 2.08762001991) -> 1.0(ref = 0.490897715092) |  Labels:is_known(qv = 1.20467424393) -> -1.0(ref = -0.535897135735) |  Occupation:voice(qv = -0.869226932526) -> -1.0(ref = -1.95000004768) |  Occupation:dancer(qv = -1.06645715237) -> -1.0(ref = -1.0) |  category:List_of_Indian_film_music_directors(qv = -0.585999548435) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:1990(qv = 3.32749319077) -> 1.0(ref = 4.19333934784) |  last_activity:still_active(qv = 3.36141014099) -> -1.0(ref = 2.59384942055) |  decades_active:2010(qv = 2.51238155365) -> 1.0(ref = 3.78299951553) |  decades_active:2000(qv = 2.79866719246) -> 1.0(ref = 2.9294731617) |  Genres:post-punk(qv = -0.042334202677) -> -1.0(ref = -0.502123177052) |  category:List_of_deaths_in_rock_and_roll(qv = 1.33296716213) -> -1.0(ref = 0.524080872536) |  Labels:is_known(qv = 1.047321558) -> 1.0(ref = 1.60429573059) |  Genres:blues[1](qv = -0.863787055016) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.408866018057) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.0203144475818) -> 0.0(ref = 0.0) | reached max session length
# epoch 26100,loss 1.46834, epsilon 0.11986, rewards: ( e-greedy 3.32159, greedy 4.69400)
# rec 1.292 reg 0.176
# epoch 26200,loss 1.80249, epsilon 0.11916, rewards: ( e-greedy 3.27143, greedy 4.64560)
# rec 1.627 reg 0.176
# epoch 26300,loss 1.37017, epsilon 0.11847, rewards: ( e-greedy 3.32829, greedy 4.67104)
# rec 1.195 reg 0.176
# epoch 26400,loss 1.37504, epsilon 0.11779, rewards: ( e-greedy 3.38346, greedy 4.72194)
# rec 1.200 reg 0.175
# epoch 26500,loss 1.53915, epsilon 0.11712, rewards: ( e-greedy 3.39811, greedy 4.73275)
# rec 1.364 reg 0.175
# epoch 26600,loss 1.42091, epsilon 0.11645, rewards: ( e-greedy 3.38230, greedy 4.74047)
# rec 1.246 reg 0.175
# epoch 26700,loss 1.45206, epsilon 0.11579, rewards: ( e-greedy 3.42607, greedy 4.74542)
# rec 1.278 reg 0.174
# epoch 26800,loss 1.51490, epsilon 0.11513, rewards: ( e-greedy 3.42846, greedy 4.77988)
# rec 1.341 reg 0.174
# epoch 26900,loss 1.66877, epsilon 0.11449, rewards: ( e-greedy 3.36862, greedy 4.69389)
# rec 1.495 reg 0.174
# epoch 27000,loss 1.24524, epsilon 0.11385, rewards: ( e-greedy 3.39776, greedy 4.71850)
# rec 1.072 reg 0.174
# Learning curves:
# Random session examples
# session # 0
#  decades_active:1990(qv = 3.44170260429) -> 1.0(ref = 4.15636348724) |  last_activity:still_active(qv = 3.32248783112) -> 1.0(ref = 4.00322723389) |  decades_active:2010(qv = 3.10262084007) -> 1.0(ref = 3.16129183769) |  decades_active:2000(qv = 2.33765387535) -> 1.0(ref = 2.27504396439) |  decades_active:1980(qv = 1.34215140343) -> 1.0(ref = 3.12680101395) |  Labels:is_known(qv = 1.15457046032) -> 1.0(ref = 2.23873782158) |  Website:is_known(qv = 0.900924801826) -> 1.0(ref = 1.30393457413) |  Birth name:is_known(qv = 0.319931179285) -> 1.0(ref = 0.0500000119209) |  Genres:rock(qv = 0.194611564279) -> -1.0(ref = -1.0) |  end_session_now(qv = -0.00936290342361) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 3.44170260429) -> 1.0(ref = 4.15636348724) |  last_activity:still_active(qv = 3.32248783112) -> 1.0(ref = 4.00322723389) |  decades_active:2010(qv = 3.10262084007) -> 1.0(ref = 3.16129183769) |  decades_active:2000(qv = 2.33765387535) -> 1.0(ref = 2.27504396439) |  decades_active:1980(qv = 1.34215140343) -> 1.0(ref = 1.29747331142) |  Labels:is_known(qv = 1.15457046032) -> 1.0(ref = 0.313129842281) |  Website:is_known(qv = 0.900924801826) -> -1.0(ref = -0.72302120924) |  Birth name:is_known(qv = 0.291556626558) -> 1.0(ref = 1.0) |  end_session_now(qv = -0.0116622308269) -> 0.0(ref = 0.0) |
#
# session # 2
#  decades_active:1990(qv = 3.44170188904) -> 1.0(ref = 4.15636396408) |  last_activity:still_active(qv = 3.32248854637) -> -1.0(ref = 1.01390814781) |  decades_active:2010(qv = 2.54340672493) -> 1.0(ref = 2.11990332603) |  Genres:metal(qv = 0.965356826782) -> -1.0(ref = 1.178845644) |  decades_active:2000(qv = 2.2935218811) -> 1.0(ref = 1.31886351109) |  Genres:jazz(qv = 0.0139299444854) -> -1.0(ref = 0.335645794868) |  Labels:is_known(qv = 0.970369517803) -> 1.0(ref = 1.40594291687) |  category:List_of_new-age_music_artists(qv = -0.832787275314) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.337112516165) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.0033839000389) -> 0.0(ref = 0.0) | reached max session length
# epoch 27100,loss 1.43617, epsilon 0.11321, rewards: ( e-greedy 3.40198, greedy 4.77865)
# rec 1.263 reg 0.173
# epoch 27200,loss 1.29308, epsilon 0.11258, rewards: ( e-greedy 3.47878, greedy 4.82679)
# rec 1.120 reg 0.173
# epoch 27300,loss 1.46022, epsilon 0.11196, rewards: ( e-greedy 3.53090, greedy 4.89111)
# rec 1.287 reg 0.173
# epoch 27400,loss 1.59971, epsilon 0.11134, rewards: ( e-greedy 3.46181, greedy 4.79900)
# rec 1.427 reg 0.173

# %% [markdown]
# # Evaluating results

# %%
score_log.plot("final")

# %%
print "Random session examples"
env.load_random_batch(train_attrs,train_cats,10)
display_sessions(with_plots=True)
# Out:
# Random session examples
# session # 0
#  decades_active:1990(qv = 4.45578384399) -> 1.0(ref = 5.07791852951) |  last_activity:still_active(qv = 4.29254579544) -> 1.0(ref = 4.61675834656) |  decades_active:2010(qv = 3.76464653015) -> 1.0(ref = 3.80711388588) |  decades_active:2000(qv = 2.94027018547) -> 1.0(ref = 2.95485687256) |  decades_active:1980(qv = 2.0577442646) -> -1.0(ref = -0.0615994930267) |  Labels:is_known(qv = 1.90344882011) -> 1.0(ref = 0.987790048122) |  Website:is_known(qv = 1.05256450176) -> -1.0(ref = -0.0128526091576) |  Instruments:guitar(qv = 1.03910255432) -> 1.0(ref = 1.95000004768) |  Genres:rock(qv = 0.900610387325) -> 1.0(ref = 1.0) |  end_session_now(qv = -0.000360924750566) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:1990(qv = 4.45578384399) -> -1.0(ref = 2.49263358116) |  Website:is_known(qv = 3.67645645142) -> 1.0(ref = 5.07930850983) |  decades_active:2010(qv = 3.63389325142) -> 1.0(ref = 4.29400920868) |  last_activity:still_active(qv = 3.51260066032) -> 1.0(ref = 3.4673781395) |  decades_active:2000(qv = 2.59724020958) -> 1.0(ref = 1.75106477737) |  Instruments:vocals(qv = 1.79120779037) -> -1.0(ref = 0.790594577789) |  Labels:is_known(qv = 1.83768129349) -> 1.0(ref = 1.88483643532) |  Birth name:is_known(qv = 0.931406736374) -> 1.0(ref = 1.0) |  end_session_now(qv = -0.00010175537318) -> 0.0(ref = 0.0) |
# session # 2
#  decades_active:1990(qv = 4.45578336716) -> 1.0(ref = 5.07791805267) |  last_activity:still_active(qv = 4.2925453186) -> 1.0(ref = 4.61675834656) |  decades_active:2010(qv = 3.76464629173) -> 1.0(ref = 3.80711436272) |  decades_active:2000(qv = 2.94027066231) -> 1.0(ref = 2.9548573494) |  decades_active:1980(qv = 2.05774450302) -> 1.0(ref = 3.36791682243) |  Labels:is_known(qv = 1.73146045208) -> 1.0(ref = 2.49254417419) |  Website:is_known(qv = 1.32294523716) -> 1.0(ref = 1.57109904289) |  Birth name:is_known(qv = 0.601156890392) -> 1.0(ref = 1.95000004768) |  Genres:rock(qv = 0.183227926493) -> 1.0(ref = 1.0) |  end_session_now(qv = -5.00762835145e-05) -> 0.0(ref = 0.0) | reached max session length
# session # 3
#  decades_active:1990(qv = 4.45578384399) -> 1.0(ref = 5.07791852951) |  last_activity:still_active(qv = 4.29254579544) -> 1.0(ref = 4.61675834656) |  decades_active:2010(qv = 3.76464653015) -> 1.0(ref = 3.80711388588) |  decades_active:2000(qv = 2.94027018547) -> 1.0(ref = 2.95485687256) |  decades_active:1980(qv = 2.0577442646) -> 1.0(ref = 2.00970029831) |  Labels:is_known(qv = 1.73146009445) -> -1.0(ref = 1.06284236908) |  Birth name:is_known(qv = 1.43794822693) -> 1.0(ref = 2.17141294479) |  Instruments:guitar(qv = 1.23306620121) -> -1.0(ref = -1.0) |  end_session_now(qv = -8.37119296193e-05) -> 0.0(ref = 0.0) |
# session # 4
#  decades_active:1990(qv = 4.45578384399) -> 1.0(ref = 5.07791852951) |  last_activity:still_active(qv = 4.29254579544) -> 1.0(ref = 4.61675834656) |  decades_active:2010(qv = 3.76464653015) -> 1.0(ref = 3.80711388588) |  decades_active:2000(qv = 2.94027018547) -> 1.0(ref = 2.95485687256) |  decades_active:1980(qv = 2.0577442646) -> 1.0(ref = 3.36791658401) |  Labels:is_known(qv = 1.73146009445) -> 1.0(ref = 2.49254369736) |  Website:is_known(qv = 1.32294523716) -> 1.0(ref = 1.57109880447) |  Birth name:is_known(qv = 0.601156592369) -> 1.0(ref = 1.95000004768) |  Genres:rock(qv = 0.1832280159) -> 1.0(ref = 1.0) |  end_session_now(qv = -5.00762835145e-05) -> 0.0(ref = 0.0) | reached max session length
# session # 5
#  decades_active:1990(qv = 4.45578384399) -> 1.0(ref = 5.07791852951) |  last_activity:still_active(qv = 4.29254579544) -> -1.0(ref = 0.0257387161255) |  decades_active:2010(qv = 4.49997711182) -> -1.0(ref = 1.07972502708) |  category:List_of_deaths_in_rock_and_roll(qv = 4.55495357513) -> -1.0(ref = 2.18918418884) |  Birth name:is_known(qv = 3.35703611374) -> 1.0(ref = 2.58044242859) |  Labels:is_known(qv = 2.49399876595) -> -1.0(ref = 1.66362380981) |  Occupation:songwriter(qv = 2.73287820816) -> 1.0(ref = 2.80381464958) |  decades_active:1970(qv = 1.89875233173) -> 1.0(ref = 1.95000004768) |  decades_active:1980(qv = 0.976219117641) -> 1.0(ref = 1.0) |  end_session_now(qv = -3.40864062309e-05) -> 0.0(ref = 0.0) | reached max session length
# session # 6
#  decades_active:1990(qv = 4.45578384399) -> 1.0(ref = 5.07791852951) |  last_activity:still_active(qv = 4.29254579544) -> 1.0(ref = 4.61675834656) |  decades_active:2010(qv = 3.76464653015) -> 1.0(ref = 3.80711388588) |  decades_active:2000(qv = 2.94027018547) -> 1.0(ref = 2.95485687256) |  decades_active:1980(qv = 2.0577442646) -> 1.0(ref = 3.36791658401) |  Labels:is_known(qv = 1.73146009445) -> 1.0(ref = 2.49254369736) |  Website:is_known(qv = 1.32294523716) -> 1.0(ref = 1.57109880447) |  category:List_of_band_name_etymologies(qv = -0.773052453995) -> -1.0(ref = -0.0500000119209) |  Birth name:is_known(qv = 0.369494915009) -> 1.0(ref = 1.0) |  end_session_now(qv = 0.000115952454507) -> 0.0(ref = 0.0) | reached max session length
# session # 7
#  decades_active:1990(qv = 4.45578336716) -> 1.0(ref = 5.07791805267) |  last_activity:still_active(qv = 4.2925453186) -> 1.0(ref = 4.61675834656) |  decades_active:2010(qv = 3.76464629173) -> 1.0(ref = 3.80711436272) |  decades_active:2000(qv = 2.94027066231) -> 1.0(ref = 2.9548573494) |  decades_active:1980(qv = 2.05774450302) -> 1.0(ref = 3.36791682243) |  Labels:is_known(qv = 1.73146045208) -> 1.0(ref = 2.49254417419) |  Website:is_known(qv = 1.32294523716) -> 1.0(ref = 1.57109904289) |  Birth name:is_known(qv = 0.601156890392) -> -1.0(ref = -1.95000004768) |  Instruments:guitar(qv = 0.268345296383) -> -1.0(ref = -1.0) |  end_session_now(qv = -0.000134135596454) -> 0.0(ref = 0.0) | reached max session length
# session # 8
#  decades_active:1990(qv = 4.45578384399) -> -1.0(ref = 2.49263358116) |  Website:is_known(qv = 3.67645645142) -> 1.0(ref = 3.10355687141) |  decades_active:2010(qv = 3.63389325142) -> -1.0(ref = 2.21427035332) |  Instruments:piano(qv = 2.54327988625) -> 1.0(ref = 3.3834426403) |  Instruments:vocals(qv = 2.50888705254) -> 1.0(ref = 2.85271310806) |  Labels:is_known(qv = 1.57463431358) -> 1.0(ref = 1.95022416115) |  Birth name:is_known(qv = 0.805451214314) -> 1.0(ref = 1.00023591518) |  end_session_now(qv = 0.000248307362199) -> 0.0(ref = 0.0) |
# session # 9
#  decades_active:1990(qv = 4.45578384399) -> 1.0(ref = 5.07791852951) |  last_activity:still_active(qv = 4.29254579544) -> 1.0(ref = 4.61675834656) |  decades_active:2010(qv = 3.76464653015) -> 1.0(ref = 3.80711388588) |  decades_active:2000(qv = 2.94027018547) -> 1.0(ref = 2.95485687256) |  decades_active:1980(qv = 2.0577442646) -> -1.0(ref = -0.0615994930267) |  Labels:is_known(qv = 1.90344882011) -> 1.0(ref = 0.987790048122) |  Website:is_known(qv = 1.05256450176) -> -1.0(ref = -0.0128526091576) |  Instruments:guitar(qv = 1.03910255432) -> 1.0(ref = 1.95000004768) |  Genres:rock(qv = 0.900610387325) -> 1.0(ref = 1.0) |  end_session_now(qv = -0.000360924750566) -> 0.0(ref = 0.0) | reached max session length
