# %%
#experiment name and snapshot folder (used for model persistence)
experiment_setup_name = "research.rl_comparison.a3c"
snapshot_path = "/home/jheuristic/yozhik/agentnet_snapshots/"

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline


#theano imports
#the problem is too simple to be run on GPU. Seriously.
# %env THEANO_FLAGS='device=cpu'
import theano
import theano.tensor as T
floatX = theano.config.floatX

import lasagne
# Out:
# env: THEANO_FLAGS='device=cpu'

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # This tutorial builds above the basic tutorial and shows several advanced tools
# * multi-layer (and in principle, arbitrary) agent memory
# * different reinforcement learning algorithms
# * model persistence
#
# __[todo: add more]__

# %% [markdown]
# # Experiment setup
# * Here we load an experiment environment (description below)
# * Designing one from scratch is explained in later tutorials

# %%
import agentnet.experiments.wikicat as experiment
print experiment.__doc__
# Out:
# This experiment Wikipedia data sample on musicians, scraped via the scripts present in this directory.
# For each musician, we know a number of boolean features (factors) on various topics like
#  * whether or not he/she was active in 1990's, 2000's, etc.
#  * whether or not he/she plays guitar, piano, etc
#  * whether or not he/she was born in 50's, 60's, etc.
#  * what wikipedia categories does he/she belong to
#  etc.
#
#
#
# In the initial moment of time, agent knows nothing about any of them.
# At each turn, agent may decide to
#  - "open" one of the hidden factors.
#    - if the factor turns out to be 1, agent receives +3 reward for Wikipedia categories, +1 for other categories,
#    - Otherwise, the reward equals -1 for Wikipedia categories, -1 for other categores
#    - all these rewards are parameterisable during environment creation
#  - decide to quit session
#    - yields reward of 0 and ends the interaction.
#    - all farther actions will have no effect until next session
#
# It is expected, that in order to maximize it's expected reward, the agent
# will converge to a strategy of polling several key features and then utilizing learned
# dependencies between these factors and other ones. For example, if a particular genre was
# popular during particular decays, it makes sense to poll genres and than "open" the corresponding
# most probable years.
#
# The experiment setup contains a single class WikicatEnvironment that
# implements both BaseEnvironment and BaseObjective.

# %%
#Create an environment with all default parameters
env = experiment.WikicatEnvironment()

# %%
from sklearn.cross_validation import train_test_split
attrs, categories, feature_names = env.get_dataset()

train_attrs,test_attrs,train_cats,test_cats = train_test_split(attrs,categories,test_size=0.99,random_state=32)

print "train size:", train_attrs.shape,train_cats.shape
print "train size:", test_attrs.shape,test_cats.shape

print "features:",feature_names[::20]
# Out:
# train size: (85, 300) (85, 93)
# train size: (8509, 300) (8509, 93)
# features: ['Children:is_known', 'Instruments:vocals', 'Genres:electronic', 'Origin:scotland', 'Genres:jazz', 'Genres:electric', 'Occupation:bassist', 'Instruments:violin', 'Genres:instrumental', 'Occupation:entrepreneur', 'Instruments:mandolin', 'Instruments:vocalist', 'Genres:synthpop', 'decades_active:1990', 'Occupation:remixer', 'category:List_of_musical_artists_from_Japan', 'category:List_of_ambient_music_artists', 'category:List_of_crooners', 'category:List_of_country_music_performers', 'category:List_of_bass_guitarists']

# %%
env.load_random_batch(train_attrs,train_cats,5)

# %% [markdown]
# # agent setup
# * An agent implementation has to contain three parts:
#  * Memory layer(s)
#   * in this case, we train two GRU layers [details below]
#  * Q-values evaluation layers
#   * in this case, a lasagne dense layer based on memory layer
#  * Resolver - acton picker layer
#   * in this case, the resolver has epsilon-greedy policy
#
#
# ### two-layer memory architecture
# We train two memory states:
#   * first one, based on observations,
#   * second one, based on first one;
#
# Note that here we update the second memory layer based on the CURRENT state
# of the first one. Instead, you can try to feed it with a previous state.
#
# The q-values are estimated on a concatenated state, effectively on both memory
# states together, but there is no problem with limiting q-evaluator to only one:
# just pass the correct gru layer as an incoming layer to the q-evaluator.
#
# ### Implementation:
# We concatenate both memories into 1 state to pass it through the session loop.
#
# To perform memory update, we need to slice the concatenated state back into
# two memory states.
#
# We do so by defining an input map function and passing it into agent.
#
# We than concatenate two new states back to form a new memory state.

# %%
from agentnet.resolver import ProbablisticResolver
from agentnet.memory import GRUMemoryLayer
from agentnet.agent import Agent

# %%
import lasagne
n_hid_1=128 #first GRU memory
n_hid_2=64 #second GRU memory


_observation_layer = lasagne.layers.InputLayer([None,env.observation_size],name="obs_input")

_prev_gru1_layer = lasagne.layers.InputLayer([None,n_hid_1],name="prev_gru1_state_input")
_prev_gru2_layer = lasagne.layers.InputLayer([None,n_hid_2],name="prev_gru2_state_input")

#memory
gru1 = GRUMemoryLayer(n_hid_1,
                     _observation_layer,
                     _prev_gru1_layer,
                     name="gru1")

gru2 = GRUMemoryLayer(n_hid_2,
                     gru1,        #note that it takes CURRENT gru1 output as input.
                                  #replacing that with _prev_gru1_state would imply taking previous one.
                     _prev_gru2_layer,
                     name="gru2")

concatenated_memory = lasagne.layers.concat([gru1,gru2])

#policy
n_actions = len(feature_names)



greed = theano.shared(np.float32(1),"prob_multiplier")

policy_layer = lasagne.layers.DenseLayer(concatenated_memory, #taking both memories. 
                                                        #Replacing with gru1 or gru2 would mean taking one
                                         num_units = n_actions,
                                         nonlinearity=lambda x: lasagne.nonlinearities.softmax(x*greed),
                                         name="policy_original")


state_value_layer = lasagne.layers.DenseLayer(concatenated_memory,
                                       num_units = 1,
                                       nonlinearity = lasagne.nonlinearities.linear,
                                       name = "Vpredicted")

#resolver


resolver = ProbablisticResolver(policy_layer,assume_normalized=True,name="resolver")



#we need to define the new input map because concatenated_memory is a ConcatLayer and does not have default one

def custom_input_map(last_hidden,observation):
    """just a function that maps memory states to respective inputs"""
    return {
        _prev_gru1_layer:last_hidden[:,0:n_hid_1],
        _prev_gru2_layer:last_hidden[:,n_hid_1:n_hid_1+n_hid_2],
        _observation_layer:observation
    }

#all together
agent = Agent(concatenated_memory,policy_layer,resolver,input_map=custom_input_map
             )

# %%
#Since it's a single lasagne network, one can get it's weights, output, etc
weights = lasagne.layers.get_all_params([resolver,state_value_layer],trainable=True)
weights
# Out:
# [gru1.W_in_to_updategate,
#  gru1.W_hid_to_updategate,
#  gru1.b_updategate,
#  gru1.W_in_to_resetgate,
#  gru1.W_hid_to_resetgate,
#  gru1.b_resetgate,
#  gru1.W_in_to_hidden_update,
#  gru1.W_hid_to_hidden_update,
#  gru1.b_hidden_update,
#  gru2.W_in_to_updategate,
#  gru2.W_hid_to_updategate,
#  gru2.b_updategate,
#  gru2.W_in_to_resetgate,
#  gru2.W_hid_to_resetgate,
#  gru2.b_resetgate,
#  gru2.W_in_to_hidden_update,
#  gru2.W_hid_to_hidden_update,
#  gru2.b_hidden_update,
#  policy_original.W,
#  policy_original.b,
#  Vpredicted.W,
#  Vpredicted.b]

# %% [markdown]
# ## Agent setup in detail
# * __Memory layers__
#  * One-step recurrent layer
#      * takes input and one's previous state
#      * returns new memory state
#    * Can be arbitrary lasagne layer
#    * Several one-step recurrent units are implemented in __agentnet.memory__
#    * Note that lasagne's default recurrent networks roll for several steps at once
#      * in other words, __using lasagne recurrent units as memory means recurrence inside recurrence__
#  * Using more than one memory layer is explained in farther tutorials
#
#
# * __Q-values evaluation layer__
#  * Can be arbitrary lasagne network
#  * returns predicted Q-values for each action
#  * Usually depends on memory as an input
#
#
# * __Resolver__ - action picker
#  * Decides on what action is taken
#  * Normally takes Q-values as input
#  * Currently all experiments require integer output
#  * Several resolver layers are implemented in __agentnet.resolver__

# %% [markdown]
# # Interacting with environment
# * an agent has a method that produces symbolic environment interaction sessions
# * interactions result in sequences of observations, actions, q-values,etc
# * one has to pre-define maximum session length.
#  * in this case, environment implements an indicator of whether session has ended by current tick
# * Since this environment also implements Objective methods, it can evaluate rewards for each [batch, time_tick]

# %%
#produce interaction sequences of length <= 25
history = agent.get_sessions(env,session_length=25,
                             batch_size=env.batch_size,
                             additional_output_layers = [state_value_layer],
                             )

state_seq,observation_seq,hidden_seq,policy_seq,action_seq,V_seq = history


V_seq = V_seq[:,:,0] #drop n_units dimension since we have 1 neuron only

#get rewards for all actions
rewards_seq = env.get_reward_sequences(state_seq,action_seq)

#get indicator whether session is still active
is_alive_seq = env.get_whether_alive(observation_seq)

# %%
#Let us compile a function that returns all interaction logs
get_history = theano.function([],history+(is_alive_seq,rewards_seq,),mode=theano.compile.mode.FAST_RUN)

# %% [markdown]
# # Evaluating loss function
# * This part is similar to the basic tutorial but for the fact that we use SARSA

# %% [markdown]
# #### Define loss functions

# %%
#get reference Qvalues according to Qlearning algorithm


from agentnet.learning import a2c_n_step as actor_critic


#gamma - delayed reward coefficient - what fraction of reward is retained if it is obtained one tick later
gamma = theano.shared(np.float32(0.95),name = 'q_learning_gamma')


elwise_loss = actor_critic.get_elementwise_objective(policy_seq,V_seq,action_seq,rewards_seq,
                                                    is_alive=is_alive_seq,
                                                    gamma_or_gammas=gamma,n_steps = 1)

# %%
policy_loss  = elwise_loss.sum() / is_alive_seq.sum()

# %%
from agentnet.utils.mdp import get_action_Qvalues
action_probas = get_action_Qvalues(policy_seq,action_seq)

# %%
#regularize network weights

from lasagne.regularization import regularize_network_params, regularize_layer_params, l2
reg_l2 = (regularize_network_params(resolver,l2) +\
          regularize_layer_params(state_value_layer,l2)
         ) *1e-4

# %%
# - H(p(s,theta)). 

entropy_elwise = - T.sum(policy_seq * T.log(policy_seq),axis=-1)
entropy_reg_elwise = T.maximum(T.log(action_probas),-1e3) * entropy_elwise 

reg_entropy =  T.sum(entropy_reg_elwise*is_alive_seq)/ is_alive_seq.sum() * 0.05

# %%
loss = policy_loss + reg_l2 + reg_entropy

# %% [markdown]
# #### Compute weight updates

# %%
updates = lasagne.updates.adadelta(loss,
                                             weights,learning_rate=0.05)

# %% [markdown]
# #### Some auxilary evaluation metrics

# %%
mean_session_reward = rewards_seq.sum(axis=1).mean()
#...

# %% [markdown]
# # Compile train and evaluation functions

# %%
train_fun = theano.function([],[loss,mean_session_reward],updates=updates)

evaluation_fun = theano.function([],[loss,policy_loss,reg_l2,reg_entropy,mean_session_reward])

# %% [markdown]
# # session visualization tools
#
#
# * this is a completely optional step of visualizing agent's sessions as chains of actions
# * usually useful to get insight on what worked and what din't
# * in this case, we print strings following pattern
#   * [action_name] ([predicted action qvalue]) -> reward [reference qvalue] | next iteration
#
# * plot shows
#     * time ticks over X, abstract values over Y
#     * bold lines are Qvalues for actions
#     * dots on bold lines represent what actions were taken at each moment of time
#     * dashed lines are agent's hidden state neurons
#     * blue vertical line - session end
#
#
# __Warning! the visualization tools are underdeveloped and only allow simple operations.__
#
# if you found yourself struggling to make it do what you want for 5 minutes, go write your own tool [and contribute it :)]

# %%
from agentnet.display.sessions import print_sessions
get_printables = theano.function([], [
        hidden_seq,policy_seq, action_seq,rewards_seq,policy_seq,is_alive_seq
    ])

def display_sessions(with_plots = False):
        
    hidden_log,qvalues_log,actions_log,reward_log, reference_prob_log, is_alive_log = get_printables()
    
    
    print_sessions(qvalues_log,actions_log,reward_log,
                   is_alive_seq = is_alive_log,
                   #hidden_seq=hidden_log, #do not plot hidden since there's too many actions already
                   reference_policy_seq = reference_prob_log,
                   action_names=feature_names,
                   legend = False, #do not show legend since there's too many labeled objects
                  plot_policy = with_plots)

# %%
#visualize untrained network performance (which is mostly random)
env.load_random_batch(train_attrs,train_cats,1)
display_sessions(with_plots=True)
# Out:
# session # 0
#  Genres:wave(qv = 0.00253807101399) -> -1.0(ref = 0.00253807101399) |  Genres:traditional(qv = 0.00250831875019) -> -1.0(ref = 0.00250831875019) |  Occupation:educator(qv = 0.00256112404168) -> -1.0(ref = 0.00256112404168) |  Genres:adult(qv = 0.00246178777888) -> -1.0(ref = 0.00246178777888) |  Genres:world(qv = 0.00242409319617) -> -1.0(ref = 0.00242409319617) |  Occupation:bassist(qv = 0.00274536223151) -> -1.0(ref = 0.00274536223151) |  Genres:electric(qv = 0.00256824330427) -> -1.0(ref = 0.00256824330427) |  Origin:korea(qv = 0.0023842563387) -> -1.0(ref = 0.0023842563387) |  category:List_of_Iranian_musicians(qv = 0.00260439445265) -> -1.0(ref = 0.00260439445265) |  Genres:soul(qv = 0.00236508063972) -> -1.0(ref = 0.00236508063972) |  Genres:symphonic(qv = 0.00252419826575) -> -1.0(ref = 0.00252419826575) |  category:List_of_jazz_drummers(qv = 0.00275116972625) -> -1.0(ref = 0.00275116972625) |  Genres:rap(qv = 0.00241543003358) -> -1.0(ref = 0.00241543003358) |  category:List_of_video_game_musicians(qv = 0.00264639896341) -> -1.0(ref = 0.00264639896341) |  category:List_of_bass_guitarists(qv = 0.00268858158961) -> -1.0(ref = 0.00268858158961) |  Genres:instrumental(qv = 0.00261539453641) -> -1.0(ref = 0.00261539453641) |  Occupation:personality(qv = 0.00268955971114) -> -1.0(ref = 0.00268955971114) |  Genres:adult(qv = 0.0024186365772) -> -0.5(ref = 0.0024186365772) |  Genres:alternative(qv = 0.00260953302495) -> -1.0(ref = 0.00260953302495) |  Genres:country(qv = 0.00267291720957) -> -1.0(ref = 0.00267291720957) |  first_activity:1989(qv = 0.00245634978637) -> -1.0(ref = 0.00245634978637) |  Origin:germany(qv = 0.00246421340853) -> -1.0(ref = 0.00246421340853) |  Occupation:host(qv = 0.00260612508282) -> -1.0(ref = 0.00260612508282) |  Genres:bebop(qv = 0.00258804671466) -> -1.0(ref = 0.00258804671466) |  Genres:disco(qv = 0.0026813717559) -> 0.0(ref = 0.0026813717559) | reached max session length

# %% [markdown]
# # Training loop

# %%
#tools for model persistence
from agentnet.utils.persistence import save,load
import os

# %%
from agentnet.display import Metrics
score_log = Metrics()

# %%
#starting epoch
epoch_counter = 1

#moving average estimation
alpha = 0.1
ma_reward_current = -7.
ma_reward_greedy = -7.

# %%
n_epochs = 250000
batch_size= 50

for i in range(n_epochs):    
    
    #train
    env.load_random_batch(train_attrs,train_cats,batch_size)
    

    loss,avg_reward = train_fun()
    
    
    
    #update resolver's greed
    if epoch_counter%10 ==0:
        current_greed =  0.05 + 0.95*( np.exp(epoch_counter/(epoch_counter+5000.))/np.e)
        greed.set_value(np.float32(current_greed))
    
    
    
    ##record current learning progress and show learning curves
    if epoch_counter%100 ==0:

        ##update learning curves
        full_loss, q_loss, l2_penalty,entropy_penalty, avg_reward_current = evaluation_fun()
        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current
        score_log["expected e-greedy reward"][epoch_counter] = ma_reward_current
        
        
        
        #greedy train
        greed.set_value(np.float32(3))

        avg_reward_greedy = evaluation_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["expected reward greed=3"][epoch_counter] = ma_reward_greedy
        
        
        #back to less greedy
        greed.set_value(np.float32(current_greed))

        print "epoch %i,loss %.5f, greed %.5f, rewards: ( in_train %.5f, greedy %.5f) "%(
            epoch_counter,full_loss,current_greed,ma_reward_current,ma_reward_greedy)
        print "rec %.3f l2 %.3f ent %.3f"%(q_loss,l2_penalty,entropy_penalty)

    if epoch_counter %1000 ==0:
        print "Learning curves:"
        score_log.plot()


        print "Random session examples"
        env.load_random_batch(train_attrs,train_cats,3)
        display_sessions(with_plots=False)
    
    #save snapshot
    if epoch_counter %10000 ==0:
        snap_name = "{}.epoch{}.pcl".format(os.path.join(snapshot_path,experiment_setup_name), epoch_counter)
        save(resolver,snap_name)
        print "saved", snap_name

        
        
    epoch_counter  +=1

    
# Time to drink some coffee!
# Out:
# epoch 100,loss -1.58000, greed 0.40641, rewards: ( in_train -8.36200, greedy -8.17400)
# rec -0.074 l2 0.266 ent -1.772
# epoch 200,loss -0.05876, greed 0.41319, rewards: ( in_train -9.26980, greedy -7.50660)
# rec 1.435 l2 0.269 ent -1.762
# epoch 300,loss -0.65944, greed 0.41984, rewards: ( in_train -8.61282, greedy -6.76594)
# rec 0.346 l2 0.269 ent -1.275
# epoch 400,loss -1.09521, greed 0.42636, rewards: ( in_train -7.96954, greedy -6.08735)
# rec -0.173 l2 0.269 ent -1.191
# epoch 500,loss -1.43630, greed 0.43275, rewards: ( in_train -7.39058, greedy -5.47861)
# rec -0.527 l2 0.268 ent -1.178
# epoch 600,loss -0.64328, greed 0.43901, rewards: ( in_train -6.82353, greedy -4.93075)
# rec 0.253 l2 0.268 ent -1.164
# epoch 700,loss -1.49377, greed 0.44515, rewards: ( in_train -6.34717, greedy -4.43768)
# rec -0.609 l2 0.267 ent -1.152
# epoch 800,loss -1.35803, greed 0.45117, rewards: ( in_train -5.90546, greedy -3.99391)
# rec -0.493 l2 0.267 ent -1.132
# epoch 900,loss -1.11754, greed 0.45708, rewards: ( in_train -5.48491, greedy -3.59452)
# rec -0.255 l2 0.266 ent -1.129
# epoch 1000,loss -1.34554, greed 0.46287, rewards: ( in_train -5.10842, greedy -3.23507)
# rec -0.517 l2 0.266 ent -1.094
# Learning curves:
# Random session examples
# session # 0
#  Occupation:writer(qv = 0.00250055454671) -> -1.0(ref = 0.00250055454671) |  category:List_of_guitarists(qv = 0.00185237673577) -> 3.0(ref = 0.00185237673577) |  end_session_now(qv = 0.76837605238) -> 0.0(ref = 0.76837605238) |
#
# session # 1
#  Origin:california(qv = 0.00247857742943) -> -1.0(ref = 0.00247857742943) |  category:List_of_hip_hop_musicians_from_New_York_City(qv = 0.00160922110081) -> -1.0(ref = 0.00160922110081) |  category:List_of_flautists(qv = 0.000661055266391) -> -1.0(ref = 0.000661055266391) |  end_session_now(qv = 0.936247467995) -> 0.0(ref = 0.936247467995) |
#
# session # 2
#  Genres:post-punk(qv = 0.00256567890756) -> -1.0(ref = 0.00256567890756) |  decades_active:1980(qv = 0.00301434728317) -> 1.0(ref = 0.00301434728317) |  Instruments:singing(qv = 0.000591941759922) -> -1.0(ref = 0.000591941759922) |  end_session_now(qv = 0.939767956734) -> 0.0(ref = 0.939767956734) |
#
# epoch 1100,loss -1.06962, greed 0.46855, rewards: ( in_train -4.75958, greedy -2.91156)
# rec -0.243 l2 0.265 ent -1.092
# epoch 1200,loss -1.19305, greed 0.47412, rewards: ( in_train -4.44862, greedy -2.62040)
# rec -0.367 l2 0.265 ent -1.091
# epoch 1300,loss -1.13439, greed 0.47958, rewards: ( in_train -4.15776, greedy -2.35836)
# rec -0.316 l2 0.264 ent -1.082
# epoch 1400,loss -0.81963, greed 0.48494, rewards: ( in_train -3.88798, greedy -2.12253)
# rec -0.013 l2 0.264 ent -1.070
# epoch 1500,loss -0.84522, greed 0.49020, rewards: ( in_train -3.64118, greedy -1.91227)
# rec -0.057 l2 0.263 ent -1.051
# epoch 1600,loss -0.03418, greed 0.49536, rewards: ( in_train -3.38107, greedy -1.70705)
# rec 0.782 l2 0.263 ent -1.079
# epoch 1700,loss -1.14326, greed 0.50043, rewards: ( in_train -3.20396, greedy -1.53634)
# rec -0.504 l2 0.262 ent -0.902
# epoch 1800,loss -0.42536, greed 0.50540, rewards: ( in_train -2.99456, greedy -1.38971)
# rec 0.161 l2 0.262 ent -0.848
# epoch 1900,loss -0.46655, greed 0.51028, rewards: ( in_train -2.77211, greedy -1.25874)
# rec 0.102 l2 0.262 ent -0.830
# epoch 2000,loss -0.27287, greed 0.51506, rewards: ( in_train -2.55190, greedy -1.06986)
# rec 0.142 l2 0.261 ent -0.677
# Learning curves:
# Random session examples
# session # 0
#  Birth name:is_known(qv = 0.0119106313214) -> 1.0(ref = 0.0119106313214) |  decades_active:1990(qv = 0.0855388641357) -> 1.0(ref = 0.0855388641357) |  Labels:is_known(qv = 0.169959634542) -> 1.0(ref = 0.169959634542) |  decades_active:2000(qv = 0.0388221777976) -> 1.0(ref = 0.0388221777976) |  Website:is_known(qv = 0.0331063270569) -> 1.0(ref = 0.0331063270569) |  end_session_now(qv = 0.356463104486) -> 0.0(ref = 0.356463104486) |
#
# session # 1
#  category:List_of_jazz_bassists(qv = 0.0022128932178) -> -1.0(ref = 0.0022128932178) |  Other names:is_known(qv = 0.00116757396609) -> -1.0(ref = 0.00116757396609) |  decades_active:2010(qv = 0.195408403873) -> -1.0(ref = 0.195408403873) |  Labels:is_known(qv = 0.18355794251) -> 1.0(ref = 0.18355794251) |  Labels:is_known(qv = 0.177282899618) -> -0.5(ref = 0.177282899618) |  end_session_now(qv = 0.360432416201) -> 0.0(ref = 0.360432416201) |
#
# session # 2
#  category:List_of_soft_rock_artists_and_songs(qv = 0.0027281048242) -> -1.0(ref = 0.0027281048242) |  category:List_of_hip_hop_musicians(qv = 0.00156887248158) -> -1.0(ref = 0.00156887248158) |  category:List_of_soft_rock_artists_and_songs(qv = 0.000773191568442) -> -0.5(ref = 0.000773191568442) |  Labels:is_known(qv = 0.180271223187) -> 1.0(ref = 0.180271223187) |  end_session_now(qv = 0.304497033358) -> 0.0(ref = 0.304497033358) |
#
# epoch 2100,loss 0.12027, greed 0.51977, rewards: ( in_train -2.31471, greedy -0.85588)
# rec 0.551 l2 0.261 ent -0.692
# epoch 2200,loss -0.26539, greed 0.52438, rewards: ( in_train -2.13524, greedy -0.67829)
# rec 0.097 l2 0.261 ent -0.623
# epoch 2300,loss -0.32698, greed 0.52892, rewards: ( in_train -1.95371, greedy -0.54346)
# rec 0.025 l2 0.260 ent -0.612
# epoch 2400,loss -0.08760, greed 0.53337, rewards: ( in_train -1.77034, greedy -0.40511)
# rec 0.215 l2 0.260 ent -0.562
# epoch 2500,loss 0.13146, greed 0.53775, rewards: ( in_train -1.55931, greedy -0.26160)
# rec 0.390 l2 0.259 ent -0.518
# epoch 2600,loss -0.17296, greed 0.54204, rewards: ( in_train -1.40538, greedy -0.10044)
# rec 0.065 l2 0.259 ent -0.497
# epoch 2700,loss 0.41351, greed 0.54627, rewards: ( in_train -1.18484, greedy 0.01260)
# rec 0.602 l2 0.259 ent -0.448
# epoch 2800,loss 0.27621, greed 0.55041, rewards: ( in_train -1.00335, greedy 0.10634)
# rec 0.464 l2 0.258 ent -0.446
# epoch 2900,loss 0.04166, greed 0.55449, rewards: ( in_train -0.88102, greedy 0.20171)
# rec 0.210 l2 0.258 ent -0.426
# epoch 3000,loss 0.58885, greed 0.55850, rewards: ( in_train -0.66292, greedy 0.34354)
# rec 0.725 l2 0.258 ent -0.394
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 0.0487529411912) -> 1.0(ref = 0.0487529411912) |  Birth name:is_known(qv = 0.111977271736) -> 1.0(ref = 0.111977271736) |  Birth name:is_known(qv = 0.11976057291) -> -0.5(ref = 0.11976057291) |  last_activity:still_active(qv = 0.134162187576) -> 1.0(ref = 0.134162187576) |  Birth name:is_known(qv = 0.112923517823) -> -0.5(ref = 0.112923517823) |  end_session_now(qv = 0.257990032434) -> 0.0(ref = 0.257990032434) |
#
# session # 1
#  category:List_of_video_game_musicians(qv = 0.00181052298285) -> -1.0(ref = 0.00181052298285) |  category:List_of_Dutch_musicians(qv = 0.000220877234824) -> -1.0(ref = 0.000220877234824) |  decades_active:1990(qv = 0.131197616458) -> 1.0(ref = 0.131197616458) |  last_activity:still_active(qv = 0.132290989161) -> 1.0(ref = 0.132290989161) |  Labels:is_known(qv = 0.12594050169) -> 1.0(ref = 0.12594050169) |  Labels:is_known(qv = 0.108687244356) -> -0.5(ref = 0.108687244356) |  decades_active:2000(qv = 0.0818824395537) -> 1.0(ref = 0.0818824395537) |  Labels:is_known(qv = 0.0906134843826) -> -0.5(ref = 0.0906134843826) |  decades_active:1990(qv = 0.0886414796114) -> -0.5(ref = 0.0886414796114) |  end_session_now(qv = 0.449889421463) -> 0.0(ref = 0.449889421463) |
#
# session # 2
#  first_activity:1974(qv = 0.00180432596244) -> -1.0(ref = 0.00180432596244) |  decades_active:2010(qv = 0.20112901926) -> -1.0(ref = 0.20112901926) |  decades_active:2010(qv = 0.169422462583) -> -0.5(ref = 0.169422462583) |  decades_active:2010(qv = 0.123855181038) -> -0.5(ref = 0.123855181038) |  Website:is_known(qv = 0.08297162503) -> -1.0(ref = 0.08297162503) |  end_session_now(qv = 0.267296642065) -> 0.0(ref = 0.267296642065) |
#
# epoch 3100,loss 0.13982, greed 0.56244, rewards: ( in_train -0.56663, greedy 0.38818)
# rec 0.297 l2 0.257 ent -0.414
# epoch 3200,loss 0.37849, greed 0.56631, rewards: ( in_train -0.45896, greedy 0.44536)
# rec 0.514 l2 0.257 ent -0.393
# epoch 3300,loss 0.28984, greed 0.57012, rewards: ( in_train -0.37307, greedy 0.47983)
# rec 0.419 l2 0.257 ent -0.386
# epoch 3400,loss 0.30759, greed 0.57386, rewards: ( in_train -0.22176, greedy 0.61985)
# rec 0.423 l2 0.256 ent -0.372
# epoch 3500,loss 0.40609, greed 0.57754, rewards: ( in_train -0.07758, greedy 0.71886)
# rec 0.507 l2 0.256 ent -0.356
# epoch 3600,loss 0.40722, greed 0.58116, rewards: ( in_train 0.02117, greedy 0.80297)
# rec 0.473 l2 0.255 ent -0.322
# epoch 3700,loss 0.24872, greed 0.58472, rewards: ( in_train 0.06606, greedy 0.83168)
# rec 0.338 l2 0.255 ent -0.345
# epoch 3800,loss 0.50054, greed 0.58823, rewards: ( in_train 0.12645, greedy 0.85151)
# rec 0.559 l2 0.255 ent -0.313
# epoch 3900,loss 0.43554, greed 0.59167, rewards: ( in_train 0.22081, greedy 0.94636)
# rec 0.481 l2 0.254 ent -0.300
# epoch 4000,loss 0.22329, greed 0.59507, rewards: ( in_train 0.24873, greedy 0.97772)
# rec 0.271 l2 0.254 ent -0.302
# Learning curves:
# Random session examples
# session # 0
#  Spouse(s):is_known(qv = 0.00111007934902) -> -1.0(ref = 0.00111007934902) |  decades_active:2010(qv = 0.232639431953) -> 1.0(ref = 0.232639431953) |  decades_active:1990(qv = 0.139014661312) -> 1.0(ref = 0.139014661312) |  last_activity:still_active(qv = 0.156592920423) -> 1.0(ref = 0.156592920423) |  last_activity:still_active(qv = 0.141472920775) -> -0.5(ref = 0.141472920775) |  decades_active:2000(qv = 0.0589137226343) -> 1.0(ref = 0.0589137226343) |  end_session_now(qv = 0.510568857193) -> 0.0(ref = 0.510568857193) |
#
# session # 1
#  decades_active:2010(qv = 0.127839684486) -> 1.0(ref = 0.127839684486) |  Labels:is_known(qv = 0.143887743354) -> -1.0(ref = 0.143887743354) |  last_activity:still_active(qv = 0.126280725002) -> 1.0(ref = 0.126280725002) |  decades_active:2010(qv = 0.131317824125) -> -0.5(ref = 0.131317824125) |  last_activity:still_active(qv = 0.140875905752) -> -0.5(ref = 0.140875905752) |  decades_active:2000(qv = 0.0585056878626) -> 1.0(ref = 0.0585056878626) |  end_session_now(qv = 0.509465932846) -> 0.0(ref = 0.509465932846) |
#
# session # 2
#  decades_active:2010(qv = 0.127839699388) -> 1.0(ref = 0.127839699388) |  Occupation:actor(qv = 4.6889152145e-05) -> -1.0(ref = 4.6889152145e-05) |  decades_active:1990(qv = 0.14012517035) -> 1.0(ref = 0.14012517035) |  decades_active:2000(qv = 0.161951288581) -> 1.0(ref = 0.161951288581) |  Birth name:is_known(qv = 0.124580420554) -> -1.0(ref = 0.124580420554) |  end_session_now(qv = 0.385428398848) -> 0.0(ref = 0.385428398848) |
#
# epoch 4100,loss 0.48963, greed 0.59840, rewards: ( in_train 0.32585, greedy 1.01595)
# rec 0.513 l2 0.254 ent -0.277
# epoch 4200,loss 0.51859, greed 0.60169, rewards: ( in_train 0.38727, greedy 1.03736)
# rec 0.545 l2 0.253 ent -0.279
# epoch 4300,loss 0.61108, greed 0.60492, rewards: ( in_train 0.48254, greedy 1.09062)
# rec 0.618 l2 0.253 ent -0.260
# epoch 4400,loss 0.60754, greed 0.60810, rewards: ( in_train 0.54329, greedy 1.10856)
# rec 0.621 l2 0.252 ent -0.266
# epoch 4500,loss 0.58927, greed 0.61124, rewards: ( in_train 0.60996, greedy 1.10770)
# rec 0.581 l2 0.252 ent -0.244
# epoch 4600,loss 0.43121, greed 0.61432, rewards: ( in_train 0.65996, greedy 1.16793)
# rec 0.433 l2 0.252 ent -0.253
# epoch 4700,loss 0.38326, greed 0.61736, rewards: ( in_train 0.68597, greedy 1.24214)
# rec 0.374 l2 0.251 ent -0.243
# epoch 4800,loss 0.58369, greed 0.62035, rewards: ( in_train 0.72937, greedy 1.28892)
# rec 0.554 l2 0.251 ent -0.222
# epoch 4900,loss 0.46177, greed 0.62330, rewards: ( in_train 0.73843, greedy 1.31903)
# rec 0.442 l2 0.251 ent -0.231
# epoch 5000,loss 0.64900, greed 0.62620, rewards: ( in_train 0.82459, greedy 1.37513)
# rec 0.622 l2 0.250 ent -0.223
# Learning curves:
# Random session examples
# session # 0
#  Birth name:is_known(qv = 0.0923041626811) -> 1.0(ref = 0.0923041626811) |  decades_active:2010(qv = 0.235506117344) -> 1.0(ref = 0.235506117344) |  Labels:is_known(qv = 0.141501158476) -> -1.0(ref = 0.141501158476) |  Birth name:is_known(qv = 0.163004487753) -> -0.5(ref = 0.163004487753) |  Birth name:is_known(qv = 0.140026882291) -> -0.5(ref = 0.140026882291) |  Birth name:is_known(qv = 0.105810962617) -> -0.5(ref = 0.105810962617) |  decades_active:2000(qv = 0.0465142764151) -> 1.0(ref = 0.0465142764151) |  end_session_now(qv = 0.595418334007) -> 0.0(ref = 0.595418334007) |
#
# session # 1
#  decades_active:2010(qv = 0.188355788589) -> 1.0(ref = 0.188355788589) |  Labels:is_known(qv = 0.141654416919) -> 1.0(ref = 0.141654416919) |  decades_active:1990(qv = 0.13377790153) -> 1.0(ref = 0.13377790153) |  decades_active:2000(qv = 0.171937137842) -> 1.0(ref = 0.171937137842) |  last_activity:still_active(qv = 0.161420196295) -> 1.0(ref = 0.161420196295) |  decades_active:2010(qv = 0.07454354316) -> -0.5(ref = 0.07454354316) |  Birth name:is_known(qv = 0.0929538756609) -> 1.0(ref = 0.0929538756609) |  Website:is_known(qv = 0.0935452729464) -> 1.0(ref = 0.0935452729464) |  end_session_now(qv = 0.632988154888) -> 0.0(ref = 0.632988154888) |
#
# session # 2
#  Birth name:is_known(qv = 0.0923041328788) -> 1.0(ref = 0.0923041328788) |  decades_active:1990(qv = 0.125470459461) -> 1.0(ref = 0.125470459461) |  last_activity:still_active(qv = 0.143659412861) -> 1.0(ref = 0.143659412861) |  decades_active:1990(qv = 0.126006454229) -> -0.5(ref = 0.126006454229) |  last_activity:still_active(qv = 0.152729406953) -> -0.5(ref = 0.152729406953) |  Labels:is_known(qv = 0.0905578732491) -> 1.0(ref = 0.0905578732491) |  decades_active:1990(qv = 0.0550669543445) -> -0.5(ref = 0.0550669543445) |  end_session_now(qv = 0.58057397604) -> 0.0(ref = 0.58057397604) |
#
# epoch 5100,loss 0.46481, greed 0.62906, rewards: ( in_train 0.81013, greedy 1.38462)
# rec 0.432 l2 0.250 ent -0.217
# epoch 5200,loss 0.74922, greed 0.63188, rewards: ( in_train 0.90812, greedy 1.44715)
# rec 0.711 l2 0.250 ent -0.212
# epoch 5300,loss 0.63839, greed 0.63466, rewards: ( in_train 0.88831, greedy 1.46044)
# rec 0.587 l2 0.249 ent -0.198
# epoch 5400,loss 0.75720, greed 0.63739, rewards: ( in_train 0.94948, greedy 1.47340)
# rec 0.707 l2 0.249 ent -0.199
# epoch 5500,loss 0.69838, greed 0.64009, rewards: ( in_train 0.99453, greedy 1.49006)
# rec 0.656 l2 0.249 ent -0.206
# epoch 5600,loss 0.61629, greed 0.64274, rewards: ( in_train 1.04207, greedy 1.54305)
# rec 0.566 l2 0.248 ent -0.198
# epoch 5700,loss 0.55354, greed 0.64536, rewards: ( in_train 1.05687, greedy 1.57275)
# rec 0.511 l2 0.248 ent -0.205
# epoch 5800,loss 0.47819, greed 0.64795, rewards: ( in_train 1.08418, greedy 1.61347)
# rec 0.433 l2 0.247 ent -0.202
# epoch 5900,loss 0.79692, greed 0.65049, rewards: ( in_train 1.11776, greedy 1.66312)
# rec 0.742 l2 0.247 ent -0.192
# epoch 6000,loss 0.74265, greed 0.65300, rewards: ( in_train 1.17899, greedy 1.70381)
# rec 0.685 l2 0.247 ent -0.189
# Learning curves:
# Random session examples
# session # 0
#  Birth name:is_known(qv = 0.09316650033) -> -1.0(ref = 0.09316650033) |  decades_active:1990(qv = 0.145673379302) -> 1.0(ref = 0.145673379302) |  decades_active:1990(qv = 0.130392163992) -> -0.5(ref = 0.130392163992) |  Birth name:is_known(qv = 0.138882979751) -> -0.5(ref = 0.138882979751) |  decades_active:1990(qv = 0.105846725404) -> -0.5(ref = 0.105846725404) |  end_session_now(qv = 0.360069215298) -> 0.0(ref = 0.360069215298) |
#
# session # 1
#  decades_active:1990(qv = 0.126041218638) -> 1.0(ref = 0.126041218638) |  Labels:is_known(qv = 0.1325815171) -> 1.0(ref = 0.1325815171) |  decades_active:2010(qv = 0.214509233832) -> 1.0(ref = 0.214509233832) |  Website:is_known(qv = 0.104389682412) -> 1.0(ref = 0.104389682412) |  decades_active:2010(qv = 0.129645779729) -> -0.5(ref = 0.129645779729) |  Website:is_known(qv = 0.146699622273) -> -0.5(ref = 0.146699622273) |  decades_active:2000(qv = 0.0500039085746) -> 1.0(ref = 0.0500039085746) |  end_session_now(qv = 0.523870229721) -> 0.0(ref = 0.523870229721) |
#
# session # 2
#  Birth name:is_known(qv = 0.0931665077806) -> 1.0(ref = 0.0931665077806) |  decades_active:2010(qv = 0.253003656864) -> 1.0(ref = 0.253003656864) |  decades_active:2000(qv = 0.227956667542) -> 1.0(ref = 0.227956667542) |  decades_active:1990(qv = 0.166200205684) -> 1.0(ref = 0.166200205684) |  decades_active:2010(qv = 0.1474609375) -> -0.5(ref = 0.1474609375) |  end_session_now(qv = 0.289402186871) -> 0.0(ref = 0.289402186871) |
#
# epoch 6100,loss 0.85032, greed 0.65547, rewards: ( in_train 1.28009, greedy 1.77843)
# rec 0.800 l2 0.246 ent -0.196
# epoch 6200,loss 0.58163, greed 0.65791, rewards: ( in_train 1.25208, greedy 1.77259)
# rec 0.523 l2 0.246 ent -0.188
# epoch 6300,loss 0.82586, greed 0.66032, rewards: ( in_train 1.34587, greedy 1.81433)
# rec 0.768 l2 0.246 ent -0.188
# epoch 6400,loss 0.70834, greed 0.66269, rewards: ( in_train 1.36628, greedy 1.83190)
# rec 0.650 l2 0.245 ent -0.187
# epoch 6500,loss 0.77435, greed 0.66504, rewards: ( in_train 1.35466, greedy 1.85071)
# rec 0.706 l2 0.245 ent -0.176
# epoch 6600,loss 0.67509, greed 0.66734, rewards: ( in_train 1.41919, greedy 1.90164)
# rec 0.616 l2 0.245 ent -0.185
# epoch 6700,loss 0.82303, greed 0.66962, rewards: ( in_train 1.45327, greedy 1.96047)
# rec 0.757 l2 0.244 ent -0.178
# epoch 6800,loss 0.82184, greed 0.67187, rewards: ( in_train 1.49094, greedy 1.93142)
# rec 0.759 l2 0.244 ent -0.181
# epoch 6900,loss 0.63245, greed 0.67409, rewards: ( in_train 1.52685, greedy 1.99528)
# rec 0.572 l2 0.244 ent -0.184
# epoch 7000,loss 0.78257, greed 0.67628, rewards: ( in_train 1.52016, greedy 2.03375)
# rec 0.714 l2 0.243 ent -0.174
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 0.278746664524) -> 1.0(ref = 0.278746664524) |  Labels:is_known(qv = 0.159361258149) -> 1.0(ref = 0.159361258149) |  last_activity:still_active(qv = 0.174339711666) -> -1.0(ref = 0.174339711666) |  end_session_now(qv = 0.0677091553807) -> 0.0(ref = 0.0677091553807) |
#
# session # 1
#  decades_active:2000(qv = 0.278746664524) -> 1.0(ref = 0.278746664524) |  Labels:is_known(qv = 0.159361258149) -> 1.0(ref = 0.159361258149) |  decades_active:2010(qv = 0.241399854422) -> 1.0(ref = 0.241399854422) |  Birth name:is_known(qv = 0.181495904922) -> 1.0(ref = 0.181495904922) |  Labels:is_known(qv = 0.115048088133) -> -0.5(ref = 0.115048088133) |  decades_active:2010(qv = 0.0917468518019) -> -0.5(ref = 0.0917468518019) |  end_session_now(qv = 0.500079751015) -> 0.0(ref = 0.500079751015) |
#
# session # 2
#  decades_active:1990(qv = 0.123871460557) -> 1.0(ref = 0.123871460557) |  decades_active:2010(qv = 0.241570800543) -> 1.0(ref = 0.241570800543) |  Birth name:is_known(qv = 0.137832850218) -> 1.0(ref = 0.137832850218) |  last_activity:still_active(qv = 0.2090690732) -> 1.0(ref = 0.2090690732) |  last_activity:still_active(qv = 0.133773952723) -> -0.5(ref = 0.133773952723) |  decades_active:2010(qv = 0.0656487867236) -> -0.5(ref = 0.0656487867236) |  end_session_now(qv = 0.591298222542) -> 0.0(ref = 0.591298222542) |
#
# epoch 7100,loss 0.81980, greed 0.67844, rewards: ( in_train 1.52615, greedy 2.04838)
# rec 0.750 l2 0.243 ent -0.173
# epoch 7200,loss 0.77797, greed 0.68057, rewards: ( in_train 1.53953, greedy 2.05054)
# rec 0.700 l2 0.243 ent -0.165
# epoch 7300,loss 0.59265, greed 0.68268, rewards: ( in_train 1.55258, greedy 2.09649)
# rec 0.522 l2 0.242 ent -0.172
# epoch 7400,loss 0.84051, greed 0.68475, rewards: ( in_train 1.58332, greedy 2.11484)
# rec 0.771 l2 0.242 ent -0.172
# epoch 7500,loss 0.78543, greed 0.68680, rewards: ( in_train 1.56199, greedy 2.09035)
# rec 0.713 l2 0.242 ent -0.169
# epoch 7600,loss 0.81126, greed 0.68883, rewards: ( in_train 1.58679, greedy 2.11832)
# rec 0.735 l2 0.241 ent -0.165
# epoch 7700,loss 0.62790, greed 0.69083, rewards: ( in_train 1.57411, greedy 2.14149)
# rec 0.553 l2 0.241 ent -0.165
# epoch 7800,loss 0.54646, greed 0.69280, rewards: ( in_train 1.50570, greedy 2.09934)
# rec 0.474 l2 0.241 ent -0.168
# epoch 7900,loss 0.61453, greed 0.69475, rewards: ( in_train 1.56113, greedy 2.12640)
# rec 0.544 l2 0.240 ent -0.170
# epoch 8000,loss 0.75416, greed 0.69668, rewards: ( in_train 1.56202, greedy 2.12876)
# rec 0.678 l2 0.240 ent -0.164
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2010(qv = 0.205948516726) -> 1.0(ref = 0.205948516726) |  decades_active:2000(qv = 0.507008850574) -> 1.0(ref = 0.507008850574) |  decades_active:2010(qv = 0.135653436184) -> -0.5(ref = 0.135653436184) |  Birth name:is_known(qv = 0.197945609689) -> -1.0(ref = 0.197945609689) |  Labels:is_known(qv = 0.11566285044) -> 1.0(ref = 0.11566285044) |  end_session_now(qv = 0.519779503345) -> 0.0(ref = 0.519779503345) |
#
# session # 1
#  decades_active:2010(qv = 0.205948516726) -> 1.0(ref = 0.205948516726) |  decades_active:2010(qv = 0.0575024671853) -> -0.5(ref = 0.0575024671853) |  Website:is_known(qv = 0.0516422912478) -> -1.0(ref = 0.0516422912478) |  decades_active:2010(qv = 0.0178184136748) -> -0.5(ref = 0.0178184136748) |  Labels:is_known(qv = 0.109997160733) -> 1.0(ref = 0.109997160733) |  end_session_now(qv = 0.536347985268) -> 0.0(ref = 0.536347985268) |
#
# session # 2
#  decades_active:2000(qv = 0.34341776371) -> -1.0(ref = 0.34341776371) |  decades_active:1990(qv = 0.15644004941) -> -1.0(ref = 0.15644004941) |  last_activity:still_active(qv = 0.0911920145154) -> -1.0(ref = 0.0911920145154) |  Website:is_known(qv = 0.106295600533) -> -1.0(ref = 0.106295600533) |  end_session_now(qv = 0.709792733192) -> 0.0(ref = 0.709792733192) |
#
# epoch 8100,loss 0.73870, greed 0.69858, rewards: ( in_train 1.61982, greedy 2.14289)
# rec 0.664 l2 0.240 ent -0.165
# epoch 8200,loss 0.78461, greed 0.70046, rewards: ( in_train 1.63183, greedy 2.14460)
# rec 0.712 l2 0.239 ent -0.167
# epoch 8300,loss 0.78819, greed 0.70231, rewards: ( in_train 1.66865, greedy 2.17414)
# rec 0.718 l2 0.239 ent -0.169
# epoch 8400,loss 0.47723, greed 0.70414, rewards: ( in_train 1.65479, greedy 2.22073)
# rec 0.413 l2 0.239 ent -0.174
# epoch 8500,loss 0.55349, greed 0.70595, rewards: ( in_train 1.60031, greedy 2.22465)
# rec 0.485 l2 0.239 ent -0.170
# epoch 8600,loss 0.80891, greed 0.70774, rewards: ( in_train 1.66828, greedy 2.25919)
# rec 0.737 l2 0.238 ent -0.167
# epoch 8700,loss 0.75017, greed 0.70951, rewards: ( in_train 1.67145, greedy 2.28127)
# rec 0.671 l2 0.238 ent -0.159
# epoch 8800,loss 0.76150, greed 0.71126, rewards: ( in_train 1.72530, greedy 2.33414)
# rec 0.690 l2 0.238 ent -0.166
# epoch 8900,loss 0.64363, greed 0.71298, rewards: ( in_train 1.77977, greedy 2.39973)
# rec 0.573 l2 0.237 ent -0.166
# epoch 9000,loss 0.72650, greed 0.71469, rewards: ( in_train 1.81180, greedy 2.39675)
# rec 0.648 l2 0.237 ent -0.159
# Learning curves:
# Random session examples
# session # 0
#  last_activity:still_active(qv = 0.0490971505642) -> 1.0(ref = 0.0490971505642) |  decades_active:2000(qv = 0.45370003581) -> 1.0(ref = 0.45370003581) |  decades_active:2010(qv = 0.430191129446) -> 1.0(ref = 0.430191129446) |  decades_active:1990(qv = 0.233019545674) -> 1.0(ref = 0.233019545674) |  decades_active:1990(qv = 0.11956898123) -> -0.5(ref = 0.11956898123) |  Labels:is_known(qv = 0.109443433583) -> 1.0(ref = 0.109443433583) |  Instruments:guitar(qv = 0.103077761829) -> 1.0(ref = 0.103077761829) |  Birth name:is_known(qv = 0.0748889222741) -> -1.0(ref = 0.0748889222741) |  Labels:is_known(qv = 0.0370676852763) -> -0.5(ref = 0.0370676852763) |  end_session_now(qv = 0.79052901268) -> 0.0(ref = 0.79052901268) |
#
# session # 1
#  Instruments:guitar(qv = 0.0136625114828) -> 1.0(ref = 0.0136625114828) |  Labels:is_known(qv = 0.0980897992849) -> 1.0(ref = 0.0980897992849) |  decades_active:2000(qv = 0.326851725578) -> 1.0(ref = 0.326851725578) |  Birth name:is_known(qv = 0.0639500394464) -> -1.0(ref = 0.0639500394464) |  decades_active:2000(qv = 0.0138633335009) -> -0.5(ref = 0.0138633335009) |  decades_active:2010(qv = 0.369343370199) -> 1.0(ref = 0.369343370199) |  Labels:is_known(qv = 0.10175357759) -> -0.5(ref = 0.10175357759) |  last_activity:still_active(qv = 0.0706263929605) -> 1.0(ref = 0.0706263929605) |  end_session_now(qv = 0.702385663986) -> 0.0(ref = 0.702385663986) |
#
# session # 2
#  decades_active:1990(qv = 0.0988488346338) -> -1.0(ref = 0.0988488346338) |  last_activity:still_active(qv = 0.0480193272233) -> 1.0(ref = 0.0480193272233) |  decades_active:2000(qv = 0.270773857832) -> 1.0(ref = 0.270773857832) |  Labels:is_known(qv = 0.125788405538) -> 1.0(ref = 0.125788405538) |  Labels:is_known(qv = 0.0728577598929) -> -0.5(ref = 0.0728577598929) |  end_session_now(qv = 0.249943882227) -> 0.0(ref = 0.249943882227) |
#
# epoch 9100,loss 0.58864, greed 0.71637, rewards: ( in_train 1.86762, greedy 2.43108)
# rec 0.509 l2 0.237 ent -0.157
# epoch 9200,loss 0.86164, greed 0.71804, rewards: ( in_train 1.89085, greedy 2.44897)
# rec 0.782 l2 0.237 ent -0.157
# epoch 9300,loss 0.80250, greed 0.71969, rewards: ( in_train 1.92077, greedy 2.46507)
# rec 0.719 l2 0.236 ent -0.153
# epoch 9400,loss 0.75677, greed 0.72132, rewards: ( in_train 1.94069, greedy 2.48857)
# rec 0.671 l2 0.236 ent -0.150
# epoch 9500,loss 0.73693, greed 0.72293, rewards: ( in_train 1.97862, greedy 2.52371)
# rec 0.652 l2 0.236 ent -0.151
# epoch 9600,loss 0.75111, greed 0.72452, rewards: ( in_train 1.99776, greedy 2.55834)
# rec 0.662 l2 0.235 ent -0.146
# epoch 9700,loss 0.81030, greed 0.72609, rewards: ( in_train 2.08798, greedy 2.61651)
# rec 0.719 l2 0.235 ent -0.144
# epoch 9800,loss 0.75152, greed 0.72765, rewards: ( in_train 2.02319, greedy 2.58185)
# rec 0.656 l2 0.235 ent -0.139
# epoch 9900,loss 0.86587, greed 0.72918, rewards: ( in_train 2.06187, greedy 2.57567)
# rec 0.773 l2 0.235 ent -0.141
# epoch 10000,loss 0.71798, greed 0.73070, rewards: ( in_train 2.08568, greedy 2.62010)
# rec 0.625 l2 0.234 ent -0.142
# Learning curves:
# Random session examples
# session # 0
#  Birth name:is_known(qv = 0.0805459916592) -> 1.0(ref = 0.0805459916592) |  decades_active:2000(qv = 0.537980556488) -> -1.0(ref = 0.537980556488) |  Birth name:is_known(qv = 0.141903996468) -> -0.5(ref = 0.141903996468) |  decades_active:2010(qv = 0.415039718151) -> -1.0(ref = 0.415039718151) |  Birth name:is_known(qv = 0.195784926414) -> -0.5(ref = 0.195784926414) |  end_session_now(qv = 0.599809229374) -> 0.0(ref = 0.599809229374) |
#
# session # 1
#  Labels:is_known(qv = 0.212006747723) -> 1.0(ref = 0.212006747723) |  decades_active:2000(qv = 0.647012531757) -> 1.0(ref = 0.647012531757) |  last_activity:still_active(qv = 0.200886756182) -> 1.0(ref = 0.200886756182) |  decades_active:1990(qv = 0.0725238919258) -> 1.0(ref = 0.0725238919258) |  last_activity:still_active(qv = 0.0424193628132) -> -0.5(ref = 0.0424193628132) |  decades_active:2010(qv = 0.790900230408) -> 1.0(ref = 0.790900230408) |  decades_active:2000(qv = 0.00428849318996) -> -0.5(ref = 0.00428849318996) |  decades_active:1990(qv = 0.0760673061013) -> -0.5(ref = 0.0760673061013) |  Birth name:is_known(qv = 0.0765027180314) -> 1.0(ref = 0.0765027180314) |  end_session_now(qv = 0.787680983543) -> 0.0(ref = 0.787680983543) |
#
# session # 2
#  last_activity:still_active(qv = 0.0453545898199) -> 1.0(ref = 0.0453545898199) |  decades_active:2000(qv = 0.49108093977) -> 1.0(ref = 0.49108093977) |  decades_active:1990(qv = 0.129977613688) -> 1.0(ref = 0.129977613688) |  Birth name:is_known(qv = 0.0428623557091) -> -1.0(ref = 0.0428623557091) |  decades_active:2010(qv = 0.626087725163) -> 1.0(ref = 0.626087725163) |  end_session_now(qv = 0.258237540722) -> 0.0(ref = 0.258237540722) |
#
# saved /home/jheuristic/yozhik/agentnet_snapshots/research.rl_comparison.a3c.epoch10000.pcl
# epoch 10100,loss 0.77665, greed 0.73221, rewards: ( in_train 2.15511, greedy 2.66509)
# rec 0.681 l2 0.234 ent -0.138
# epoch 10200,loss 0.71446, greed 0.73370, rewards: ( in_train 2.21060, greedy 2.72058)
# rec 0.621 l2 0.234 ent -0.140
# epoch 10300,loss 0.85164, greed 0.73517, rewards: ( in_train 2.23254, greedy 2.70852)
# rec 0.758 l2 0.233 ent -0.140

# %% [markdown]
# # Evaluating results

# %%
score_log.plot("final")

# %%
print "Random session examples"
env.load_random_batch(train_attrs,train_cats,10)
display_sessions(with_plots=True)
# Out:
# Random session examples
# session # 0
#  decades_active:2010(qv = 0.225377634168) -> 1.0(ref = 0.225377634168) |  decades_active:1990(qv = 0.241083040833) -> 1.0(ref = 0.241083040833) |  Birth name:is_known(qv = 0.140769511461) -> 1.0(ref = 0.140769511461) |  Labels:is_known(qv = 0.571787953377) -> -1.0(ref = 0.571787953377) |  decades_active:2000(qv = 0.95791643858) -> 1.0(ref = 0.95791643858) |  Instruments:guitar(qv = 0.853216230869) -> 1.0(ref = 0.853216230869) |  last_activity:still_active(qv = 0.996760010719) -> 1.0(ref = 0.996760010719) |  end_session_now(qv = 0.998055934906) -> 0.0(ref = 0.998055934906) |
# session # 1
#  decades_active:2010(qv = 0.225377634168) -> 1.0(ref = 0.225377634168) |  Labels:is_known(qv = 0.226069152355) -> 1.0(ref = 0.226069152355) |  decades_active:1990(qv = 0.304363250732) -> -1.0(ref = 0.304363250732) |  decades_active:2000(qv = 0.263475954533) -> 1.0(ref = 0.263475954533) |  Website:is_known(qv = 0.59718734026) -> 1.0(ref = 0.59718734026) |  last_activity:still_active(qv = 0.959318816662) -> 1.0(ref = 0.959318816662) |  Birth name:is_known(qv = 0.939086318016) -> 1.0(ref = 0.939086318016) |  Instruments:guitar(qv = 0.908739507198) -> 1.0(ref = 0.908739507198) |  end_session_now(qv = 0.999401152134) -> 0.0(ref = 0.999401152134) |
# session # 2
#  Labels:is_known(qv = 0.205824702978) -> 1.0(ref = 0.205824702978) |  Birth name:is_known(qv = 0.124316982925) -> 1.0(ref = 0.124316982925) |  decades_active:2010(qv = 0.37209290266) -> 1.0(ref = 0.37209290266) |  decades_active:1990(qv = 0.305009841919) -> 1.0(ref = 0.305009841919) |  decades_active:2000(qv = 0.27751609683) -> 1.0(ref = 0.27751609683) |  last_activity:still_active(qv = 0.936467111111) -> 1.0(ref = 0.936467111111) |  Website:is_known(qv = 0.997323513031) -> 1.0(ref = 0.997323513031) |  end_session_now(qv = 0.985532879829) -> 0.0(ref = 0.985532879829) |
# session # 3
#  decades_active:2010(qv = 0.225377634168) -> 1.0(ref = 0.225377634168) |  Labels:is_known(qv = 0.226069152355) -> 1.0(ref = 0.226069152355) |  Website:is_known(qv = 0.132050782442) -> 1.0(ref = 0.132050782442) |  last_activity:still_active(qv = 0.291484832764) -> 1.0(ref = 0.291484832764) |  decades_active:1990(qv = 0.665915429592) -> 1.0(ref = 0.665915429592) |  Birth name:is_known(qv = 0.562155842781) -> 1.0(ref = 0.562155842781) |  decades_active:2000(qv = 0.989854693413) -> 1.0(ref = 0.989854693413) |  end_session_now(qv = 0.993866443634) -> 0.0(ref = 0.993866443634) |
# session # 4
#  decades_active:2000(qv = 0.292577177286) -> 1.0(ref = 0.292577177286) |  Labels:is_known(qv = 0.210974693298) -> 1.0(ref = 0.210974693298) |  decades_active:1990(qv = 0.298865318298) -> 1.0(ref = 0.298865318298) |  decades_active:2010(qv = 0.486406028271) -> 1.0(ref = 0.486406028271) |  last_activity:still_active(qv = 0.58577978611) -> 1.0(ref = 0.58577978611) |  Website:is_known(qv = 0.713852584362) -> -1.0(ref = 0.713852584362) |  Birth name:is_known(qv = 0.99715679884) -> 1.0(ref = 0.99715679884) |  end_session_now(qv = 0.940956890583) -> 0.0(ref = 0.940956890583) |
# session # 5
#  Labels:is_known(qv = 0.205824702978) -> 1.0(ref = 0.205824702978) |  decades_active:2000(qv = 0.303275674582) -> 1.0(ref = 0.303275674582) |  last_activity:still_active(qv = 0.159905642271) -> 1.0(ref = 0.159905642271) |  decades_active:2010(qv = 0.366220355034) -> 1.0(ref = 0.366220355034) |  Birth name:is_known(qv = 0.250423699617) -> 1.0(ref = 0.250423699617) |  decades_active:1990(qv = 0.822070837021) -> -1.0(ref = 0.822070837021) |  Website:is_known(qv = 0.998482942581) -> 1.0(ref = 0.998482942581) |  Instruments:guitar(qv = 0.896786034107) -> 1.0(ref = 0.896786034107) |  end_session_now(qv = 0.999864041805) -> 0.0(ref = 0.999864041805) |
# session # 6
#  Birth name:is_known(qv = 0.150619328022) -> -1.0(ref = 0.150619328022) |  decades_active:2000(qv = 0.409322470427) -> 1.0(ref = 0.409322470427) |  Labels:is_known(qv = 0.426329761744) -> 1.0(ref = 0.426329761744) |  decades_active:2010(qv = 0.470713615417) -> 1.0(ref = 0.470713615417) |  decades_active:1990(qv = 0.542914628983) -> 1.0(ref = 0.542914628983) |  last_activity:still_active(qv = 0.795881867409) -> 1.0(ref = 0.795881867409) |  Website:is_known(qv = 0.998707771301) -> -1.0(ref = 0.998707771301) |  Instruments:guitar(qv = 0.9923427701) -> 1.0(ref = 0.9923427701) |  end_session_now(qv = 0.999651432037) -> 0.0(ref = 0.999651432037) |
# session # 7
#  Birth name:is_known(qv = 0.150619328022) -> -1.0(ref = 0.150619328022) |  decades_active:2000(qv = 0.409322470427) -> 1.0(ref = 0.409322470427) |  Labels:is_known(qv = 0.426329761744) -> 1.0(ref = 0.426329761744) |  decades_active:2010(qv = 0.470713615417) -> 1.0(ref = 0.470713615417) |  decades_active:1990(qv = 0.542914628983) -> 1.0(ref = 0.542914628983) |  last_activity:still_active(qv = 0.795881867409) -> 1.0(ref = 0.795881867409) |  Website:is_known(qv = 0.998707771301) -> 1.0(ref = 0.998707771301) |  end_session_now(qv = 0.976777553558) -> 0.0(ref = 0.976777553558) |
# session # 8
#  last_activity:still_active(qv = 0.027573807165) -> 1.0(ref = 0.027573807165) |  decades_active:2000(qv = 0.161993220448) -> 1.0(ref = 0.161993220448) |  decades_active:2010(qv = 0.322302132845) -> 1.0(ref = 0.322302132845) |  Birth name:is_known(qv = 0.252203345299) -> -1.0(ref = 0.252203345299) |  decades_active:1990(qv = 0.736831903458) -> 1.0(ref = 0.736831903458) |  Labels:is_known(qv = 0.985947310925) -> -1.0(ref = 0.985947310925) |  Website:is_known(qv = 0.906930804253) -> -1.0(ref = 0.906930804253) |  end_session_now(qv = 0.942194104195) -> 0.0(ref = 0.942194104195) |
# session # 9
#  decades_active:2000(qv = 0.292577177286) -> -1.0(ref = 0.292577177286) |  Labels:is_known(qv = 0.59780818224) -> -1.0(ref = 0.59780818224) |  Birth name:is_known(qv = 0.980939686298) -> 1.0(ref = 0.980939686298) |  end_session_now(qv = 0.980345010757) -> 0.0(ref = 0.980345010757) |
