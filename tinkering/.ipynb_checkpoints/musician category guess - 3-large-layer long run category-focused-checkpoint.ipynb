# %%
experiment_setup_name = "wikicat.long_run.category_focused.100s_batch.nesterov.3layer.large"

# %%
import sys,os
sys.path.append("..")

from matplotlib import pyplot as plt
# %matplotlib inline




import pandas as pd
import numpy as np


# %env THEANO_FLAGS='device=gpu2'

import theano
import theano.tensor as T
import lasagne
# Out:
# env: THEANO_FLAGS='device=gpu2'
# Using gpu device 2: Tesla K40m (CNMeM is disabled, CuDNN 4004)
# /home/jheuristic/thenv/local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
from config import snapshot_path

floatX = theano.config.floatX

from auxilary import _shared,set_shared,_in1d
from persistence import save,load

# %%
floatX = theano.config.floatX

from auxilary import _shared,set_shared,_in1d
from persistence import save,load

# %% [markdown]
# # Эта тетрадка рассказывает нелёгком пути обучения
# * Recurrent Q-network
# * two layers of GRU memory
# * Qvalues predicted via dense layer from both memory layers
# * epsilon-greedy decision making
# * trained with Nesterov Mommentum SGD

# %% [markdown]
# # Постановка задачи
# * В начале сетке даётся некоторый человек, про которого она пока ничего не знает
# * Человек - музыкант или околомузыкальная личность (с меньшей вероятностью - группа или... страна)
# * Про человека известен некоторый набор фактов
#  * факты типа "Известно, что" - за то, что какой-то аттрибут есть в его вики-карточке
#    * например Nickname:is_known - есть прозвище, Died:is_known - есть дата смерти
#  * Категориальные факты
#    * инструменты, на которых играет человек
#    * происхождение
#    * декады активности
#    * и т.п.
#
#
# * За один шаг сетка может
#  * сказать, что какой-то аттрибут про пользователя есть
#    * например, Nickname:is_known - предположение, что у пользователя есть прозвище
#    * если догадка верна, сеть получает положительное подкрепление ("конфетку")
#    * если нет - отрицательное ("подзатыльник")
#  * сказать "больше ничего не угадаю, несите следующего"
#    * нулевое подкрепление
#    * случайно выбирается следующий пользователь

# %% [markdown]
# # данные
# * Всего в выборке 393 аттрибута
#  * примеры аттрибутов в табе ниже
# * В данном случае сеть обучается на чуть менее, чем 2500 случайных людей
# * всего в выборке почти 100к людей/групп/всякого трэша

# %%
#вгрузим данные про кучу музыкантов 
#как оно собирается - ./data/preprocessing.ipynb
import pandas as pd
df = pd.DataFrame.from_csv("../data/musicians_categorized.csv")

# %%
#гистограмма количества аттрибутов известных про музыканта
plt.hist((df.values).sum(axis=1),bins=50)
print (df.values).mean()
print df.shape
# Out:
# 0.0346481118134
# (22612, 393)

# %%
#отрежем тех, про кого известно менее 5 аттрибутов
df =  df[df.values.sum(axis=1) > 15]
print "всего самплов", df.shape
# Out:
# всего самплов (8594, 393)

# %%
from sklearn.cross_validation import train_test_split

# %%
#split categories and attributes
feature_names = df.columns
categorical_columns = np.nonzero(map(lambda s: s.startswith("category:"),feature_names))[0]
attribute_columns = np.nonzero(map(lambda s: not s.startswith("category:"),feature_names))[0]

data_cats = df.iloc[:,categorical_columns]
data_attrs = df.iloc[:,attribute_columns]

# %%
#поделим выборку
train_cats,test_cats,train_attrs,test_attrs = train_test_split(data_cats,data_attrs,test_size=0.5,random_state=42)
print "обучающая выборка:" ,len(train_attrs)
print "контрольная выборка:", len(test_attrs)
# Out:
# обучающая выборка: 4297
# контрольная выборка: 4297

# %% [markdown]
# # problem definition
#
# Обучатор состоит из 2 частей
# * "среды обучения"
# * определятора полезностей
# * самой нейронки
#
# Среда обучения - такая штука, которая
# * подсовывает нейронке людей,
#  * каждый раз выбирается случайное подмножество людей
#    * (можно и 100 и 10 - просто не успел сравнить)
#    * возвращает ответы на действия нейронки, попутно обновляя своё состояние
# Определятор полезностей
# * умеет считать полезность каждого действия по паре "состояние СРЕДЫ, действие агента ИЗ этого состояния"
# * имеет функции для быстрого определения наград за все действия в сессиях
#
# Нейронка будет далее по списку
#
#
# __***для простоты, CategoryGuess будет имплементировать И среду И награждатор (см. класс ниже)***__

# %%
from objective import BaseObjective
from environment import BaseEnvironment

class CategoryGuess(BaseObjective,BaseEnvironment):
    def __init__(self,n_attrs,n_categories,batch_size=10):
        self._attributes = _shared("X_attrs_data",np.zeros([batch_size,n_attrs]),'uint8')
        self._categories =  _shared("categories_data",np.zeros([batch_size,n_categories]),'uint8')
        self._batch_size = self._attributes.shape[0]
        
        _end_action = T.zeros([self._batch_size,1], dtype='uint8')
        
        self._joint_data = T.concatenate([self._attributes,
                                          self._categories,
                                          _end_action,
                                         ],axis=1
).astype('float32') #it is highly important to make sure 
        #that variables touched by theano.grad have float* type
    
        #indices
        self._category_action_ids = T.arange(
            self._attributes.shape[1],
            self._attributes.shape[1]+self._categories.shape[1]
        )
        
        self._end_action_id = self._joint_data.shape[1]-1
    def load_data_batch(self,attrs_batch,categories_batch):
        attrs_batch = np.array(attrs_batch)
        categories_batch = np.array(categories_batch)
        set_shared(self._attributes,attrs_batch)
        set_shared(self._categories,categories_batch)

    @property
    def n_actions(self):
        return int(self._joint_data.shape[1].eval())
    @property
    def observation_size(self):
        return int((self._joint_data.shape[1]+1).eval())
    @property
    def state_size(self):
        return int(self._joint_data.shape[1].eval())
    @property
    def batch_size(self):
        return int(self._batch_size.get_value())
        
    
    def get_action_results(self,last_state,action,time_i):
        
        #state is a boolean vector: whether or not i-th action
        #was tried already during this session
        #last output[:,end_code] always remains 1 after first being triggered
        
        
        batch_range = T.arange(action.shape[0])

        can_do_action = T.eq(last_state[:,self._end_action_id],0)
        
        state_after_action = T.set_subtensor(last_state[batch_range,action],1)
        
        new_state = T.switch(
            can_do_action.reshape([-1,1]),
            state_after_action,
            last_state
        )
        
        
        
        observation = T.concatenate([
                self._joint_data[batch_range,action,None],#uint8[batch,1]
                T.extra_ops.to_one_hot(action,self._joint_data.shape[1]),
            ],axis=1)
        
        return new_state, observation

    def get_reward(self,session_states,session_actions,batch_i):
        """
        WARNING! this runs on a single session, not on a batch
        reward given for taking the action in current environment state
        arguments:
            session_states float[time_i, memory_id]: environment state before taking action
            session_actions int[time_i]: agent action at this tick
        returns:
            reward float[time_i]: reward for taking action from the given state
        """
        time_range = T.arange(session_actions.shape[0])
        

        _has_tried_already = session_states[time_range,session_actions]
        _session_is_active = T.eq(session_states[:,self._end_action_id],0)
        
        _has_finished_now = T.eq(session_actions,self._end_action_id)
        _has_finished_now = T.set_subtensor(_has_finished_now[-1],1)
        _end_tick = _has_finished_now.nonzero()[0][0]
        
        _action_is_categorical = _in1d(session_actions, self._category_action_ids)
        
        _at_least_one_categorical_action = T.any(_action_is_categorical[:_end_tick])
        
        
        _response = self._joint_data[batch_i,session_actions].ravel()
        
        #categorical and attributes
        _reward_for_intermediate_action = T.switch(
            _action_is_categorical,
            _response*3-1,
            _response*2-1
        )
        _reward_for_intermediate_action_first_time = T.switch(
                _has_tried_already,
                -0.1,
                _reward_for_intermediate_action,
            )

        #ending session
        _reward_for_end_action = T.switch(_at_least_one_categorical_action, #if chosen at least 1 category
                                          0,   #do not penalize
                                          -3.)  #else punish
        
        #include end action
        _reward_for_action = T.switch(
            _has_finished_now,
            _reward_for_end_action,
            _reward_for_intermediate_action_first_time,
        )
        
        
        _final_reward = T.switch(
            _session_is_active,
            _reward_for_action,
            0,

            
        )
        
        
        return _final_reward.astype(floatX)

# %%
env = CategoryGuess(train_attrs.shape[1],train_cats.shape[1],5)

# %% [markdown]
# # agent setup
# В свою очередь, нейронка состоит из 3 частей
# * память агента
#     * на вход получает пару (предыдущее состояние памятиа агента, сенсорная инфа о среде на ЭТОМ шагу)
#     * определяет текущее состояние памяти агента (на том же шагу, что и сенсорная инф-ция со входа)
#     * тут - GRUlayer, в потенциале - вообще что угодно, хоть 10 шагов LSTM за 1 раз
#        * какой именно GRUlayer:
#        * Reset gate - dense w/ expit
#        * Update gate - dense w/ expit
#        * Hidden update gate - dense w/ tanh
#
# * определятор Q-значений
#     * на вход получает память агента
#     * определяет Q_значения каждого действия
#     * тут - DenseLayer, потенциал - что угодно
# * приниматор решений по Q-значениям
#     * на вход получает Q-значения для действий
#     * определяет, как вывод нейронки трансформируется в решение,
#     * формат выхода - целые числа - номера выбранных действий
#      * тут - с вероятностью epsilon берётся решение,
#        * которому предсказана наибольшая полезность
#        * иначе берётся случайное равновероятное
#      * альтернативный вариант - решения выбираются с веростностями
#        * $Pi(a) = softmax(Qi(a)) = {e^{Qi(x)}} / {\sum\limits_{j=1}^n e^{Qj(X)}}$
#        * где Q(a) - предсказанная полезность действия a
# * всё это делается векторизованно для батча произвольной размерности
#
#
# ### Agent - просто обёртка над этими 3 пунктами
# * строго говоря, можно воткнуть любую нейронку, которая мапает
# * `float last_agent_state[batch,units], float observation[batch,sensors] ->`
# * `-> float new_agent_state[batch,units], float qvalues[batch,actions], int actions[batch]`

# %%
from resolver import EpsilonGreedyResolver
from memory import GRUMemoryLayer
from agent import Agent

# %%
import lasagne
__idea__="""
 
We train two memory states:
    first one, based on observations, and second one, based on first one;

Note that here we update the second memory layer based on the CURRENT state
of the first one. Instead, you can try to feed it with a previous state.

The q-values are estimated on a concatenated state, effectively on both memory
states together, but there is no problem with limiting q-evaluator to only one:
just pass the correct gru layer as an incoming layer to the q-evaluator.

Implementation:
We concatenate both memories into 1 state to pass it through the session loop.

To perform memory update, we need to slice the concatenated state back into
two memory states.

We do so by defining an input map function and passing it into agent.

We than concatenate two new states back to form a new memory state.

"""
n_hid_1=2048 #first GRU memory
n_hid_2=2048 #second GRU memory
n_hid_3=2048 #second GRU memory


_observation_layer = lasagne.layers.InputLayer([None,env.observation_size],name="obs_input")

_prev_gru1_layer = lasagne.layers.InputLayer([None,n_hid_1],name="prev_gru1_state_input")
_prev_gru2_layer = lasagne.layers.InputLayer([None,n_hid_2],name="prev_gru2_state_input")
_prev_gru3_layer = lasagne.layers.InputLayer([None,n_hid_3],name="prev_gru3_state_input")

#memory
gru1 = GRUMemoryLayer(n_hid_1,
                     _observation_layer,
                     _prev_gru1_layer,
                     name="gru1")

gru2 = GRUMemoryLayer(n_hid_2,
                     gru1,        #note that it takes CURRENT gru1 output as input.
                                  #replacing that with _prev_gru1_state would imply taking previous one.
                     _prev_gru2_layer,
                     name="gru2")

gru3 = GRUMemoryLayer(n_hid_3,
                     gru2,        #note that it takes CURRENT gru2 output as input.
                                  #replacing that with _prev_gru2_state would imply taking previous one.
                     _prev_gru3_layer,
                     name="gru3")


concatenated_memory = lasagne.layers.concat([gru1,gru2,gru3])

#q_eval
q_eval = lasagne.layers.DenseLayer(concatenated_memory, #taking both memories. 
                                                        #Replacing with gru1 or gru2 would mean taking one
                                   num_units = env.n_actions,
                                   nonlinearity=lasagne.nonlinearities.linear,name="QEvaluator")
#resolver
epsilon = _shared("e-greedy.epsilon",0.9,dtype=floatX)

resolver = EpsilonGreedyResolver(q_eval,epsilon=epsilon,name="resolver")



#we need to define the new input map because concatenated_memory is a ConcatLayer and does not have default one

def custom_input_map(last_hidden,observation):
    """just a function that maps memory states to respective inputs"""
    return {
        _prev_gru1_layer:last_hidden[:,0:n_hid_1],
        _prev_gru2_layer:last_hidden[:,n_hid_1:n_hid_1+n_hid_2],
        _prev_gru3_layer:last_hidden[:,n_hid_1+n_hid_2:n_hid_1+n_hid_2+n_hid_3],
        _observation_layer:observation
    }

#all together
agent = Agent(concatenated_memory,q_eval,resolver,input_map=custom_input_map
             )

# %%
history = agent.get_sessions(env,session_length=20,
                       batch_size=env._joint_data.shape[0],)
state_seq,observation_seq,hidden_seq,qvalues_seq,action_seq = history

rewards_seq = env.get_reward_sequences(state_seq,action_seq)

# %%
get_history = theano.function([],history+(rewards_seq,),mode=theano.compile.mode.FAST_RUN)

# %% [markdown]
# # weights
# * вот так нахаляву можно вытащить ВСЕ веса нейронок агента
# * что НЕ вытаскивается
#  * архитектура сети
#  * гиперпараметры (жадность, gamma)
#  * состояния среды/наблюдения
# * короче, вытаскиваются только "нейронячие" параметры
# * хочешь, чтобы в твоём слое вытащилась какая-то shared переменная - добавь её в параметры слоя [с каким-ть тэгом, если хочешь]
# * всё как в ванильной лазанье

# %%
#all trainable weights
weights = lasagne.layers.get_all_params(resolver,trainable=True)
weights
# Out:
# [gru1.W_in_to_updategate,
#  gru1.W_hid_to_updategate,
#  gru1.b_updategate,
#  gru1.W_in_to_resetgate,
#  gru1.W_hid_to_resetgate,
#  gru1.b_resetgate,
#  gru1.W_in_to_hidden_update,
#  gru1.W_hid_to_hidden_update,
#  gru1.b_hidden_update,
#  gru2.W_in_to_updategate,
#  gru2.W_hid_to_updategate,
#  gru2.b_updategate,
#  gru2.W_in_to_resetgate,
#  gru2.W_hid_to_resetgate,
#  gru2.b_resetgate,
#  gru2.W_in_to_hidden_update,
#  gru2.W_hid_to_hidden_update,
#  gru2.b_hidden_update,
#  gru3.W_in_to_updategate,
#  gru3.W_hid_to_updategate,
#  gru3.b_updategate,
#  gru3.W_in_to_resetgate,
#  gru3.W_hid_to_resetgate,
#  gru3.b_resetgate,
#  gru3.W_in_to_hidden_update,
#  gru3.W_hid_to_hidden_update,
#  gru3.b_hidden_update,
#  QEvaluator.W,
#  QEvaluator.b]

# %%
#all weights but for Qvalues prediciton ones (not to penalize q-predictors by l2)
weights_inner = filter(lambda w: "QEvaluator" not in w.name,weights)
weights_inner
# Out:
# [gru1.W_in_to_updategate,
#  gru1.W_hid_to_updategate,
#  gru1.b_updategate,
#  gru1.W_in_to_resetgate,
#  gru1.W_hid_to_resetgate,
#  gru1.b_resetgate,
#  gru1.W_in_to_hidden_update,
#  gru1.W_hid_to_hidden_update,
#  gru1.b_hidden_update,
#  gru2.W_in_to_updategate,
#  gru2.W_hid_to_updategate,
#  gru2.b_updategate,
#  gru2.W_in_to_resetgate,
#  gru2.W_hid_to_resetgate,
#  gru2.b_resetgate,
#  gru2.W_in_to_hidden_update,
#  gru2.W_hid_to_hidden_update,
#  gru2.b_hidden_update,
#  gru3.W_in_to_updategate,
#  gru3.W_hid_to_updategate,
#  gru3.b_updategate,
#  gru3.W_in_to_resetgate,
#  gru3.W_hid_to_resetgate,
#  gru3.b_resetgate,
#  gru3.W_in_to_hidden_update,
#  gru3.W_hid_to_hidden_update,
#  gru3.b_hidden_update]

# %% [markdown]
# # целевая функция для обучения сети
#
# * Интуитивно, цель - предсказывать Q-значения (полезности) действий
# * $Q(s,a) = R(s,a) + gamma* Max_{a'}{ Q(s',a')}  $
#  * R(s,a) - непосредственная награда за действие (+5 если угадал, -1 если нет и т.п.)
#  * s' - состояние, в которое агент попал, сделав действие a из состояния s
#  * a' - действие, которое можно совершить в состоянии s'
#  * gamma - во сколько раз награда/пинок через 1 шаг менее значимы, чем сейчас
#  * интуиция - "в состоянии s полезность действия a - это непосредственная печенька за это действие ПЛЮС все печеньки, которые можно собрать, если после этого действия вести себя оптимально"
#
# * В реальном мире оптимизируются попарно 2 приближения этой функции
# * $ RMSE_{reccurent}: (NN_s(a) - (R + gamma* Max_a'{ NN_s'(a')})^2$
#  * NN_s(a) предсказаннная из состояния s полезност Q(s,a)
#  * считается для тех NN_s(a), которые агент совершил
#  * NN_s'(a') - полезности всех действий сразу после совершения a из состяния s
#
# * $ RMSE_{naive}: (NN_s(a^*) - (R + gamma*  NN_s'(a'^*))^2$
#  * аналогично предыдущему, но a* - реально совершённое агентом действие
#  * оценка смещена, но куда проще оптимизируется, чем предыдущая
#    * по крайней мере, с softmax принятием решений

# %%
#get pairs of corresponding [predicted Qvalues, reference Qvalues] to train on

is_alive_seq = T.eq(state_seq[:,:,-1],0)

#gamma - delayed reward coefficient - what fraction of reward is retained if it is obtained one tick later
gamma = _shared('q_learning_gamma',np.float32(0.95),floatX)

ref_tuples = env.get_reference(qvalues_seq,action_seq,rewards_seq,is_alive_seq,gamma_or_gammas=gamma,)

action_Qvalues, predicted_Qvalues, is_end = ref_tuples

# %%
#concatenate "alive" ticks from all sessions to then compute errors

to_be_raveled = [action_seq,rewards_seq,action_Qvalues, predicted_Qvalues, is_end]

raveled_tuples = env.ravel_alive(is_alive_seq,*to_be_raveled)

action_ids_ravel,immediate_rewards_ravel,action_Qvalues_ravel,\
reference_Qvalues_ravel,is_end_ravel= raveled_tuples



from auxilary import consider_constant
reference_Qvalues_ravel = consider_constant(reference_Qvalues_ravel)

# %%
loss_recurrent = lasagne.objectives.squared_error(reference_Qvalues_ravel,action_Qvalues_ravel).mean()

# %%
weight_ravel = T.concatenate([w.ravel() for w in weights_inner])
reg_l2 = reg_l2 = T.mean(weight_ravel**2)*0.1

# %%
loss = loss_recurrent + reg_l2

# %% [markdown]
# # алгоритм обучения
# * обучаются все параметры обычным Stochastic Gradient Descent с Nestrov Mommentum
# * регуляризации нет, ибо пока не понадобилась

# %%
_updates = lasagne.updates.adadelta(loss,weights,learning_rate=0.01)#,momentum=0.9)
#updates = lasagne.updates.sgd(loss_recurrent,weights,0.1)

# %%
mean_session_reward = immediate_rewards_ravel.sum()/ rewards_seq.shape[0]
train_fun = theano.function([],[loss,loss_recurrent,reg_l2,mean_session_reward],updates=_updates)
loss_fun = theano.function([],[loss,loss_recurrent,reg_l2,mean_session_reward])

# %% [markdown]
# # evaluation
# * удобная [мне одному] функция, которая показывает примеры сессий и внутреннее состояние нейронки
# * текстовая часть -
#     * #(номер_действия) (имя_действия) (предсказанное_Qvalue) -> (награда) | следующая итерация
# * картинка (если display = True)
#     * X - моменты времени, Y - попугаи
#     * жЫрные линии - Q-значения категорий
#     * тонкие линии - Q-значения узнавания аттрибутов
#     * точки на линиях - выбранные действия
#     * пунктирные линии - активация нейронов в памяти агента
#     * синяя черта (тонкая, вертикальная) - конец сессии (действие или лимит времени)

# %%
evaluation_fun = theano.function([],[action_ids_ravel,action_Qvalues_ravel,immediate_rewards_ravel,
                                     reference_Qvalues_ravel,is_end_ravel,
                                     hidden_seq,qvalues_seq,action_seq])

# %%
#new names order
feature_names = list(data_attrs.columns) + list(data_cats.columns) + ["<end_session_action>"]
is_categorical = lambda i: feature_names[i].startswith("category:")

def print_session(n_sessions = 3,display=False,legend=True):
    
    a_lot_of_data = evaluation_fun()    
    actions,qvalues,rewards,ref_qvalues,end_sel = a_lot_of_data[:5]
    hidden_log,qvalues_log,action_log = a_lot_of_data[5:]
    
    
    
    b_i = 0 #batch iter ~ session iter
    t_i = 0 #time iter
    

    for a,q,r,q_ref,is_end in zip(actions,qvalues,rewards,ref_qvalues,end_sel):
        print "#%i: %s (%.3f) -> %s |"%(a,feature_names[a],q, r,),
        
        
        t_i +=1
        if is_end ==1:
            
            print '<end>'
            print 'true:',
            for cat in env._categories.get_value()[b_i].nonzero()[0]:
                print feature_names[cat+env._attributes.shape[1].eval()],
            print
                
            #plot qvalues
            if display:
                plt.figure(figsize=[16,8])

                q_values = qvalues_log[b_i].T
                for i in range(q_values.shape[0]):
                    plt.plot(q_values[i],label=feature_names[i],linewidth = 1 + 4*is_categorical(i))

                hidden_activity =  hidden_log[b_i].T
                for i, hh in enumerate(hidden_activity):
                    plt.plot(hh,'--',label='n'+str(i))
                    
                session_actions = action_log[b_i,:t_i]
                action_range = np.arange(len(session_actions))
                plt.scatter(action_range, qvalues_log[b_i][action_range, session_actions])


                #session end
                plt.plot(np.repeat(t_i-1,2),np.linspace(-0.5,0.5,2))
                plt.xlim(0,max(t_i*1.1,2))
                plt.xticks(np.arange(t_i))
                plt.grid()
                if legend:
                    plt.legend()
                plt.show()
                
            print
            #/
            b_i +=1
            t_i = 0

            if b_i >= n_sessions:
                break

# %% [markdown]
# # training

# %%
def load_random_batch(env,attrs,cats,batch_size=10):
    
    attrs,cats = np.array(attrs),np.array(cats)
    
    assert len(attrs) == len(cats)
    batch_ids = np.random.randint(0,len(attrs),batch_size)
    env.load_data_batch(attrs[batch_ids],cats[batch_ids])

# %%
from collections import defaultdict

epoch_counter = 1
score_log = defaultdict(dict) #{metric_name: {epoch:value} }

def plot_scores(title="metrics"):
    plt.figure(figsize=[10,10])
    plt.title("metrics history")
    for metric_name, metric_dict in score_log.items():            
        plt.plot(*zip(*sorted(metric_dict.items())),label = metric_name)

    plt.title(title)
    plt.grid()
    plt.legend(loc='lower right')
    plt.show()

# %%
alpha = 0.1
ma_reward = 0.
ma_reward_greedy = 0.
ma_reward_test = 0.

# %% [markdown]
# # само обучение
# * шаг алгоритма -
#  * выбрать B случайных людей
#  * пересчитать "жадность" алгоритма (чем дальше, тем более жадный)
#  * сделать шаг обучения
#  * раз в M итераций - добавить точку на график обучения по 3 метрикам
#    * ожидание награды за сессию при текущей жадности на тренировочных данных
#    * то же самое при максимальной жадности
#  * раз в N итераций -
#    * показать несколько примеров сессий на обучающих данных при разной жадности
#    * показать графики обучения
# * раз в K итераций - записать веса нейронки в файл (snapshot)

# %%
n_epochs = 10**6
batch_size=10
for i in range(n_epochs):
    
    resolver.rng.seed(epoch_counter)
    
    creeping_greed = min(0.1 + (1.-np.exp(-epoch_counter/100000.)*0.9),0.95)
    creeping_epsilon = 1.-creeping_greed
    
    
    #train
    load_random_batch(env,train_attrs,train_cats,batch_size=batch_size)
    
    loss,q_loss,reg_loss,avg_reward = train_fun()
    
    
    
    #reward loss moving average
    ma_reward = alpha*avg_reward+ (1-alpha)*ma_reward
    
    
    
    
    if epoch_counter%1000==0:
        print "Evaluation:"
        print '\ndeterministic'
        set_shared(resolver.epsilon,0)
        print_session(1)
        
        
        
        print '\ncurrent_greediness (%f)'%creeping_greed
        set_shared(resolver.epsilon,creeping_epsilon)
        print_session(1)
        
        plot_scores(experiment_setup_name)

    if epoch_counter% 25000 ==0:
        save(resolver,"{}/{}.epoch{}.pcl".format(snapshot_path,experiment_setup_name,epoch_counter))
        print "snapshot saved"
        
        


    if epoch_counter%100 ==0:
        print "epoch %i,loss %.5f, greed %.5f, rewards: ( train %.5f, det_train %.5f) "%(
            epoch_counter,loss,creeping_greed,ma_reward,ma_reward_greedy)
        print "rec %.3f reg %.3f"%(q_loss,reg_loss)
        
        score_log["in-training session avg reward"][epoch_counter] = ma_reward
        
        
        
        #greedy train
        set_shared(resolver.epsilon,0)
        avg_reward_greedy = loss_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["avg session reward greedy (on training)"][epoch_counter] = ma_reward_greedy

        #greedy test
        set_shared(resolver.epsilon,0)
        load_random_batch(env,test_attrs,test_cats,batch_size=batch_size)

        avg_reward_test = loss_fun()[-1]
        ma_reward_test = (1-alpha)*ma_reward_test + alpha*avg_reward_test
        score_log["avg session reward greedy (on test)"][epoch_counter] = ma_reward_test
        

        
        #back to epsilon-greedy
        set_shared(resolver.epsilon,creeping_epsilon)


        
        
    epoch_counter  +=1
# Out:
# epoch 344200,loss 0.75610, greed 0.95000, rewards: ( train -0.83163, det_train 5.62160)
# rec 0.755 reg 0.001
# epoch 344300,loss 0.50353, greed 0.95000, rewards: ( train 1.26494, det_train 5.21744)
# rec 0.503 reg 0.001
# epoch 344400,loss 0.64149, greed 0.95000, rewards: ( train 1.40919, det_train 4.91870)
# rec 0.640 reg 0.001
# epoch 344500,loss 0.67295, greed 0.95000, rewards: ( train 2.42812, det_train 4.46783)
# rec 0.672 reg 0.001
# epoch 344600,loss 0.56901, greed 0.95000, rewards: ( train 2.32260, det_train 4.14305)
# rec 0.568 reg 0.001
# epoch 344700,loss 0.67431, greed 0.95000, rewards: ( train 2.71488, det_train 4.17274)
# rec 0.673 reg 0.001
# epoch 344800,loss 0.72960, greed 0.95000, rewards: ( train 2.23954, det_train 3.91747)
# rec 0.729 reg 0.001
# epoch 344900,loss 0.55681, greed 0.95000, rewards: ( train 1.89476, det_train 3.83472)
# rec 0.556 reg 0.001
# Evaluation:
#
# deterministic
# #26: decades_active:2010 (3.695) -> 1.0 | #25: last_activity:still_active (3.504) -> 1.0 | #166: decades_active:2000 (2.751) -> 1.0 | #260: decades_active:1990 (2.037) -> 1.0 | #3: Instruments:guitar (1.489) -> 1.0 | #167: Genres:rock (1.825) -> 1.0 | #149: Labels:is_known (1.359) -> 1.0 | #262: Occupation:musician (0.721) -> 1.0 | #91: decades_active:1980 (0.305) -> 1.0 | #20: Instruments:vocals (0.161) -> 1.0 | #3: Instruments:guitar (-0.161) -> -0.1 | #167: Genres:rock (-0.147) -> -0.1 | #262: Occupation:musician (-0.420) -> -0.1 | #1: Birth name:is_known (-0.687) -> -1.0 | #247: Website:is_known (-1.484) -> 1.0 | #20: Instruments:vocals (-1.715) -> -0.1 | #3: Instruments:guitar (-1.861) -> -0.1 | #167: Genres:rock (-1.922) -> -0.1 | #262: Occupation:musician (-1.716) -> -0.1 | #25: last_activity:still_active (-1.929) -> -3.0 | <end>
# true: category:List_of_Arabic_pop_musicians category:List_of_African_musicians
#
#
# current_greediness (0.950000)
# #26: decades_active:2010 (3.695) -> 1.0 | #25: last_activity:still_active (3.504) -> 1.0 | #166: decades_active:2000 (2.751) -> 1.0 | #260: decades_active:1990 (2.037) -> 1.0 | #3: Instruments:guitar (1.489) -> 1.0 | #167: Genres:rock (1.825) -> 1.0 | #149: Labels:is_known (1.359) -> 1.0 | #262: Occupation:musician (0.721) -> 1.0 | #91: decades_active:1980 (0.305) -> 1.0 | #20: Instruments:vocals (0.161) -> 1.0 | #3: Instruments:guitar (-0.161) -> -0.1 | #167: Genres:rock (-0.147) -> -0.1 | #262: Occupation:musician (-0.420) -> -0.1 | #1: Birth name:is_known (-0.687) -> -1.0 | #247: Website:is_known (-1.484) -> 1.0 | #20: Instruments:vocals (-1.715) -> -0.1 | #3: Instruments:guitar (-1.861) -> -0.1 | #167: Genres:rock (-1.922) -> -0.1 | #262: Occupation:musician (-1.716) -> -0.1 | #25: last_activity:still_active (-1.929) -> -3.0 | <end>
# true: category:List_of_Arabic_pop_musicians category:List_of_African_musicians
# epoch 345000,loss 0.67954, greed 0.95000, rewards: ( train 1.99391, det_train 3.76225)
# rec 0.679 reg 0.001
# epoch 345100,loss 0.57821, greed 0.95000, rewards: ( train 3.09246, det_train 3.35002)
# rec 0.577 reg 0.001
# epoch 345200,loss 0.48567, greed 0.95000, rewards: ( train 2.59068, det_train 3.40502)
# rec 0.485 reg 0.001
# epoch 345300,loss 0.62989, greed 0.95000, rewards: ( train 2.79201, det_train 3.47852)
# rec 0.629 reg 0.001
# epoch 345400,loss 0.48817, greed 0.95000, rewards: ( train 2.85156, det_train 3.55767)
# rec 0.487 reg 0.001
# epoch 345500,loss 0.57938, greed 0.95000, rewards: ( train 2.25139, det_train 3.71190)
# rec 0.578 reg 0.001
# epoch 345600,loss 0.59754, greed 0.95000, rewards: ( train 1.48337, det_train 3.76371)
# rec 0.597 reg 0.001
# epoch 345700,loss 0.50444, greed 0.95000, rewards: ( train 2.71169, det_train 3.59734)
# rec 0.503 reg 0.001
# epoch 345800,loss 0.94553, greed 0.95000, rewards: ( train 1.76662, det_train 3.81561)
# rec 0.945 reg 0.001
# epoch 345900,loss 0.56069, greed 0.95000, rewards: ( train 2.13853, det_train 3.63104)
# rec 0.560 reg 0.001
# Evaluation:
#
# deterministic
# #1: Birth name:is_known (3.214) -> 1.0 | #26: decades_active:2010 (2.831) -> 1.0 | #25: last_activity:still_active (2.752) -> 1.0 | #166: decades_active:2000 (1.819) -> 1.0 | #260: decades_active:1990 (1.192) -> 1.0 | #149: Labels:is_known (0.193) -> -1.0 | #91: decades_active:1980 (-0.218) -> 1.0 | #167: Genres:rock (-0.596) -> 1.0 | #3: Instruments:guitar (-0.563) -> 1.0 | #167: Genres:rock (-0.443) -> -0.1 | #262: Occupation:musician (-0.102) -> -1.0 | #384: category:List_of_pop_and_rock_pianists (-1.229) -> -1.0 | #384: category:List_of_pop_and_rock_pianists (-0.598) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.500) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.561) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.641) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.662) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.565) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.396) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.187) -> 0.0 | <end>
# true: category:List_of_bass_guitarists category:List_of_rhythm_guitarists
#
#
# current_greediness (0.950000)
# #1: Birth name:is_known (3.214) -> 1.0 | #26: decades_active:2010 (2.831) -> 1.0 | #25: last_activity:still_active (2.752) -> 1.0 | #166: decades_active:2000 (1.819) -> 1.0 | #260: decades_active:1990 (1.192) -> 1.0 | #149: Labels:is_known (0.193) -> -1.0 | #91: decades_active:1980 (-0.218) -> 1.0 | #167: Genres:rock (-0.596) -> 1.0 | #3: Instruments:guitar (-0.563) -> 1.0 | #167: Genres:rock (-0.443) -> -0.1 | #262: Occupation:musician (-0.102) -> -1.0 | #384: category:List_of_pop_and_rock_pianists (-1.229) -> -1.0 | #384: category:List_of_pop_and_rock_pianists (-0.598) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.500) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.561) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.641) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.662) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.565) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.396) -> -0.1 | #384: category:List_of_pop_and_rock_pianists (-0.187) -> 0.0 | <end>
# true: category:List_of_bass_guitarists category:List_of_rhythm_guitarists
# epoch 346000,loss 0.51031, greed 0.95000, rewards: ( train 1.82543, det_train 3.62394)
# rec 0.509 reg 0.001
# epoch 346100,loss 0.64476, greed 0.95000, rewards: ( train 2.14694, det_train 3.63155)
# rec 0.644 reg 0.001
# epoch 346200,loss 0.77406, greed 0.95000, rewards: ( train 2.73481, det_train 3.38439)
# rec 0.773 reg 0.001
# epoch 346300,loss 0.66842, greed 0.95000, rewards: ( train 2.34623, det_train 3.47395)
# rec 0.667 reg 0.001
# epoch 346400,loss 0.61925, greed 0.95000, rewards: ( train 2.15187, det_train 3.48556)
# rec 0.618 reg 0.001
# epoch 346500,loss 0.53764, greed 0.95000, rewards: ( train 2.77517, det_train 3.34200)
# rec 0.537 reg 0.001
# epoch 346600,loss 0.40858, greed 0.95000, rewards: ( train 2.81534, det_train 3.51980)
# rec 0.408 reg 0.001
# epoch 346700,loss 0.48170, greed 0.95000, rewards: ( train 2.60771, det_train 3.67982)
# rec 0.481 reg 0.001
# epoch 346800,loss 0.53925, greed 0.95000, rewards: ( train 2.43473, det_train 3.73184)
# rec 0.538 reg 0.001
# epoch 346900,loss 0.67149, greed 0.95000, rewards: ( train 2.58163, det_train 3.60166)
# rec 0.670 reg 0.001
# Evaluation:
#
# deterministic
# #26: decades_active:2010 (3.756) -> 1.0 | #25: last_activity:still_active (3.427) -> 1.0 | #166: decades_active:2000 (2.663) -> 1.0 | #247: Website:is_known (1.744) -> -1.0 | #91: decades_active:1980 (1.806) -> 1.0 | #260: decades_active:1990 (1.292) -> 1.0 | #149: Labels:is_known (0.035) -> -1.0 | #91: decades_active:1980 (-0.301) -> -0.1 | #3: Instruments:guitar (-0.255) -> 1.0 | #167: Genres:rock (0.474) -> 1.0 | #3: Instruments:guitar (-0.173) -> -0.1 | #262: Occupation:musician (-0.025) -> -1.0 | #1: Birth name:is_known (-0.812) -> 1.0 | #20: Instruments:vocals (-0.900) -> 1.0 | #354: category:List_of_deaths_in_rock_and_roll (-1.514) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-0.596) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.161) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.180) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.107) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.088) -> 0.0 | <end>
# true: category:List_of_lead_vocalists category:List_of_guitarists category:List_of_singer-songwriters category:List_of_rhythm_guitarists
#
#
# current_greediness (0.950000)
# #26: decades_active:2010 (3.756) -> 1.0 | #250: Native name:is_known (1.974) -> -1.0 | #91: decades_active:1980 (3.371) -> 1.0 | #166: decades_active:2000 (3.139) -> 1.0 | #25: last_activity:still_active (2.107) -> 1.0 | #260: decades_active:1990 (1.228) -> 1.0 | #149: Labels:is_known (0.562) -> -1.0 | #91: decades_active:1980 (0.081) -> -0.1 | #3: Instruments:guitar (-0.176) -> 1.0 | #167: Genres:rock (0.401) -> 1.0 | #3: Instruments:guitar (-0.218) -> -0.1 | #262: Occupation:musician (-0.136) -> -1.0 | #20: Instruments:vocals (-1.092) -> 1.0 | #221: decades_active:1970 (-1.368) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-1.070) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-0.344) -> -0.1 | #380: category:List_of_bass_guitarists (-1.891) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-0.571) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.090) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (0.046) -> 0.0 | <end>
# true: category:List_of_lead_vocalists category:List_of_guitarists category:List_of_singer-songwriters category:List_of_rhythm_guitarists
# epoch 347000,loss 0.51000, greed 0.95000, rewards: ( train 2.44603, det_train 3.61349)
# rec 0.509 reg 0.001
# epoch 347100,loss 0.63614, greed 0.95000, rewards: ( train 2.64715, det_train 3.69314)
# rec 0.635 reg 0.001
# epoch 347200,loss 0.50797, greed 0.95000, rewards: ( train 2.01386, det_train 3.79983)
# rec 0.507 reg 0.001
# epoch 347300,loss 0.57275, greed 0.95000, rewards: ( train 1.80579, det_train 3.69884)
# rec 0.572 reg 0.001
# epoch 347400,loss 0.81902, greed 0.95000, rewards: ( train 2.84837, det_train 3.60796)
# rec 0.818 reg 0.001
# epoch 347500,loss 0.74849, greed 0.95000, rewards: ( train 2.55831, det_train 3.65416)
# rec 0.747 reg 0.001
# epoch 347600,loss 0.79563, greed 0.95000, rewards: ( train 2.37757, det_train 3.68175)
# rec 0.795 reg 0.001
# epoch 347700,loss 0.53190, greed 0.95000, rewards: ( train 2.44731, det_train 3.50557)
# rec 0.531 reg 0.001
# epoch 347800,loss 0.47894, greed 0.95000, rewards: ( train 2.00727, det_train 3.51402)
# rec 0.478 reg 0.001
# epoch 347900,loss 0.63869, greed 0.95000, rewards: ( train 3.04884, det_train 3.51861)
# rec 0.638 reg 0.001
# Evaluation:
#
# deterministic
# #26: decades_active:2010 (3.675) -> -1.0 | #1: Birth name:is_known (2.436) -> 1.0 | #239: Died:is_known (2.413) -> 1.0 | #221: decades_active:1970 (2.690) -> 1.0 | #43: decades_active:1960 (2.537) -> 1.0 | #91: decades_active:1980 (1.963) -> 1.0 | #260: decades_active:1990 (1.572) -> 1.0 | #149: Labels:is_known (0.925) -> 1.0 | #354: category:List_of_deaths_in_rock_and_roll (0.485) -> 2.0 | #167: Genres:rock (0.570) -> 1.0 | #3: Instruments:guitar (0.593) -> 1.0 | #167: Genres:rock (0.896) -> -0.1 | #262: Occupation:musician (0.540) -> 1.0 | #354: category:List_of_deaths_in_rock_and_roll (-0.124) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (0.095) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.055) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.185) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.206) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.139) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.104) -> 0.0 | <end>
# true: category:List_of_performers_on_Top_of_the_Pops category:List_of_deaths_in_rock_and_roll category:List_of_bass_guitarists category:List_of_slide_guitarists
#
#
# current_greediness (0.950000)
# #26: decades_active:2010 (3.675) -> -1.0 | #1: Birth name:is_known (2.436) -> 1.0 | #239: Died:is_known (2.413) -> 1.0 | #221: decades_active:1970 (2.690) -> 1.0 | #43: decades_active:1960 (2.537) -> 1.0 | #91: decades_active:1980 (1.963) -> 1.0 | #260: decades_active:1990 (1.572) -> 1.0 | #149: Labels:is_known (0.925) -> 1.0 | #354: category:List_of_deaths_in_rock_and_roll (0.485) -> 2.0 | #167: Genres:rock (0.570) -> 1.0 | #3: Instruments:guitar (0.593) -> 1.0 | #167: Genres:rock (0.896) -> -0.1 | #262: Occupation:musician (0.540) -> 1.0 | #60: Origin:scotland (-1.335) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-0.102) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.061) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.095) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.121) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.065) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.033) -> 0.0 | <end>
# true: category:List_of_performers_on_Top_of_the_Pops category:List_of_deaths_in_rock_and_roll category:List_of_bass_guitarists category:List_of_slide_guitarists
# epoch 348000,loss 0.51551, greed 0.95000, rewards: ( train 3.01275, det_train 3.43475)
# rec 0.515 reg 0.001
# epoch 348100,loss 0.62663, greed 0.95000, rewards: ( train 2.80827, det_train 3.70628)
# rec 0.626 reg 0.001
# epoch 348200,loss 0.66366, greed 0.95000, rewards: ( train 2.66759, det_train 3.86865)
# rec 0.663 reg 0.001
# epoch 348300,loss 0.54615, greed 0.95000, rewards: ( train 2.66127, det_train 3.70378)
# rec 0.545 reg 0.001
# epoch 348400,loss 0.51400, greed 0.95000, rewards: ( train 2.89832, det_train 3.53041)
# rec 0.513 reg 0.001
# epoch 348500,loss 0.60263, greed 0.95000, rewards: ( train 2.79223, det_train 3.62337)
# rec 0.602 reg 0.001
# epoch 348600,loss 0.40990, greed 0.95000, rewards: ( train 2.80786, det_train 3.72703)
# rec 0.409 reg 0.001
# epoch 348700,loss 0.69605, greed 0.95000, rewards: ( train 2.78995, det_train 3.71933)
# rec 0.695 reg 0.001
# epoch 348800,loss 0.50444, greed 0.95000, rewards: ( train 2.98835, det_train 3.74639)
# rec 0.503 reg 0.001
# epoch 348900,loss 0.78245, greed 0.95000, rewards: ( train 2.61413, det_train 3.92475)
# rec 0.781 reg 0.001
# Evaluation:
#
# deterministic
# #26: decades_active:2010 (3.558) -> 1.0 | #25: last_activity:still_active (3.326) -> 1.0 | #166: decades_active:2000 (2.310) -> 1.0 | #3: Instruments:guitar (1.673) -> 1.0 | #167: Genres:rock (1.837) -> 1.0 | #262: Occupation:musician (1.870) -> 1.0 | #260: decades_active:1990 (1.810) -> 1.0 | #221: decades_active:1970 (0.693) -> 1.0 | #149: Labels:is_known (0.702) -> -1.0 | #91: decades_active:1980 (0.853) -> 1.0 | #221: decades_active:1970 (-0.720) -> -0.1 | #1: Birth name:is_known (-0.556) -> 1.0 | #20: Instruments:vocals (-0.715) -> 1.0 | #3: Instruments:guitar (-0.390) -> -0.1 | #167: Genres:rock (-0.817) -> -0.1 | #3: Instruments:guitar (-1.179) -> -0.1 | #262: Occupation:musician (-1.328) -> -0.1 | #221: decades_active:1970 (-1.644) -> -0.1 | #359: category:List_of_alternative_country_musicians (-1.590) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-0.965) -> 0.0 | <end>
# true: category:List_of_bass_guitarists
#
#
# current_greediness (0.950000)
# #96: Genres:black (2.796) -> -1.0 | #26: decades_active:2010 (3.847) -> 1.0 | #166: decades_active:2000 (3.252) -> 1.0 | #25: last_activity:still_active (2.459) -> 1.0 | #3: Instruments:guitar (1.690) -> 1.0 | #167: Genres:rock (1.726) -> 1.0 | #262: Occupation:musician (1.838) -> 1.0 | #260: decades_active:1990 (2.111) -> 1.0 | #149: Labels:is_known (0.633) -> -1.0 | #91: decades_active:1980 (0.767) -> 1.0 | #221: decades_active:1970 (-0.110) -> 1.0 | #260: decades_active:1990 (-0.613) -> -0.1 | #1: Birth name:is_known (-0.540) -> 1.0 | #20: Instruments:vocals (-0.668) -> 1.0 | #3: Instruments:guitar (-0.358) -> -0.1 | #167: Genres:rock (-0.521) -> -0.1 | #262: Occupation:musician (-1.159) -> -0.1 | #3: Instruments:guitar (-1.451) -> -0.1 | #167: Genres:rock (-1.337) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-1.280) -> -3.0 | <end>
# true: category:List_of_bass_guitarists
# epoch 349000,loss 0.62655, greed 0.95000, rewards: ( train 2.56724, det_train 3.84928)
# rec 0.626 reg 0.001
# epoch 349100,loss 0.69631, greed 0.95000, rewards: ( train 2.15023, det_train 3.79635)
# rec 0.695 reg 0.001
# epoch 349200,loss 0.66858, greed 0.95000, rewards: ( train 2.32145, det_train 3.87272)
# rec 0.668 reg 0.001
# epoch 349300,loss 0.57895, greed 0.95000, rewards: ( train 2.65568, det_train 3.77744)
# rec 0.578 reg 0.001
# epoch 349400,loss 0.69438, greed 0.95000, rewards: ( train 2.57722, det_train 3.82970)
# rec 0.693 reg 0.001
# epoch 349500,loss 0.40432, greed 0.95000, rewards: ( train 2.42614, det_train 3.55673)
# rec 0.403 reg 0.001
# epoch 349600,loss 0.64749, greed 0.95000, rewards: ( train 2.90877, det_train 3.67906)
# rec 0.646 reg 0.001
# epoch 349700,loss 0.51080, greed 0.95000, rewards: ( train 2.13824, det_train 3.53415)
# rec 0.510 reg 0.001
# epoch 349800,loss 0.60283, greed 0.95000, rewards: ( train 2.02081, det_train 3.63574)
# rec 0.602 reg 0.001
# epoch 349900,loss 0.62119, greed 0.95000, rewards: ( train 2.53633, det_train 3.45516)
# rec 0.620 reg 0.001
# Evaluation:
#
# deterministic
# #26: decades_active:2010 (3.910) -> 1.0 | #25: last_activity:still_active (3.592) -> 1.0 | #166: decades_active:2000 (2.746) -> 1.0 | #149: Labels:is_known (1.899) -> -1.0 | #91: decades_active:1980 (1.700) -> 1.0 | #260: decades_active:1990 (1.414) -> 1.0 | #167: Genres:rock (0.409) -> -1.0 | #221: decades_active:1970 (-0.646) -> 1.0 | #43: decades_active:1960 (-0.672) -> 1.0 | #166: decades_active:2000 (-0.678) -> -0.1 | #247: Website:is_known (-0.728) -> -1.0 | #1: Birth name:is_known (-0.785) -> 1.0 | #166: decades_active:2000 (-1.446) -> -0.1 | #166: decades_active:2000 (-1.471) -> -0.1 | #149: Labels:is_known (-1.413) -> -0.1 | #20: Instruments:vocals (-1.264) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-1.058) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-0.396) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.371) -> -0.1 | #138: Instruments:keyboards (-0.203) -> 0.0 | <end>
# true: category:List_of_Iranian_musicians
#
#
# current_greediness (0.950000)
# #26: decades_active:2010 (3.910) -> 1.0 | #25: last_activity:still_active (3.592) -> 1.0 | #166: decades_active:2000 (2.746) -> 1.0 | #149: Labels:is_known (1.899) -> -1.0 | #91: decades_active:1980 (1.700) -> 1.0 | #260: decades_active:1990 (1.414) -> 1.0 | #91: decades_active:1980 (-1.224) -> -0.1 | #167: Genres:rock (0.582) -> -1.0 | #221: decades_active:1970 (-0.620) -> 1.0 | #166: decades_active:2000 (-0.643) -> -0.1 | #1: Birth name:is_known (-0.588) -> 1.0 | #247: Website:is_known (-1.022) -> -1.0 | #166: decades_active:2000 (-1.510) -> -0.1 | #20: Instruments:vocals (-1.236) -> -1.0 | #166: decades_active:2000 (-1.510) -> -0.1 | #247: Website:is_known (-1.322) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-1.207) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-0.457) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.320) -> -0.1 | #319: category:List_of_folk_rock_artists (-0.447) -> 0.0 | <end>
# true: category:List_of_Iranian_musicians
# snapshot saved
# epoch 350000,loss 0.71620, greed 0.95000, rewards: ( train 2.74449, det_train 3.57565)
# rec 0.715 reg 0.001
# epoch 350100,loss 0.50047, greed 0.95000, rewards: ( train 2.81426, det_train 3.55208)
# rec 0.499 reg 0.001
# epoch 350200,loss 0.58593, greed 0.95000, rewards: ( train 2.33495, det_train 3.58987)
# rec 0.585 reg 0.001
# epoch 350300,loss 0.44147, greed 0.95000, rewards: ( train 2.86316, det_train 3.48089)
# rec 0.440 reg 0.001
# epoch 350400,loss 0.43916, greed 0.95000, rewards: ( train 2.60779, det_train 3.56680)
# rec 0.438 reg 0.001
# epoch 350500,loss 0.63728, greed 0.95000, rewards: ( train 2.64744, det_train 3.60312)
# rec 0.636 reg 0.001
# epoch 350600,loss 0.53534, greed 0.95000, rewards: ( train 2.34753, det_train 3.59181)
# rec 0.534 reg 0.001
# epoch 350700,loss 0.68366, greed 0.95000, rewards: ( train 3.12984, det_train 3.77063)
# rec 0.683 reg 0.001
# epoch 350800,loss 0.69450, greed 0.95000, rewards: ( train 3.36685, det_train 3.69956)
# rec 0.694 reg 0.001
# epoch 350900,loss 0.53847, greed 0.95000, rewards: ( train 2.24687, det_train 3.66461)
# rec 0.537 reg 0.001
# Evaluation:
#
# deterministic
# #26: decades_active:2010 (3.639) -> 1.0 | #25: last_activity:still_active (3.545) -> 1.0 | #166: decades_active:2000 (2.416) -> 1.0 | #149: Labels:is_known (1.707) -> 1.0 | #260: decades_active:1990 (1.020) -> 1.0 | #247: Website:is_known (0.669) -> 1.0 | #91: decades_active:1980 (-0.040) -> 1.0 | #3: Instruments:guitar (0.023) -> -1.0 | #221: decades_active:1970 (-0.164) -> 1.0 | #43: decades_active:1960 (-0.729) -> -1.0 | #91: decades_active:1980 (-0.658) -> -0.1 | #1: Birth name:is_known (-0.638) -> -1.0 | #221: decades_active:1970 (-1.142) -> -0.1 | #26: decades_active:2010 (-1.285) -> -0.1 | #25: last_activity:still_active (-1.375) -> -0.1 | #75: Occupation:singer (-1.360) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-1.033) -> -1.0 | #354: category:List_of_deaths_in_rock_and_roll (-0.468) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.303) -> -0.1 | #354: category:List_of_deaths_in_rock_and_roll (-0.179) -> 0.0 | <end>
# true: category:List_of_lead_guitarists category:List_of_tenors_in_non-classical_music category:List_of_performers_on_Top_of_the_Pops category:List_of_Scottish_musicians
#
#
# current_greediness (0.950000)
# #26: decades_active:2010 (3.639) -> 1.0 | #25: last_activity:still_active (3.545) -> 1.0 | #166: decades_active:2000 (2.416) -> 1.0 | #149: Labels:is_known (1.707) -> 1.0 | #260: decades_active:1990 (1.020) -> 1.0 | #247: Website:is_known (0.669) -> 1.0 | #91: decades_active:1980 (-0.040) -> 1.0 | #3: Instruments:guitar (0.023) -> -1.0 | #95: Origin:angeles (-1.616) -> -1.0 | #221: decades_active:1970 (-0.397) -> 1.0 | #1: Birth name:is_known (-0.837) -> -1.0 | #91: decades_active:1980 (-1.211) -> -0.1 | #221: decades_active:1970 (-1.095) -> -0.1 | #262: Occupation:musician (-1.201) -> 1.0 | #26: decades_active:2010 (-1.319) -> -0.1 | #378: category:List_of_singer-songwriters (-1.226) -> -1.0 | #378: category:List_of_singer-songwriters (-0.925) -> -0.1 | #378: category:List_of_singer-songwriters (-0.815) -> -0.1 | #345: category:List_of_noise_musicians (-0.745) -> -1.0 | #345: category:List_of_noise_musicians (-0.280) -> 0.0 | <end>
# true: category:List_of_lead_guitarists category:List_of_tenors_in_non-classical_music category:List_of_performers_on_Top_of_the_Pops category:List_of_Scottish_musicians
# epoch 351000,loss 0.75882, greed 0.95000, rewards: ( train 2.72974, det_train 3.71215)
# rec 0.758 reg 0.001
# epoch 351100,loss 0.44675, greed 0.95000, rewards: ( train 2.68890, det_train 3.53093)
# rec 0.446 reg 0.001
# epoch 351200,loss 0.72941, greed 0.95000, rewards: ( train 3.14220, det_train 3.68184)
# rec 0.728 reg 0.001
# epoch 351300,loss 0.43435, greed 0.95000, rewards: ( train 1.61104, det_train 3.67065)
# rec 0.433 reg 0.001
# epoch 351400,loss 0.81714, greed 0.95000, rewards: ( train 2.84204, det_train 3.58359)
# rec 0.816 reg 0.001
# epoch 351500,loss 0.53036, greed 0.95000, rewards: ( train 3.18320, det_train 3.33923)
# rec 0.529 reg 0.001
# epoch 351600,loss 0.38866, greed 0.95000, rewards: ( train 2.72238, det_train 3.43931)
# rec 0.388 reg 0.001
# epoch 351700,loss 0.41468, greed 0.95000, rewards: ( train 2.73675, det_train 3.67238)
# rec 0.414 reg 0.001
# epoch 351800,loss 0.65599, greed 0.95000, rewards: ( train 2.76646, det_train 3.73714)
# rec 0.655 reg 0.001
# epoch 351900,loss 0.82336, greed 0.95000, rewards: ( train 3.04078, det_train 3.68442)
# rec 0.822 reg 0.001
# Evaluation:
#
# deterministic
# #26: decades_active:2010 (3.846) -> 1.0 | #25: last_activity:still_active (3.489) -> 1.0 | #149: Labels:is_known (2.687) -> 1.0 | #166: decades_active:2000 (2.196) -> 1.0 | #260: decades_active:1990 (1.359) -> 1.0 | #247: Website:is_known (0.810) -> 1.0 | #91: decades_active:1980 (0.337) -> 1.0 | #3: Instruments:guitar (-0.031) -> 1.0 | #167: Genres:rock (0.673) -> 1.0 | #262: Occupation:musician (0.510) -> 1.0 | #26: decades_active:2010 (-0.008) -> -0.1 | #91: decades_active:1980 (0.030) -> -0.1 | #1: Birth name:is_known (-0.021) -> -1.0 | #378: category:List_of_singer-songwriters (-0.354) -> 2.0 | #378: category:List_of_singer-songwriters (0.194) -> -0.1 | #378: category:List_of_singer-songwriters (0.496) -> -0.1 | #378: category:List_of_singer-songwriters (0.520) -> -0.1 | #378: category:List_of_singer-songwriters (0.510) -> -0.1 | #378: category:List_of_singer-songwriters (0.468) -> -0.1 | #378: category:List_of_singer-songwriters (0.388) -> 0.0 | <end>
# true: category:List_of_singer-songwriters
#
#
# current_greediness (0.950000)
# #26: decades_active:2010 (3.846) -> 1.0 | #25: last_activity:still_active (3.489) -> 1.0 | #149: Labels:is_known (2.687) -> 1.0 | #166: decades_active:2000 (2.196) -> 1.0 | #260: decades_active:1990 (1.359) -> 1.0 | #247: Website:is_known (0.810) -> 1.0 | #91: decades_active:1980 (0.337) -> 1.0 | #3: Instruments:guitar (-0.031) -> 1.0 | #167: Genres:rock (0.673) -> 1.0 | #262: Occupation:musician (0.510) -> 1.0 | #182: Origin:england (-0.769) -> -1.0 | #91: decades_active:1980 (-0.297) -> -0.1 | #378: category:List_of_singer-songwriters (-0.252) -> 2.0 | #378: category:List_of_singer-songwriters (0.252) -> -0.1 | #378: category:List_of_singer-songwriters (0.510) -> -0.1 | #378: category:List_of_singer-songwriters (0.584) -> -0.1 | #378: category:List_of_singer-songwriters (0.480) -> -0.1 | #378: category:List_of_singer-songwriters (0.446) -> -0.1 | #378: category:List_of_singer-songwriters (0.431) -> -0.1 | #378: category:List_of_singer-songwriters (0.379) -> 0.0 | <end>
# true: category:List_of_singer-songwriters
# epoch 352000,loss 0.52193, greed 0.95000, rewards: ( train 2.86975, det_train 3.69598)
# rec 0.521 reg 0.001
# epoch 352100,loss 0.55431, greed 0.95000, rewards: ( train 2.63061, det_train 3.68838)
# rec 0.553 reg 0.001
# epoch 352200,loss 0.71492, greed 0.95000, rewards: ( train 2.66821, det_train 3.35155)
# rec 0.714 reg 0.001
# epoch 352300,loss 0.69165, greed 0.95000, rewards: ( train 3.04165, det_train 3.53139)
# rec 0.691 reg 0.001
# epoch 352400,loss 0.51857, greed 0.95000, rewards: ( train 3.07084, det_train 3.75125)
# rec 0.518 reg 0.001
# epoch 352500,loss 0.55822, greed 0.95000, rewards: ( train 3.02409, det_train 3.90313)
# rec 0.557 reg 0.001
# epoch 352600,loss 0.55425, greed 0.95000, rewards: ( train 2.51337, det_train 3.92181)
# rec 0.553 reg 0.001
# epoch 352700,loss 0.67175, greed 0.95000, rewards: ( train 3.08601, det_train 3.82063)
# rec 0.671 reg 0.001

# %%
plot_scores("final")

# %%
load_random_batch(env,train_attrs,train_cats,10)
print_session(10)
# Out:
# #166: decades_active:2000 (4.409) -> 1.0 | #260: decades_active:1990 (4.266) -> -1.0 | #26: decades_active:2010 (4.100) -> 1.0 | #25: last_activity:still_active (3.116) -> 1.0 | #149: Labels:is_known (2.387) -> -1.0 | #247: Website:is_known (1.086) -> -1.0 | #166: decades_active:2000 (0.823) -> 0.0 | #3: Instruments:guitar (0.752) -> -1.0 | #166: decades_active:2000 (0.428) -> 0.0 | #26: decades_active:2010 (0.563) -> 0.0 | #166: decades_active:2000 (0.452) -> 0.0 | #149: Labels:is_known (0.409) -> 0.0 | #166: decades_active:2000 (0.285) -> 0.0 | #166: decades_active:2000 (0.087) -> 0.0 | #26: decades_active:2010 (0.069) -> 0.0 | #166: decades_active:2000 (0.004) -> 0.0 | #25: last_activity:still_active (0.096) -> 0.0 | #166: decades_active:2000 (0.035) -> 0.0 | #166: decades_active:2000 (-0.004) -> 0.0 | #166: decades_active:2000 (-0.026) -> 0.0 | <end>
# true: category:List_of_female_heavy_metal_singers category:List_of_girl_groups category:List_of_lead_vocalists
#
# #166: decades_active:2000 (4.409) -> -1.0 | #149: Labels:is_known (2.057) -> 1.0 | #239: Died:is_known (1.841) -> -1.0 | #247: Website:is_known (1.552) -> 1.0 | #3: Instruments:guitar (0.847) -> -1.0 | #1: Birth name:is_known (0.623) -> -1.0 | #149: Labels:is_known (0.202) -> 0.0 | #166: decades_active:2000 (0.182) -> 0.0 | #166: decades_active:2000 (0.082) -> 0.0 | #166: decades_active:2000 (0.070) -> 0.0 | #166: decades_active:2000 (0.058) -> 0.0 | #166: decades_active:2000 (0.010) -> 0.0 | #166: decades_active:2000 (0.002) -> 0.0 | #166: decades_active:2000 (0.001) -> 0.0 | #149: Labels:is_known (0.042) -> 0.0 | #334: category:List_of_all-female_bands (-1.123) -> -1.0 | #166: decades_active:2000 (0.117) -> 0.0 | #166: decades_active:2000 (0.138) -> 0.0 | #166: decades_active:2000 (0.133) -> 0.0 | #166: decades_active:2000 (0.064) -> 0.0 | <end>
# true: category:List_of_musicians_who_play_left-handed category:List_of_guitarists category:List_of_rhythm_guitarists
#
# #166: decades_active:2000 (4.409) -> 1.0 | #260: decades_active:1990 (4.266) -> 1.0 | #141: Genres:new (2.129) -> -1.0 | #26: decades_active:2010 (4.221) -> 1.0 | #25: last_activity:still_active (3.144) -> 1.0 | #358: category:List_of_Indian_film_music_directors (1.043) -> -1.0 | #149: Labels:is_known (2.027) -> 1.0 | #91: decades_active:1980 (1.628) -> 1.0 | #247: Website:is_known (1.319) -> 1.0 | #3: Instruments:guitar (1.159) -> 1.0 | #167: Genres:rock (1.238) -> -1.0 | #166: decades_active:2000 (0.561) -> 0.0 | #166: decades_active:2000 (0.422) -> 0.0 | #26: decades_active:2010 (0.325) -> 0.0 | #166: decades_active:2000 (0.238) -> 0.0 | #25: last_activity:still_active (0.185) -> 0.0 | #6: Occupation:radio (-1.159) -> -1.0 | #149: Labels:is_known (0.039) -> 0.0 | #166: decades_active:2000 (-0.048) -> 0.0 | #166: decades_active:2000 (-0.055) -> 0.0 | <end>
# true: category:List_of_jazz_musicians category:List_of_jazz_fusion_musicians category:List_of_jazz_guitarists
#
# #166: decades_active:2000 (4.409) -> 1.0 | #260: decades_active:1990 (4.266) -> 1.0 | #26: decades_active:2010 (4.049) -> 1.0 | #25: last_activity:still_active (3.110) -> 1.0 | #149: Labels:is_known (2.493) -> -1.0 | #91: decades_active:1980 (1.779) -> 1.0 | #3: Instruments:guitar (1.542) -> -1.0 | #91: decades_active:1980 (0.759) -> 0.0 | #221: decades_active:1970 (1.158) -> 1.0 | #167: Genres:rock (0.649) -> 1.0 | #3: Instruments:guitar (1.223) -> 0.0 | #166: decades_active:2000 (0.222) -> 0.0 | #26: decades_active:2010 (0.218) -> 0.0 | #149: Labels:is_known (0.230) -> 0.0 | #166: decades_active:2000 (0.136) -> 0.0 | #26: decades_active:2010 (0.231) -> 0.0 | #128: decades_active:1930 (-0.543) -> -1.0 | #166: decades_active:2000 (0.174) -> 0.0 | #166: decades_active:2000 (0.027) -> 0.0 | #166: decades_active:2000 (-0.093) -> 0.0 | <end>
# true: category:List_of_drummers
#
# #166: decades_active:2000 (4.409) -> 1.0 | #260: decades_active:1990 (4.266) -> 1.0 | #26: decades_active:2010 (4.049) -> 1.0 | #25: last_activity:still_active (3.110) -> 1.0 | #149: Labels:is_known (2.493) -> 1.0 | #247: Website:is_known (2.035) -> -1.0 | #91: decades_active:1980 (1.549) -> -1.0 | #166: decades_active:2000 (1.129) -> 0.0 | #3: Instruments:guitar (1.058) -> 1.0 | #167: Genres:rock (0.928) -> 1.0 | #3: Instruments:guitar (1.148) -> 0.0 | #262: Occupation:musician (1.351) -> 1.0 | #26: decades_active:2010 (0.932) -> 0.0 | #1: Birth name:is_known (0.841) -> 1.0 | #25: last_activity:still_active (0.162) -> 0.0 | #20: Instruments:vocals (0.129) -> 1.0 | #166: decades_active:2000 (0.012) -> 0.0 | #258: Genres:experimental (-0.989) -> -1.0 | #260: decades_active:1990 (-0.036) -> 0.0 | #166: decades_active:2000 (0.015) -> 0.0 | <end>
# true: category:List_of_Indian_film_music_directors category:List_of_Indian_playback_singers category:List_of_singer-songwriters
#
# #166: decades_active:2000 (4.409) -> 1.0 | #260: decades_active:1990 (4.266) -> -1.0 | #26: decades_active:2010 (4.100) -> 1.0 | #25: last_activity:still_active (3.116) -> 1.0 | #149: Labels:is_known (2.387) -> 1.0 | #247: Website:is_known (1.812) -> -1.0 | #109: Genres:music (-0.223) -> -1.0 | #166: decades_active:2000 (1.007) -> 0.0 | #166: decades_active:2000 (0.941) -> 0.0 | #166: decades_active:2000 (0.761) -> 0.0 | #26: decades_active:2010 (0.732) -> 0.0 | #149: Labels:is_known (0.643) -> 0.0 | #1: Birth name:is_known (0.572) -> 1.0 | #3: Instruments:guitar (0.235) -> -1.0 | #166: decades_active:2000 (0.136) -> 0.0 | #25: last_activity:still_active (0.016) -> 0.0 | #166: decades_active:2000 (0.056) -> 0.0 | #166: decades_active:2000 (0.041) -> 0.0 | #26: decades_active:2010 (0.057) -> 0.0 | #166: decades_active:2000 (0.064) -> 0.0 | <end>
# true: category:List_of_lead_vocalists
#
# #166: decades_active:2000 (4.409) -> 1.0 | #260: decades_active:1990 (4.266) -> 1.0 | #26: decades_active:2010 (4.049) -> 1.0 | #25: last_activity:still_active (3.110) -> 1.0 | #149: Labels:is_known (2.493) -> 1.0 | #247: Website:is_known (2.035) -> 1.0 | #3: Instruments:guitar (1.253) -> -1.0 | #26: decades_active:2010 (0.929) -> 0.0 | #91: decades_active:1980 (1.104) -> 1.0 | #260: decades_active:1990 (0.626) -> 0.0 | #166: decades_active:2000 (0.417) -> 0.0 | #149: Labels:is_known (0.418) -> 0.0 | #166: decades_active:2000 (0.299) -> 0.0 | #1: Birth name:is_known (0.269) -> 1.0 | #26: decades_active:2010 (0.206) -> 0.0 | #166: decades_active:2000 (0.065) -> 0.0 | #25: last_activity:still_active (0.011) -> 0.0 | #166: decades_active:2000 (0.023) -> 0.0 | #166: decades_active:2000 (0.029) -> 0.0 | #260: decades_active:1990 (0.009) -> 0.0 | <end>
# true:
#
# #166: decades_active:2000 (4.409) -> -1.0 | #149: Labels:is_known (2.057) -> 1.0 | #239: Died:is_known (1.841) -> -1.0 | #247: Website:is_known (1.552) -> -1.0 | #20: Instruments:vocals (1.148) -> 1.0 | #3: Instruments:guitar (1.664) -> 1.0 | #167: Genres:rock (1.101) -> 1.0 | #262: Occupation:musician (1.009) -> 1.0 | #82: Instruments:bass (0.728) -> 1.0 | #82: Instruments:bass (0.780) -> 0.0 | #82: Instruments:bass (0.721) -> 0.0 | #82: Instruments:bass (0.601) -> 0.0 | #82: Instruments:bass (0.446) -> 0.0 | #82: Instruments:bass (0.350) -> 0.0 | #82: Instruments:bass (0.256) -> 0.0 | #82: Instruments:bass (0.158) -> 0.0 | #166: decades_active:2000 (0.086) -> 0.0 | #149: Labels:is_known (0.145) -> 0.0 | #166: decades_active:2000 (0.101) -> 0.0 | #166: decades_active:2000 (0.122) -> 0.0 | <end>
# true: category:List_of_alternative_rock_artists
#
# #166: decades_active:2000 (4.409) -> 1.0 | #260: decades_active:1990 (4.266) -> 1.0 | #26: decades_active:2010 (4.049) -> -1.0 | #91: decades_active:1980 (3.703) -> 1.0 | #239: Died:is_known (3.108) -> 1.0 | #221: decades_active:1970 (2.604) -> 1.0 | #43: decades_active:1960 (1.387) -> 1.0 | #45: decades_active:1950 (1.486) -> 1.0 | #9: Genres:electropop (-0.054) -> -1.0 | #149: Labels:is_known (1.240) -> 1.0 | #166: decades_active:2000 (0.644) -> 0.0 | #1: Birth name:is_known (0.519) -> -1.0 | #166: decades_active:2000 (0.206) -> 0.0 | #26: decades_active:2010 (0.070) -> 0.0 | #166: decades_active:2000 (0.086) -> 0.0 | #149: Labels:is_known (0.043) -> 0.0 | #166: decades_active:2000 (0.016) -> 0.0 | #26: decades_active:2010 (0.062) -> 0.0 | #166: decades_active:2000 (0.040) -> 0.0 | #166: decades_active:2000 (0.063) -> 0.0 | <end>
# true: category:List_of_soul_musicians category:List_of_performers_on_Top_of_the_Pops category:List_of_deaths_in_rock_and_roll category:List_of_guitarists category:List_of_bass_guitarists
#
# #166: decades_active:2000 (4.409) -> 1.0 | #260: decades_active:1990 (4.266) -> 1.0 | #26: decades_active:2010 (4.049) -> 1.0 | #25: last_activity:still_active (3.110) -> 1.0 | #149: Labels:is_known (2.493) -> 1.0 | #247: Website:is_known (2.035) -> -1.0 | #91: decades_active:1980 (1.549) -> 1.0 | #3: Instruments:guitar (1.233) -> 1.0 | #167: Genres:rock (1.396) -> 1.0 | #3: Instruments:guitar (1.393) -> 0.0 | #262: Occupation:musician (1.442) -> -1.0 | #26: decades_active:2010 (1.019) -> 0.0 | #166: decades_active:2000 (0.744) -> 0.0 | #1: Birth name:is_known (0.638) -> 1.0 | #26: decades_active:2010 (0.192) -> 0.0 | #20: Instruments:vocals (0.254) -> 1.0 | #166: decades_active:2000 (-0.041) -> 0.0 | #25: last_activity:still_active (-0.059) -> 0.0 | #260: decades_active:1990 (0.087) -> 0.0 | #166: decades_active:2000 (0.001) -> 0.0 | <end>
# true: category:List_of_soft_rock_artists_and_songs category:List_of_singer-songwriters category:List_of_Canadian_musicians

# %%
print_session(display=True,legend=False)

# %%
load_random_batch(env,test_attrs,test_cats,10)
print_session(10)

# %%
print_session(display=True,legend=False)
