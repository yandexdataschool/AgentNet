# %%
#experiment name and snapshot folder (used for model persistence)
experiment_setup_name = "tutorial.wikicat.advanced"
snapshot_path = "/home/jheuristic/yozhik/agentnet_snapshots/"

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline


#theano imports
#the problem is too simple to be run on GPU. Seriously.
# %env THEANO_FLAGS='device=cpu'
import theano
import theano.tensor as T
floatX = theano.config.floatX

import lasagne
# Out:
# env: THEANO_FLAGS='device=cpu'

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # This tutorial vuilds above the basic tutorial and shows several advanced tools
# * multi-layer (and in principle, arbitrary) agent memory
# * different reinforcement learning algorithms
# * model persistence
#
# __[todo: add more]__

# %% [markdown]
# # Experiment setup
# * Here we load an experiment environment (description below)
# * Designing one from scratch is explained in later tutorials

# %%
import agentnet.experiments.wikicat as experiment
print experiment.__doc__
# Out:
# This experiment Wikipedia data sample on musicians, scraped via the scripts present in this directory.
# For each musician, we know a number of boolean features (factors) on various topics like
#  * whether or not he/she was active in 1990's, 2000's, etc.
#  * whether or not he/she plays guitar, piano, etc
#  * whether or not he/she was born in 50's, 60's, etc.
#  * what wikipedia categories does he/she belong to
#  etc.
#
#
#
# In the initial moment of time, agent knows nothing about any of them.
# At each turn, agent may decide to
#  - "open" one of the hidden factors.
#    - if the factor turns out to be 1, agent receives +3 reward for Wikipedia categories, +1 for other categories,
#    - Otherwise, the reward equals -1 for Wikipedia categories, -1 for other categores
#    - all these rewards are parameterisable during environment creation
#  - decide to quit session
#    - yields reward of 0 and ends the interaction.
#    - all farther actions will have no effect until next session
#
# It is expected, that in order to maximize it's expected reward, the agent
# will converge to a strategy of polling several key features and then utilizing learned
# dependencies between these factors and other ones. For example, if a particular genre was
# popular during particular decays, it makes sense to poll genres and than "open" the corresponding
# most probable years.
#
# The experiment setup contains a single class WikicatEnvironment that
# implements both BaseEnvironment and BaseObjective.

# %%
#Create an environment with all default parameters
env = experiment.WikicatEnvironment()

# %%
from sklearn.cross_validation import train_test_split
attrs, categories, feature_names = env.get_dataset(experiment_path="")

train_attrs,test_attrs,train_cats,test_cats = train_test_split(attrs,categories,test_size=0.99,random_state=32)

print "train size:", train_attrs.shape,train_cats.shape
print "train size:", test_attrs.shape,test_cats.shape

print "features:",feature_names[::20]
# Out:
# train size: (85, 300) (85, 93)
# train size: (8509, 300) (8509, 93)
# features: ['Children:is_known', 'Instruments:vocals', 'Genres:electronic', 'Origin:scotland', 'Genres:jazz', 'Genres:electric', 'Occupation:bassist', 'Instruments:violin', 'Genres:instrumental', 'Occupation:entrepreneur', 'Instruments:mandolin', 'Instruments:vocalist', 'Genres:synthpop', 'decades_active:1990', 'Occupation:remixer', 'category:List_of_musical_artists_from_Japan', 'category:List_of_ambient_music_artists', 'category:List_of_crooners', 'category:List_of_country_music_performers', 'category:List_of_bass_guitarists']

# %%
env.load_random_batch(train_attrs,train_cats,5)

# %% [markdown]
# # agent setup
# * An agent implementation has to contain three parts:
#  * Memory layer(s)
#   * in this case, we train two GRU layers [details below]
#  * Q-values evaluation layers
#   * in this case, a lasagne dense layer based on memory layer
#  * Resolver - acton picker layer
#   * in this case, the resolver has epsilon-greedy policy
#
#
# ### two-layer memory architecture
# We train two memory states:
#   * first one, based on observations,
#   * second one, based on first one;
#
# Note that here we update the second memory layer based on the CURRENT state
# of the first one. Instead, you can try to feed it with a previous state.
#
# The q-values are estimated on a concatenated state, effectively on both memory
# states together, but there is no problem with limiting q-evaluator to only one:
# just pass the correct gru layer as an incoming layer to the q-evaluator.
#
# ### Implementation:
# We concatenate both memories into 1 state to pass it through the session loop.
#
# To perform memory update, we need to slice the concatenated state back into
# two memory states.
#
# We do so by defining an input map function and passing it into agent.
#
# We than concatenate two new states back to form a new memory state.

# %%
from agentnet.resolver import EpsilonGreedyResolver
from agentnet.memory import GRUMemoryLayer
from agentnet.agent import Agent

# %%
import lasagne
n_hid_1=128 #first GRU memory
n_hid_2=64 #second GRU memory


_observation_layer = lasagne.layers.InputLayer([None,env.observation_size],name="obs_input")

_prev_gru1_layer = lasagne.layers.InputLayer([None,n_hid_1],name="prev_gru1_state_input")
_prev_gru2_layer = lasagne.layers.InputLayer([None,n_hid_2],name="prev_gru2_state_input")

#memory
gru1 = GRUMemoryLayer(n_hid_1,
                     _observation_layer,
                     _prev_gru1_layer,
                     name="gru1")

gru2 = GRUMemoryLayer(n_hid_2,
                     gru1,        #note that it takes CURRENT gru1 output as input.
                                  #replacing that with _prev_gru1_state would imply taking previous one.
                     _prev_gru2_layer,
                     name="gru2")

concatenated_memory = lasagne.layers.concat([gru1,gru2])

#q_eval
n_actions = len(feature_names)
q_eval = lasagne.layers.DenseLayer(concatenated_memory, #taking both memories. 
                                                        #Replacing with gru1 or gru2 would mean taking one
                                   num_units = n_actions,
                                   nonlinearity=lasagne.nonlinearities.linear,name="QEvaluator")
#resolver
epsilon = theano.shared(np.float32(0.1),"e-greedy.epsilon")

resolver = EpsilonGreedyResolver(q_eval,epsilon=epsilon,name="resolver")



from collections import OrderedDict
#all together
agent = Agent(_observation_layer,
              OrderedDict([
                    (gru1,_prev_gru1_layer),
                    (gru2,_prev_gru2_layer)
              ]),
              q_eval,resolver)

# %%
#Since it's a single lasagne network, one can get it's weights, output, etc
weights = lasagne.layers.get_all_params(resolver,trainable=True)
weights
# Out:
# [gru1.W_in_to_updategate,
#  gru1.W_hid_to_updategate,
#  gru1.b_updategate,
#  gru1.W_in_to_resetgate,
#  gru1.W_hid_to_resetgate,
#  gru1.b_resetgate,
#  gru1.W_in_to_hidden_update,
#  gru1.W_hid_to_hidden_update,
#  gru1.b_hidden_update,
#  gru2.W_in_to_updategate,
#  gru2.W_hid_to_updategate,
#  gru2.b_updategate,
#  gru2.W_in_to_resetgate,
#  gru2.W_hid_to_resetgate,
#  gru2.b_resetgate,
#  gru2.W_in_to_hidden_update,
#  gru2.W_hid_to_hidden_update,
#  gru2.b_hidden_update,
#  QEvaluator.W,
#  QEvaluator.b]

# %% [markdown]
# ## Agent setup in detail
# * __Memory layers__
#  * One-step recurrent layer
#      * takes input and one's previous state
#      * returns new memory state
#    * Can be arbitrary lasagne layer
#    * Several one-step recurrent units are implemented in __agentnet.memory__
#    * Note that lasagne's default recurrent networks roll for several steps at once
#      * in other words, __using lasagne recurrent units as memory means recurrence inside recurrence__
#  * Using more than one memory layer is explained in farther tutorials
#
#
# * __Q-values evaluation layer__
#  * Can be arbitrary lasagne network
#  * returns predicted Q-values for each action
#  * Usually depends on memory as an input
#
#
# * __Resolver__ - action picker
#  * Decides on what action is taken
#  * Normally takes Q-values as input
#  * Currently all experiments require integer output
#  * Several resolver layers are implemented in __agentnet.resolver__

# %% [markdown]
# # Interacting with environment
# * an agent has a method that produces symbolic environment interaction sessions
# * interactions result in sequences of observations, actions, q-values,etc
# * one has to pre-define maximum session length.
#  * in this case, environment implements an indicator of whether session has ended by current tick
# * Since this environment also implements Objective methods, it can evaluate rewards for each [batch, time_tick]

# %%
#produce interaction sequences of length <= 10
state_seq,observation_seq,agent_state,action_seq,qvalues_seq = agent.get_sessions(
    env,
    session_length=10,
    batch_size=env.batch_size,
)


gru1_seq = agent_state[gru1]
gru2_seq = agent_state[gru2]

#get rewards for all actions
rewards_seq = env.get_reward_sequences(state_seq,action_seq)

#get indicator whether session is still active
is_alive_seq = env.get_whether_alive(observation_seq)

# %% [markdown]
# # Evaluating loss function
# * This part is similar to the basic tutorial but for the fact that we use 3-step q-learning
#
#
#  #### Get (prediction,reference) pairs

# %%
#get reference Qvalues according to Qlearning algorithm


from agentnet.learning import qlearning_n_step

#gamma - delayed reward coefficient - what fraction of reward is retained if it is obtained one tick later
gamma = theano.shared(np.float32(0.95),name = 'q_learning_gamma')


reference_Qvalues = qlearning_n_step.get_reference_Qvalues(qvalues_seq,
                               action_seq,
                               rewards_seq,
                               n_steps=3,
                               gamma_or_gammas=gamma,)

# %%
#zero-out future rewards at session end
from agentnet.utils.mdp import get_end_indicator

end_action_ids = get_end_indicator(is_alive_seq).nonzero()

# "set reference Qvalues at end action ids to just the immediate rewards"
reference_Qvalues = T.set_subtensor(reference_Qvalues[end_action_ids],
                                    rewards_seq[end_action_ids])

# %%
#prevent gradient updates over reference Qvalues (since they depend on predicted Qvalues)
from agentnet.utils import consider_constant
reference_Qvalues = consider_constant(reference_Qvalues)

# %%
from agentnet.utils.mdp import get_action_Qvalues
action_Qvalues = get_action_Qvalues(qvalues_seq,action_seq)

# %% [markdown]
# #### Define loss functions

# %%
#tensor of elementwise squared errors
squared_error = lasagne.objectives.squared_error(reference_Qvalues,action_Qvalues)

#zero-out ticks after session ended
squared_error = squared_error * is_alive_seq

#compute average of squared error sums per session
mse_loss = squared_error.sum() / is_alive_seq.sum()

# %%
#regularize network weights

from lasagne.regularization import regularize_network_params, l2
reg_l2 = regularize_network_params(resolver,l2)*10**-4

# %%
loss = mse_loss + reg_l2

# %% [markdown]
# #### Compute weight updates

# %%
updates = lasagne.updates.adadelta(loss,
                                             weights,learning_rate=0.01)

# %% [markdown]
# #### Some auxilary evaluation metrics

# %%
mean_session_reward = rewards_seq.sum(axis=1).mean()
#...

# %% [markdown]
# # Compile train and evaluation functions

# %%
train_fun = theano.function([],[loss,mean_session_reward],updates=updates)

evaluation_fun = theano.function([],[loss,mse_loss,reg_l2,mean_session_reward])

# %% [markdown]
# # session visualization tools
#
#
# * this is a completely optional step of visualizing agent's sessions as chains of actions
# * usually useful to get insight on what worked and what din't
# * in this case, we print strings following pattern
#   * [action_name] ([predicted action qvalue]) -> reward [reference qvalue] | next iteration
#
# * plot shows
#     * time ticks over X, abstract values over Y
#     * bold lines are Qvalues for actions
#     * dots on bold lines represent what actions were taken at each moment of time
#     * dashed lines are agent's hidden state neurons
#     * blue vertical line - session end
#
#
# __Warning! the visualization tools are underdeveloped and only allow simple operations.__
#
# if you found yourself struggling to make it do what you want for 5 minutes, go write your own tool [and contribute it :)]

# %%
from agentnet.display.sessions import print_sessions
get_printables = theano.function([], [
        gru2_seq,qvalues_seq, action_seq,rewards_seq,reference_Qvalues,is_alive_seq
    ])

def display_sessions(with_plots = False):
        
    hidden_log,qvalues_log,actions_log,reward_log, reference_qv_log, is_alive_log = get_printables()
    
    
    print_sessions(qvalues_log,actions_log,reward_log,
                   is_alive_seq = is_alive_log,
                   #hidden_seq=hidden_log, #do not plot hidden since there's too many actions already
                   reference_policy_seq = reference_qv_log,
                   action_names=feature_names,
                   legend = False, #do not show legend since there's too many labeled objects
                  plot_policy = with_plots)

# %%
#visualize untrained network performance (which is mostly random)
env.load_random_batch(train_attrs,train_cats,1)
display_sessions(with_plots=True)
# Out:
# session # 0
#  Children:is_known(qv = 0.0) -> -1.0(ref = -0.885345876217) |  category:List_of_banjo_players(qv = 0.120688542724) -> -1.0(ref = -2.75329017639) |  category:List_of_progressive_rock_supergroups(qv = 0.124997913837) -> -1.0(ref = -1.84556865692) |  Origin:japan(qv = 0.107538074255) -> -1.0(ref = -0.890072286129) |  Origin:france(qv = 0.115713402629) -> -1.0(ref = -2.74716377258) |  Height:is_known(qv = 0.131285354495) -> -1.0(ref = -1.83911991119) |  Genres:contemporary(qv = -0.134226471186) -> -1.0(ref = -0.883284211159) |  category:List_of_gospel_musicians(qv = 0.122858732939) -> -1.0(ref = -1.95000004768) |  last_activity:1989(qv = -0.106627136469) -> -1.0(ref = -1.0) |  decades_active:1990(qv = 0.125021219254) -> 0.0(ref = 0.0) | reached max session length

# %% [markdown]
# # Training loop

# %%
#tools for model persistence (in progress now. Requires unique names)
from agentnet.utils.persistence import save,load
import os

# %%
from agentnet.display import Metrics
score_log = Metrics()

# %%
#starting epoch
epoch_counter = 1

#moving average estimation
alpha = 0.1
ma_reward_current = -7.
ma_reward_greedy = -7.

# %%
n_epochs = 100000
batch_size= 10

for i in range(n_epochs):    
    
    #train
    env.load_random_batch(train_attrs,train_cats,batch_size)
    resolver.rng.seed(i)    
    loss,avg_reward = train_fun()
    
    
    
    ##update resolver's epsilon (chance of random action instead of optimal one)
    if epoch_counter%10 ==0:
        current_epsilon =  0.05 + 0.95*np.exp(-epoch_counter/10000.)
        resolver.epsilon.set_value(np.float32(current_epsilon))
    
    
    
    ##record current learning progress and show learning curves
    if epoch_counter%100 ==0:

        ##update learning curves
        full_loss, q_loss, l2_penalty, avg_reward_current = evaluation_fun()
        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current
        score_log["expected e-greedy reward"][epoch_counter] = ma_reward_current
        
        
        
        #greedy train
        resolver.epsilon.set_value(0)
        avg_reward_greedy = evaluation_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["expected greedy reward"][epoch_counter] = ma_reward_greedy
        
        
        #back to epsilon-greedy
        resolver.epsilon.set_value(np.float32(current_epsilon))

        print "epoch %i,loss %.5f, epsilon %.5f, rewards: ( e-greedy %.5f, greedy %.5f) "%(
            epoch_counter,full_loss,current_epsilon,ma_reward_current,ma_reward_greedy)
        print "rec %.3f reg %.3f"%(q_loss,l2_penalty)

    if epoch_counter %1000 ==0:
        print "Learning curves:"
        score_log.plot()


        print "Random session examples"
        env.load_random_batch(train_attrs,train_cats,3)
        display_sessions(with_plots=False)
    
    #save snapshot
    if epoch_counter %10000 ==0:
        snap_name = "{}.epoch{}.pcl".format(os.path.join(snapshot_path,experiment_setup_name), epoch_counter)
        save(resolver,snap_name)
        print "saved", snap_name

        
        
    epoch_counter  +=1

    
# Time to drink some coffee!
# Out:
# epoch 100,loss 2.74287, epsilon 0.99055, rewards: ( e-greedy -7.04000, greedy -6.94000)
# rec 2.479 reg 0.264
# epoch 200,loss 3.10190, epsilon 0.98119, rewards: ( e-greedy -7.14600, greedy -6.97100)
# rec 2.838 reg 0.264
# epoch 300,loss 2.89930, epsilon 0.97192, rewards: ( e-greedy -7.22640, greedy -6.91390)
# rec 2.636 reg 0.264
# epoch 400,loss 3.05706, epsilon 0.96275, rewards: ( e-greedy -7.36876, greedy -6.97251)
# rec 2.793 reg 0.264
# epoch 500,loss 2.94012, epsilon 0.95367, rewards: ( e-greedy -7.41188, greedy -6.93526)
# rec 2.677 reg 0.264
# epoch 600,loss 2.55562, epsilon 0.94468, rewards: ( e-greedy -7.39570, greedy -6.95673)
# rec 2.292 reg 0.263
# epoch 700,loss 2.66205, epsilon 0.93577, rewards: ( e-greedy -7.37613, greedy -7.04106)
# rec 2.399 reg 0.263
# epoch 800,loss 2.72028, epsilon 0.92696, rewards: ( e-greedy -7.32351, greedy -7.12195)
# rec 2.457 reg 0.263
# epoch 900,loss 2.73510, epsilon 0.91823, rewards: ( e-greedy -7.34616, greedy -7.12976)
# rec 2.472 reg 0.263
# epoch 1000,loss 2.76402, epsilon 0.90960, rewards: ( e-greedy -7.39155, greedy -7.04178)
# rec 2.501 reg 0.263
# Learning curves:
# Random session examples
# session # 0
#  Instruments:organ(qv = -0.0126906316727) -> -1.0(ref = -0.900823056698) |  Genres:thrash(qv = -0.0349345803261) -> -1.0(ref = -2.75357699394) |  Instruments:guitar(qv = -0.000734981149435) -> -1.0(ref = -1.84587049484) |  Awards:is_known(qv = -0.0018014293164) -> -1.0(ref = -0.890389978886) |  decades_active:before_1920(qv = -0.0985494032502) -> -1.0(ref = -2.75491213799) |  category:List_of_performers_on_Top_of_the_Pops(qv = 0.119205124676) -> -1.0(ref = -1.84727597237) |  Genres:soft(qv = -0.00420634960756) -> -1.0(ref = -0.891869425774) |  category:List_of_J-pop_artists(qv = -0.115917176008) -> -1.0(ref = -1.95000004768) |  Instruments:vocals(qv = -0.00675578601658) -> -1.0(ref = -1.0) |  decades_active:before_1920(qv = 0.00260036392137) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Instruments:drum(qv = -0.0131963249296) -> -1.0(ref = -0.915930390358) |  Genres:celtic(qv = 0.00159658072516) -> -1.0(ref = -2.74907398224) |  Residence:is_known(qv = 0.030301168561) -> -1.0(ref = -1.84113049507) |  category:List_of_jazz_fusion_musicians(qv = 0.00214078696445) -> -1.0(ref = -0.885400474072) |  category:List_of_music_arrangers(qv = 0.0178749468178) -> -1.0(ref = -2.72698402405) |  Occupation:entrepreneur(qv = -0.022100975737) -> -1.0(ref = -1.81787776947) |  first_activity:1989(qv = -0.0511670932174) -> -1.0(ref = -0.860923886299) |  Genres:roll(qv = 0.146395921707) -> -1.0(ref = -1.95000004768) |  Occupation:producer(qv = 0.218123778701) -> -1.0(ref = -1.0) |  Instruments:vocal(qv = -0.0747407227755) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Religion:is_known(qv = -0.00541172549129) -> -1.0(ref = -0.92196893692) |  Genres:band(qv = -0.050696041435) -> -1.0(ref = -2.74829053879) |  Origin:angeles(qv = -0.00966482795775) -> -1.0(ref = -1.84030580521) |  Occupation:activist(qv = -0.0119382385164) -> -1.0(ref = -0.88453245163) |  last_activity:2004(qv = -0.0278166364878) -> -1.0(ref = -2.75772976875) |  Genres:thrash(qv = 0.00557830650359) -> -1.0(ref = -1.85024189949) |  category:List_of_Nigerian_musicians(qv = -0.0740206539631) -> -1.0(ref = -0.894991517067) |  category:List_of_alternative_country_musicians(qv = 0.110535256565) -> -1.0(ref = -1.95000004768) |  Occupation:director(qv = -0.0111650507897) -> -1.0(ref = -1.0) |  first_activity:1953(qv = -0.01875667274) -> 0.0(ref = 0.0) | reached max session length
# epoch 1100,loss 2.71849, epsilon 0.90104, rewards: ( e-greedy -7.38239, greedy -7.01260)
# rec 2.456 reg 0.263
# epoch 1200,loss 2.72055, epsilon 0.89257, rewards: ( e-greedy -7.36415, greedy -6.98134)
# rec 2.458 reg 0.263
# epoch 1300,loss 3.08309, epsilon 0.88419, rewards: ( e-greedy -7.48274, greedy -6.96321)
# rec 2.820 reg 0.263
# epoch 1400,loss 2.64560, epsilon 0.87589, rewards: ( e-greedy -7.44946, greedy -6.81689)
# rec 2.383 reg 0.263
# epoch 1500,loss 2.75547, epsilon 0.86767, rewards: ( e-greedy -7.44452, greedy -6.87520)
# rec 2.493 reg 0.262
# epoch 1600,loss 2.88306, epsilon 0.85954, rewards: ( e-greedy -7.43507, greedy -6.68268)
# rec 2.621 reg 0.262
# epoch 1700,loss 2.69573, epsilon 0.85148, rewards: ( e-greedy -7.44656, greedy -6.50441)
# rec 2.434 reg 0.262
# epoch 1800,loss 2.81626, epsilon 0.84351, rewards: ( e-greedy -7.47190, greedy -6.51397)
# rec 2.554 reg 0.262
# epoch 1900,loss 2.58653, epsilon 0.83561, rewards: ( e-greedy -7.47471, greedy -6.42757)
# rec 2.325 reg 0.262
# epoch 2000,loss 2.60911, epsilon 0.82779, rewards: ( e-greedy -7.43224, greedy -6.32482)
# rec 2.347 reg 0.262
# Learning curves:
# Random session examples
# session # 0
#  Origin:india(qv = -0.0141865769401) -> -1.0(ref = -0.941348552704) |  first_activity:1968(qv = -0.0407541878521) -> -1.0(ref = -2.75826573372) |  Political party:is_known(qv = 0.0455283895135) -> -1.0(ref = -1.85080599785) |  Genres:nu(qv = -0.119257740676) -> -1.0(ref = -0.895585179329) |  Occupation:poet(qv = -0.0546972453594) -> -1.0(ref = -2.77584457397) |  Genres:latin(qv = -0.112965941429) -> -1.0(ref = -1.86931014061) |  Instruments:saxophone(qv = -0.0639033615589) -> -1.0(ref = -0.91506332159) |  Instruments:vocals(qv = 0.0894070267677) -> 1.0(ref = 0.0500000119209) |  Origin:korea(qv = 0.119702942669) -> -1.0(ref = -1.0) |  Origin:california(qv = 0.0842252597213) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  first_activity:1947(qv = -0.0159067604691) -> -1.0(ref = -0.897644639015) |  category:List_of_jazz_saxophonists(qv = -0.0479734055698) -> -1.0(ref = -2.75515222549) |  Genres:industrial(qv = -0.096469014883) -> -1.0(ref = -1.84752869606) |  category:List_of_bands_with_more_than_one_lead_vocalist(qv = -0.00257354322821) -> -1.0(ref = -0.892135500908) |  category:List_of_trumpeters(qv = -0.0927662402391) -> -1.0(ref = -2.77054858208) |  Origin:ontario(qv = -0.0662180483341) -> -1.0(ref = -1.86373531818) |  last_activity:1998(qv = 0.00600599590689) -> -1.0(ref = -0.909195065498) |  category:List_of_hip_hop_musicians_from_New_York_City(qv = -0.0562737137079) -> -1.0(ref = -1.95000004768) |  Genres:blues[1](qv = 0.120399743319) -> -1.0(ref = -1.0) |  Genres:reggae(qv = -0.0778870433569) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Genres:rap(qv = -0.0210302397609) -> -1.0(ref = -0.940320312977) |  Occupation:instrumentalist(qv = -0.0290832035244) -> -1.0(ref = -2.75920677185) |  Instruments:keyboard(qv = 0.0207116100937) -> -1.0(ref = -1.85179662704) |  category:List_of_hip_hop_musicians_from_New_York_City(qv = -0.0758114904165) -> -1.0(ref = -0.896628081799) |  Genres:symphonic(qv = -0.0803814530373) -> -1.0(ref = -2.73900365829) |  Origin:georgia(qv = -0.153777435422) -> -1.0(ref = -1.83053028584) |  category:List_of_Asian-American_hip_hop_musicians(qv = -0.0249438472092) -> -1.0(ref = -0.874242424965) |  category:List_of_Scottish_musicians(qv = -0.100528925657) -> -1.0(ref = -1.95000004768) |  Occupation:film(qv = 0.114503324032) -> -1.0(ref = -1.0) |  Genres:rap(qv = -0.107069499791) -> 0.0(ref = 0.0) | reached max session length
# epoch 2100,loss 2.86680, epsilon 0.82006, rewards: ( e-greedy -7.55402, greedy -6.36233)
# rec 2.605 reg 0.262
# epoch 2200,loss 2.74487, epsilon 0.81239, rewards: ( e-greedy -7.55862, greedy -6.35610)
# rec 2.483 reg 0.262
# epoch 2300,loss 2.64654, epsilon 0.80481, rewards: ( e-greedy -7.52275, greedy -6.23049)
# rec 2.385 reg 0.262
# epoch 2400,loss 2.47888, epsilon 0.79730, rewards: ( e-greedy -7.44548, greedy -6.20244)
# rec 2.217 reg 0.261
# epoch 2500,loss 2.47129, epsilon 0.78986, rewards: ( e-greedy -7.44593, greedy -6.17720)
# rec 2.210 reg 0.261
# epoch 2600,loss 3.01328, epsilon 0.78250, rewards: ( e-greedy -7.39634, greedy -5.69448)
# rec 2.752 reg 0.261
# epoch 2700,loss 3.09107, epsilon 0.77521, rewards: ( e-greedy -7.34670, greedy -5.02503)
# rec 2.830 reg 0.261
# epoch 2800,loss 2.36149, epsilon 0.76799, rewards: ( e-greedy -7.30203, greedy -4.74253)
# rec 2.100 reg 0.261
# epoch 2900,loss 2.83926, epsilon 0.76085, rewards: ( e-greedy -7.16683, greedy -4.29827)
# rec 2.578 reg 0.261
# epoch 3000,loss 2.64053, epsilon 0.75378, rewards: ( e-greedy -6.98515, greedy -3.82845)
# rec 2.379 reg 0.261
# Learning curves:
# Random session examples
# session # 0
#  Label(s):is_known(qv = -0.0599743500352) -> -1.0(ref = -0.939906358719) |  decades_active:2000(qv = 0.063256457448) -> 1.0(ref = -0.830506682396) |  last_activity:1998(qv = -0.130682677031) -> -1.0(ref = -1.92684912682) |  category:List_of_musicians_from_Chicago(qv = 0.0488549731672) -> -1.0(ref = -0.975630760193) |  Genres:west(qv = 0.0256518181413) -> -1.0(ref = -2.83791565895) |  Genres:ska(qv = -0.339189887047) -> -1.0(ref = -1.93464803696) |  Occupation:tv(qv = -0.0210099648684) -> -1.0(ref = -0.983839988708) |  Occupation:comedian(qv = -0.29332703352) -> -1.0(ref = -1.95000004768) |  Origin:australia(qv = -0.233438909054) -> -1.0(ref = -1.0) |  Occupation:guitarist(qv = -0.206186547875) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Origin:scotland(qv = -0.0796618312597) -> -1.0(ref = -0.98506218195) |  category:List_of_Canadian_composers(qv = -0.164543896914) -> -1.0(ref = -2.81920337677) |  Origin:u.s.(qv = -0.14072099328) -> -1.0(ref = -1.91495096684) |  category:List_of_Christian_hip_hop_and_rap_artists(qv = -0.131337940693) -> -1.0(ref = -0.963106274605) |  Instruments:acoustic(qv = -0.103061228991) -> -1.0(ref = -1.04207181931) |  Relatives:is_known(qv = -0.111683398485) -> -1.0(ref = -0.0442861318588) |  decades_active:2000(qv = 0.00719622336328) -> 1.0(ref = 1.00601458549) |  Partner(s):is_known(qv = -0.190375089645) -> -1.0(ref = -1.95000004768) |  first_activity:1956(qv = -0.121381945908) -> -1.0(ref = -1.0) |  category:List_of_Arabic_pop_musicians(qv = 0.0123091954738) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Origin:chicago(qv = -0.0402256175876) -> -1.0(ref = -0.96233612299) |  Alma mater:is_known(qv = -0.0788958072662) -> -1.0(ref = -1.01734519005) |  Occupation:tv(qv = -0.0737939924002) -> -1.0(ref = -0.0182581543922) |  Birth name:is_known(qv = 0.0548562295735) -> 1.0(ref = 1.03341245651) |  decades_active:2000(qv = 0.0351709537208) -> 1.0(ref = -0.36397087574) |  Genres:coast(qv = -0.147789388895) -> -1.0(ref = -1.43575882912) |  decades_active:2000(qv = 0.0828442275524) -> -0.5(ref = -0.458693474531) |  Parent(s):is_known(qv = -0.448713898659) -> -1.0(ref = -1.47500002384) |  decades_active:2000(qv = -0.0217736661434) -> -0.5(ref = -0.5) |  Relatives:is_known(qv = -0.246296152472) -> 0.0(ref = 0.0) | reached max session length
# epoch 3100,loss 2.24753, epsilon 0.74677, rewards: ( e-greedy -6.74663, greedy -3.34560)
# rec 1.986 reg 0.261
# epoch 3200,loss 2.44473, epsilon 0.73984, rewards: ( e-greedy -6.52697, greedy -3.07604)
# rec 2.184 reg 0.261
# epoch 3300,loss 2.53141, epsilon 0.73298, rewards: ( e-greedy -6.42427, greedy -2.76844)
# rec 2.270 reg 0.261
# epoch 3400,loss 2.11749, epsilon 0.72618, rewards: ( e-greedy -6.12184, greedy -2.41159)
# rec 1.857 reg 0.261
# epoch 3500,loss 2.34599, epsilon 0.71945, rewards: ( e-greedy -6.07466, greedy -2.17043)
# rec 2.085 reg 0.261
# epoch 3600,loss 2.12971, epsilon 0.71279, rewards: ( e-greedy -5.84719, greedy -1.87839)
# rec 1.869 reg 0.261
# epoch 3700,loss 2.12398, epsilon 0.70620, rewards: ( e-greedy -5.52748, greedy -1.61555)
# rec 1.863 reg 0.261
# epoch 3800,loss 2.17852, epsilon 0.69967, rewards: ( e-greedy -5.31473, greedy -1.37900)
# rec 1.918 reg 0.261
# epoch 3900,loss 1.85749, epsilon 0.69320, rewards: ( e-greedy -5.02325, greedy -1.14110)
# rec 1.597 reg 0.261
# epoch 4000,loss 2.00186, epsilon 0.68680, rewards: ( e-greedy -4.83093, greedy -0.92699)
# rec 1.741 reg 0.261
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 0.0232865475118) -> 1.0(ref = 1.02754020691) |  Origin:los(qv = -0.34258928895) -> -1.0(ref = -1.0) |
#
# session # 1
#  Origin:germany(qv = -0.104593895376) -> -1.0(ref = -1.00428259373) |  Origin:michigan(qv = -0.169219464064) -> -1.0(ref = -0.144634902477) |  decades_active:2000(qv = -0.0490002855659) -> 1.0(ref = 1.0) |
#
# session # 2
#  Genres:synthpop(qv = -0.107886575162) -> -1.0(ref = -1.03514111042) |  decades_active:2000(qv = -0.0369906052947) -> 1.0(ref = -0.930239200592) |  Genres:celtic(qv = -0.440042316914) -> -1.0(ref = -2.03183078766) |  category:List_of_Arabic_pop_musicians(qv = -0.281376630068) -> -1.0(ref = -1.0861376524) |  Genres:avant-garde(qv = -0.478617280722) -> -1.0(ref = -3.07577824593) |  Instruments:sampler(qv = -0.545550704002) -> -1.0(ref = -2.1850297451) |  Instruments:vocals(qv = -0.203311085701) -> -1.0(ref = -1.24739980698) |  Relatives:is_known(qv = -0.73453605175) -> -1.0(ref = -1.95000004768) |  category:List_of_individual_K-pop_artists(qv = -0.445186197758) -> -1.0(ref = -1.0) |
#
# epoch 4100,loss 2.29614, epsilon 0.68047, rewards: ( e-greedy -4.63784, greedy -0.77429)
# rec 2.035 reg 0.261
# epoch 4200,loss 1.28396, epsilon 0.67419, rewards: ( e-greedy -4.37405, greedy -0.59686)
# rec 1.023 reg 0.261
# epoch 4300,loss 1.91240, epsilon 0.66798, rewards: ( e-greedy -4.21165, greedy -0.43717)
# rec 1.652 reg 0.261
# epoch 4400,loss 1.94793, epsilon 0.66183, rewards: ( e-greedy -4.02548, greedy -0.31846)
# rec 1.687 reg 0.261
# epoch 4500,loss 1.06759, epsilon 0.65575, rewards: ( e-greedy -3.79293, greedy -0.18661)
# rec 0.807 reg 0.261
# epoch 4600,loss 1.34023, epsilon 0.64972, rewards: ( e-greedy -3.62364, greedy -0.11795)
# rec 1.079 reg 0.261
# epoch 4700,loss 1.55513, epsilon 0.64375, rewards: ( e-greedy -3.44128, greedy -0.00615)
# rec 1.294 reg 0.261
# epoch 4800,loss 1.65681, epsilon 0.63784, rewards: ( e-greedy -3.48215, greedy 0.01946)
# rec 1.396 reg 0.261
# epoch 4900,loss 1.66990, epsilon 0.63200, rewards: ( e-greedy -3.38893, greedy 0.09251)
# rec 1.409 reg 0.261
# epoch 5000,loss 1.80751, epsilon 0.62620, rewards: ( e-greedy -3.43004, greedy 0.13326)
# rec 1.547 reg 0.261
# Learning curves:
# Random session examples
# session # 0
#  Genres:heavy(qv = -0.216327339411) -> -1.0(ref = -1.0225468874) |  decades_active:2000(qv = -0.0237336233258) -> 1.0(ref = 1.0) |
#
# session # 1
#  Origin:michigan(qv = -0.19277150929) -> -1.0(ref = -1.00037956238) |  first_activity:1971(qv = -0.42990514636) -> -1.0(ref = 0.717542052269) |  Genres:progressive(qv = -0.913175880909) -> 1.0(ref = 1.80793905258) |  decades_active:2000(qv = -0.162787184119) -> 1.0(ref = 1.0) |
#
# session # 2
#  decades_active:2000(qv = 0.0573006756604) -> 1.0(ref = 0.984753906727) |  Instruments:vocalist(qv = -0.331353902817) -> -1.0(ref = -2.51651668549) |  decades_active:2000(qv = -0.0871350467205) -> -0.5(ref = -1.59633338451) |  category:List_of_gospel_musicians(qv = -1.05156242847) -> -1.0(ref = -1.15403521061) |  last_activity:1989(qv = -1.21816289425) -> -1.0(ref = -2.99285316467) |  Occupation:saxophonist(qv = -1.36719977856) -> -1.0(ref = -2.09774017334) |  Genres:rap(qv = -1.34362053871) -> -1.0(ref = -1.0) |
#
# epoch 5100,loss 1.50810, epsilon 0.62047, rewards: ( e-greedy -3.37704, greedy 0.19494)
# rec 1.248 reg 0.261
# epoch 5200,loss 1.47216, epsilon 0.61479, rewards: ( e-greedy -3.16933, greedy 0.22544)
# rec 1.212 reg 0.261
# epoch 5300,loss 1.30737, epsilon 0.60917, rewards: ( e-greedy -3.18240, greedy 0.25290)
# rec 1.047 reg 0.260
# epoch 5400,loss 1.54332, epsilon 0.60361, rewards: ( e-greedy -3.12916, greedy 0.32761)
# rec 1.283 reg 0.260
# epoch 5500,loss 1.55502, epsilon 0.59810, rewards: ( e-greedy -2.93124, greedy 0.39485)
# rec 1.295 reg 0.260
# epoch 5600,loss 0.98481, epsilon 0.59265, rewards: ( e-greedy -2.80812, greedy 0.45536)
# rec 0.724 reg 0.260
# epoch 5700,loss 1.42258, epsilon 0.58725, rewards: ( e-greedy -2.87731, greedy 0.50983)
# rec 1.162 reg 0.260
# epoch 5800,loss 1.46361, epsilon 0.58190, rewards: ( e-greedy -2.81458, greedy 0.52384)
# rec 1.203 reg 0.260
# epoch 5900,loss 1.35148, epsilon 0.57661, rewards: ( e-greedy -2.75312, greedy 0.51146)
# rec 1.091 reg 0.260
# epoch 6000,loss 1.39545, epsilon 0.57137, rewards: ( e-greedy -2.79281, greedy 0.48031)
# rec 1.135 reg 0.260
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 0.101069912314) -> 1.0(ref = 1.0) |
#
# session # 1
#  decades_active:2000(qv = 0.101069912314) -> 1.0(ref = 0.961012482643) |  Genres:bop(qv = -0.478386163712) -> -1.0(ref = 2.5707256794) |  decades_active:1990(qv = -0.061957269907) -> 1.0(ref = 3.75865864754) |  category:List_of_adult_alternative_artists(qv = -0.813317000866) -> 3.0(ref = 3.0) |
#
# session # 2
#  decades_active:2000(qv = 0.101069919765) -> 1.0(ref = 0.961012482643) |  category:List_of_deaths_in_rock_and_roll(qv = -0.416456699371) -> -1.0(ref = -2.99703931808) |  first_activity:1977(qv = -1.10197758675) -> -1.0(ref = -2.10214662552) |  category:List_of_rhythm_guitarists(qv = -0.837785243988) -> -1.0(ref = -1.16015422344) |  decades_active:1990(qv = -0.168583422899) -> 1.0(ref = -0.898693323135) |  Occupation:comedian(qv = -1.61600625515) -> -1.0(ref = -1.99862456322) |  Genres:hip(qv = -1.09197986126) -> -1.0(ref = -1.05118381977) |  Origin:washington(qv = -1.0784163475) -> -1.0(ref = -1.95000004768) |  Birth name:is_known(qv = -0.0724409893155) -> -1.0(ref = -1.0) |  Birth name:is_known(qv = -0.10034352541) -> 0.0(ref = 0.0) | reached max session length
# epoch 6100,loss 1.21821, epsilon 0.56618, rewards: ( e-greedy -2.75353, greedy 0.44228)
# rec 0.958 reg 0.260
# epoch 6200,loss 1.33895, epsilon 0.56105, rewards: ( e-greedy -2.78317, greedy 0.44805)
# rec 1.079 reg 0.260
# epoch 6300,loss 1.16929, epsilon 0.55596, rewards: ( e-greedy -2.68986, greedy 0.50325)
# rec 0.910 reg 0.260
# epoch 6400,loss 1.45092, epsilon 0.55093, rewards: ( e-greedy -2.51087, greedy 0.48292)
# rec 1.191 reg 0.260
# epoch 6500,loss 1.80570, epsilon 0.54594, rewards: ( e-greedy -2.45478, greedy 0.46463)
# rec 1.546 reg 0.260
# epoch 6600,loss 1.08226, epsilon 0.54101, rewards: ( e-greedy -2.37931, greedy 0.50317)
# rec 0.823 reg 0.259
# epoch 6700,loss 1.56247, epsilon 0.53612, rewards: ( e-greedy -2.57637, greedy 0.43285)
# rec 1.303 reg 0.259
# epoch 6800,loss 1.47601, epsilon 0.53129, rewards: ( e-greedy -2.50374, greedy 0.45457)
# rec 1.217 reg 0.259
# epoch 6900,loss 1.76172, epsilon 0.52650, rewards: ( e-greedy -2.28836, greedy 0.47911)
# rec 1.502 reg 0.259
# epoch 7000,loss 1.10811, epsilon 0.52176, rewards: ( e-greedy -2.21453, greedy 0.51620)
# rec 0.849 reg 0.259
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 0.157316416502) -> 1.0(ref = 1.0) |
#
# session # 1
#  decades_active:2000(qv = 0.157316416502) -> 1.0(ref = 0.948814153671) |  category:List_of_blues_musicians(qv = -0.656892776489) -> -1.0(ref = -1.1669626236) |  Occupation:drummer(qv = -0.94318574667) -> -1.0(ref = -0.175750136375) |  decades_active:1990(qv = -0.0534685328603) -> 1.0(ref = 1.0) |
#
# session # 2
#  decades_active:2000(qv = 0.157316416502) -> -1.0(ref = -1.0289952755) |  category:List_of_musicians_who_play_left-handed(qv = -0.54213064909) -> -1.0(ref = -1.09776723385) |  Occupation:songwriter(qv = -0.449532449245) -> 1.0(ref = -0.102912902832) |  Origin:san(qv = -1.38735282421) -> -1.0(ref = -1.1609609127) |  category:List_of_noise_musicians(qv = -1.0754673481) -> -1.0(ref = -2.97131872177) |  category:List_of_flautists(qv = -1.12529635429) -> -1.0(ref = -2.07507228851) |  Occupation:pianist(qv = -1.02482390404) -> -1.0(ref = -1.13165521622) |  Birth name:is_known(qv = -0.138584405184) -> -1.0(ref = -0.0500000119209) |  Instruments:vocals(qv = -0.16624994576) -> 1.0(ref = 1.0) |  category:List_of_progressive_rock_supergroups(qv = -1.27571284771) -> 0.0(ref = 0.0) | reached max session length
# epoch 7100,loss 1.47175, epsilon 0.51706, rewards: ( e-greedy -2.17307, greedy 0.42458)
# rec 1.213 reg 0.259
# epoch 7200,loss 1.27912, epsilon 0.51241, rewards: ( e-greedy -2.32577, greedy 0.36212)
# rec 1.020 reg 0.259
# epoch 7300,loss 1.16830, epsilon 0.50781, rewards: ( e-greedy -2.40819, greedy 0.39591)
# rec 0.909 reg 0.259
# epoch 7400,loss 1.57202, epsilon 0.50326, rewards: ( e-greedy -2.46737, greedy 0.39632)
# rec 1.313 reg 0.259
# epoch 7500,loss 1.24249, epsilon 0.49875, rewards: ( e-greedy -2.46063, greedy 0.45669)
# rec 0.984 reg 0.259
# epoch 7600,loss 1.54977, epsilon 0.49428, rewards: ( e-greedy -2.43957, greedy 0.49102)
# rec 1.291 reg 0.259
# epoch 7700,loss 1.20312, epsilon 0.48986, rewards: ( e-greedy -2.49561, greedy 0.39692)
# rec 0.945 reg 0.258
# epoch 7800,loss 1.19993, epsilon 0.48549, rewards: ( e-greedy -2.52105, greedy 0.37722)
# rec 0.942 reg 0.258
# epoch 7900,loss 1.43246, epsilon 0.48115, rewards: ( e-greedy -2.74395, greedy 0.18450)
# rec 1.174 reg 0.258
# epoch 8000,loss 1.40876, epsilon 0.47686, rewards: ( e-greedy -2.61455, greedy 0.25105)
# rec 1.151 reg 0.258
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 0.240071594715) -> 1.0(ref = 0.987709403038) |  first_activity:1956(qv = -0.534666955471) -> -1.0(ref = 0.746255517006) |  decades_active:1990(qv = -0.034256644547) -> 1.0(ref = 1.83816373348) |  decades_active:2010(qv = -0.222791537642) -> 1.0(ref = 0.882277607918) |  Labels:is_known(qv = -0.123918309808) -> -1.0(ref = -1.1774392128) |  Origin:south(qv = -1.261942029) -> -1.0(ref = -0.186778128147) |  Birth name:is_known(qv = -0.0878805965185) -> 1.0(ref = 0.856023013592) |  Instruments:vocals(qv = -0.151554718614) -> -1.0(ref = -1.47500002384) |  Birth name:is_known(qv = -0.152069732547) -> -0.5(ref = -0.5) |  Instruments:vocals(qv = -0.141037151217) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:2000(qv = 0.240071594715) -> 1.0(ref = 0.987709403038) |  Labels:is_known(qv = -0.012937489897) -> 1.0(ref = 1.37545084953) |  decades_active:1990(qv = -0.0425043217838) -> 1.0(ref = 0.395211458206) |  decades_active:1990(qv = -0.10790348053) -> -0.5(ref = -0.636619508266) |  Instruments:vocal(qv = -1.10873627663) -> -1.0(ref = -1.09375572205) |  last_activity:still_active(qv = -0.170409500599) -> 1.0(ref = -0.0986902713776) |  Birth name:is_known(qv = -0.13076877594) -> -1.0(ref = -1.15651607513) |  Instruments:vocals(qv = -0.164753824472) -> 1.0(ref = 0.0500000119209) |  Genres:ambient(qv = -1.26728928089) -> -1.0(ref = -1.0) |  Birth name:is_known(qv = -0.141781911254) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  first_activity:1974(qv = -0.244092434645) -> 1.0(ref = 1.16206884384) |  Instruments:bass(qv = -0.499091267586) -> -1.0(ref = -2.96349048615) |  Genres:score(qv = -0.695112526417) -> -1.0(ref = -2.06683206558) |  last_activity:2001(qv = -1.0317813158) -> -1.0(ref = -1.12298130989) |  Birth name:is_known(qv = -0.12945407629) -> 1.0(ref = -1.01641869545) |  Origin:australia(qv = -1.15893793106) -> -1.0(ref = -2.12254595757) |  Occupation:educator(qv = -1.0253893137) -> -1.0(ref = -1.18162739277) |  Occupation:film(qv = -1.30666971207) -> -1.0(ref = -1.47500002384) |  Birth name:is_known(qv = -0.114545233548) -> -0.5(ref = -0.5) |  Instruments:vocals(qv = -0.130947262049) -> 0.0(ref = 0.0) | reached max session length
# epoch 8100,loss 1.27838, epsilon 0.47262, rewards: ( e-greedy -2.52810, greedy 0.28595)
# rec 1.020 reg 0.258
# epoch 8200,loss 1.45991, epsilon 0.46841, rewards: ( e-greedy -2.48029, greedy 0.27235)
# rec 1.202 reg 0.258
# epoch 8300,loss 1.51717, epsilon 0.46425, rewards: ( e-greedy -2.52226, greedy 0.30512)
# rec 1.259 reg 0.258
# epoch 8400,loss 1.45162, epsilon 0.46012, rewards: ( e-greedy -2.57003, greedy 0.31960)
# rec 1.194 reg 0.258
# epoch 8500,loss 1.57281, epsilon 0.45604, rewards: ( e-greedy -2.48803, greedy 0.40264)
# rec 1.315 reg 0.258
# epoch 8600,loss 1.29350, epsilon 0.45200, rewards: ( e-greedy -2.29923, greedy 0.65738)
# rec 1.036 reg 0.258
# epoch 8700,loss 1.38008, epsilon 0.44800, rewards: ( e-greedy -2.19930, greedy 0.70664)
# rec 1.123 reg 0.258
# epoch 8800,loss 1.26651, epsilon 0.44404, rewards: ( e-greedy -2.15937, greedy 0.84598)
# rec 1.009 reg 0.257
# epoch 8900,loss 1.15552, epsilon 0.44012, rewards: ( e-greedy -2.23844, greedy 0.71138)
# rec 0.898 reg 0.257
# epoch 9000,loss 1.31086, epsilon 0.43624, rewards: ( e-greedy -2.18959, greedy 0.80024)
# rec 1.054 reg 0.257
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 0.370869159698) -> -1.0(ref = -0.81593477726) |  decades_active:2000(qv = 0.193752855062) -> -0.5(ref = -0.41848385334) |  Labels:is_known(qv = 0.142683207989) -> 1.0(ref = 0.0858064889908) |  decades_active:1990(qv = 0.118747860193) -> -1.0(ref = -0.962308943272) |  last_activity:still_active(qv = 0.0396747849882) -> -1.0(ref = -2.83478116989) |  Birth name:is_known(qv = 0.0551942028105) -> -1.0(ref = -1.93134868145) |  category:List_of_Scottish_musicians(qv = -1.17724573612) -> -1.0(ref = -0.980367064476) |  category:List_of_Polish_musicians_and_musical_groups(qv = -0.946194112301) -> -1.0(ref = -1.95000004768) |  Native name:is_known(qv = -0.845900177956) -> -1.0(ref = -1.0) |  decades_active:1970(qv = -0.72560274601) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:2000(qv = 0.370869159698) -> 1.0(ref = 1.14723002911) |  Occupation:dancer(qv = -0.636213302612) -> -1.0(ref = -1.02006399632) |  Genres:roll(qv = -0.785719811916) -> -1.0(ref = -0.0211199522018) |  Labels:is_known(qv = 0.0792953819036) -> 1.0(ref = 1.03040003777) |  Genres:experimental(qv = -1.13052117825) -> -1.0(ref = 0.867344856262) |  last_activity:still_active(qv = 0.0555115528405) -> 1.0(ref = 1.96562623978) |  Birth name:is_known(qv = 0.058380600065) -> 1.0(ref = 1.01644873619) |  Occupation:singer(qv = -0.631693661213) -> -1.0(ref = -0.0500000119209) |  first_activity:1986(qv = -0.974880039692) -> 1.0(ref = 1.0) |  Birth name:is_known(qv = 0.0837931409478) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Occupation:musician(qv = -0.110786445439) -> -1.0(ref = -0.598114967346) |  Genres:j-pop(qv = -0.534696578979) -> -1.0(ref = -0.986588835716) |  category:List_of_R%26B_musicians(qv = -0.523808300495) -> -1.0(ref = 0.0141170024872) |  decades_active:1990(qv = 0.164206475019) -> 1.0(ref = 1.06749165058) |  Labels:is_known(qv = 0.0710438266397) -> 1.0(ref = 1.060998559) |  Birth name:is_known(qv = 0.0666800811887) -> 1.0(ref = 0.064208984375) |  Genres:west(qv = -1.01259064674) -> -1.0(ref = -0.985043168068) |  Origin:atlanta(qv = -1.18492174149) -> -1.0(ref = -1.95000004768) |  category:List_of_girl_groups(qv = -1.07427453995) -> -1.0(ref = -1.0) |  Birth name:is_known(qv = 0.159126356244) -> 0.0(ref = 0.0) | reached max session length
# epoch 9100,loss 1.50688, epsilon 0.43240, rewards: ( e-greedy -2.39063, greedy 0.71022)
# rec 1.250 reg 0.257
# epoch 9200,loss 1.53232, epsilon 0.42859, rewards: ( e-greedy -2.41657, greedy 0.67420)
# rec 1.275 reg 0.257
# epoch 9300,loss 1.64130, epsilon 0.42483, rewards: ( e-greedy -2.24491, greedy 0.73678)
# rec 1.384 reg 0.257
# epoch 9400,loss 1.07662, epsilon 0.42110, rewards: ( e-greedy -2.18542, greedy 0.89310)
# rec 0.820 reg 0.257
# epoch 9500,loss 1.21407, epsilon 0.41740, rewards: ( e-greedy -2.03188, greedy 0.99879)
# rec 0.957 reg 0.257
# epoch 9600,loss 1.49929, epsilon 0.41375, rewards: ( e-greedy -1.86869, greedy 1.06391)
# rec 1.243 reg 0.257
# epoch 9700,loss 1.40577, epsilon 0.41013, rewards: ( e-greedy -1.62182, greedy 1.16752)
# rec 1.149 reg 0.257
# epoch 9800,loss 1.17503, epsilon 0.40655, rewards: ( e-greedy -1.65964, greedy 1.07577)
# rec 0.919 reg 0.256
# epoch 9900,loss 1.23044, epsilon 0.40300, rewards: ( e-greedy -1.57868, greedy 1.00319)
# rec 0.974 reg 0.256
# epoch 10000,loss 1.24254, epsilon 0.39949, rewards: ( e-greedy -1.50081, greedy 1.00287)
# rec 0.986 reg 0.256
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 0.527805864811) -> 1.0(ref = 1.31309294701) |  Labels:is_known(qv = 0.329571545124) -> 1.0(ref = -0.695704817772) |  Occupation:remixer(qv = -1.02313351631) -> -1.0(ref = -1.78495240211) |  Residence:is_known(qv = -0.831288874149) -> -1.0(ref = -0.826265692711) |  decades_active:1990(qv = 0.182878211141) -> 1.0(ref = 2.8873872757) |  Birth name:is_known(qv = 0.115067943931) -> 1.0(ref = 1.98672330379) |  last_activity:still_active(qv = 0.0421885363758) -> 1.0(ref = 1.03865611553) |  decades_active:1980(qv = -0.124268569052) -> 1.0(ref = 0.524999976158) |  last_activity:still_active(qv = 0.0560524314642) -> -0.5(ref = -0.5) |  Instruments:and(qv = -0.947831749916) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Genres:electro(qv = -0.270367980003) -> -1.0(ref = -0.33743584156) |  decades_active:2000(qv = 0.697435975075) -> 1.0(ref = -0.622144699097) |  Genres:coast(qv = -0.895193696022) -> -1.0(ref = -1.70752072334) |  first_activity:1986(qv = -0.932587981224) -> -1.0(ref = -0.744758725166) |  Instrument(s):is_known(qv = -0.950020074844) -> -1.0(ref = 0.904898643494) |  Labels:is_known(qv = 0.217497527599) -> 1.0(ref = 2.00515651703) |  Birth name:is_known(qv = 0.195761099458) -> 1.0(ref = 1.05805945396) |  Genres:psychedelic(qv = -1.19512867928) -> -1.0(ref = -1.95000004768) |  last_activity:1995(qv = -1.24974620342) -> -1.0(ref = -1.0) |  Instruments:flute(qv = -1.33896422386) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Instruments:banjo(qv = -0.26510438323) -> -1.0(ref = -0.382671177387) |  Known for:is_known(qv = -0.580827891827) -> -1.0(ref = 1.05145549774) |  decades_active:2000(qv = 0.540193319321) -> 1.0(ref = 2.15942692757) |  decades_active:1990(qv = 0.335427999496) -> 1.0(ref = 1.22044944763) |  Labels:is_known(qv = 0.232052117586) -> 1.0(ref = 0.974045038223) |  Birth name:is_known(qv = 0.182188719511) -> -1.0(ref = -0.0273210406303) |  last_activity:still_active(qv = 0.117755256593) -> 1.0(ref = 1.02387261391) |  Instruments:vocals(qv = 0.025129083544) -> 1.0(ref = 0.524999976158) |  last_activity:still_active(qv = 0.035602722317) -> -0.5(ref = -0.5) |  Instruments:vocals(qv = 0.0397732295096) -> 0.0(ref = 0.0) | reached max session length
# saved /home/jheuristic/yozhik/agentnet_snapshots/tutorial.wikicat.advanced.epoch10000.pcl
# epoch 10100,loss 1.84600, epsilon 0.39601, rewards: ( e-greedy -1.51573, greedy 1.03258)
# rec 1.590 reg 0.256
# epoch 10200,loss 1.24434, epsilon 0.39257, rewards: ( e-greedy -1.48415, greedy 1.00433)
# rec 0.988 reg 0.256
# epoch 10300,loss 1.50088, epsilon 0.38916, rewards: ( e-greedy -1.57574, greedy 0.94389)
# rec 1.245 reg 0.256
# epoch 10400,loss 1.25432, epsilon 0.38578, rewards: ( e-greedy -1.54317, greedy 0.97950)
# rec 0.998 reg 0.256
# epoch 10500,loss 1.38798, epsilon 0.38244, rewards: ( e-greedy -1.58885, greedy 0.96155)
# rec 1.132 reg 0.256
# epoch 10600,loss 1.34072, epsilon 0.37913, rewards: ( e-greedy -1.37496, greedy 1.09540)
# rec 1.085 reg 0.256
# epoch 10700,loss 1.43378, epsilon 0.37586, rewards: ( e-greedy -1.31247, greedy 1.05086)
# rec 1.178 reg 0.256
# epoch 10800,loss 1.41587, epsilon 0.37262, rewards: ( e-greedy -1.15122, greedy 1.24077)
# rec 1.160 reg 0.256
# epoch 10900,loss 1.04058, epsilon 0.36941, rewards: ( e-greedy -1.18610, greedy 1.22670)
# rec 0.785 reg 0.255
# epoch 11000,loss 1.40829, epsilon 0.36623, rewards: ( e-greedy -1.19749, greedy 1.35403)
# rec 1.153 reg 0.255
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 0.712977051735) -> -1.0(ref = -0.449067115784) |  decades_active:2000(qv = 0.579929351807) -> -0.5(ref = -0.139439314604) |  Labels:is_known(qv = 0.58000177145) -> 1.0(ref = 0.379537582397) |  Origin:city(qv = -0.751945376396) -> -1.0(ref = -0.653118312359) |  decades_active:1990(qv = 0.365138620138) -> -1.0(ref = -0.869081199169) |  Birth name:is_known(qv = 0.303573638201) -> 1.0(ref = 0.137809276581) |  last_activity:still_active(qv = 0.217974692583) -> -1.0(ref = -0.907569169998) |  last_activity:still_active(qv = 0.0972956195474) -> -0.5(ref = -1.45000004768) |  Alma mater:is_known(qv = -0.922976613045) -> -1.0(ref = -1.0) |  Genres:gothic(qv = -0.852301061153) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:2000(qv = 0.712977051735) -> -1.0(ref = -0.449067115784) |  Political party:is_known(qv = -0.498623490334) -> -1.0(ref = -2.52495384216) |  first_activity:1983(qv = -0.505696237087) -> -1.0(ref = -1.60521459579) |  Genres:contemporary(qv = -0.818728625774) -> -1.0(ref = -0.637067973614) |  category:List_of_jazz_drummers(qv = -0.87714189291) -> -1.0(ref = -0.880933523178) |  Birth name:is_known(qv = 0.322598963976) -> 1.0(ref = 0.12533313036) |  last_activity:still_active(qv = 0.17140775919) -> -1.0(ref = -0.920701980591) |  last_activity:still_active(qv = 0.0834716334939) -> -0.5(ref = -1.45000004768) |  Origin:australia(qv = -0.824952423573) -> -1.0(ref = -1.0) |  Website:is_known(qv = 0.0790553614497) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Genres:rockabilly(qv = -0.232017889619) -> -1.0(ref = -0.106344819069) |  decades_active:2000(qv = 0.940689682961) -> 1.0(ref = 1.39296352863) |  Labels:is_known(qv = 0.639329493046) -> 1.0(ref = 0.413645863533) |  first_activity:1950(qv = -0.847280681133) -> -1.0(ref = -0.617214918137) |  decades_active:1990(qv = 0.402931690216) -> 1.0(ref = 1.04233026505) |  Birth name:is_known(qv = 0.324449062347) -> -1.0(ref = 0.0445581674576) |  last_activity:still_active(qv = 0.244154945016) -> 1.0(ref = 1.0995349884) |  decades_active:2010(qv = 0.104773655534) -> 1.0(ref = 0.524999976158) |  decades_active:2010(qv = 0.130207970738) -> -0.5(ref = -0.5) |  decades_active:2010(qv = 0.114280998707) -> 0.0(ref = 0.0) | reached max session length
# epoch 11100,loss 1.32871, epsilon 0.36308, rewards: ( e-greedy -1.21774, greedy 1.22862)
# rec 1.073 reg 0.255
# epoch 11200,loss 1.14311, epsilon 0.35997, rewards: ( e-greedy -1.13597, greedy 1.39576)
# rec 0.888 reg 0.255
# epoch 11300,loss 1.10739, epsilon 0.35688, rewards: ( e-greedy -1.04237, greedy 1.48618)
# rec 0.852 reg 0.255
# epoch 11400,loss 1.33703, epsilon 0.35383, rewards: ( e-greedy -1.14813, greedy 1.38757)
# rec 1.082 reg 0.255
# epoch 11500,loss 1.32078, epsilon 0.35080, rewards: ( e-greedy -1.10832, greedy 1.45881)
# rec 1.066 reg 0.255
# epoch 11600,loss 1.31117, epsilon 0.34781, rewards: ( e-greedy -1.05249, greedy 1.46293)
# rec 1.056 reg 0.255
# epoch 11700,loss 1.44577, epsilon 0.34485, rewards: ( e-greedy -1.00224, greedy 1.56664)
# rec 1.191 reg 0.255
# epoch 11800,loss 1.05606, epsilon 0.34191, rewards: ( e-greedy -0.98201, greedy 1.56497)
# rec 0.801 reg 0.255
# epoch 11900,loss 1.54207, epsilon 0.33901, rewards: ( e-greedy -0.97381, greedy 1.51848)
# rec 1.288 reg 0.255
# epoch 12000,loss 1.59208, epsilon 0.33613, rewards: ( e-greedy -0.96143, greedy 1.53163)
# rec 1.338 reg 0.254
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 0.916893482208) -> 1.0(ref = 1.71771812439) |  Labels:is_known(qv = 0.755492866039) -> 1.0(ref = 1.51134371758) |  decades_active:1990(qv = 0.733162343502) -> 1.0(ref = 0.538256645203) |  Genres:electronic(qv = -0.893356084824) -> -1.0(ref = -0.486045658588) |  Birth name:is_known(qv = 0.541004598141) -> 1.0(ref = 3.07010245323) |  last_activity:still_active(qv = 0.391047328711) -> 1.0(ref = 2.17905521393) |  Genres:avant-garde(qv = -0.821233689785) -> 1.0(ref = 1.2411108017) |  last_activity:still_active(qv = 0.25380089879) -> -0.5(ref = 0.449999988079) |  decades_active:2010(qv = 0.14985178411) -> 1.0(ref = 1.0) |  decades_active:2010(qv = 0.117969028652) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:2000(qv = 0.916893482208) -> 1.0(ref = 1.71771812439) |  Labels:is_known(qv = 0.755492866039) -> -1.0(ref = -0.643720567226) |  Genres:blues(qv = -0.691292583942) -> -1.0(ref = 0.375030994415) |  decades_active:1990(qv = 0.575556635857) -> 1.0(ref = 1.44740104675) |  Birth name:is_known(qv = 0.470948398113) -> 1.0(ref = -0.193424344063) |  Genres:rap(qv = -0.73428273201) -> -1.0(ref = -1.25623619556) |  Birth name:is_known(qv = 0.251478374004) -> -0.5(ref = -0.269722342491) |  last_activity:still_active(qv = 0.242397531867) -> 1.0(ref = 1.95000004768) |  decades_active:2010(qv = 0.123350284994) -> 1.0(ref = 1.0) |  category:List_of_new-age_music_artists(qv = -1.15509223938) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  category:List_of_trumpeters(qv = -0.284522205591) -> -1.0(ref = 0.0479559898376) |  decades_active:2000(qv = 1.10311162472) -> 1.0(ref = -0.355942487717) |  Instruments:keyboard(qv = -0.664818644524) -> -1.0(ref = -1.42730784416) |  Origin:angeles(qv = -0.76516777277) -> -1.0(ref = -0.449797809124) |  Origin:kingston(qv = -0.976677238941) -> -1.0(ref = -0.691218495369) |  decades_active:1990(qv = 0.448504596949) -> 1.0(ref = 0.325033187866) |  category:List_of_South_Korean_musicians(qv = -1.04244887829) -> -1.0(ref = -0.710491418839) |  Birth name:is_known(qv = 0.304745852947) -> 1.0(ref = 1.95000004768) |  last_activity:still_active(qv = 0.2516079247) -> 1.0(ref = 1.0) |  decades_active:2010(qv = 0.0986588522792) -> 0.0(ref = 0.0) | reached max session length
# epoch 12100,loss 1.36860, epsilon 0.33329, rewards: ( e-greedy -0.73029, greedy 1.70846)
# rec 1.114 reg 0.254
# epoch 12200,loss 1.44334, epsilon 0.33047, rewards: ( e-greedy -0.60226, greedy 1.78762)
# rec 1.189 reg 0.254
# epoch 12300,loss 1.74335, epsilon 0.32768, rewards: ( e-greedy -0.68203, greedy 1.61886)
# rec 1.489 reg 0.254
# epoch 12400,loss 1.73726, epsilon 0.32492, rewards: ( e-greedy -0.64883, greedy 1.62197)
# rec 1.483 reg 0.254
# epoch 12500,loss 1.41071, epsilon 0.32218, rewards: ( e-greedy -0.65395, greedy 1.68977)
# rec 1.157 reg 0.254
# epoch 12600,loss 1.87961, epsilon 0.31947, rewards: ( e-greedy -0.86355, greedy 1.44080)
# rec 1.626 reg 0.254
# epoch 12700,loss 1.27591, epsilon 0.31679, rewards: ( e-greedy -0.72720, greedy 1.50172)
# rec 1.022 reg 0.254
# epoch 12800,loss 1.27536, epsilon 0.31414, rewards: ( e-greedy -0.53448, greedy 1.66155)
# rec 1.022 reg 0.254
# epoch 12900,loss 1.55284, epsilon 0.31151, rewards: ( e-greedy -0.58603, greedy 1.54039)
# rec 1.299 reg 0.254
# epoch 13000,loss 1.19346, epsilon 0.30891, rewards: ( e-greedy -0.51243, greedy 1.66135)
# rec 0.940 reg 0.254
# Learning curves:
# Random session examples
# session # 0
#  Instruments:vocalist(qv = -0.270214378834) -> -1.0(ref = 0.460320472717) |  decades_active:2000(qv = 1.53717947006) -> -1.0(ref = -2.28461408615) |  Labels:is_known(qv = 0.962861061096) -> -1.0(ref = -1.35222554207) |  decades_active:1990(qv = 0.798148810863) -> -1.0(ref = -0.370763659477) |  Birth name:is_known(qv = 0.662354052067) -> 1.0(ref = -0.742429733276) |  last_activity:still_active(qv = 0.551763355732) -> -1.0(ref = -1.83413660526) |  decades_active:2010(qv = 0.295601457357) -> -1.0(ref = -0.878038525581) |  Genres:swing(qv = -0.623497128487) -> -1.0(ref = -1.47500002384) |  decades_active:1990(qv = 0.121636264026) -> -0.5(ref = -0.5) |  last_activity:still_active(qv = 0.0782535821199) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:2000(qv = 1.12174105644) -> 1.0(ref = 1.90917110443) |  Labels:is_known(qv = 0.957022309303) -> 1.0(ref = 3.46478867531) |  decades_active:1990(qv = 0.933769702911) -> 1.0(ref = 2.59451436996) |  Birth name:is_known(qv = 0.805265665054) -> 1.0(ref = 1.67843604088) |  Genres:pop(qv = -0.274279028177) -> 1.0(ref = -0.0838707685471) |  Genres:latin(qv = -0.760704159737) -> -1.0(ref = -1.14091658592) |  Birth name:is_known(qv = 0.458004951477) -> -0.5(ref = -0.148333311081) |  last_activity:still_active(qv = 0.37017545104) -> 1.0(ref = 1.95000004768) |  decades_active:2010(qv = 0.21043124795) -> 1.0(ref = 1.0) |  decades_active:2010(qv = 0.0819757804275) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:2000(qv = 1.12174093723) -> 1.0(ref = 1.90917134285) |  Labels:is_known(qv = 0.957022547722) -> 1.0(ref = -0.289914131165) |  Genres:traditional(qv = -0.936296641827) -> -1.0(ref = -1.35780441761) |  Genres:bebop(qv = -0.77670699358) -> -1.0(ref = -0.376636207104) |  category:List_of_Maryland_music_people(qv = -0.841380834579) -> -1.0(ref = -0.769482135773) |  category:List_of_bebop_musicians(qv = -0.762628912926) -> -1.0(ref = 0.242650389671) |  Birth name:is_known(qv = 0.405602484941) -> 1.0(ref = 1.30805301666) |  last_activity:still_active(qv = 0.324266403913) -> 1.0(ref = 0.0500000119209) |  decades_active:1920(qv = -0.984966039658) -> -1.0(ref = -1.0) |  decades_active:1990(qv = 0.0783253088593) -> 0.0(ref = 0.0) | reached max session length
# epoch 13100,loss 1.42917, epsilon 0.30633, rewards: ( e-greedy -0.58118, greedy 1.59022)
# rec 1.176 reg 0.253
# epoch 13200,loss 1.31400, epsilon 0.30378, rewards: ( e-greedy -0.35307, greedy 1.77119)
# rec 1.061 reg 0.253
# epoch 13300,loss 1.21752, epsilon 0.30125, rewards: ( e-greedy -0.24776, greedy 1.85908)
# rec 0.964 reg 0.253
# epoch 13400,loss 1.56239, epsilon 0.29875, rewards: ( e-greedy -0.14298, greedy 1.84317)
# rec 1.309 reg 0.253
# epoch 13500,loss 1.31301, epsilon 0.29628, rewards: ( e-greedy -0.10868, greedy 1.89385)
# rec 1.060 reg 0.253
# epoch 13600,loss 1.42145, epsilon 0.29383, rewards: ( e-greedy 0.06218, greedy 1.97447)
# rec 1.168 reg 0.253
# epoch 13700,loss 1.49220, epsilon 0.29140, rewards: ( e-greedy 0.21097, greedy 2.11702)
# rec 1.239 reg 0.253
# epoch 13800,loss 1.17083, epsilon 0.28900, rewards: ( e-greedy 0.26987, greedy 2.25532)
# rec 0.918 reg 0.253
# epoch 13900,loss 1.54301, epsilon 0.28662, rewards: ( e-greedy 0.18788, greedy 2.22479)
# rec 1.290 reg 0.253
# epoch 14000,loss 2.00436, epsilon 0.28427, rewards: ( e-greedy 0.09409, greedy 2.14231)
# rec 1.752 reg 0.253
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 1.33517575264) -> 1.0(ref = 2.11367273331) |  Labels:is_known(qv = 1.17228722572) -> 1.0(ref = 2.35822677612) |  decades_active:1990(qv = 1.1720969677) -> 1.0(ref = 1.42971229553) |  decades_active:1990(qv = 1.02676951885) -> -0.5(ref = 0.45232874155) |  Birth name:is_known(qv = 1.00245130062) -> -1.0(ref = 1.02463698387) |  last_activity:still_active(qv = 0.88188791275) -> 1.0(ref = 2.13119697571) |  decades_active:2010(qv = 0.505448877811) -> 1.0(ref = 1.19073355198) |  decades_active:2010(qv = 0.200772196054) -> -0.5(ref = 0.449999988079) |  decades_active:1980(qv = 0.121525496244) -> 1.0(ref = 1.0) |  decades_active:1980(qv = 0.0906222313643) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:2000(qv = 1.33517575264) -> 1.0(ref = 2.11367273331) |  Labels:is_known(qv = 1.17228722572) -> 1.0(ref = 1.83997952938) |  decades_active:1990(qv = 1.1720969677) -> 1.0(ref = 0.884189009666) |  category:List_of_musicians_who_play_left-handed(qv = -0.751302599907) -> -1.0(ref = -0.121906340122) |  Birth name:is_known(qv = 0.924309134483) -> 1.0(ref = -0.0798695087433) |  Relatives:is_known(qv = -0.634993314743) -> -1.0(ref = -1.13670480251) |  Birth name:is_known(qv = 0.436626702547) -> -0.5(ref = -0.143899798393) |  last_activity:still_active(qv = 0.374842315912) -> 1.0(ref = 0.524999976158) |  Labels:is_known(qv = -0.1467692554) -> -0.5(ref = -0.5) |  first_activity:1947(qv = -0.514843583107) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:2000(qv = 1.33517599106) -> 1.0(ref = 2.11367297173) |  Instruments:vocalist(qv = -0.465974926949) -> -1.0(ref = -1.60257399082) |  decades_active:2000(qv = 1.16370618343) -> -0.5(ref = -0.634288430214) |  category:List_of_drummers(qv = -0.577269613743) -> -1.0(ref = -0.141356229782) |  decades_active:1990(qv = 0.903835535049) -> 1.0(ref = 1.21335923672) |  Genres:techno(qv = -0.717517077923) -> -1.0(ref = 0.224588632584) |  last_activity:still_active(qv = 0.504951179028) -> 1.0(ref = 1.2890406847) |  decades_active:2010(qv = 0.304253399372) -> 1.0(ref = 1.95000004768) |  decades_active:1980(qv = 0.103398874402) -> 1.0(ref = 1.0) |  decades_active:1980(qv = 0.0800552517176) -> 0.0(ref = 0.0) | reached max session length
# epoch 14100,loss 1.12784, epsilon 0.28194, rewards: ( e-greedy 0.12468, greedy 2.23308)
# rec 0.875 reg 0.253
# epoch 14200,loss 1.27329, epsilon 0.27963, rewards: ( e-greedy 0.20722, greedy 2.18977)
# rec 1.021 reg 0.253
# epoch 14300,loss 1.56190, epsilon 0.27734, rewards: ( e-greedy 0.28649, greedy 2.22579)
# rec 1.309 reg 0.252
# epoch 14400,loss 1.55929, epsilon 0.27508, rewards: ( e-greedy 0.22284, greedy 2.21821)
# rec 1.307 reg 0.252
# epoch 14500,loss 1.46196, epsilon 0.27284, rewards: ( e-greedy 0.24556, greedy 2.19639)
# rec 1.210 reg 0.252
# epoch 14600,loss 1.73537, epsilon 0.27062, rewards: ( e-greedy 0.20600, greedy 2.18675)
# rec 1.483 reg 0.252
# epoch 14700,loss 2.01633, epsilon 0.26843, rewards: ( e-greedy 0.17040, greedy 2.03808)
# rec 1.764 reg 0.252
# epoch 14800,loss 1.50853, epsilon 0.26626, rewards: ( e-greedy 0.28836, greedy 2.22927)
# rec 1.256 reg 0.252
# epoch 14900,loss 1.58044, epsilon 0.26410, rewards: ( e-greedy 0.38953, greedy 2.38134)
# rec 1.328 reg 0.252
# epoch 15000,loss 1.61046, epsilon 0.26197, rewards: ( e-greedy 0.55057, greedy 2.56321)
# rec 1.359 reg 0.252
# Learning curves:
# Random session examples
# session # 0
#  Genres:celtic(qv = -0.288850128651) -> -1.0(ref = 0.939994692802) |  decades_active:2000(qv = 2.04209971428) -> 1.0(ref = 0.0175440311432) |  Genres:melodic(qv = -0.532011032104) -> -1.0(ref = -1.03416419029) |  category:List_of_adult_alternative_artists(qv = -0.751930356026) -> -1.0(ref = -0.0359623432159) |  decades_active:1990(qv = 1.01477646828) -> 1.0(ref = 3.05466246605) |  last_activity:still_active(qv = 0.842559099197) -> 1.0(ref = 2.16280269623) |  decades_active:2010(qv = 0.628534793854) -> 1.0(ref = 1.22400271893) |  Genres:bop(qv = -0.542885541916) -> -1.0(ref = -1.47500002384) |  decades_active:2010(qv = 0.101284533739) -> -0.5(ref = -0.5) |  Website:is_known(qv = 0.0778818652034) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:2000(qv = 1.52584123611) -> 1.0(ref = 2.29607725143) |  Labels:is_known(qv = 1.36429202557) -> 1.0(ref = 0.540235877037) |  Labels:is_known(qv = 1.35671877861) -> -0.5(ref = -0.483962267637) |  Occupation:tv(qv = -0.695582926273) -> -1.0(ref = 0.0168818235397) |  category:List_of_Dutch_musicians(qv = -0.689562439919) -> -1.0(ref = -2.71108055115) |  Origin:sweden(qv = -0.886567294598) -> -1.0(ref = -1.80113744736) |  Occupation:dj(qv = -0.662163674831) -> -1.0(ref = -0.843302667141) |  decades_active:2010(qv = 0.164944574237) -> 1.0(ref = 1.95000004768) |  Website:is_known(qv = 0.0818150043488) -> 1.0(ref = 1.0) |  Instruments:guitar(qv = 0.0910852849483) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:2000(qv = 1.52584147453) -> 1.0(ref = 2.29607725143) |  Labels:is_known(qv = 1.36429178715) -> 1.0(ref = 2.42705392838) |  Labels:is_known(qv = 1.35671854019) -> -0.5(ref = 1.50216221809) |  decades_active:1990(qv = 1.31790673733) -> 1.0(ref = 2.10753917694) |  Origin:jamaica(qv = -0.651765823364) -> -1.0(ref = -0.645749568939) |  Birth name:is_known(qv = 0.908211767673) -> 1.0(ref = 0.372895181179) |  last_activity:still_active(qv = 0.736843347549) -> -1.0(ref = -0.660110354424) |  Origin:washington(qv = -0.7093963027) -> -1.0(ref = -0.0500000119209) |  decades_active:2010(qv = 0.109337948263) -> 1.0(ref = 1.0) |  category:List_of_Asian-American_hip_hop_musicians(qv = -0.496957927942) -> 0.0(ref = 0.0) | reached max session length
# epoch 15100,loss 1.67394, epsilon 0.25986, rewards: ( e-greedy 0.47052, greedy 2.41689)
# rec 1.422 reg 0.252
# epoch 15200,loss 1.62663, epsilon 0.25778, rewards: ( e-greedy 0.32347, greedy 2.30520)
# rec 1.375 reg 0.252
# epoch 15300,loss 1.40774, epsilon 0.25571, rewards: ( e-greedy 0.52112, greedy 2.46468)
# rec 1.156 reg 0.252
# epoch 15400,loss 1.54824, epsilon 0.25366, rewards: ( e-greedy 0.56901, greedy 2.56821)
# rec 1.297 reg 0.252
# epoch 15500,loss 1.53049, epsilon 0.25164, rewards: ( e-greedy 0.65211, greedy 2.62639)
# rec 1.279 reg 0.251
# epoch 15600,loss 1.30754, epsilon 0.24963, rewards: ( e-greedy 0.84690, greedy 2.69875)
# rec 1.056 reg 0.251
# epoch 15700,loss 1.48762, epsilon 0.24764, rewards: ( e-greedy 0.97721, greedy 2.86388)
# rec 1.236 reg 0.251
# epoch 15800,loss 1.58973, epsilon 0.24568, rewards: ( e-greedy 0.85949, greedy 2.77249)
# rec 1.338 reg 0.251
# epoch 15900,loss 1.90721, epsilon 0.24373, rewards: ( e-greedy 0.80354, greedy 2.74524)
# rec 1.656 reg 0.251
# ...
# rec 1.777 reg 0.247
# epoch 21000,loss 1.96400, epsilon 0.16633, rewards: ( e-greedy 1.72387, greedy 3.05966)
# rec 1.717 reg 0.247
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 2.46674585342) -> -1.0(ref = 0.460375070572) |  Labels:is_known(qv = 1.53723692894) -> 1.0(ref = 3.73420810699) |  decades_active:1990(qv = 1.50432479382) -> 1.0(ref = 2.87811374664) |  Birth name:is_known(qv = 1.30416464806) -> 1.0(ref = 1.97696185112) |  decades_active:1990(qv = 1.02838099003) -> -0.5(ref = -2.10832166672) |  Partner(s):is_known(qv = -0.417108923197) -> -1.0(ref = -1.69297003746) |  Origin:texas(qv = -0.481171160936) -> -1.0(ref = -0.729442179203) |  decades_active:2010(qv = 0.284797698259) -> -1.0(ref = -1.95000004768) |  decades_active:1930(qv = -0.521674692631) -> -1.0(ref = -1.0) |  Occupation:songwriter(qv = 0.00710600800812) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:2000(qv = 2.46674585342) -> -1.0(ref = 0.460375070572) |  Genres:black(qv = -0.378832936287) -> -1.0(ref = 1.58597803116) |  Labels:is_known(qv = 1.31861150265) -> 1.0(ref = 2.72208213806) |  decades_active:1990(qv = 1.11457002163) -> 1.0(ref = 1.812718153) |  Birth name:is_known(qv = 0.855492770672) -> 1.0(ref = -0.804112195969) |  last_activity:still_active(qv = 0.608807086945) -> -1.0(ref = -1.89906549454) |  decades_active:2010(qv = 0.434430480003) -> -1.0(ref = -0.94638478756) |  Website:is_known(qv = 0.0564370527864) -> -1.0(ref = -1.95000004768) |  Instruments:vocals(qv = 0.0181371401995) -> -1.0(ref = -1.0) |  first_activity:1986(qv = -0.070154055953) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:2000(qv = 2.46674585342) -> -1.0(ref = 0.460374951363) |  Labels:is_known(qv = 1.53723680973) -> 1.0(ref = 1.53726315498) |  decades_active:1990(qv = 1.50432467461) -> -1.0(ref = 0.565540194511) |  Birth name:is_known(qv = 1.03762674332) -> 1.0(ref = 1.6479370594) |  last_activity:still_active(qv = 0.68203908205) -> -1.0(ref = -1.0288066864) |  decades_active:2010(qv = 0.401542186737) -> -1.0(ref = -0.0303227901459) |  Website:is_known(qv = 0.0457008294761) -> 1.0(ref = 1.02071285248) |  Instruments:vocals(qv = 0.0218030046672) -> 1.0(ref = 0.0500000119209) |  Instruments:guitar(qv = 0.0407348535955) -> -1.0(ref = -1.0) |  Occupation:songwriter(qv = -0.0425092950463) -> 0.0(ref = 0.0) | reached max session length
# epoch 21100,loss 2.03596, epsilon 0.16518, rewards: ( e-greedy 1.75148, greedy 3.03370)
# rec 1.789 reg 0.247
# epoch 21200,loss 1.56353, epsilon 0.16403, rewards: ( e-greedy 1.75133, greedy 3.00533)
# rec 1.316 reg 0.247
# epoch 21300,loss 1.31163, epsilon 0.16290, rewards: ( e-greedy 1.87120, greedy 3.10980)
# rec 1.064 reg 0.247
# epoch 21400,loss 1.20990, epsilon 0.16177, rewards: ( e-greedy 1.85408, greedy 3.16382)
# rec 0.963 reg 0.247
# epoch 21500,loss 1.48984, epsilon 0.16066, rewards: ( e-greedy 1.89867, greedy 3.22243)
# rec 1.243 reg 0.247
# epoch 21600,loss 1.49962, epsilon 0.15956, rewards: ( e-greedy 1.93880, greedy 3.25019)
# rec 1.253 reg 0.247
# epoch 21700,loss 1.55653, epsilon 0.15847, rewards: ( e-greedy 2.11492, greedy 3.42017)
# rec 1.310 reg 0.247
# epoch 21800,loss 1.51248, epsilon 0.15739, rewards: ( e-greedy 2.06343, greedy 3.31815)
# rec 1.266 reg 0.247
# epoch 21900,loss 1.57993, epsilon 0.15632, rewards: ( e-greedy 2.18709, greedy 3.39134)
# rec 1.333 reg 0.247
# epoch 22000,loss 1.88745, epsilon 0.15526, rewards: ( e-greedy 2.25338, greedy 3.46221)
# rec 1.641 reg 0.247
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 2.57037568092) -> 1.0(ref = 3.11932992935) |  category:List_of_jazz_saxophonists(qv = -0.43803948164) -> -1.0(ref = -0.0426275134087) |  Instruments:synthesizers(qv = -0.337450444698) -> -1.0(ref = 1.00776052475) |  Birth name:is_known(qv = 1.48222982883) -> 1.0(ref = 2.11343216896) |  last_activity:still_active(qv = 1.17203390598) -> 1.0(ref = 1.11045324802) |  decades_active:2010(qv = 0.852006554604) -> 1.0(ref = 0.116266608238) |  Website:is_known(qv = 0.275802016258) -> -1.0(ref = -0.930245697498) |  Instruments:vocals(qv = 0.0734255611897) -> 1.0(ref = 1.95000004768) |  Occupation:songwriter(qv = -0.0842699706554) -> 1.0(ref = 1.0) |  Instruments:vocals(qv = -0.00312733929604) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  category:List_of_hip_hop_musicians(qv = -0.0507490187883) -> -1.0(ref = 1.81160759926) |  decades_active:2000(qv = 2.95958685875) -> 1.0(ref = 1.88570725918) |  Labels:is_known(qv = 2.19338941574) -> -1.0(ref = 0.932323455811) |  decades_active:1990(qv = 1.46394884586) -> 1.0(ref = 2.03402471542) |  Birth name:is_known(qv = 1.08844709396) -> 1.0(ref = 1.08894264698) |  last_activity:still_active(qv = 0.720503091812) -> -1.0(ref = 0.0936238765717) |  decades_active:2010(qv = 0.433139264584) -> 1.0(ref = 1.15118300915) |  Website:is_known(qv = 0.159140020609) -> -1.0(ref = -1.95000004768) |  Instruments:vocals(qv = 0.0336683355272) -> -1.0(ref = -1.0) |  Instruments:vocals(qv = -0.0718248784542) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:2000(qv = 2.57037520409) -> 1.0(ref = 3.11932992935) |  Labels:is_known(qv = 2.23087358475) -> -1.0(ref = -0.33789473772) |  first_activity:1962(qv = -0.415121138096) -> -1.0(ref = 0.696952939034) |  Birth name:is_known(qv = 1.28718268871) -> 1.0(ref = 1.7862663269) |  last_activity:still_active(qv = 0.827648758888) -> -1.0(ref = 0.901477694511) |  decades_active:2010(qv = 0.518593251705) -> 1.0(ref = 2.00155544281) |  Website:is_known(qv = 0.169272780418) -> 1.0(ref = 1.05426883698) |  Instruments:vocals(qv = 0.0571251474321) -> 1.0(ref = 1.95000004768) |  Instruments:guitar(qv = 0.041750933975) -> 1.0(ref = 1.0) |  Instruments:guitar(qv = 0.00334634864703) -> 0.0(ref = 0.0) | reached max session length
# epoch 22100,loss 2.10725, epsilon 0.15422, rewards: ( e-greedy 2.17804, greedy 3.40098)
# rec 1.861 reg 0.247
# epoch 22200,loss 1.87261, epsilon 0.15318, rewards: ( e-greedy 2.19524, greedy 3.41589)
# rec 1.626 reg 0.247
# epoch 22300,loss 2.09129, epsilon 0.15215, rewards: ( e-greedy 2.16071, greedy 3.39430)
# rec 1.845 reg 0.247
# epoch 22400,loss 1.38734, epsilon 0.15114, rewards: ( e-greedy 2.15964, greedy 3.37487)
# rec 1.141 reg 0.246
# epoch 22500,loss 1.42081, epsilon 0.15013, rewards: ( e-greedy 2.25868, greedy 3.46238)
# rec 1.174 reg 0.246
# epoch 22600,loss 1.30743, epsilon 0.14913, rewards: ( e-greedy 2.36781, greedy 3.66114)
# rec 1.061 reg 0.246
# epoch 22700,loss 1.56147, epsilon 0.14815, rewards: ( e-greedy 2.46603, greedy 3.64503)
# rec 1.315 reg 0.246
# epoch 22800,loss 1.93435, epsilon 0.14717, rewards: ( e-greedy 2.26943, greedy 3.47553)
# rec 1.688 reg 0.246
# epoch 22900,loss 2.50362, epsilon 0.14620, rewards: ( e-greedy 2.14748, greedy 3.28797)
# rec 2.257 reg 0.246
# epoch 23000,loss 1.72219, epsilon 0.14525, rewards: ( e-greedy 2.15274, greedy 3.24918)
# rec 1.476 reg 0.246
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 2.69640302658) -> 1.0(ref = 3.26971459389) |  Labels:is_known(qv = 2.38917326927) -> 1.0(ref = 4.35397911072) |  decades_active:1990(qv = 2.30172133446) -> 1.0(ref = 3.53050422668) |  Birth name:is_known(qv = 2.06912302971) -> 1.0(ref = 2.66368865967) |  last_activity:still_active(qv = 1.7512512207) -> 1.0(ref = 2.09959459305) |  decades_active:2010(qv = 1.31397461891) -> 1.0(ref = 1.0) |
#
# session # 1
#  decades_active:2000(qv = 2.69640302658) -> 1.0(ref = 3.26971459389) |  Labels:is_known(qv = 2.38917326927) -> -1.0(ref = 1.79847002029) |  decades_active:1990(qv = 1.79411900043) -> 1.0(ref = 2.94575786591) |  Birth name:is_known(qv = 1.51551389694) -> 1.0(ref = 2.04816627502) |  last_activity:still_active(qv = 1.10333287716) -> -1.0(ref = -0.909812390804) |  decades_active:2010(qv = 0.676639914513) -> 1.0(ref = 0.0949343442917) |  Website:is_known(qv = 0.190653428435) -> -1.0(ref = -0.952700674534) |  Instruments:vocals(qv = 0.049788787961) -> -1.0(ref = -1.95000004768) |  Instruments:guitar(qv = -0.0696702972054) -> -1.0(ref = -1.0) |  Genres:hop(qv = -0.0612999163568) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:2000(qv = 2.696403265) -> -1.0(ref = 0.484634995461) |  Labels:is_known(qv = 1.56277370453) -> 1.0(ref = 1.24330472946) |  decades_active:1990(qv = 1.42663383484) -> -1.0(ref = 0.256110191345) |  Birth name:is_known(qv = 0.893502235413) -> 1.0(ref = 1.32222127914) |  last_activity:still_active(qv = 0.339180231094) -> -1.0(ref = -1.06873261929) |  decades_active:2010(qv = 0.110425174236) -> -1.0(ref = -0.0723500847816) |  Instruments:vocals(qv = -0.0389093905687) -> 1.0(ref = 0.976473629475) |  Instruments:guitar(qv = -0.0247645825148) -> 1.0(ref = 0.524999976158) |  Instruments:guitar(qv = -0.049531660974) -> -0.5(ref = -0.5) |  category:List_of_bebop_musicians(qv = -0.0521192885935) -> 0.0(ref = 0.0) | reached max session length
# epoch 23100,loss 2.19267, epsilon 0.14430, rewards: ( e-greedy 2.05246, greedy 3.19926)
# rec 1.947 reg 0.246
# epoch 23200,loss 1.89999, epsilon 0.14336, rewards: ( e-greedy 1.97222, greedy 3.22933)
# rec 1.654 reg 0.246
# epoch 23300,loss 1.88744, epsilon 0.14243, rewards: ( e-greedy 1.85999, greedy 3.17640)
# rec 1.642 reg 0.246
# epoch 23400,loss 1.29152, epsilon 0.14151, rewards: ( e-greedy 2.15899, greedy 3.48876)
# rec 1.046 reg 0.246
# epoch 23500,loss 1.59853, epsilon 0.14060, rewards: ( e-greedy 2.25309, greedy 3.52488)
# rec 1.353 reg 0.246
# epoch 23600,loss 1.38872, epsilon 0.13970, rewards: ( e-greedy 2.53779, greedy 3.74240)
# rec 1.143 reg 0.246
# epoch 23700,loss 1.89986, epsilon 0.13881, rewards: ( e-greedy 2.54901, greedy 3.74816)
# rec 1.654 reg 0.246
# epoch 23800,loss 1.69275, epsilon 0.13792, rewards: ( e-greedy 2.58911, greedy 3.81834)
# rec 1.447 reg 0.246
# epoch 23900,loss 1.69035, epsilon 0.13705, rewards: ( e-greedy 2.71520, greedy 3.88651)
# rec 1.445 reg 0.246
# epoch 24000,loss 1.64972, epsilon 0.13618, rewards: ( e-greedy 2.88368, greedy 3.98786)
# rec 1.404 reg 0.246
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 2.79515624046) -> 1.0(ref = 3.35272145271) |  Labels:is_known(qv = 2.47654891014) -> 1.0(ref = 2.68464612961) |  decades_active:1990(qv = 2.43347835541) -> 1.0(ref = 1.77331185341) |  category:List_of_roots_reggae_artists(qv = -0.169123440981) -> -1.0(ref = 0.814012527466) |  Birth name:is_known(qv = 1.90948688984) -> -1.0(ref = 1.09645724297) |  last_activity:still_active(qv = 1.77712321281) -> 1.0(ref = 2.20679712296) |  decades_active:2010(qv = 1.17820429802) -> 1.0(ref = 1.27031266689) |  Website:is_known(qv = 0.284539610147) -> 1.0(ref = 0.0500000119209) |  Instruments:vocals(qv = 0.11333501339) -> -1.0(ref = -1.0) |  Instruments:guitar(qv = -0.0191967710853) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:2000(qv = 2.79515624046) -> 1.0(ref = 3.35272145271) |  Labels:is_known(qv = 2.47654891014) -> 1.0(ref = 4.54827022552) |  decades_active:1990(qv = 2.43347835541) -> 1.0(ref = 3.73502111435) |  Birth name:is_known(qv = 2.20657110214) -> 1.0(ref = 2.87896966934) |  last_activity:still_active(qv = 1.97786283493) -> 1.0(ref = 1.86930513382) |  decades_active:2010(qv = 1.5393396616) -> 1.0(ref = 0.915058076382) |  last_activity:still_active(qv = 0.5456802845) -> -0.5(ref = -0.0894125699997) |  Genres:blues(qv = -0.370358884335) -> -1.0(ref = -0.0500000119209) |  Instruments:vocals(qv = 0.0982057154179) -> 1.0(ref = 1.0) |  Instruments:guitar(qv = 0.0412162169814) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Origin:norway(qv = -0.129099175334) -> -1.0(ref = 2.00583100319) |  decades_active:2000(qv = 3.16403269768) -> -1.0(ref = 1.29961800575) |  Labels:is_known(qv = 1.55185353756) -> 1.0(ref = 2.42065048218) |  Birth name:is_known(qv = 1.14400815964) -> 1.0(ref = 1.49542140961) |  last_activity:still_active(qv = 0.52149617672) -> -1.0(ref = -2.89822721481) |  decades_active:2010(qv = 0.299392640591) -> -1.0(ref = -1.99813401699) |  Instruments:bass(qv = -0.320731788874) -> -1.0(ref = -1.05066740513) |  Instruments:vocals(qv = -0.0533340573311) -> 1.0(ref = 0.0500000119209) |  Occupation:dancer(qv = -0.409277319908) -> -1.0(ref = -1.0) |  Instruments:vocals(qv = -0.0630856156349) -> 0.0(ref = 0.0) | reached max session length
# epoch 24100,loss 1.78395, epsilon 0.13532, rewards: ( e-greedy 2.82031, greedy 3.96907)
# rec 1.539 reg 0.245
# epoch 24200,loss 1.47316, epsilon 0.13448, rewards: ( e-greedy 2.81328, greedy 3.96216)
# rec 1.228 reg 0.245
# epoch 24300,loss 1.71256, epsilon 0.13363, rewards: ( e-greedy 2.76195, greedy 3.91095)
# rec 1.467 reg 0.245
# epoch 24400,loss 2.24401, epsilon 0.13280, rewards: ( e-greedy 2.74075, greedy 3.94985)
# rec 1.999 reg 0.245
# epoch 24500,loss 1.92139, epsilon 0.13198, rewards: ( e-greedy 2.52168, greedy 3.80987)
# rec 1.676 reg 0.245
# epoch 24600,loss 1.73848, epsilon 0.13116, rewards: ( e-greedy 2.51951, greedy 3.78888)
# rec 1.493 reg 0.245
# epoch 24700,loss 1.98949, epsilon 0.13036, rewards: ( e-greedy 2.31756, greedy 3.54499)
# rec 1.744 reg 0.245
# epoch 24800,loss 1.41771, epsilon 0.12956, rewards: ( e-greedy 2.46080, greedy 3.68549)
# rec 1.173 reg 0.245
# epoch 24900,loss 1.96539, epsilon 0.12876, rewards: ( e-greedy 2.49472, greedy 3.63694)
# rec 1.720 reg 0.245
# epoch 25000,loss 1.54957, epsilon 0.12798, rewards: ( e-greedy 2.54525, greedy 3.69325)
# rec 1.305 reg 0.245
# Learning curves:
# Random session examples
# session # 0
#  decades_active:2000(qv = 2.87971806526) -> 1.0(ref = 3.4047563076) |  Labels:is_known(qv = 2.53132247925) -> 1.0(ref = 0.548165380955) |  Genres:trip(qv = -0.230857789516) -> -1.0(ref = -0.475615382195) |  Ethnicity:is_known(qv = -0.688327550888) -> -1.0(ref = 0.551983833313) |  last_activity:still_active(qv = 1.63366723061) -> 1.0(ref = 2.94199943542) |  decades_active:2010(qv = 1.29035687447) -> 1.0(ref = 2.04420995712) |  Website:is_known(qv = 0.356879085302) -> 1.0(ref = 1.09916853905) |  Instruments:vocals(qv = 0.104387894273) -> 1.0(ref = 0.0500000119209) |  Instruments:guitar(qv = 0.111245810986) -> -1.0(ref = -1.0) |  Instruments:vocals(qv = -0.085632905364) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  decades_active:2000(qv = 2.87971806526) -> 1.0(ref = 3.4047563076) |  Occupation:radio(qv = -0.309619635344) -> -1.0(ref = 0.285218119621) |  decades_active:1990(qv = 2.03364276886) -> 1.0(ref = 1.352861166) |  Birth name:is_known(qv = 1.77688777447) -> -1.0(ref = 0.371432781219) |  last_activity:still_active(qv = 1.44361341) -> 1.0(ref = 1.03449237347) |  category:List_of_gospel_musicians(qv = -0.284670561552) -> -1.0(ref = 0.0363078117371) |  decades_active:2010(qv = 0.502148985863) -> 1.0(ref = 1.09085035324) |  Website:is_known(qv = 0.0956319496036) -> 1.0(ref = 1.95000004768) |  Instruments:vocals(qv = 0.0341279953718) -> 1.0(ref = 1.0) |  Instruments:guitar(qv = 0.0718873590231) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  decades_active:2000(qv = 2.8797185421) -> 1.0(ref = 3.40475583076) |  Labels:is_known(qv = 2.53132200241) -> 1.0(ref = 2.69996643066) |  decades_active:1990(qv = 2.4473733902) -> 1.0(ref = 1.7894384861) |  Birth name:is_known(qv = 2.17771887779) -> -1.0(ref = 0.830987930298) |  last_activity:still_active(qv = 1.9273557663) -> 1.0(ref = 1.12173640728) |  decades_active:2010(qv = 1.40768551826) -> 1.0(ref = 0.128143548965) |  Website:is_known(qv = 0.429910004139) -> -1.0(ref = -0.917743623257) |  Instruments:vocals(qv = 0.0865856558084) -> 1.0(ref = 1.95000004768) |  Instruments:guitar(qv = 0.0778150707483) -> 1.0(ref = 1.0) |  Instruments:guitar(qv = -0.0197434835136) -> 0.0(ref = 0.0) | reached max session length
# epoch 25100,loss 1.88794, epsilon 0.12720, rewards: ( e-greedy 2.49073, greedy 3.68392)
# rec 1.643 reg 0.245
# epoch 25200,loss 1.54082, epsilon 0.12644, rewards: ( e-greedy 2.63165, greedy 3.82553)
# rec 1.296 reg 0.245
# epoch 25300,loss 2.00677, epsilon 0.12568, rewards: ( e-greedy 2.50349, greedy 3.64298)
# rec 1.762 reg 0.245

# %% [markdown]
# # Evaluating results

# %%
score_log.plot("final")

# %%
print "Random session examples"
env.load_random_batch(train_attrs,train_cats,10)
display_sessions(with_plots=True)

# %%
#load earlier snapshot.
#warning - this overrides the latest network params with earlier ones. 
#Replace 20000 with some 100000 if you wish to load latest snapshod back.
snap_name = "{}.epoch{}.pcl".format(os.path.join(snapshot_path,experiment_setup_name), 20000)
load(resolver,snap_name)

# %%
print "Random session examples"
env.load_random_batch(train_attrs,train_cats,10)
display_sessions(with_plots=True)
