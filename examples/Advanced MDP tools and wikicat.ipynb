# %%
#experiment name and snapshot folder (used for model persistence)
experiment_setup_name = "tutorial.wikicat.advanced"
snapshot_path = "./agentnet_snapshots/"
# !mkdir ./agentnet_snapshots
# Out:
# mkdir: cannot create directory `./agentnet_snapshots': File exists

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline


#theano imports
#the problem is too simple to be run on GPU. Seriously.
# %env THEANO_FLAGS='device=gpu0'
import theano
import theano.tensor as T
floatX = theano.config.floatX

import lasagne
# Out:
# env: THEANO_FLAGS='device=gpu0'
# Using gpu device 0: Tesla K40m (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 4004.)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # This tutorial builds above the basic tutorial and shows several advanced tools
# * multi-layer (and in principle, arbitrary) agent memory
# * different reinforcement learning algorithms
# * model persistence
#
# __[todo: add more]__

# %% [markdown]
# # Experiment setup
# * Here we load an experiment environment (description below)
# * Designing one from scratch is explained in later tutorials

# %%
import agentnet.experiments.wikicat as experiment
print experiment.__doc__
# Out:
# This experiment Wikipedia data sample on musicians, scraped via the scripts present in this directory.
# For each musician, we know a number of boolean features (factors) on various topics like
#  * whether or not he/she was active in 1990's, 2000's, etc.
#  * whether or not he/she plays guitar, piano, etc
#  * whether or not he/she was born in 50's, 60's, etc.
#  * what wikipedia categories does he/she belong to
#  etc.
#
#
#
# In the initial moment of time, agent knows nothing about any of them.
# At each turn, agent may decide to
#  - "open" one of the hidden factors.
#    - if the factor turns out to be 1, agent receives +3 reward for Wikipedia categories, +1 for other categories,
#    - Otherwise, the reward equals -1 for Wikipedia categories, -1 for other categores
#    - all these rewards are parameterisable during environment creation
#  - decide to quit session
#    - yields reward of 0 and ends the interaction.
#    - all farther actions will have no effect until next session
#
# It is expected, that in order to maximize it's expected reward, the agent
# will converge to a strategy of polling several key features and then utilizing learned
# dependencies between these factors and other ones. For example, if a particular genre was
# popular during particular decays, it makes sense to poll genres and than "open" the corresponding
# most probable years.
#
# The experiment setup contains a single class WikicatEnvironment that
# implements both BaseEnvironment and BaseObjective.

# %%
#Create an environment with all default parameters
env = experiment.WikicatEnvironment()

# %%
from sklearn.cross_validation import train_test_split
attrs, categories, feature_names = env.get_dataset(experiment_path="")

train_attrs,test_attrs,train_cats,test_cats = train_test_split(attrs,categories,test_size=0.99,random_state=32)

print "train size:", train_attrs.shape,train_cats.shape
print "train size:", test_attrs.shape,test_cats.shape

print "features:",feature_names[::20]
# Out:
# train size: (85, 300) (85, 93)
# train size: (8509, 300) (8509, 93)
# features: ['Children:is_known', 'Instruments:vocals', 'Genres:electronic', 'Origin:scotland', 'Genres:jazz', 'Genres:electric', 'Occupation:bassist', 'Instruments:violin', 'Genres:instrumental', 'Occupation:entrepreneur', 'Instruments:mandolin', 'Instruments:vocalist', 'Genres:synthpop', 'decades_active:1990', 'Occupation:remixer', 'category:List_of_musical_artists_from_Japan', 'category:List_of_ambient_music_artists', 'category:List_of_crooners', 'category:List_of_country_music_performers', 'category:List_of_bass_guitarists']

# %%
env.load_random_batch(train_attrs,train_cats,5)

# %% [markdown]
# # agent setup
# * An agent implementation has to contain three parts:
#  * Memory layer(s)
#   * in this case, we train two GRU layers [details below]
#  * Q-values evaluation layers
#   * in this case, a lasagne dense layer based on memory layer
#  * Resolver - acton picker layer
#   * in this case, the resolver has epsilon-greedy policy
#
#
# ### two-layer memory architecture
# We train two memory states:
#   * first one, based on observations,
#   * second one, based on first one;
#
# Note that here we update the second memory layer based on the CURRENT state
# of the first one. Instead, you can try to feed it with a previous state.
#
# The q-values are estimated on a concatenated state, effectively on both memory
# states together, but there is no problem with limiting q-evaluator to only one:
# just pass the correct gru layer as an incoming layer to the q-evaluator.
#
# ### Implementation:
# We concatenate both memories into 1 state to pass it through the session loop.
#
# To perform memory update, we need to slice the concatenated state back into
# two memory states.
#
# We do so by defining an input map function and passing it into agent.
#
# We than concatenate two new states back to form a new memory state.

# %%
from agentnet.resolver import EpsilonGreedyResolver
from agentnet.memory.rnn import GRUCell
from agentnet.memory import GRUMemoryLayer
from agentnet.agent import Agent

# %%
import lasagne
n_hid_1=512 #first GRU memory
n_hid_2=512 #second GRU memory


_observation_layer = lasagne.layers.InputLayer([None]+list(env.observation_shapes),name="obs_input")

_prev_gru1_layer = lasagne.layers.InputLayer([None,n_hid_1],name="prev_gru1_state_input")
_prev_gru2_layer = lasagne.layers.InputLayer([None,n_hid_2],name="prev_gru2_state_input")

#memory
gru1 = GRUMemoryLayer(n_hid_1,
                     _observation_layer,
                     _prev_gru1_layer,
                     name="gru1")

gru2 = GRUMemoryLayer(n_hid_2,
                     gru1,        #note that it takes CURRENT gru1 output as input.
                                  #replacing that with _prev_gru1_state would imply taking previous one.
                     _prev_gru2_layer,
                     name="gru2")


concatenated_memory = lasagne.layers.concat([gru1,gru2])

#q_eval
n_actions = len(feature_names)
q_eval = lasagne.layers.DenseLayer(concatenated_memory, #taking both memories. 
                                                        #Replacing with gru1 or gru2 would mean taking one
                                   num_units = n_actions,
                                   nonlinearity=lasagne.nonlinearities.linear,name="QEvaluator")
#resolver
epsilon = theano.shared(np.float32(0.1),"e-greedy.epsilon")

resolver = EpsilonGreedyResolver(q_eval,epsilon=epsilon,name="resolver")



from collections import OrderedDict
#all together
agent = Agent(_observation_layer,
              OrderedDict([
                    (gru1,_prev_gru1_layer),
                    (gru2,_prev_gru2_layer)
              ]),
              q_eval,resolver)

# %%
#Since it's a single lasagne network, one can get it's weights, output, etc
weights = lasagne.layers.get_all_params(resolver,trainable=True)
weights
# Out:
# [gru1.W_in_to_updategate,
#  gru1.W_hid_to_updategate,
#  gru1.b_updategate,
#  gru1.W_in_to_resetgate,
#  gru1.W_hid_to_resetgate,
#  gru1.b_resetgate,
#  gru1.W_in_to_hidden_update,
#  gru1.W_hid_to_hidden_update,
#  gru1.b_hidden_update,
#  gru2.W_in_to_updategate,
#  gru2.W_hid_to_updategate,
#  gru2.b_updategate,
#  gru2.W_in_to_resetgate,
#  gru2.W_hid_to_resetgate,
#  gru2.b_resetgate,
#  gru2.W_in_to_hidden_update,
#  gru2.W_hid_to_hidden_update,
#  gru2.b_hidden_update,
#  QEvaluator.W,
#  QEvaluator.b]

# %% [markdown]
# ## Agent setup in detail
# * __Memory layers__
#  * One-step recurrent layer
#      * takes input and one's previous state
#      * returns new memory state
#    * Can be arbitrary lasagne layer
#    * Several one-step recurrent units are implemented in __agentnet.memory__
#    * Note that lasagne's default recurrent networks roll for several steps at once
#      * in other words, __using lasagne recurrent units as memory means recurrence inside recurrence__
#  * Using more than one memory layer is explained in farther tutorials
#
#
# * __Q-values evaluation layer__
#  * Can be arbitrary lasagne network
#  * returns predicted Q-values for each action
#  * Usually depends on memory as an input
#
#
# * __Resolver__ - action picker
#  * Decides on what action is taken
#  * Normally takes Q-values as input
#  * Currently all experiments require integer output
#  * Several resolver layers are implemented in __agentnet.resolver__

# %% [markdown]
# # Interacting with environment
# * an agent has a method that produces symbolic environment interaction sessions
# * interactions result in sequences of observations, actions, q-values,etc
# * one has to pre-define maximum session length.
#  * in this case, environment implements an indicator of whether session has ended by current tick
# * Since this environment also implements Objective methods, it can evaluate rewards for each [batch, time_tick]

# %%
#produce interaction sequences of length <= 10
(state_seq),observation_seq,agent_state,action_seq,qvalues_seq = agent.get_sessions(
    env,
    session_length=10,
    batch_size=env.batch_size,
)


gru1_seq = agent_state[gru1]
gru2_seq = agent_state[gru2]

#get rewards for all actions
rewards_seq = env.get_reward_sequences(state_seq,action_seq)

#get indicator whether session is still active
is_alive_seq = env.get_whether_alive(observation_seq)

# %% [markdown]
# # Evaluating loss function
# * This part is similar to the basic tutorial but for the fact that we use 3-step q-learning
#
# * we evaluate the Q-loss manually, so this entire block is in essence equivalent to `qlearning_n_step.get_elementwise_objective(...)`
#
#
#  #### Get (prediction,reference) pairs

# %%
#get reference Qvalues according to Qlearning algorithm


from agentnet.learning import qlearning_n_step

#gamma - delayed reward coefficient - what fraction of reward is retained if it is obtained one tick later
gamma = theano.shared(np.float32(0.95),name = 'q_learning_gamma')


reference_Qvalues = qlearning_n_step.get_elementwise_objective(qvalues_seq,
                                                               action_seq,
                                                               rewards_seq,
                                                               n_steps=3,
                                                               gamma_or_gammas=gamma,
                                                               return_reference=True)

# %%
#zero-out future rewards at session end
from agentnet.learning.helpers import get_end_indicator

end_action_ids = get_end_indicator(is_alive_seq).nonzero()

# "set reference Qvalues at end action ids to just the immediate rewards"
reference_Qvalues = T.set_subtensor(reference_Qvalues[end_action_ids],
                                    rewards_seq[end_action_ids])

# %%
#prevent gradient updates over reference Qvalues (since they depend on predicted Qvalues)
from theano.gradient import disconnected_grad
reference_Qvalues = disconnected_grad(reference_Qvalues)

# %%
from agentnet.learning.helpers import get_action_Qvalues
action_Qvalues = get_action_Qvalues(qvalues_seq,action_seq)

# %% [markdown]
# #### Define loss functions

# %%
#tensor of elementwise squared errors
squared_error = lasagne.objectives.squared_error(reference_Qvalues,action_Qvalues)

#zero-out ticks after session ended
squared_error = squared_error * is_alive_seq

#all code from Evaluation Loss Function beginning to this point is equivalent to
#squared_error = qlearning_n_step.get_elementwise_objective(...)


#compute average of squared error sums per session
mse_loss = squared_error.sum() / is_alive_seq.sum()

# %%
#regularize network weights

from lasagne.regularization import regularize_network_params, l2
reg_l2 = regularize_network_params(resolver,l2)*10**-4

# %%
loss = mse_loss + reg_l2

# %% [markdown]
# #### Compute weight updates

# %%
updates = lasagne.updates.adadelta(loss,
                                             weights,learning_rate=0.01)

# %% [markdown]
# #### Some auxilary evaluation metrics

# %%
mean_session_reward = rewards_seq.sum(axis=1).mean()
#...

# %% [markdown]
# # Compile train and evaluation functions

# %%
train_fun = theano.function([],[loss,mean_session_reward],updates=updates)

evaluation_fun = theano.function([],[loss,mse_loss,reg_l2,mean_session_reward])

# %% [markdown]
# # session visualization tools
#
#
# * this is a completely optional step of visualizing agent's sessions as chains of actions
# * usually useful to get insight on what worked and what din't
# * in this case, we print strings following pattern
#   * [action_name] ([predicted action qvalue]) -> reward [reference qvalue] | next iteration
#
# * plot shows
#     * time ticks over X, abstract values over Y
#     * bold lines are Qvalues for actions
#     * dots on bold lines represent what actions were taken at each moment of time
#     * dashed lines are agent's hidden state neurons
#     * blue vertical line - session end
#
#
# __Warning! the visualization tools are underdeveloped and only allow simple operations.__
#
# if you found yourself struggling to make it do what you want for 5 minutes, go write your own tool [and contribute it :)]

# %%
from agentnet.display.sessions import print_sessions
get_printables = theano.function([], [
        gru2_seq,qvalues_seq, action_seq,rewards_seq,reference_Qvalues,is_alive_seq
    ])

def display_sessions(with_plots = False):
        
    hidden_log,qvalues_log,actions_log,reward_log, reference_qv_log, is_alive_log = get_printables()
    
    
    print_sessions(qvalues_log,actions_log,reward_log,
                   is_alive_seq = is_alive_log,
                   #hidden_seq=hidden_log, #do not plot hidden since there's too many actions already
                   reference_policy_seq = reference_qv_log,
                   action_names=feature_names,
                   legend = False, #do not show legend since there's too many labeled objects
                  plot_policy = with_plots)

# %%
#visualize untrained network performance (which is mostly random)
env.load_random_batch(train_attrs,train_cats,1)
display_sessions(with_plots=True)
# Out:
# session # 0
#  Children:is_known(qv = 0.0) -> -1.0(ref = -0.827008545399) |  category:List_of_pop_and_rock_pianists(qv = 0.182096242905) -> -1.0(ref = -2.47762155533) |  Origin:australia(qv = 0.217411950231) -> -1.0(ref = -1.55539107323) |  first_activity:1950(qv = 0.349017471075) -> -1.0(ref = -0.584622204304) |  Genres:symphonic(qv = 0.437239766121) -> -1.0(ref = -2.22813820839) |  Occupation:director(qv = 0.599149763584) -> -1.0(ref = -1.29277718067) |  Genres:contemporary(qv = 0.257113397121) -> -1.0(ref = -0.308186501265) |  Origin:scotland(qv = 0.728224754333) -> -1.0(ref = -1.95000004768) |  last_activity:1989(qv = -0.0146864885464) -> -1.0(ref = -1.0) |  Origin:scotland(qv = 0.779298365116) -> 0.0(ref = 0.0) | reached max session length

# %% [markdown]
# # Training loop

# %%
#tools for model persistence
from agentnet.utils.persistence import save,load
import os

# %%
from agentnet.display import Metrics
score_log = Metrics()

# %%
#starting epoch
epoch_counter = 1

#moving average estimation
alpha = 0.1
ma_reward_current = -7.
ma_reward_greedy = -7.

# %%
# %%time
n_epochs = 100000
batch_size= 10

for i in range(n_epochs):    
    
    #train
    env.load_random_batch(train_attrs,train_cats,batch_size)
    resolver.rng.seed(i)    
    loss,avg_reward = train_fun()
    
    
    
    ##update resolver's epsilon (chance of random action instead of optimal one)
    if epoch_counter%10 ==0:
        current_epsilon =  0.05 + 0.95*np.exp(-epoch_counter/10000.)
        resolver.epsilon.set_value(np.float32(current_epsilon))
    
    
    
    ##record current learning progress and show learning curves
    if epoch_counter%100 ==0:

        ##update learning curves
        full_loss, q_loss, l2_penalty, avg_reward_current = evaluation_fun()
        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current
        score_log["expected e-greedy reward"][epoch_counter] = ma_reward_current
        
        
        
        #greedy train
        resolver.epsilon.set_value(0)
        avg_reward_greedy = evaluation_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["expected greedy reward"][epoch_counter] = ma_reward_greedy
        
        
        #back to epsilon-greedy
        resolver.epsilon.set_value(np.float32(current_epsilon))

        print "epoch %i,loss %.5f, epsilon %.5f, rewards: ( e-greedy %.5f, greedy %.5f) "%(
            epoch_counter,full_loss,current_epsilon,ma_reward_current,ma_reward_greedy)
        print "rec %.3f reg %.3f"%(q_loss,l2_penalty)

    if epoch_counter %1000 ==0:
        print "Learning curves:"
        score_log.plot()


        print "Random session examples"
        env.load_random_batch(train_attrs,train_cats,3)
        display_sessions(with_plots=False)
    
    #save snapshot
    if epoch_counter %10000 ==0:
        snap_name = "{}.epoch{}.pcl".format(os.path.join(snapshot_path,experiment_setup_name), epoch_counter)
        save(resolver,snap_name)
        print "saved", snap_name

        
        
    epoch_counter  +=1

    
# Time to drink some coffee!
# Out:
# epoch 100,loss 4.94711, epsilon 0.99055, rewards: ( e-greedy -7.12000, greedy -7.15000)
# rec 1.927 reg 3.020
# epoch 200,loss 4.93972, epsilon 0.98119, rewards: ( e-greedy -7.11800, greedy -7.17500)
# rec 1.920 reg 3.019
# epoch 300,loss 5.09970, epsilon 0.97192, rewards: ( e-greedy -7.22620, greedy -7.10250)
# rec 2.082 reg 3.018
# epoch 400,loss 5.04805, epsilon 0.96275, rewards: ( e-greedy -7.23358, greedy -7.08225)
# rec 2.031 reg 3.017
# epoch 500,loss 5.05871, epsilon 0.95367, rewards: ( e-greedy -7.26522, greedy -6.93402)
# rec 2.043 reg 3.016
# epoch 600,loss 4.91172, epsilon 0.94468, rewards: ( e-greedy -7.36370, greedy -6.95562)
# rec 1.897 reg 3.014
# epoch 700,loss 5.13302, epsilon 0.93577, rewards: ( e-greedy -7.22233, greedy -6.69506)
# rec 2.120 reg 3.013
# epoch 800,loss 5.03104, epsilon 0.92696, rewards: ( e-greedy -7.35010, greedy -6.32555)
# rec 2.019 reg 3.012
# epoch 900,loss 4.97101, epsilon 0.91823, rewards: ( e-greedy -7.41009, greedy -6.09300)
# rec 1.960 reg 3.011
# epoch 1000,loss 4.90803, epsilon 0.90960, rewards: ( e-greedy -7.42908, greedy -5.55370)
# rec 1.898 reg 3.010
# Learning curves:
# Random session examples
# session # 0
#  Instruments:organ(qv = -0.0264788735658) -> -1.0(ref = -0.829942047596) |  Genres:thrash(qv = -0.146764844656) -> -1.0(ref = -0.630319595337) |  Instruments:guitar(qv = 0.0972199067473) -> 1.0(ref = 0.389137268066) |  Awards:is_known(qv = -0.234771132469) -> -1.0(ref = -0.643013417721) |  decades_active:before_1920(qv = -0.332607150078) -> -1.0(ref = -2.41159296036) |  Instruments:fiddle(qv = 0.424763858318) -> -1.0(ref = -1.48588728905) |  Genres:soft(qv = -0.178323194385) -> -1.0(ref = -0.51146030426) |  category:List_of_J-pop_artists(qv = -0.488864868879) -> -1.0(ref = -0.0500000119209) |  Instruments:vocals(qv = 0.326889693737) -> 1.0(ref = 1.0) |  decades_active:before_1920(qv = -0.0686190798879) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Instruments:drum(qv = -0.0206468850374) -> -1.0(ref = -0.829460024834) |  Genres:celtic(qv = 0.0159210320562) -> -1.0(ref = -2.52930879593) |  Residence:is_known(qv = -0.318539887667) -> -1.0(ref = -1.60979866982) |  category:List_of_jazz_fusion_musicians(qv = 0.0656082108617) -> -1.0(ref = -0.641893386841) |  category:List_of_music_arrangers(qv = -0.189471453428) -> -1.0(ref = -2.43995666504) |  Occupation:entrepreneur(qv = -0.186458006501) -> -1.0(ref = -1.51574385166) |  first_activity:1989(qv = -0.343194007874) -> -1.0(ref = -0.542888224125) |  Genres:rock(qv = 0.481170296669) -> -1.0(ref = -1.95000004768) |  Occupation:producer(qv = -0.256589770317) -> -1.0(ref = -1.0) |  Instruments:vocal(qv = -0.541452646255) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Religion:is_known(qv = -0.0301207769662) -> -1.0(ref = -0.848477423191) |  Genres:band(qv = -0.00675578368828) -> -1.0(ref = -2.52557420731) |  Origin:angeles(qv = -0.159041330218) -> -1.0(ref = -1.60586750507) |  Occupation:activist(qv = 0.0285066366196) -> -1.0(ref = -0.637755274773) |  last_activity:2004(qv = -0.027684904635) -> -1.0(ref = -2.40653276443) |  Genres:thrash(qv = -0.335226744413) -> -1.0(ref = -1.48056077957) |  category:List_of_Nigerian_musicians(qv = -0.195033624768) -> -1.0(ref = -0.50585347414) |  end_session_now(qv = 0.520154237747) -> 0.0(ref = 0.0) |
#
# epoch 1100,loss 4.72514, epsilon 0.90104, rewards: ( e-greedy -7.28617, greedy -5.16833)
# rec 1.717 reg 3.008
# epoch 1200,loss 4.83855, epsilon 0.89257, rewards: ( e-greedy -7.31255, greedy -4.81150)
# rec 1.831 reg 3.007
# epoch 1300,loss 4.91987, epsilon 0.88419, rewards: ( e-greedy -7.28630, greedy -4.45535)
# rec 1.914 reg 3.006
# epoch 1400,loss 4.57830, epsilon 0.87589, rewards: ( e-greedy -7.13267, greedy -4.21481)
# rec 1.573 reg 3.005
# epoch 1500,loss 4.48015, epsilon 0.86767, rewards: ( e-greedy -7.05440, greedy -3.85333)
# rec 1.476 reg 3.004
# epoch 1600,loss 4.50816, epsilon 0.85954, rewards: ( e-greedy -7.02396, greedy -3.59800)
# rec 1.505 reg 3.003
# epoch 1700,loss 4.61842, epsilon 0.85148, rewards: ( e-greedy -6.97157, greedy -3.26320)
# rec 1.617 reg 3.002
# epoch 1800,loss 4.31684, epsilon 0.84351, rewards: ( e-greedy -6.74441, greedy -2.82688)
# rec 1.316 reg 3.001
# epoch 1900,loss 4.30399, epsilon 0.83561, rewards: ( e-greedy -6.72997, greedy -2.43919)
# rec 1.304 reg 3.000
# epoch 2000,loss 4.61994, epsilon 0.82779, rewards: ( e-greedy -6.76197, greedy -2.13527)
# rec 1.621 reg 2.998
# Learning curves:
# Random session examples
# session # 0
#  Origin:india(qv = -0.067069940269) -> -1.0(ref = -0.951695144176) |  first_activity:1968(qv = -0.0500560291111) -> -1.0(ref = -2.89084386826) |  Political party:is_known(qv = -0.533639788628) -> -1.0(ref = -1.99036192894) |  Genres:nu(qv = -0.50116610527) -> -1.0(ref = -1.04248631001) |  Occupation:poet(qv = -0.829645574093) -> -1.0(ref = -2.85600137711) |  Genres:latin(qv = -1.17119133472) -> -1.0(ref = -1.95368564129) |  Instruments:saxophone(qv = -1.3586628437) -> -1.0(ref = -1.00387966633) |  decades_active:1990(qv = -0.00408389372751) -> 1.0(ref = 1.95000004768) |  decades_active:1980(qv = -0.0106005771086) -> 1.0(ref = 1.0) |  Origin:california(qv = -1.02844786644) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  first_activity:1947(qv = -0.0556042715907) -> -1.0(ref = -0.933972120285) |  category:List_of_jazz_saxophonists(qv = -0.177981585264) -> -1.0(ref = -2.86245799065) |  Genres:industrial(qv = -0.3894059062) -> -1.0(ref = -1.96048223972) |  category:List_of_bands_with_more_than_one_lead_vocalist(qv = -0.747379481792) -> -1.0(ref = -1.01103401184) |  category:List_of_trumpeters(qv = -0.672735393047) -> -1.0(ref = -2.72287011147) |  Origin:ontario(qv = -1.15625405312) -> -1.0(ref = -1.81354761124) |  last_activity:1998(qv = -1.18826878071) -> -1.0(ref = -0.856365919113) |  category:List_of_hip_hop_musicians_from_New_York_City(qv = -1.2195327282) -> -1.0(ref = -1.95000004768) |  Genres:rock(qv = 0.277637153864) -> -1.0(ref = -1.0) |  Genres:reggae(qv = -0.621578454971) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Genres:rap(qv = -0.105436608195) -> -1.0(ref = -0.972917437553) |  Occupation:instrumentalist(qv = -0.163139313459) -> -1.0(ref = -2.9276869297) |  Instruments:keyboard(qv = -0.649610221386) -> -1.0(ref = -2.02914404869) |  category:List_of_hip_hop_musicians_from_New_York_City(qv = -0.741482138634) -> -1.0(ref = -1.08330965042) |  Genres:symphonic(qv = -1.05792200565) -> -1.0(ref = -2.85922241211) |  Origin:georgia(qv = -0.899308621883) -> -1.0(ref = -1.95707631111) |  category:List_of_Asian-American_hip_hop_musicians(qv = -1.12056994438) -> -1.0(ref = -1.00744879246) |  category:List_of_Scottish_musicians(qv = -0.953843712807) -> -1.0(ref = -1.0) |  end_session_now(qv = -0.0421790517867) -> 0.0(ref = 0.0) |
#
# epoch 2100,loss 4.49073, epsilon 0.82006, rewards: ( e-greedy -6.64577, greedy -1.76174)
# rec 1.493 reg 2.997
# epoch 2200,loss 4.14276, epsilon 0.81239, rewards: ( e-greedy -6.44620, greedy -1.46557)
# rec 1.146 reg 2.996
# epoch 2300,loss 3.97557, epsilon 0.80481, rewards: ( e-greedy -6.11658, greedy -1.29901)
# rec 0.980 reg 2.995
# epoch 2400,loss 4.27242, epsilon 0.79730, rewards: ( e-greedy -6.01992, greedy -1.06911)
# rec 1.278 reg 2.994
# epoch 2500,loss 4.09604, epsilon 0.78986, rewards: ( e-greedy -5.89293, greedy -0.88220)
# rec 1.103 reg 2.993
# epoch 2600,loss 3.93713, epsilon 0.78250, rewards: ( e-greedy -5.81863, greedy -0.69398)
# rec 0.945 reg 2.992
# epoch 2700,loss 3.94916, epsilon 0.77521, rewards: ( e-greedy -5.73177, greedy -0.47458)
# rec 0.958 reg 2.991
# epoch 2800,loss 4.11949, epsilon 0.76799, rewards: ( e-greedy -5.55359, greedy -0.26712)
# rec 1.130 reg 2.990
# epoch 2900,loss 4.47194, epsilon 0.76085, rewards: ( e-greedy -5.42323, greedy -0.04041)
# rec 1.483 reg 2.989
# epoch 3000,loss 4.04680, epsilon 0.75378, rewards: ( e-greedy -5.36091, greedy -0.00637)
# rec 1.059 reg 2.987
# Learning curves:
# Random session examples
# session # 0
#  Label(s):is_known(qv = -0.107337839901) -> -1.0(ref = -0.802379965782) |  decades_active:2010(qv = 0.208021074533) -> 1.0(ref = -0.337758868933) |  last_activity:1998(qv = -1.09254431725) -> -1.0(ref = -1.408167243) |  decades_active:2010(qv = 0.128369480371) -> -0.5(ref = -0.429649710655) |  last_activity:still_active(qv = 0.07405295223) -> 1.0(ref = -0.428748518229) |  Genres:ska(qv = -1.37355327606) -> -1.0(ref = -1.50394582748) |  decades_active:2010(qv = 0.0916009247303) -> -0.5(ref = -0.530469357967) |  Occupation:comedian(qv = -1.26846861839) -> -1.0(ref = -1.95000004768) |  Origin:australia(qv = -0.85319262743) -> -1.0(ref = -1.0) |  Occupation:guitarist(qv = -0.340146154165) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Origin:scotland(qv = -0.176066994667) -> -1.0(ref = -0.891228199005) |  category:List_of_Canadian_composers(qv = -0.441407501698) -> -1.0(ref = -2.84306979179) |  Origin:u.s.(qv = -0.754814207554) -> -1.0(ref = -1.94007360935) |  category:List_of_Christian_hip_hop_and_rap_artists(qv = -1.03706789017) -> -1.0(ref = -0.989551126957) |  Instruments:acoustic(qv = -1.16294765472) -> -1.0(ref = -0.983781456947) |  Relatives:is_known(qv = -1.67105281353) -> -1.0(ref = 0.0170721709728) |  decades_active:2010(qv = 0.214558765292) -> 1.0(ref = 1.07060229778) |  Partner(s):is_known(qv = -1.01075160503) -> -1.0(ref = -1.95000004768) |  first_activity:1956(qv = -0.91542750597) -> -1.0(ref = -1.0) |  last_activity:still_active(qv = 0.299060255289) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Origin:chicago(qv = -0.116808280349) -> -1.0(ref = -0.854051470757) |  Alma mater:is_known(qv = -0.462217479944) -> -1.0(ref = -0.967289924622) |  Occupation:tv(qv = -0.630805015564) -> -1.0(ref = 0.0344316288829) |  decades_active:2010(qv = 0.172651171684) -> 1.0(ref = 1.08887541294) |  decades_active:2010(qv = 0.0935530737042) -> -0.5(ref = -1.79050505161) |  Genres:coast(qv = -1.43465685844) -> -1.0(ref = -1.35842633247) |  decades_active:2010(qv = 0.0295159369707) -> -0.5(ref = -0.377290904522) |  Parent(s):is_known(qv = -1.49129271507) -> -1.0(ref = -0.0500000119209) |  last_activity:still_active(qv = 0.0771411433816) -> 1.0(ref = 1.0) |  Relatives:is_known(qv = -0.635034620762) -> 0.0(ref = 0.0) | reached max session length
# epoch 3100,loss 3.81675, epsilon 0.74677, rewards: ( e-greedy -5.23482, greedy 0.19427)
# rec 0.830 reg 2.986
# epoch 3200,loss 3.73248, epsilon 0.73984, rewards: ( e-greedy -5.12134, greedy 0.51484)
# rec 0.747 reg 2.985
# epoch 3300,loss 3.86034, epsilon 0.73298, rewards: ( e-greedy -5.01920, greedy 0.67336)
# rec 0.876 reg 2.984
# epoch 3400,loss 4.33130, epsilon 0.72618, rewards: ( e-greedy -4.97728, greedy 0.66602)
# rec 1.348 reg 2.983
# epoch 3500,loss 4.10842, epsilon 0.71945, rewards: ( e-greedy -4.89956, greedy 0.80442)
# rec 1.127 reg 2.982
# epoch 3600,loss 4.17083, epsilon 0.71279, rewards: ( e-greedy -4.86460, greedy 0.91398)
# rec 1.190 reg 2.981
# epoch 3700,loss 3.94113, epsilon 0.70620, rewards: ( e-greedy -4.67814, greedy 1.09758)
# rec 0.962 reg 2.979
# epoch 3800,loss 4.06184, epsilon 0.69967, rewards: ( e-greedy -4.66533, greedy 1.00282)
# rec 1.084 reg 2.978
# epoch 3900,loss 3.98730, epsilon 0.69320, rewards: ( e-greedy -4.71879, greedy 1.04254)
# rec 1.010 reg 2.977
# epoch 4000,loss 3.94771, epsilon 0.68680, rewards: ( e-greedy -4.64691, greedy 1.16828)
# rec 0.972 reg 2.976
# Learning curves:
# Random session examples
# session # 0
#  Labels:is_known(qv = 0.172417864203) -> 1.0(ref = 1.14044439793) |  Origin:los(qv = -0.617280364037) -> -1.0(ref = 0.863470435143) |  decades_active:2000(qv = 0.342158287764) -> 1.0(ref = 1.96154785156) |  decades_active:2010(qv = 0.218057706952) -> 1.0(ref = 1.01215565205) |  last_activity:still_active(qv = 0.0127954566851) -> 1.0(ref = 1.10003733635) |  end_session_now(qv = 0.0546207167208) -> 0.0(ref = 0.0) |
#
# session # 1
#  Origin:germany(qv = -0.20079125464) -> -1.0(ref = -0.840994775295) |  Origin:michigan(qv = -0.332994222641) -> -1.0(ref = -1.01319813728) |  decades_active:2000(qv = 0.25918084383) -> 1.0(ref = -0.0138928228989) |  decades_active:2010(qv = 0.131276488304) -> -1.0(ref = -1.06725561619) |  Occupation:teacher(qv = -1.86984491348) -> -1.0(ref = -2.78856515884) |  Origin:texas(qv = -1.50731909275) -> -1.0(ref = -1.88270020485) |  Occupation:actor(qv = -1.15383136272) -> -1.0(ref = -0.92915815115) |  end_session_now(qv = 0.0745703801513) -> 0.0(ref = 0.0) |
#
# session # 2
#  Genres:synthpop(qv = -0.201516970992) -> -1.0(ref = -0.851721346378) |  Labels:is_known(qv = 0.156082779169) -> 1.0(ref = -0.581899106503) |  Genres:celtic(qv = -0.938732683659) -> -1.0(ref = -1.66515696049) |  category:List_of_Arabic_pop_musicians(qv = -1.47558617592) -> -1.0(ref = -0.700165271759) |  Genres:avant-garde(qv = -1.51444077492) -> -1.0(ref = -1.04706931114) |  Instruments:sampler(qv = -1.55913460255) -> -1.0(ref = -0.0495466776192) |  decades_active:2010(qv = 0.195421218872) -> 1.0(ref = 1.00047719479) |  Relatives:is_known(qv = -1.35307562351) -> -1.0(ref = -1.95000004768) |  category:List_of_individual_K-pop_artists(qv = -0.479700028896) -> -1.0(ref = -1.0) |  Birth name:is_known(qv = 0.198545992374) -> 0.0(ref = 0.0) | reached max session length
# epoch 4100,loss 4.08935, epsilon 0.68047, rewards: ( e-greedy -4.61222, greedy 1.25146)
# rec 1.115 reg 2.975
# epoch 4200,loss 3.93941, epsilon 0.67419, rewards: ( e-greedy -4.52600, greedy 1.19631)
# rec 0.966 reg 2.974
# epoch 4300,loss 3.77667, epsilon 0.66798, rewards: ( e-greedy -4.39340, greedy 1.42668)
# rec 0.804 reg 2.972
# epoch 4400,loss 3.85668, epsilon 0.66183, rewards: ( e-greedy -4.31406, greedy 1.45401)
# rec 0.886 reg 2.971
# epoch 4500,loss 4.12021, epsilon 0.65575, rewards: ( e-greedy -4.31765, greedy 1.38361)
# rec 1.150 reg 2.970
# epoch 4600,loss 3.96849, epsilon 0.64972, rewards: ( e-greedy -4.10089, greedy 1.52025)
# rec 1.000 reg 2.969
# epoch 4700,loss 3.82486, epsilon 0.64375, rewards: ( e-greedy -3.92080, greedy 1.66822)
# rec 0.857 reg 2.968
# epoch 4800,loss 4.11215, epsilon 0.63784, rewards: ( e-greedy -3.98872, greedy 1.45140)
# rec 1.146 reg 2.966
# epoch 4900,loss 3.81390, epsilon 0.63200, rewards: ( e-greedy -3.91485, greedy 1.42626)
# rec 0.849 reg 2.965
# epoch 5000,loss 3.95699, epsilon 0.62620, rewards: ( e-greedy -3.81836, greedy 1.38364)
# rec 0.993 reg 2.964
# Learning curves:
# Random session examples
# session # 0
#  Genres:heavy(qv = -0.153368964791) -> -1.0(ref = -0.605606675148) |  Labels:is_known(qv = 0.415150880814) -> 1.0(ref = 1.54936778545) |  decades_active:2000(qv = 0.629528105259) -> 1.0(ref = 0.578281879425) |  Instruments:percussion(qv = -1.1466306448) -> -1.0(ref = -0.443913787603) |  Genres:house(qv = -1.26103878021) -> -1.0(ref = 1.15287005901) |  decades_active:2010(qv = 0.555142343044) -> 1.0(ref = 2.26617908478) |  last_activity:still_active(qv = 0.367408275604) -> 1.0(ref = 1.33282017708) |  decades_active:2010(qv = 0.350337058306) -> -0.5(ref = -1.45000004768) |  Genres:hop(qv = -0.695655167103) -> -1.0(ref = -1.0) |  Genres:chicago(qv = -0.272252142429) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Origin:michigan(qv = -0.16282863915) -> -1.0(ref = -0.502943217754) |  first_activity:1971(qv = -0.498067289591) -> -1.0(ref = -0.690261483192) |  Genres:progressive(qv = -0.86172658205) -> -1.0(ref = 0.326040565968) |  decades_active:2000(qv = 0.736024260521) -> 1.0(ref = 1.39583218098) |  decades_active:2010(qv = 0.41666546464) -> 1.0(ref = 1.36195480824) |  last_activity:still_active(qv = 0.30112683773) -> 1.0(ref = 0.38100501895) |  Genres:wave(qv = -1.06594991684) -> -1.0(ref = -0.65157365799) |  last_activity:still_active(qv = 0.366764605045) -> -0.5(ref = -1.45000004768) |  category:List_of_indie_pop_artists(qv = -0.860105454922) -> -1.0(ref = -1.0) |  Birth name:is_known(qv = 0.153494134545) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Labels:is_known(qv = 0.354904949665) -> 1.0(ref = 1.3775780201) |  Instruments:vocalist(qv = -0.651906847954) -> -1.0(ref = -0.484472900629) |  decades_active:2000(qv = 0.744593977928) -> 1.0(ref = 0.542660117149) |  category:List_of_gospel_musicians(qv = -1.37869608402) -> -1.0(ref = -0.48141041398) |  last_activity:1989(qv = -1.19314563274) -> -1.0(ref = -2.479377985) |  Occupation:saxophonist(qv = -1.16861712933) -> -1.0(ref = -1.55724000931) |  Genres:rap(qv = -1.36945605278) -> -1.0(ref = -0.586568415165) |  decades_active:2010(qv = 0.435191124678) -> 1.0(ref = 0.0500000119209) |  Genres:metal(qv = -0.536983788013) -> -1.0(ref = -1.0) |  Other names:is_known(qv = -0.468839943409) -> 0.0(ref = 0.0) | reached max session length
# epoch 5100,loss 4.15037, epsilon 0.62047, rewards: ( e-greedy -3.79153, greedy 1.51527)
# rec 1.188 reg 2.963
# epoch 5200,loss 3.82013, epsilon 0.61479, rewards: ( e-greedy -3.73737, greedy 1.60874)
# rec 0.859 reg 2.962
# epoch 5300,loss 4.05764, epsilon 0.60917, rewards: ( e-greedy -3.64864, greedy 1.54287)
# rec 1.097 reg 2.960
# epoch 5400,loss 4.01738, epsilon 0.60361, rewards: ( e-greedy -3.58877, greedy 1.57858)
# rec 1.058 reg 2.959
# epoch 5500,loss 4.05577, epsilon 0.59810, rewards: ( e-greedy -3.35990, greedy 1.70573)
# rec 1.098 reg 2.958
# epoch 5600,loss 3.97432, epsilon 0.59265, rewards: ( e-greedy -3.43391, greedy 1.63015)
# rec 1.017 reg 2.957
# epoch 5700,loss 3.68105, epsilon 0.58725, rewards: ( e-greedy -3.50552, greedy 1.65714)
# rec 0.725 reg 2.956
# epoch 5800,loss 3.90744, epsilon 0.58190, rewards: ( e-greedy -3.35996, greedy 1.62642)
# rec 0.953 reg 2.954
# epoch 5900,loss 3.93089, epsilon 0.57661, rewards: ( e-greedy -3.13897, greedy 1.80878)
# rec 0.978 reg 2.953
# epoch 6000,loss 4.34496, epsilon 0.57137, rewards: ( e-greedy -3.25507, greedy 1.75290)
# rec 1.393 reg 2.952
# Learning curves:
# Random session examples
# session # 0
#  Labels:is_known(qv = 0.548310279846) -> -1.0(ref = -0.41504150629) |  Labels:is_known(qv = 0.615745782852) -> -0.5(ref = -1.8482811451) |  Occupation:artist(qv = -0.997814893723) -> -1.0(ref = -1.41924333572) |  category:List_of_folk_musicians(qv = -0.819651782513) -> -1.0(ref = -0.441308796406) |  Origin:kingston(qv = -0.943379044533) -> -1.0(ref = 1.00641691685) |  decades_active:2010(qv = 0.377514958382) -> 1.0(ref = 2.11201786995) |  decades_active:1980(qv = 0.0675429850817) -> 1.0(ref = 1.17054510117) |  decades_active:2010(qv = 0.179521158338) -> -0.5(ref = 0.449999988079) |  last_activity:still_active(qv = 0.195087373257) -> 1.0(ref = 1.0) |  Genres:electronic(qv = -0.246590018272) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Labels:is_known(qv = 0.548310279846) -> 1.0(ref = 1.580296278) |  Genres:bop(qv = -0.616124272346) -> -1.0(ref = -0.54529440403) |  decades_active:2000(qv = 0.950269699097) -> 1.0(ref = 0.478637456894) |  category:List_of_adult_alternative_artists(qv = -0.854291558266) -> -1.0(ref = -0.548802673817) |  decades_active:2010(qv = 0.47494456172) -> 1.0(ref = -0.788862586021) |  Home town:is_known(qv = -1.0213663578) -> -1.0(ref = -1.88301324844) |  Genres:and(qv = -0.885252356529) -> -1.0(ref = -0.929487586021) |  Birth name:is_known(qv = 0.0742236077785) -> 1.0(ref = 1.95000004768) |  Website:is_known(qv = 0.138894587755) -> 1.0(ref = 1.0) |  Occupation:songwriter(qv = -0.178133010864) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Labels:is_known(qv = 0.548310279846) -> 1.0(ref = 1.580296278) |  category:List_of_deaths_in_rock_and_roll(qv = -0.443642348051) -> -1.0(ref = -2.34052228928) |  first_activity:1977(qv = -0.656683862209) -> -1.0(ref = -1.41107606888) |  category:List_of_rhythm_guitarists(qv = -1.04757702351) -> -1.0(ref = -0.432711601257) |  decades_active:2000(qv = 0.597145676613) -> 1.0(ref = -0.516103327274) |  Occupation:comedian(qv = -1.08786451817) -> -1.0(ref = -1.59589827061) |  Genres:hip(qv = -0.69626814127) -> -1.0(ref = -0.627261340618) |  Origin:washington(qv = -0.731560587883) -> -1.0(ref = -1.95000004768) |  Birth name:is_known(qv = 0.275713533163) -> -1.0(ref = -1.0) |  Genres:hop(qv = 0.381855100393) -> 0.0(ref = 0.0) | reached max session length
# epoch 6100,loss 3.81815, epsilon 0.56618, rewards: ( e-greedy -3.15956, greedy 1.77761)
# rec 0.867 reg 2.951
# epoch 6200,loss 4.39756, epsilon 0.56105, rewards: ( e-greedy -3.25361, greedy 1.66485)
# rec 1.448 reg 2.950
# epoch 6300,loss 3.83249, epsilon 0.55596, rewards: ( e-greedy -3.19325, greedy 1.69337)
# rec 0.884 reg 2.949
# epoch 6400,loss 3.72299, epsilon 0.55093, rewards: ( e-greedy -3.13892, greedy 1.66903)
# rec 0.776 reg 2.947
# epoch 6500,loss 3.90235, epsilon 0.54594, rewards: ( e-greedy -3.09503, greedy 1.73213)
# rec 0.956 reg 2.946
# epoch 6600,loss 4.10273, epsilon 0.54101, rewards: ( e-greedy -2.94053, greedy 1.92391)
# rec 1.158 reg 2.945
# epoch 6700,loss 3.84534, epsilon 0.53612, rewards: ( e-greedy -3.00647, greedy 1.94152)
# rec 0.901 reg 2.944
# epoch 6800,loss 4.25275, epsilon 0.53129, rewards: ( e-greedy -2.92083, greedy 1.90237)
# rec 1.310 reg 2.943
# epoch 6900,loss 4.28898, epsilon 0.52650, rewards: ( e-greedy -2.80374, greedy 1.82713)
# rec 1.347 reg 2.942
# epoch 7000,loss 4.64542, epsilon 0.52176, rewards: ( e-greedy -2.97337, greedy 1.60442)
# rec 1.705 reg 2.940
# Learning curves:
# Random session examples
# session # 0
#  Labels:is_known(qv = 0.708192050457) -> 1.0(ref = 1.72734332085) |  decades_active:2000(qv = 0.765624582767) -> 1.0(ref = 1.3500187397) |  Genres:indie(qv = -0.544845104218) -> -1.0(ref = 0.368440806866) |  decades_active:2010(qv = 0.760222673416) -> 1.0(ref = 1.44046401978) |  last_activity:still_active(qv = 0.463646352291) -> 1.0(ref = 1.00474882126) |  Genres:free(qv = -1.16075706482) -> -1.0(ref = 0.0049987132661) |  decades_active:1990(qv = 0.363603621721) -> 1.0(ref = 1.05789339542) |  Nationality:is_known(qv = -0.889851570129) -> -1.0(ref = -1.95000004768) |  Birth name:is_known(qv = 0.205069303513) -> -1.0(ref = -1.0) |  Occupation:writer(qv = 0.114332094789) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Labels:is_known(qv = 0.708192050457) -> 1.0(ref = 1.72734332085) |  category:List_of_blues_musicians(qv = -0.572643220425) -> -1.0(ref = -0.510717988014) |  Occupation:drummer(qv = -0.810430824757) -> -1.0(ref = 0.515033721924) |  decades_active:2000(qv = 1.1602653265) -> 1.0(ref = 1.59477233887) |  decades_active:2010(qv = 0.626076161861) -> 1.0(ref = -0.605770111084) |  Origin:india(qv = -0.977503657341) -> -1.0(ref = -1.69028437138) |  Genres:world(qv = -0.762794971466) -> -1.0(ref = -0.726615190506) |  decades_active:1990(qv = 0.287773489952) -> 1.0(ref = 0.524999976158) |  Labels:is_known(qv = -0.58142209053) -> -0.5(ref = -0.5) |  decades_active:1940(qv = 0.0776057168841) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Labels:is_known(qv = 0.708192050457) -> 1.0(ref = 1.72734332085) |  category:List_of_musicians_who_play_left-handed(qv = -0.471366167068) -> -1.0(ref = -2.06719040871) |  Occupation:songwriter(qv = -0.316150397062) -> -1.0(ref = -1.12335824966) |  Origin:san(qv = -0.82530194521) -> -1.0(ref = -0.129850745201) |  category:List_of_noise_musicians(qv = -0.910552740097) -> -1.0(ref = -2.41874217987) |  category:List_of_flautists(qv = -0.749787867069) -> -1.0(ref = -1.49341285229) |  Occupation:pianist(qv = -0.77868694067) -> -1.0(ref = -0.519381999969) |  decades_active:2010(qv = 0.505913674831) -> -1.0(ref = -1.95000004768) |  last_activity:still_active(qv = 0.26726603508) -> -1.0(ref = -1.0) |  category:List_of_progressive_rock_supergroups(qv = -0.316971331835) -> 0.0(ref = 0.0) | reached max session length
# epoch 7100,loss 4.22371, epsilon 0.51706, rewards: ( e-greedy -2.75603, greedy 1.64898)
# rec 1.284 reg 2.939
# epoch 7200,loss 4.00696, epsilon 0.51241, rewards: ( e-greedy -2.65543, greedy 1.72908)
# rec 1.069 reg 2.938
# epoch 7300,loss 3.85909, epsilon 0.50781, rewards: ( e-greedy -2.57489, greedy 1.74117)
# rec 0.922 reg 2.937
# epoch 7400,loss 3.75772, epsilon 0.50326, rewards: ( e-greedy -2.46740, greedy 1.88705)
# rec 0.822 reg 2.936
# epoch 7500,loss 4.29428, epsilon 0.49875, rewards: ( e-greedy -2.40566, greedy 1.93335)
# rec 1.360 reg 2.935
# epoch 7600,loss 3.95154, epsilon 0.49428, rewards: ( e-greedy -2.43509, greedy 1.94501)
# rec 1.018 reg 2.933
# epoch 7700,loss 3.63484, epsilon 0.48986, rewards: ( e-greedy -2.31158, greedy 2.02551)
# rec 0.703 reg 2.932
# epoch 7800,loss 4.66632, epsilon 0.48549, rewards: ( e-greedy -2.40042, greedy 1.91296)
# rec 1.735 reg 2.931
# epoch 7900,loss 3.57561, epsilon 0.48115, rewards: ( e-greedy -2.37038, greedy 2.02167)
# rec 0.646 reg 2.930
# epoch 8000,loss 4.24791, epsilon 0.47686, rewards: ( e-greedy -2.12334, greedy 1.98950)
# rec 1.319 reg 2.929
# Learning curves:
# Random session examples
# session # 0
#  Labels:is_known(qv = 0.888874471188) -> 1.0(ref = 1.91334378719) |  first_activity:1956(qv = -0.440927714109) -> -1.0(ref = 1.4579051733) |  decades_active:2000(qv = 1.41932034492) -> 1.0(ref = 2.58726859093) |  decades_active:2010(qv = 1.11913180351) -> 1.0(ref = 1.67080903053) |  last_activity:still_active(qv = 0.706114828587) -> 1.0(ref = 1.12937796116) |  Origin:south(qv = -0.575787782669) -> -1.0(ref = 0.136187389493) |  decades_active:1990(qv = 0.537834465504) -> 1.0(ref = 1.19598674774) |  Birth name:is_known(qv = 0.206301897764) -> -1.0(ref = -1.95000004768) |  Website:is_known(qv = 0.0982051491737) -> -1.0(ref = -1.0) |  Occupation:record(qv = 0.0210312493145) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Labels:is_known(qv = 0.888874471188) -> 1.0(ref = 1.91334378719) |  decades_active:2000(qv = 0.961414515972) -> -1.0(ref = -0.616765201092) |  decades_active:1990(qv = 0.0872705057263) -> 1.0(ref = 0.403405040503) |  decades_active:2010(qv = 0.787208616734) -> -1.0(ref = -0.627994716167) |  Instruments:vocal(qv = -0.807247877121) -> -1.0(ref = -2.19681406021) |  decades_active:1990(qv = 0.242845624685) -> -0.5(ref = -1.25980424881) |  last_activity:still_active(qv = 0.258139759302) -> -1.0(ref = -0.799793899059) |  Birth name:is_known(qv = 0.210743278265) -> 1.0(ref = 0.0500000119209) |  Genres:ambient(qv = -0.50839817524) -> -1.0(ref = -1.0) |  first_activity:1992(qv = 0.0588267371058) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  first_activity:1974(qv = -0.170778378844) -> -1.0(ref = 0.27223727107) |  Instruments:bass(qv = -0.141175568104) -> 1.0(ref = 0.343867301941) |  Genres:score(qv = -0.608101010323) -> -1.0(ref = -0.690666019917) |  last_activity:2001(qv = -0.718753099442) -> -1.0(ref = 0.325614750385) |  decades_active:2000(qv = 1.39538395405) -> -1.0(ref = -2.43531680107) |  Origin:australia(qv = -0.845111370087) -> -1.0(ref = -1.51085984707) |  Occupation:educator(qv = -0.375711083412) -> -1.0(ref = -0.537747263908) |  Occupation:film(qv = -0.344017028809) -> -1.0(ref = -1.95000004768) |  decades_active:2010(qv = 0.25311422348) -> -1.0(ref = -1.0) |  Agent:is_known(qv = 0.153469488025) -> 0.0(ref = 0.0) | reached max session length
# epoch 8100,loss 4.19278, epsilon 0.47262, rewards: ( e-greedy -2.09601, greedy 1.95055)
# rec 1.265 reg 2.928
# epoch 8200,loss 4.28666, epsilon 0.46841, rewards: ( e-greedy -2.04641, greedy 1.99549)
# rec 1.360 reg 2.926
# epoch 8300,loss 4.10582, epsilon 0.46425, rewards: ( e-greedy -1.95677, greedy 2.17594)
# rec 1.180 reg 2.925
# epoch 8400,loss 4.10156, epsilon 0.46012, rewards: ( e-greedy -1.89609, greedy 2.13335)
# rec 1.177 reg 2.924
# epoch 8500,loss 4.98280, epsilon 0.45604, rewards: ( e-greedy -1.70648, greedy 2.17002)
# rec 2.060 reg 2.923
# epoch 8600,loss 4.10702, epsilon 0.45200, rewards: ( e-greedy -1.60583, greedy 2.23301)
# rec 1.185 reg 2.922
# epoch 8700,loss 3.78235, epsilon 0.44800, rewards: ( e-greedy -1.44025, greedy 2.31471)
# rec 0.862 reg 2.921
# epoch 8800,loss 4.29518, epsilon 0.44404, rewards: ( e-greedy -1.39623, greedy 2.34824)
# rec 1.376 reg 2.920
# epoch 8900,loss 4.58357, epsilon 0.44012, rewards: ( e-greedy -1.33660, greedy 2.32342)
# rec 1.665 reg 2.918
# epoch 9000,loss 4.44862, epsilon 0.43624, rewards: ( e-greedy -1.21294, greedy 2.38608)
# rec 1.531 reg 2.917
# Learning curves:
# Random session examples
# session # 0
#  Labels:is_known(qv = 1.05977618694) -> 1.0(ref = 2.06740689278) |  decades_active:2000(qv = 1.12358617783) -> 1.0(ref = 3.31250977516) |  decades_active:2010(qv = 1.30056750774) -> 1.0(ref = 2.43422079086) |  last_activity:still_active(qv = 0.845168113708) -> 1.0(ref = 1.50970613956) |  decades_active:2010(qv = 0.536532759666) -> -0.5(ref = -1.48192536831) |  last_activity:still_active(qv = 0.559782981873) -> -0.5(ref = -1.03360569477) |  category:List_of_Scottish_musicians(qv = -0.77266150713) -> -1.0(ref = -0.561690151691) |  category:List_of_Polish_musicians_and_musical_groups(qv = -0.725480139256) -> -1.0(ref = -1.95000004768) |  Native name:is_known(qv = -0.413513660431) -> -1.0(ref = -1.0) |  decades_active:1970(qv = -0.143294289708) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Labels:is_known(qv = 1.05977618694) -> 1.0(ref = 2.06740689278) |  Occupation:dancer(qv = -0.308257728815) -> -1.0(ref = -0.0731949582696) |  Genres:roll(qv = -0.499150544405) -> -1.0(ref = 0.97558426857) |  decades_active:2000(qv = 1.41935372353) -> 1.0(ref = 2.07956242561) |  Genres:experimental(qv = -0.659861862659) -> -1.0(ref = 1.11261808872) |  decades_active:2010(qv = 0.957440376282) -> 1.0(ref = 2.22380852699) |  last_activity:still_active(qv = 0.685337603092) -> 1.0(ref = 1.2882194519) |  Occupation:singer(qv = -0.443623840809) -> -1.0(ref = -1.95000004768) |  first_activity:1986(qv = -0.333013772964) -> -1.0(ref = -1.0) |  Origin:us(qv = 0.236845761538) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Occupation:musician(qv = 0.0722614824772) -> -1.0(ref = 0.621092796326) |  Genres:j-pop(qv = -0.488036513329) -> -1.0(ref = 0.243704587221) |  category:List_of_R%26B_musicians(qv = -0.33239325881) -> -1.0(ref = 1.30916273594) |  Labels:is_known(qv = 1.6506626606) -> 1.0(ref = 2.43069767952) |  decades_active:2000(qv = 1.50599753857) -> 1.0(ref = 1.60516417027) |  decades_active:2010(qv = 1.27243626118) -> 1.0(ref = 0.637014985085) |  Genres:west(qv = -0.889212667942) -> -1.0(ref = -0.382089495659) |  Origin:atlanta(qv = -0.795655727386) -> -1.0(ref = -1.95000004768) |  category:List_of_girl_groups(qv = -0.595190227032) -> -1.0(ref = -1.0) |  Birth name:is_known(qv = 0.065781712532) -> 0.0(ref = 0.0) | reached max session length
# epoch 9100,loss 3.75543, epsilon 0.43240, rewards: ( e-greedy -1.24165, greedy 2.42747)
# rec 0.839 reg 2.916
# epoch 9200,loss 3.95077, epsilon 0.42859, rewards: ( e-greedy -1.37748, greedy 2.48972)
# rec 1.036 reg 2.915
# epoch 9300,loss 4.66537, epsilon 0.42483, rewards: ( e-greedy -1.11474, greedy 2.62075)
# rec 1.751 reg 2.914
# epoch 9400,loss 4.06499, epsilon 0.42110, rewards: ( e-greedy -1.05326, greedy 2.70367)
# rec 1.152 reg 2.913
# epoch 9500,loss 4.19945, epsilon 0.41740, rewards: ( e-greedy -0.89294, greedy 2.75331)
# rec 1.288 reg 2.912
# epoch 9600,loss 4.16216, epsilon 0.41375, rewards: ( e-greedy -0.71364, greedy 2.81298)
# rec 1.252 reg 2.910
# epoch 9700,loss 4.56713, epsilon 0.41013, rewards: ( e-greedy -0.62728, greedy 2.76668)
# rec 1.658 reg 2.909
# epoch 9800,loss 4.41240, epsilon 0.40655, rewards: ( e-greedy -0.63455, greedy 2.68501)
# rec 1.504 reg 2.908
# epoch 9900,loss 4.18200, epsilon 0.40300, rewards: ( e-greedy -0.58109, greedy 2.58651)
# rec 1.275 reg 2.907
# epoch 10000,loss 4.75073, epsilon 0.39949, rewards: ( e-greedy -0.36299, greedy 2.69786)
# rec 1.845 reg 2.906
# Learning curves:
# Random session examples
# session # 0
#  Labels:is_known(qv = 1.26846075058) -> 1.0(ref = 2.27079582214) |  decades_active:2000(qv = 1.33767974377) -> 1.0(ref = 0.181311458349) |  Occupation:remixer(qv = -0.516174554825) -> -1.0(ref = -0.861777424812) |  Residence:is_known(qv = -0.539298117161) -> -1.0(ref = 0.145497471094) |  decades_active:2010(qv = 1.20578682423) -> 1.0(ref = 3.2292330265) |  last_activity:still_active(qv = 1.04128158092) -> 1.0(ref = 2.34656119347) |  decades_active:1990(qv = 0.616515755653) -> 1.0(ref = 1.41743278503) |  decades_active:1980(qv = -0.194973260164) -> 1.0(ref = 0.524999976158) |  decades_active:2010(qv = 0.473624497652) -> -0.5(ref = -0.5) |  Instruments:and(qv = -0.590876877308) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Genres:electro(qv = -0.116112545133) -> -1.0(ref = 0.800737977028) |  Labels:is_known(qv = 1.89551365376) -> 1.0(ref = 0.844020545483) |  Genres:coast(qv = -0.47957777977) -> -1.0(ref = -0.164188921452) |  first_activity:1986(qv = -0.440099596977) -> -1.0(ref = 0.879801154137) |  Instrument(s):is_known(qv = -0.653810918331) -> -1.0(ref = 1.91090428829) |  decades_active:2000(qv = 1.64204895496) -> 1.0(ref = 3.06410980225) |  decades_active:2010(qv = 1.62449991703) -> 1.0(ref = 2.17274713516) |  Genres:psychedelic(qv = -0.564561784267) -> -1.0(ref = -1.95000004768) |  last_activity:1995(qv = -0.361296474934) -> -1.0(ref = -1.0) |  Instruments:flute(qv = -0.455843538046) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Instruments:banjo(qv = -0.0891988798976) -> -1.0(ref = 0.820755004883) |  Known for:is_known(qv = -0.12000823766) -> -1.0(ref = 2.23782157898) |  Labels:is_known(qv = 2.06189918518) -> 1.0(ref = 3.40823316574) |  decades_active:2000(qv = 1.9086638689) -> 1.0(ref = 2.53498220444) |  decades_active:2010(qv = 1.6157708168) -> 1.0(ref = 3.27936244011) |  last_activity:still_active(qv = 1.270149827) -> 1.0(ref = 2.39932894707) |  decades_active:1990(qv = 0.837737858295) -> 1.0(ref = 1.47297775745) |  Birth name:is_known(qv = 0.497871279716) -> -1.0(ref = -1.47500002384) |  decades_active:1990(qv = 0.215274021029) -> -0.5(ref = -0.5) |  category:List_of_electric_blues_musicians(qv = 0.0565500184894) -> 0.0(ref = 0.0) | reached max session length
# saved ./agentnet_snapshots/tutorial.wikicat.advanced.epoch10000.pcl
# epoch 10100,loss 4.35782, epsilon 0.39601, rewards: ( e-greedy -0.43669, greedy 2.64807)
# rec 1.453 reg 2.905
# epoch 10200,loss 4.26748, epsilon 0.39257, rewards: ( e-greedy -0.44302, greedy 2.57827)
# rec 1.364 reg 2.904
# epoch 10300,loss 4.04078, epsilon 0.38916, rewards: ( e-greedy -0.41372, greedy 2.61544)
# rec 1.138 reg 2.903
# epoch 10400,loss 4.57284, epsilon 0.38578, rewards: ( e-greedy -0.47734, greedy 2.51389)
# rec 1.671 reg 2.901
# epoch 10500,loss 4.40336, epsilon 0.38244, rewards: ( e-greedy -0.53961, greedy 2.43751)
# rec 1.503 reg 2.900
# epoch 10600,loss 4.41525, epsilon 0.37913, rewards: ( e-greedy -0.41065, greedy 2.44875)
# rec 1.516 reg 2.899
# epoch 10700,loss 4.20207, epsilon 0.37586, rewards: ( e-greedy -0.37458, greedy 2.48388)
# rec 1.304 reg 2.898
# epoch 10800,loss 3.93384, epsilon 0.37262, rewards: ( e-greedy -0.18713, greedy 2.58549)
# rec 1.037 reg 2.897
# epoch 10900,loss 4.21572, epsilon 0.36941, rewards: ( e-greedy -0.21841, greedy 2.64194)
# rec 1.320 reg 2.896
# epoch 11000,loss 4.39158, epsilon 0.36623, rewards: ( e-greedy -0.27657, greedy 2.64275)
# rec 1.497 reg 2.895
# Learning curves:
# Random session examples
# session # 0
#  Labels:is_known(qv = 1.46421742439) -> 1.0(ref = 2.46686577797) |  decades_active:2000(qv = 1.54406917095) -> 1.0(ref = 1.87546169758) |  decades_active:2010(qv = 1.75797748566) -> 1.0(ref = 0.921538591385) |  Origin:city(qv = -0.466103672981) -> -1.0(ref = -0.0825909301639) |  decades_active:1990(qv = 0.965693771839) -> 1.0(ref = 3.09095692635) |  last_activity:still_active(qv = 0.819666087627) -> 1.0(ref = 2.20100736618) |  Birth name:is_known(qv = 0.440084636211) -> 1.0(ref = 1.26421821117) |  Website:is_known(qv = 0.278124451637) -> 1.0(ref = 0.0500000119209) |  Alma mater:is_known(qv = -0.640965998173) -> -1.0(ref = -1.0) |  Genres:gothic(qv = -0.473273128271) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Labels:is_known(qv = 1.46421742439) -> 1.0(ref = 2.46686577797) |  Political party:is_known(qv = -0.239681079984) -> -1.0(ref = -1.78738629818) |  first_activity:1983(qv = -0.305556625128) -> -1.0(ref = -0.828827679157) |  Genres:contemporary(qv = -0.657650768757) -> -1.0(ref = 0.180181398988) |  category:List_of_jazz_drummers(qv = -0.804161131382) -> -1.0(ref = 1.49115335941) |  decades_active:2000(qv = 0.993381202221) -> 1.0(ref = 2.62226676941) |  decades_active:2010(qv = 0.950262546539) -> 1.0(ref = 1.70764935017) |  last_activity:still_active(qv = 0.74489402771) -> 1.0(ref = 0.0500000119209) |  Origin:australia(qv = -0.560011327267) -> -1.0(ref = -1.0) |  decades_active:1990(qv = 0.266933679581) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Genres:rockabilly(qv = -0.0922268405557) -> -1.0(ref = 1.10175096989) |  Labels:is_known(qv = 2.21236944199) -> 1.0(ref = 2.4947681427) |  decades_active:2000(qv = 2.10332632065) -> 1.0(ref = 1.57344007492) |  first_activity:1950(qv = -0.26728028059) -> -1.0(ref = 0.603621125221) |  decades_active:2010(qv = 1.6880222559) -> 1.0(ref = 1.22446382046) |  last_activity:still_active(qv = 1.24207913876) -> -1.0(ref = 0.236277729273) |  decades_active:1990(qv = 0.802070200443) -> 1.0(ref = 1.30134499073) |  Birth name:is_known(qv = 0.317205220461) -> 1.0(ref = 0.0500000119209) |  Website:is_known(qv = 0.109899446368) -> -1.0(ref = -1.0) |  category:List_of_deaths_in_rock_and_roll(qv = -0.0573281534016) -> 0.0(ref = 0.0) | reached max session length
# epoch 11100,loss 4.40352, epsilon 0.36308, rewards: ( e-greedy -0.17391, greedy 2.73347)
# rec 1.510 reg 2.894
# epoch 11200,loss 4.66848, epsilon 0.35997, rewards: ( e-greedy -0.02652, greedy 2.84013)
# rec 1.776 reg 2.892
# epoch 11300,loss 4.05109, epsilon 0.35688, rewards: ( e-greedy 0.12113, greedy 3.02111)
# rec 1.160 reg 2.891
# epoch 11400,loss 4.92089, epsilon 0.35383, rewards: ( e-greedy -0.07098, greedy 2.84900)
# rec 2.031 reg 2.890
# epoch 11500,loss 4.58028, epsilon 0.35080, rewards: ( e-greedy -0.07389, greedy 2.84410)
# rec 1.691 reg 2.889
# epoch 11600,loss 4.03284, epsilon 0.34781, rewards: ( e-greedy -0.00650, greedy 2.87469)
# rec 1.145 reg 2.888
# epoch 11700,loss 4.56599, epsilon 0.34485, rewards: ( e-greedy -0.02585, greedy 2.87222)
# rec 1.679 reg 2.887
# epoch 11800,loss 4.01490, epsilon 0.34191, rewards: ( e-greedy 0.16674, greedy 3.00000)
# rec 1.129 reg 2.886
# epoch 11900,loss 5.34845, epsilon 0.33901, rewards: ( e-greedy 0.05006, greedy 2.84000)
# rec 2.464 reg 2.885
# epoch 12000,loss 4.28627, epsilon 0.33613, rewards: ( e-greedy 0.27006, greedy 2.98600)
# rec 1.403 reg 2.884
# Learning curves:
# Random session examples
# session # 0
#  Labels:is_known(qv = 1.67624020576) -> 1.0(ref = 2.63128185272) |  decades_active:2000(qv = 1.71713888645) -> 1.0(ref = 1.76108813286) |  decades_active:2010(qv = 1.8519963026) -> 1.0(ref = 0.801145374775) |  Genres:electronic(qv = -0.32947781682) -> -1.0(ref = -0.209320664406) |  decades_active:1990(qv = 0.832294046879) -> -1.0(ref = -0.663266837597) |  Birth name:is_known(qv = 0.436709582806) -> 1.0(ref = 0.354455947876) |  Genres:avant-garde(qv = -0.451959311962) -> -1.0(ref = -0.679520070553) |  Website:is_known(qv = 0.337347269058) -> 1.0(ref = 0.524999976158) |  Birth name:is_known(qv = 0.0541874207556) -> -0.5(ref = -0.5) |  Also known as:is_known(qv = 0.121672667563) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Labels:is_known(qv = 1.67624020576) -> 1.0(ref = 2.63128185272) |  decades_active:2000(qv = 1.71713888645) -> 1.0(ref = 1.93381941319) |  Genres:blues(qv = -0.0252180304378) -> -1.0(ref = 0.982967853546) |  decades_active:2010(qv = 1.58859264851) -> 1.0(ref = 2.08733463287) |  last_activity:still_active(qv = 1.14456284046) -> 1.0(ref = 1.39374339581) |  Genres:rap(qv = -0.525580048561) -> -1.0(ref = 0.414466708899) |  decades_active:1990(qv = 0.863373160362) -> 1.0(ref = 1.48891234398) |  Birth name:is_known(qv = 0.514644622803) -> 1.0(ref = 1.95000004768) |  Website:is_known(qv = 0.186097502708) -> 1.0(ref = 1.0) |  category:List_of_new-age_music_artists(qv = -0.286965429783) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  category:List_of_trumpeters(qv = -0.123698472977) -> -1.0(ref = 1.32392609119) |  Labels:is_known(qv = 2.44623804092) -> 1.0(ref = 0.447793513536) |  Instruments:keyboard(qv = -0.0962701737881) -> -1.0(ref = -0.581269979477) |  Origin:angeles(qv = -0.53965985775) -> -1.0(ref = 0.440768420696) |  Origin:kingston(qv = -0.569133996964) -> -1.0(ref = -0.349027991295) |  decades_active:2000(qv = 1.10276842117) -> 1.0(ref = 0.685233712196) |  category:List_of_South_Korean_musicians(qv = -0.578531563282) -> -1.0(ref = -0.331332951784) |  decades_active:2010(qv = 0.703860044479) -> 1.0(ref = 0.0500000119209) |  last_activity:still_active(qv = 0.609691977501) -> -1.0(ref = -1.0) |  decades_active:1990(qv = 0.135102406144) -> 0.0(ref = 0.0) | reached max session length
# epoch 12100,loss 4.91869, epsilon 0.33329, rewards: ( e-greedy 0.37805, greedy 2.97740)
# rec 2.036 reg 2.882
# epoch 12200,loss 5.04147, epsilon 0.33047, rewards: ( e-greedy 0.33025, greedy 2.88466)
# rec 2.160 reg 2.881
# epoch 12300,loss 4.73848, epsilon 0.32768, rewards: ( e-greedy 0.29222, greedy 2.88119)
# rec 1.858 reg 2.880
# epoch 12400,loss 4.64614, epsilon 0.32492, rewards: ( e-greedy 0.29800, greedy 2.91307)
# rec 1.767 reg 2.879
# epoch 12500,loss 4.33347, epsilon 0.32218, rewards: ( e-greedy 0.38820, greedy 3.06177)
# rec 1.455 reg 2.878
# epoch 12600,loss 4.37222, epsilon 0.31947, rewards: ( e-greedy 0.52438, greedy 3.22059)
# rec 1.495 reg 2.877
# epoch 12700,loss 4.38985, epsilon 0.31679, rewards: ( e-greedy 0.70194, greedy 3.35353)
# rec 1.514 reg 2.876
# epoch 12800,loss 4.03694, epsilon 0.31414, rewards: ( e-greedy 0.80675, greedy 3.40818)
# rec 1.162 reg 2.875
# epoch 12900,loss 3.95955, epsilon 0.31151, rewards: ( e-greedy 0.99107, greedy 3.59236)
# rec 1.086 reg 2.874
# epoch 13000,loss 4.21800, epsilon 0.30891, rewards: ( e-greedy 0.87197, greedy 3.53812)
# rec 1.346 reg 2.872
# Learning curves:
# Random session examples
# session # 0
#  Instruments:vocalist(qv = -0.0867500826716) -> -1.0(ref = 1.32041430473) |  Labels:is_known(qv = 2.44254136086) -> 1.0(ref = 4.12468671799) |  decades_active:2000(qv = 2.50192952156) -> 1.0(ref = 3.28914380074) |  decades_active:2010(qv = 2.13650131226) -> 1.0(ref = 2.40962505341) |  last_activity:still_active(qv = 1.48381578922) -> 1.0(ref = 1.29464805126) |  decades_active:1990(qv = 1.01054346561) -> 1.0(ref = 0.310155898333) |  Birth name:is_known(qv = 0.550605356693) -> -1.0(ref = -0.726151704788) |  Genres:swing(qv = -0.611348152161) -> -1.0(ref = -0.0500000119209) |  Website:is_known(qv = 0.176521092653) -> 1.0(ref = 1.0) |  Instruments:vocal(qv = -0.000950985588133) -> 0.0(ref = 0.0) | reached max session length
# session # 1
#  Labels:is_known(qv = 1.86306321621) -> 1.0(ref = 2.82579350471) |  decades_active:2000(qv = 1.92188799381) -> 1.0(ref = 3.67463302612) |  decades_active:2010(qv = 2.05004739761) -> 1.0(ref = 2.81540322304) |  last_activity:still_active(qv = 1.53130304813) -> 1.0(ref = 1.91095089912) |  Genres:pop(qv = 0.0607374384999) -> 1.0(ref = 1.31496632099) |  Genres:latin(qv = -0.462432384491) -> -1.0(ref = 0.331543534994) |  decades_active:1990(qv = 0.871703505516) -> 1.0(ref = 1.40162479877) |  Birth name:is_known(qv = 0.422762989998) -> 1.0(ref = 1.95000004768) |  Website:is_known(qv = 0.376941591501) -> 1.0(ref = 1.0) |  Occupation:personality(qv = 0.0698483288288) -> 0.0(ref = 0.0) | reached max session length
# session # 2
#  Labels:is_known(qv = 1.86306321621) -> -1.0(ref = 0.116950385273) |  decades_active:2000(qv = 1.17573726177) -> -1.0(ref = -2.80920124054) |  Genres:traditional(qv = -0.238473683596) -> -1.0(ref = -1.90442240238) |  Genres:bebop(qv = -0.618312060833) -> -1.0(ref = -0.952023625374) |  category:List_of_Maryland_music_people(qv = -0.27813577652) -> -1.0(ref = -0.972810328007) |  category:List_of_bebop_musicians(qv = -0.642117500305) -> -1.0(ref = 0.028620718047) |  Birth name:is_known(qv = 0.106235966086) -> 1.0(ref = 1.08275866508) |  end_session_now(qv = 0.0871143937111) -> 0.0(ref = 0.0) |
#
# epoch 13100,loss 4.33871, epsilon 0.30633, rewards: ( e-greedy 0.76477, greedy 3.48431)
# rec 1.467 reg 2.871
# epoch 13200,loss 4.22136, epsilon 0.30378, rewards: ( e-greedy 0.67329, greedy 3.34588)
# rec 1.351 reg 2.870
# epoch 13300,loss 4.05939, epsilon 0.30125, rewards: ( e-greedy 0.61596, greedy 3.28129)
# rec 1.190 reg 2.869

# %% [markdown]
# # Evaluating results

# %%
score_log.plot("final")

# %%
print "Random session examples"
env.load_random_batch(train_attrs,train_cats,10)
display_sessions(with_plots=True)

# %%
#load earlier snapshot.
#warning - this overrides the latest network params with earlier ones. 
#Replace 20000 with some 100000 if you wish to load latest snapshot back.
snap_name = "{}.epoch{}.pcl".format(os.path.join(snapshot_path,experiment_setup_name), 20000)
load(resolver,snap_name)

# %%
print "Random session examples"
env.load_random_batch(train_attrs,train_cats,10)
display_sessions(with_plots=True)
