# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline


#theano imports
#the problem is too simple to be run on GPU. Seriously.
# %env THEANO_FLAGS='device=cpu'
import theano
import theano.tensor as T
floatX = theano.config.floatX

import lasagne
# Out:
# env: THEANO_FLAGS='device=cpu'
# /home/jheuristic/thenv/local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # This tutorial explains the basic pipline of Agentnet experiment
# * experiment setup
# * designing agent
# * interacting with environment
# * computing losses
# * training

# %% [markdown]
# # Experiment setup
# * Here we load a simple experiment environment (description below)
# * Designing one from scratch is explained in later tutorials

# %%
import agentnet.experiments.boolean_reasoning as experiment
print experiment.__doc__
# Out:
# This is a dummy experiment setup that requires agent to make advantage of
# a simple logical formula in order to maximize expected reward.
#
# The world agent exists in has a number of boolean hidden factors:
# X1~3, Y1, Y2.
#
# The factors are not independent. Namely,
#  - Y1 = (not X1) and X2
#  - Y2 = not Y1
#
# In the initial moment of time, agent knows nothing about any of them.
# At each turn, agent may decide to
#  - "open" one of the hidden factors.
#    - if the factor turns out to be 1, agent receives +1 reward for X*, +3 for Y*
#    - Otherwise, the reward equals -1 for X*, -3 for Y*
#    - checking a single factor more than once a session will result in -0.5 reward for every attempt but for first one
#  - decide to quit session
#    - yields reward of 0 and ends the interaction.
#    - all farther actions will have no effect until next session
#
# It is expected, that in order to maximize it's expected reward, the agent
# will converge to a strategy of polling X for as long as they yield information
# on Y, and than pick one of two Ys which is 1 and quit session.
#
# The experiment setup contains a single class BooleanReasoningEnvironment that
# implements both BaseEnvironment and BaseObjective.

# %%
#Create an environment with all default parameters
env = experiment.BooleanReasoningEnvironment()

# %% [markdown]
# # agent setup
# * An agent implementation has to contain three parts:
#  * Memory layer(s)
#   * in this case, a single one-step GRU
#  * Q-values evaluation layers
#   * in this case, a lasagne dense layer based on memory layer
#  * Resolver - acton picker layer
#   * in this case, the resolver has epsilon-greedy policy

# %%
from agentnet.resolver import EpsilonGreedyResolver
from agentnet.memory import GRUMemoryLayer
from agentnet.agent import Agent

# %%
import lasagne

#only 10 hidden neurons
n_hid=10


_observation_layer = lasagne.layers.InputLayer([None,env.observation_size],name="obs_input")
_prev_state_layer = lasagne.layers.InputLayer([None,n_hid],name="prev_state_input")

#memory
#note that this isn't the same as lasagne recurrent units (see next text tab for detail)
gru = GRUMemoryLayer(n_hid,
                     _observation_layer,
                     _prev_state_layer,
                     name="gru0")

#q_eval
q_eval = lasagne.layers.DenseLayer(gru,num_units = env.n_actions,
                                   nonlinearity=lasagne.nonlinearities.linear,name="QEvaluator")

#resolver
epsilon = theano.shared(np.float32(0.1),name="e-greedy.epsilon")

resolver = EpsilonGreedyResolver(q_eval,epsilon=epsilon,name="resolver")


#all together
agent = Agent(gru,q_eval,resolver)

# %%
#Since it's a single lasagne network, one can get it's weights, output, etc
weights = lasagne.layers.get_all_params(resolver,trainable=True)
weights
# Out:
# [gru0.W_in_to_updategate,
#  gru0.W_hid_to_updategate,
#  gru0.b_updategate,
#  gru0.W_in_to_resetgate,
#  gru0.W_hid_to_resetgate,
#  gru0.b_resetgate,
#  gru0.W_in_to_hidden_update,
#  gru0.W_hid_to_hidden_update,
#  gru0.b_hidden_update,
#  QEvaluator.W,
#  QEvaluator.b]

# %% [markdown]
# ## Agent setup in detail
# * __Memory layers__
#  * One-step recurrent layer
#      * takes input and one's previous state
#      * returns new memory state
#    * Can be arbitrary lasagne layer
#    * Several one-step recurrent units are implemented in __agentnet.memory__
#    * Note that lasagne's default recurrent networks roll for several steps at once
#      * in other words, __using lasagne recurrent units as memory means recurrence inside recurrence__
#  * Using more than one memory layer is explained in farther tutorials
#
#
# * __Q-values evaluation layer__
#  * Can be arbitrary lasagne network
#  * returns predicted Q-values for each action
#  * Usually depends on memory as an input
#
#
# * __Resolver__ - action picker
#  * Decides on what action is taken
#  * Normally takes Q-values as input
#  * Currently all experiments require integer output
#  * Several resolver layers are implemented in __agentnet.resolver__

# %% [markdown]
# # Interacting with environment
# * an agent has a method that produces symbolic environment interaction sessions
# * interactions result in sequences of observations, actions, q-values,etc
# * one has to pre-define maximum session length.
#  * in this case, environment implements an indicator of whether session has ended by current tick
# * Since this environment also implements Objective methods, it can evaluate rewards for each [batch, time_tick]

# %%
#produce interaction sequences of length <= 10
history = agent.get_sessions(env,session_length=10,
                       batch_size=env.batch_size,)

state_seq,observation_seq,hidden_seq,qvalues_seq,action_seq = history

#get rewards for all actions
rewards_seq = env.get_reward_sequences(state_seq,action_seq)

#get indicator whether session is still active
is_alive_seq = env.get_whether_alive(observation_seq)

# %%
#Let us compile a function that returns all interaction logs
get_history = theano.function([],history+(is_alive_seq,rewards_seq,),mode=theano.compile.mode.FAST_RUN)

# %% [markdown]
# # Evaluating loss function
# * In this case, we want to
#  * first get pairs of (predicted Qvalue, reference Qvalue) for all actions commited
#  * second, define loss function
#  * third, compute grad and update weights
#
#
#  #### Get (prediction,reference) pairs

# %%
#get reference Qvalues according to Qlearning algorithm


from agentnet.learning import qlearning


#gamma - delayed reward coefficient - what fraction of reward is retained if it is obtained one tick later
gamma = theano.shared(np.float32(0.95),name = 'q_learning_gamma')


reference_Qvalues = qlearning.get_reference(qvalues_seq,
                               action_seq,
                               rewards_seq,
                               gamma_or_gammas=gamma,)

# %%
#zero-out future rewards at session end
from agentnet.utils.mdp import get_end_indicator

end_action_ids = get_end_indicator(is_alive_seq).nonzero()

# "set reference Qvalues at end action ids to just the immediate rewards"
reference_Qvalues = T.set_subtensor(reference_Qvalues[end_action_ids],
                                    rewards_seq[end_action_ids])

# %%
#prevent gradient updates over reference Qvalues (since they depend on predicted Qvalues)
from agentnet.utils import consider_constant
reference_Qvalues = consider_constant(reference_Qvalues)

# %%
#get predicted qvalues for commited actions (to compare with reference Qvalues)
from agentnet.utils.mdp import get_action_Qvalues

action_Qvalues = get_action_Qvalues(qvalues_seq,action_seq)

# %% [markdown]
# #### Define loss functions

# %%
#tensor of elementwise squared errors
squared_error = lasagne.objectives.squared_error(reference_Qvalues,action_Qvalues)

#zero-out ticks after session ended
squared_error = squared_error * is_alive_seq

#compute average of squared error sums per session
session_mse_loss = squared_error.sum(axis = 1).mean()

# %%
#regularize network weights

from lasagne.regularization import regularize_network_params, l2
reg_l2 = regularize_network_params(resolver,l2)*10**-3

# %%
loss = session_mse_loss + reg_l2

# %% [markdown]
# #### Compute weight updates

# %%
updates = lasagne.updates.adadelta(loss,weights,learning_rate=0.1)

# %% [markdown]
# #### Some auxilary evaluation metrics

# %%
mean_session_reward = rewards_seq.sum(axis=1).mean()
#...

# %% [markdown]
# # Compile train and evaluation functions

# %%
train_fun = theano.function([],[loss,mean_session_reward],updates=updates)

evaluation_fun = theano.function([],[loss,session_mse_loss,reg_l2,mean_session_reward])

# %% [markdown]
# # session visualization tools
#
#
# * this is a completely optional step of visualizing agent's sessions as chains of actions
# * usually useful to get insight on what worked and what din't
# * in this case, we print strings following pattern
#   * [action_name] ([predicted action qvalue]) -> reward [reference qvalue] | next iteration
#
# * plot shows
#     * time ticks over X, abstract values over Y
#     * bold lines are Qvalues for actions
#     * dots on bold lines represent what actions were taken at each moment of time
#     * dashed lines are agent's hidden state neurons
#     * blue vertical line - session end
#
#
# __Warning! the visualization tools are underdeveloped and only allow simple operations.__
#
# if you found yourself struggling to make it do what you want for 5 minutes, go write your own tool [and contribute it :)]

# %%
from agentnet.display.sessions import print_sessions
get_printables = theano.function([], [
        hidden_seq,qvalues_seq, action_seq,rewards_seq,reference_Qvalues,is_alive_seq
    ])

def display_sessions(with_plots = False):
        
    hidden_log,qvalues_log,actions_log,reward_log, reference_qv_log, is_alive_log = get_printables()
    
    
    print_sessions(qvalues_log,actions_log,reward_log,
                   is_alive_seq = is_alive_log,
                   hidden_seq=hidden_log,
                   reference_qvalues_seq = reference_qv_log,
                   action_names=env.feature_names,
                  
                  plot_qvalues = with_plots)

# %%
#visualize untrained network performance (which is mostly random)
env.generate_new_data_batch(1)
display_sessions(with_plots=True)
# Out:
# session # 0
#  X1(qv = 0.0) -> 1.0(ref = 1.11222159863) |  X2(qv = 0.118128053844) -> -1.0(ref = -0.802667737007) |  X2(qv = 0.207718193531) -> -0.5(ref = -0.253818392754) |  X2(qv = 0.259138524532) -> -0.5(ref = -0.226183325052) |  X2(qv = 0.288228094578) -> -0.5(ref = -0.210699141026) |  X2(qv = 0.30452722311) -> -0.5(ref = -0.202081114054) |  X3(qv = 0.163549721241) -> -1.0(ref = -0.88942939043) |  X2(qv = 0.116390116513) -> -0.5(ref = -0.300024151802) |  Y2(qv = -0.0298751704395) -> 3.0(ref = 3.21240019798) |  Y1(qv = 0.223579227924) -> -3.0(ref = -3.0) | reached max session length

# %% [markdown]
# # Training loop

# %%
from agentnet.display import Metrics
score_log = Metrics()

# %%
#starting epoch
epoch_counter = 1

#moving average estimation
alpha = 0.1
ma_reward_current = 0.
ma_reward_greedy = 0.

# %%
n_epochs = 10000
batch_size=10

for i in range(n_epochs):    
    
    #train
    env.generate_new_data_batch(batch_size)
    loss,avg_reward = train_fun()
    
    
    
    ##update resolver's epsilon (chance of random action instead of optimal one)
    if epoch_counter%10 ==0:
        current_epsilon =  0.05 + 0.95*np.exp(-epoch_counter/2500.)
        resolver.epsilon.set_value(np.float32(current_epsilon))
    
    
    
    ##show current learning progress
    if epoch_counter%100 ==0:

        ##update learning curves
        full_loss, q_loss, l2_penalty, avg_reward_current = evaluation_fun()
        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current
        score_log["expected epsilon-greedy reward"][epoch_counter] = ma_reward_current
        
        
        
        #greedy train
        resolver.epsilon.set_value(0)
        avg_reward_greedy = evaluation_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["expected greedy reward"][epoch_counter] = ma_reward_greedy
        
        
        #back to epsilon-greedy
        resolver.epsilon.set_value(np.float32(current_epsilon))

        print "epoch %i,loss %.5f, epsilon %.5f, rewards: ( e-greedy %.5f, greedy %.5f) "%(
            epoch_counter,full_loss,current_epsilon,ma_reward_current,ma_reward_greedy)
        print "rec %.3f reg %.3f"%(q_loss,l2_penalty)

        
    #visualize learning curve and sample sessions
    if epoch_counter %2000 ==0:
        print "Learning curves:"
        score_log.plot()
        
        print "Random session examples"
        env.generate_new_data_batch(3)
        display_sessions(with_plots=True)



        
        
    epoch_counter  +=1
# Out:
# epoch 100,loss 9.38205, epsilon 0.96275, rewards: ( e-greedy 0.02500, greedy -0.11500)
# rec 9.371 reg 0.011
# epoch 200,loss 11.43753, epsilon 0.92696, rewards: ( e-greedy -0.14750, greedy -0.42850)
# rec 11.426 reg 0.011
# epoch 300,loss 9.75713, epsilon 0.89257, rewards: ( e-greedy -0.09775, greedy -0.76565)
# rec 9.746 reg 0.011
# epoch 400,loss 11.55408, epsilon 0.85954, rewards: ( e-greedy -0.24297, greedy -0.91908)
# rec 11.542 reg 0.012
# epoch 500,loss 6.44706, epsilon 0.82779, rewards: ( e-greedy -0.13868, greedy -0.75718)
# rec 6.435 reg 0.012
# epoch 600,loss 11.54728, epsilon 0.79730, rewards: ( e-greedy -0.27481, greedy -0.88646)
# rec 11.535 reg 0.013
# epoch 700,loss 10.46791, epsilon 0.76799, rewards: ( e-greedy -0.26733, greedy -0.62781)
# rec 10.454 reg 0.014
# epoch 800,loss 10.49597, epsilon 0.73984, rewards: ( e-greedy -0.10060, greedy -0.46003)
# rec 10.481 reg 0.015
# epoch 900,loss 9.26926, epsilon 0.71279, rewards: ( e-greedy -0.08554, greedy -0.30903)
# rec 9.254 reg 0.016
# epoch 1000,loss 13.85648, epsilon 0.68680, rewards: ( e-greedy -0.15198, greedy -0.36813)
# rec 13.840 reg 0.017
# epoch 1100,loss 8.55386, epsilon 0.66183, rewards: ( e-greedy -0.10678, greedy -0.33131)
# rec 8.536 reg 0.018
# epoch 1200,loss 9.23362, epsilon 0.63784, rewards: ( e-greedy -0.07111, greedy -0.10818)
# rec 9.214 reg 0.019
# epoch 1300,loss 6.58900, epsilon 0.61479, rewards: ( e-greedy 0.01600, greedy 0.15764)
# rec 6.569 reg 0.020
# epoch 1400,loss 11.78877, epsilon 0.59265, rewards: ( e-greedy -0.07060, greedy 0.20687)
# rec 11.768 reg 0.021
# epoch 1500,loss 12.52446, epsilon 0.57137, rewards: ( e-greedy -0.10854, greedy 0.25119)
# rec 12.502 reg 0.022
# epoch 1600,loss 7.56037, epsilon 0.55093, rewards: ( e-greedy -0.11268, greedy 0.48107)
# rec 7.537 reg 0.023
# epoch 1700,loss 5.87614, epsilon 0.53129, rewards: ( e-greedy 0.08859, greedy 0.66296)
# rec 5.852 reg 0.024
# epoch 1800,loss 12.69198, epsilon 0.51241, rewards: ( e-greedy 0.17973, greedy 0.72666)
# rec 12.667 reg 0.025
# epoch 1900,loss 10.59351, epsilon 0.49428, rewards: ( e-greedy 0.20175, greedy 0.76400)
# rec 10.568 reg 0.025
# epoch 2000,loss 6.97077, epsilon 0.47686, rewards: ( e-greedy 0.30658, greedy 0.90260)
# rec 6.945 reg 0.025
# Learning curves:
# Random session examples
# session # 0
#  Y2(qv = 1.12828373909) -> 3.0(ref = 3.04389691353) |  X2(qv = 0.0437314361334) -> -1.0(ref = -0.987271547318) |  End_session_now(qv = 0.0133983772248) -> 0.0(ref = 0.0) |
# session # 1
#  X1(qv = 0.330935955048) -> 1.0(ref = 2.28871226311) |  X2(qv = 0.532965660095) -> 1.0(ref = 1.77690923214) |  Y2(qv = 0.817799210548) -> 3.0(ref = 3.00503730774) |  End_session_now(qv = 0.00530255027115) -> 0.0(ref = 0.0) |
# session # 2
#  X3(qv = 0.450107693672) -> -1.0(ref = 0.513500809669) |  X2(qv = 0.499817371368) -> -1.0(ref = 0.810695171356) |  Y2(qv = 1.90599489212) -> 3.0(ref = 3.11147594452) |  End_session_now(qv = 0.0101097468287) -> 0.0(ref = 0.0) |
# epoch 2100,loss 11.44207, epsilon 0.46012, rewards: ( e-greedy 0.29592, greedy 0.87234)
# rec 11.416 reg 0.026
# epoch 2200,loss 7.71055, epsilon 0.44404, rewards: ( e-greedy 0.30133, greedy 0.93010)
# rec 7.684 reg 0.026
# epoch 2300,loss 8.61121, epsilon 0.42859, rewards: ( e-greedy 0.48620, greedy 1.13209)
# rec 8.584 reg 0.027
# epoch 2400,loss 10.52090, epsilon 0.41375, rewards: ( e-greedy 0.50258, greedy 1.17888)
# rec 10.494 reg 0.027
# epoch 2500,loss 4.14827, epsilon 0.39949, rewards: ( e-greedy 0.57732, greedy 1.38100)
# rec 4.120 reg 0.028
# epoch 2600,loss 7.82766, epsilon 0.38578, rewards: ( e-greedy 0.53959, greedy 1.36290)
# rec 7.799 reg 0.028
# epoch 2700,loss 11.59951, epsilon 0.37262, rewards: ( e-greedy 0.60063, greedy 1.28661)
# rec 11.571 reg 0.029
# epoch 2800,loss 10.58315, epsilon 0.35997, rewards: ( e-greedy 0.62557, greedy 1.36795)
# rec 10.554 reg 0.029
# epoch 2900,loss 10.50033, epsilon 0.34781, rewards: ( e-greedy 0.66301, greedy 1.40615)
# rec 10.471 reg 0.030
# epoch 3000,loss 8.35602, epsilon 0.33613, rewards: ( e-greedy 0.63671, greedy 1.40554)
# rec 8.326 reg 0.030
# epoch 3100,loss 13.00488, epsilon 0.32492, rewards: ( e-greedy 0.73304, greedy 1.43998)
# rec 12.974 reg 0.030
# epoch 3200,loss 6.01083, epsilon 0.31414, rewards: ( e-greedy 0.79973, greedy 1.46598)
# rec 5.980 reg 0.031
# epoch 3300,loss 7.28315, epsilon 0.30378, rewards: ( e-greedy 0.76476, greedy 1.49939)
# rec 7.252 reg 0.031
# epoch 3400,loss 5.28975, epsilon 0.29383, rewards: ( e-greedy 0.85828, greedy 1.56945)
# rec 5.258 reg 0.032
# epoch 3500,loss 5.29809, epsilon 0.28427, rewards: ( e-greedy 0.96746, greedy 1.69250)
# rec 5.266 reg 0.032
# epoch 3600,loss 6.12178, epsilon 0.27508, rewards: ( e-greedy 1.05071, greedy 1.72325)
# rec 6.089 reg 0.032
# epoch 3700,loss 9.85995, epsilon 0.26626, rewards: ( e-greedy 0.99064, greedy 1.63093)
# rec 9.827 reg 0.032
# epoch 3800,loss 3.39548, epsilon 0.25778, rewards: ( e-greedy 1.10658, greedy 1.74783)
# rec 3.363 reg 0.033
# epoch 3900,loss 5.34702, epsilon 0.24963, rewards: ( e-greedy 1.20092, greedy 1.83305)
# rec 5.314 reg 0.033
# epoch 4000,loss 7.01499, epsilon 0.24180, rewards: ( e-greedy 1.30583, greedy 1.90975)
# rec 6.982 reg 0.033
# Learning curves:
# Random session examples
# session # 0
#  Y2(qv = 1.74194633961) -> 3.0(ref = 3.2414264679) |  X1(qv = 0.25413313508) -> 1.0(ref = 1.00041079521) |  End_session_now(qv = 0.00043236091733) -> 0.0(ref = 0.0) |
# session # 1
#  X1(qv = 0.79040402174) -> 1.0(ref = 2.64401578903) |  Y2(qv = 1.73054277897) -> 3.0(ref = 3.00757026672) |  End_session_now(qv = 0.0079686306417) -> 0.0(ref = 0.0) |
# session # 2
#  Y2(qv = 1.74194633961) -> 3.0(ref = 3.2414264679) |  X1(qv = 0.25413313508) -> -1.0(ref = -1.00809288025) |  End_session_now(qv = -0.00851883739233) -> 0.0(ref = 0.0) |
# epoch 4100,loss 8.55863, epsilon 0.23428, rewards: ( e-greedy 1.40024, greedy 1.97877)
# rec 8.525 reg 0.034
# epoch 4200,loss 5.87420, epsilon 0.22706, rewards: ( e-greedy 1.49022, greedy 2.00089)
# rec 5.840 reg 0.034
# epoch 4300,loss 2.42452, epsilon 0.22011, rewards: ( e-greedy 1.46620, greedy 2.12080)
# rec 2.390 reg 0.034
# epoch 4400,loss 7.28924, epsilon 0.21344, rewards: ( e-greedy 1.44958, greedy 2.06872)
# rec 7.255 reg 0.035
# epoch 4500,loss 3.06710, epsilon 0.20703, rewards: ( e-greedy 1.56962, greedy 2.20185)
# rec 3.032 reg 0.035
# epoch 4600,loss 5.12105, epsilon 0.20088, rewards: ( e-greedy 1.51266, greedy 2.09667)
# rec 5.086 reg 0.035
# epoch 4700,loss 4.28968, epsilon 0.19496, rewards: ( e-greedy 1.65139, greedy 2.19700)
# rec 4.254 reg 0.035
# epoch 4800,loss 4.59024, epsilon 0.18928, rewards: ( e-greedy 1.66125, greedy 2.27730)
# rec 4.555 reg 0.036
# epoch 4900,loss 7.96128, epsilon 0.18382, rewards: ( e-greedy 1.51513, greedy 2.18957)
# rec 7.925 reg 0.036
# epoch 5000,loss 2.90969, epsilon 0.17857, rewards: ( e-greedy 1.68361, greedy 2.31061)
# rec 2.874 reg 0.036
# epoch 5100,loss 7.38385, epsilon 0.17353, rewards: ( e-greedy 1.64525, greedy 2.20955)
# rec 7.348 reg 0.036
# epoch 5200,loss 4.26731, epsilon 0.16868, rewards: ( e-greedy 1.74573, greedy 2.26860)
# rec 4.231 reg 0.036
# epoch 5300,loss 9.70728, epsilon 0.16403, rewards: ( e-greedy 1.72116, greedy 2.18674)
# rec 9.671 reg 0.037
# epoch 5400,loss 4.27998, epsilon 0.15956, rewards: ( e-greedy 1.74904, greedy 2.21306)
# rec 4.243 reg 0.037
# epoch 5500,loss 5.70373, epsilon 0.15526, rewards: ( e-greedy 1.78414, greedy 2.23176)
# rec 5.667 reg 0.037
# epoch 5600,loss 8.65353, epsilon 0.15114, rewards: ( e-greedy 1.63072, greedy 2.10858)
# rec 8.616 reg 0.037
# epoch 5700,loss 5.60123, epsilon 0.14717, rewards: ( e-greedy 1.62265, greedy 2.11772)
# rec 5.564 reg 0.037
# epoch 5800,loss 7.86630, epsilon 0.14336, rewards: ( e-greedy 1.55538, greedy 1.98595)
# rec 7.829 reg 0.038
# epoch 5900,loss 6.99895, epsilon 0.13970, rewards: ( e-greedy 1.51985, greedy 1.92736)
# rec 6.961 reg 0.038
# epoch 6000,loss 8.04597, epsilon 0.13618, rewards: ( e-greedy 1.47286, greedy 1.83462)
# rec 8.008 reg 0.038
# Learning curves:
# Random session examples
# session # 0
#  Y2(qv = 1.90370678902) -> -3.0(ref = -2.09611916542) |  X2(qv = 0.951453447342) -> 1.0(ref = 0.999196052551) |  End_session_now(qv = -0.00084624812007) -> 0.0(ref = 0.0) |
# session # 1
#  Y2(qv = 1.90370678902) -> 3.0(ref = 3.30499362946) |  X1(qv = 0.321045964956) -> 1.0(ref = 0.99871045351) |  End_session_now(qv = -0.00135742500424) -> 0.0(ref = 0.0) |
# session # 2
#  X2(qv = 1.30805659294) -> -1.0(ref = 1.14811682701) |  Y2(qv = 2.26117563248) -> 3.0(ref = 3.36257362366) |  X1(qv = 0.381656318903) -> 1.0(ref = 0.998871028423) |  X1(qv = -0.124625205994) -> -0.5(ref = -0.504746079445) |  End_session_now(qv = -0.00499588623643) -> 0.0(ref = 0.0) |
# epoch 6100,loss 3.47003, epsilon 0.13280, rewards: ( e-greedy 1.61058, greedy 1.99116)
# rec 3.432 reg 0.038
# epoch 6200,loss 5.73260, epsilon 0.12956, rewards: ( e-greedy 1.60952, greedy 1.99204)
# rec 5.695 reg 0.038
# epoch 6300,loss 5.38229, epsilon 0.12644, rewards: ( e-greedy 1.65857, greedy 2.01284)
# rec 5.344 reg 0.038
# epoch 6400,loss 6.87419, epsilon 0.12344, rewards: ( e-greedy 1.78271, greedy 2.07155)
# rec 6.836 reg 0.038
# epoch 6500,loss 5.40900, epsilon 0.12056, rewards: ( e-greedy 1.82944, greedy 2.08440)
# rec 5.371 reg 0.038
# epoch 6600,loss 7.08667, epsilon 0.11779, rewards: ( e-greedy 1.78149, greedy 2.03596)
# rec 7.048 reg 0.038
# epoch 6700,loss 5.43356, epsilon 0.11513, rewards: ( e-greedy 1.78335, greedy 2.05236)
# rec 5.395 reg 0.038
# epoch 6800,loss 4.97732, epsilon 0.11258, rewards: ( e-greedy 1.84001, greedy 2.10713)
# rec 4.939 reg 0.039
# epoch 6900,loss 4.20979, epsilon 0.11013, rewards: ( e-greedy 1.88601, greedy 2.17641)
# rec 4.171 reg 0.039
# epoch 7000,loss 8.24172, epsilon 0.10777, rewards: ( e-greedy 1.88741, greedy 2.11877)
# rec 8.203 reg 0.039
# epoch 7100,loss 3.93111, epsilon 0.10550, rewards: ( e-greedy 1.95367, greedy 2.16690)
# rec 3.892 reg 0.039
# epoch 7200,loss 2.65647, epsilon 0.10333, rewards: ( e-greedy 2.10830, greedy 2.29021)
# rec 2.618 reg 0.039
# epoch 7300,loss 7.29755, epsilon 0.10124, rewards: ( e-greedy 2.14747, greedy 2.32119)
# rec 7.259 reg 0.039
# epoch 7400,loss 5.59828, epsilon 0.09923, rewards: ( e-greedy 2.13272, greedy 2.28907)
# rec 5.559 reg 0.039
# epoch 7500,loss 7.04715, epsilon 0.09730, rewards: ( e-greedy 2.08945, greedy 2.25016)
# rec 7.008 reg 0.039
# epoch 7600,loss 6.73762, epsilon 0.09544, rewards: ( e-greedy 2.07051, greedy 2.22514)
# rec 6.699 reg 0.039
# epoch 7700,loss 8.48964, epsilon 0.09366, rewards: ( e-greedy 1.94346, greedy 2.08263)
# rec 8.450 reg 0.039
# epoch 7800,loss 8.81438, epsilon 0.09195, rewards: ( e-greedy 1.88911, greedy 2.01437)
# rec 8.775 reg 0.040
# epoch 7900,loss 5.60344, epsilon 0.09030, rewards: ( e-greedy 1.89020, greedy 2.03293)
# rec 5.564 reg 0.039
# epoch 8000,loss 6.92639, epsilon 0.08872, rewards: ( e-greedy 1.96618, greedy 2.06964)
# rec 6.887 reg 0.039
# Learning curves:
# Random session examples
# session # 0
#  Y1(qv = -0.100947469473) -> -3.0(ref = -0.667733430862) |  Y2(qv = 2.45501756668) -> 3.0(ref = 3.37035942078) |  X1(qv = 0.389852017164) -> 1.0(ref = 0.999886333942) |  End_session_now(qv = -0.000119663774967) -> 0.0(ref = 0.0) |
# session # 1
#  Y2(qv = 1.99362897873) -> 3.0(ref = 3.33094143867) |  X1(qv = 0.34835934639) -> -1.0(ref = -1.00199365616) |  End_session_now(qv = -0.00209857523441) -> 0.0(ref = 0.0) |
# session # 2
#  Y2(qv = 1.99362897873) -> -3.0(ref = -2.03499126434) |  X2(qv = 1.01579880714) -> 1.0(ref = 0.999767303467) |  End_session_now(qv = -0.000244922935963) -> 0.0(ref = 0.0) |
# epoch 8100,loss 5.46820, epsilon 0.08721, rewards: ( e-greedy 1.97456, greedy 2.10267)
# rec 5.429 reg 0.039
# epoch 8200,loss 8.00464, epsilon 0.08575, rewards: ( e-greedy 1.94711, greedy 2.05241)
# rec 7.965 reg 0.039
# epoch 8300,loss 8.49095, epsilon 0.08435, rewards: ( e-greedy 1.86739, greedy 1.98717)
# rec 8.452 reg 0.039
# epoch 8400,loss 6.97253, epsilon 0.08300, rewards: ( e-greedy 1.82066, greedy 1.92845)
# rec 6.933 reg 0.039
# epoch 8500,loss 6.50636, epsilon 0.08170, rewards: ( e-greedy 1.85859, greedy 1.95560)
# rec 6.467 reg 0.040
# epoch 8600,loss 5.38901, epsilon 0.08046, rewards: ( e-greedy 1.93273, greedy 2.02004)
# rec 5.349 reg 0.040
# epoch 8700,loss 4.11781, epsilon 0.07927, rewards: ( e-greedy 1.99946, greedy 2.07804)
# rec 4.078 reg 0.040
# epoch 8800,loss 5.06813, epsilon 0.07812, rewards: ( e-greedy 1.99951, greedy 2.11024)
# rec 5.028 reg 0.040
# epoch 8900,loss 5.08432, epsilon 0.07702, rewards: ( e-greedy 1.99956, greedy 2.13921)
# rec 5.045 reg 0.040
# epoch 9000,loss 3.75932, epsilon 0.07596, rewards: ( e-greedy 2.00960, greedy 2.20529)
# rec 3.719 reg 0.040
# epoch 9100,loss 6.60122, epsilon 0.07494, rewards: ( e-greedy 2.01864, greedy 2.18476)
# rec 6.561 reg 0.040
# epoch 9200,loss 9.69333, epsilon 0.07396, rewards: ( e-greedy 1.93678, greedy 2.06629)
# rec 9.654 reg 0.040
# epoch 9300,loss 8.00289, epsilon 0.07302, rewards: ( e-greedy 1.94310, greedy 2.03966)
# rec 7.963 reg 0.040
# epoch 9400,loss 4.24811, epsilon 0.07212, rewards: ( e-greedy 1.99879, greedy 2.09569)
# rec 4.208 reg 0.040
# epoch 9500,loss 7.98140, epsilon 0.07125, rewards: ( e-greedy 1.88891, greedy 1.98612)
# rec 7.942 reg 0.039
# epoch 9600,loss 2.75680, epsilon 0.07042, rewards: ( e-greedy 2.03002, greedy 2.14751)
# rec 2.717 reg 0.040
# epoch 9700,loss 6.37080, epsilon 0.06962, rewards: ( e-greedy 1.99702, greedy 2.15276)
# rec 6.331 reg 0.040
# epoch 9800,loss 4.70280, epsilon 0.06885, rewards: ( e-greedy 1.99232, greedy 2.15748)
# rec 4.663 reg 0.040
# epoch 9900,loss 5.26627, epsilon 0.06811, rewards: ( e-greedy 2.02309, greedy 2.18173)
# rec 5.227 reg 0.040
# epoch 10000,loss 6.52619, epsilon 0.06740, rewards: ( e-greedy 2.01578, greedy 2.16356)
# rec 6.486 reg 0.040
# Learning curves:
# Random session examples
# session # 0
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564877748) -> 1.0(ref = 0.999641418457) |  End_session_now(qv = -0.000377427786589) -> 0.0(ref = 0.0) |
# session # 1
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564877748) -> -1.0(ref = -0.999650597572) |  End_session_now(qv = 0.000367820262909) -> 0.0(ref = 0.0) |
# session # 2
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564877748) -> 1.0(ref = 0.999641418457) |  End_session_now(qv = -0.000377427786589) -> 0.0(ref = 0.0) |

# %% [markdown]
# # Evaluate results

# %%
score_log.plot("final")

# %%
resolver.epsilon.set_value(np.float32(0.))
print "Random session examples"
env.generate_new_data_batch(10)
display_sessions(with_plots=True)
# Out:
# Random session examples
# session # 0
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564907551) -> 1.0(ref = 0.999641418457) |  End_session_now(qv = -0.000377429649234) -> 0.0(ref = 0.0) |
# session # 1
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564907551) -> 1.0(ref = 0.999641418457) |  End_session_now(qv = -0.000377429649234) -> 0.0(ref = 0.0) |
# session # 2
#  Y2(qv = 1.93897891045) -> -3.0(ref = -2.04587006569) |  X2(qv = 1.00434732437) -> 1.0(ref = 0.999549150467) |  End_session_now(qv = -0.000474581494927) -> 0.0(ref = 0.0) |
# session # 3
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564907551) -> -1.0(ref = -0.999650597572) |  End_session_now(qv = 0.000367820262909) -> 0.0(ref = 0.0) |
# session # 4
#  Y2(qv = 1.93897891045) -> -3.0(ref = -2.04587006569) |  X2(qv = 1.00434732437) -> 1.0(ref = 0.999549150467) |  End_session_now(qv = -0.000474581494927) -> 0.0(ref = 0.0) |
# session # 5
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564907551) -> 1.0(ref = 0.999641418457) |  End_session_now(qv = -0.000377429649234) -> 0.0(ref = 0.0) |
# session # 6
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564907551) -> 1.0(ref = 0.999641418457) |  End_session_now(qv = -0.000377429649234) -> 0.0(ref = 0.0) |
# session # 7
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564907551) -> 1.0(ref = 0.999641418457) |  End_session_now(qv = -0.000377429649234) -> 0.0(ref = 0.0) |
# session # 8
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564907551) -> 1.0(ref = 0.999641418457) |  End_session_now(qv = -0.000377429649234) -> 0.0(ref = 0.0) |
# session # 9
#  Y2(qv = 1.93897891045) -> 3.0(ref = 3.27508664131) |  X1(qv = 0.289564877748) -> 1.0(ref = 0.999641418457) |  End_session_now(qv = -0.000377427786589) -> 0.0(ref = 0.0) |
