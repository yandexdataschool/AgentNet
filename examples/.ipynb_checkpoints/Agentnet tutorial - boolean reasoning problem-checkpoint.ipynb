# %%
#experiment name and snapshot folder (used for model persistence)
experiment_setup_name = "tutorial.boolean_reasoning"

# %%
#instead of installing library...
from config import library_path,snapshot_path
# Out:
# AgentNet examples will store and seek thier snapshots at /home/jheuristic/yozhik/agentnet_snapshots/

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline


#theano imports
#the problem is too simple to be run on GPU. Seriously.
# %env THEANO_FLAGS='device=cpu'
import theano
import theano.tensor as T
floatX = theano.config.floatX

import lasagne
# Out:
# env: THEANO_FLAGS='device=cpu'
# /home/jheuristic/thenv/local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # This tutorial explains the basic pipline of Agentnet experiment
# * experiment setup
# * designing agent
# * interacting with environment
# * computing losses
# * training

# %% [markdown]
# # Experiment setup
# * Here we load a simple experiment environment (description below)
# * Designing one from scratch is explained in later tutorials

# %%
import AgentNet.experiments.boolean_reasoning as experiment
print experiment.__doc__
# Out:
# This is a dummy experiment setup that requires agent to make advantage of
# a simple logical formula in order to maximize expected reward.
#
# The world agent exists in has a number of boolean hidden factors:
# X1~3, Y1, Y2.
#
# The factors are not independent. Namely,
#  - Y1 = (not X1) and X2
#  - Y2 = not Y1
#
# In the initial moment of time, agent knows nothing about any of them.
# At each turn, agent may decide to
#  - "open" one of the hidden factors.
#    - if the factor turns out to be 1, agent receives +1 reward for X*, +3 for Y*
#    - Otherwise, the reward equals -1 for X*, -3 for Y*
#  - decide to quit session
#    - yields reward of 0 and ends the interaction.
#    - all farther actions will have no effect until next session
#
# It is expected, that in order to maximize it's expected reward, the agent
# will converge to a strategy of polling X for as long as they yield information
# on Y, and than pick one of two Ys which is 1 and quit session.
#
# The experiment setup contains a single class BooleanReasoningEnvironment that
# implements both BaseEnvironment and BaseObjective.

# %%
#Create an environment with all default parameters
env = experiment.BooleanReasoningEnvironment()

# %% [markdown]
# # agent setup
# * An agent implementation has to contain three parts:
#  * Memory layer(s)
#   * in this case, a single one-step GRU
#  * Q-values evaluation layers
#   * in this case, a lasagne dense layer based on memory layer
#  * Resolver - acton picker layer
#   * in this case, the resolver has epsilon-greedy policy

# %%
from AgentNet.resolver import EpsilonGreedyResolver
from AgentNet.memory import GRUMemoryLayer
from AgentNet.agent import Agent

# %%
import lasagne

#only 10 hidden neurons
n_hid=10


_observation_layer = lasagne.layers.InputLayer([None,env.observation_size],name="obs_input")
_prev_state_layer = lasagne.layers.InputLayer([None,n_hid],name="prev_state_input")

#memory
#note that this isn't the same as lasagne recurrent units (see next text tab for detail)
gru = GRUMemoryLayer(n_hid,
                     _observation_layer,
                     _prev_state_layer,
                     name="gru0")

#q_eval
q_eval = lasagne.layers.DenseLayer(gru,num_units = env.n_actions,
                                   nonlinearity=lasagne.nonlinearities.linear,name="QEvaluator")

#resolver
epsilon = theano.shared(np.float32(0.1),name="e-greedy.epsilon")

resolver = EpsilonGreedyResolver(q_eval,epsilon=epsilon,name="resolver")


#all together
agent = Agent(gru,q_eval,resolver)

# %%
#Since it's a single lasagne network, one can get it's weights, output, etc
weights = lasagne.layers.get_all_params(resolver,trainable=True)
weights
# Out:
# [gru0.W_in_to_updategate,
#  gru0.W_hid_to_updategate,
#  gru0.b_updategate,
#  gru0.W_in_to_resetgate,
#  gru0.W_hid_to_resetgate,
#  gru0.b_resetgate,
#  gru0.W_in_to_hidden_update,
#  gru0.W_hid_to_hidden_update,
#  gru0.b_hidden_update,
#  QEvaluator.W,
#  QEvaluator.b]

# %% [markdown]
# ## Agent setup in detail
# * __Memory layers__
#  * One-step recurrent layer
#      * takes input and one's previous state
#      * returns new memory state
#    * Can be arbitrary lasagne layer
#    * Several one-step recurrent units are implemented in __agentnet.memory__
#    * Note that lasagne's default recurrent networks roll for several steps at once
#      * in other words, __using lasagne recurrent units as memory means recurrence inside recurrence__
#  * Using more than one memory layer is explained in farther tutorials
#
#
# * __Q-values evaluation layer__
#  * Can be arbitrary lasagne network
#  * returns predicted Q-values for each action
#  * Usually depends on memory as an input
#
#
# * __Resolver__ - action picker
#  * Decides on what action is taken
#  * Normally takes Q-values as input
#  * Currently all experiments require integer output
#  * Several resolver layers are implemented in __agentnet.resolver__

# %% [markdown]
# # Interacting with environment
# * an agent has a method that produces symbolic environment interaction sessions
# * interactions result in sequences of observations, actions, q-values,etc
# * one has to pre-define maximum session length.
#  * in this case, environment implements an indicator of whether session has ended by current tick
# * Since this environment also implements Objective methods, it can evaluate rewards for each [batch, time_tick]

# %%
#produce interaction sequences of length <= 10
history = agent.get_sessions(env,session_length=10,
                       batch_size=env.batch_size,)

state_seq,observation_seq,hidden_seq,qvalues_seq,action_seq = history

#get rewards for all actions
rewards_seq = env.get_reward_sequences(state_seq,action_seq)

#get indicator whether session is still active
is_alive_seq = env.get_whether_alive(observation_seq)

# %%
#Let us compile a function that returns all interaction logs
get_history = theano.function([],history+(is_alive_seq,rewards_seq,),mode=theano.compile.mode.FAST_RUN)

# %% [markdown]
# # Evaluating loss function
# * In this case, we want to
#  * first get pairs of (predicted Qvalue, reference Qvalue) for all actions commited
#  * second, define loss function
#  * third, compute grad and update weights
#
#
#  #### Get (prediction,reference) pairs

# %%
#get pairs of corresponding [predicted Qvalues, reference Qvalues] to train on

#gamma - delayed reward coefficient - what fraction of reward is retained if it is obtained one tick later
gamma = theano.shared(np.float32(0.95),name = 'q_learning_gamma')

ref_tuples = env.get_reference(qvalues_seq,
                               action_seq,
                               rewards_seq,
                               is_alive_seq,
                               gamma_or_gammas=gamma,)


action_Qvalues, reference_Qvalues,_ = ref_tuples

# %%
#prevent gradient updates over reference Qvalues (since they depend on predicted Qvalues)
from AgentNet.utils import consider_constant
reference_Qvalues = consider_constant(reference_Qvalues)

# %% [markdown]
# #### Define loss functions

# %%
#tensor of elementwise squared errors
squared_error = lasagne.objectives.squared_error(reference_Qvalues,action_Qvalues)

#zero-out ticks after session ended
squared_error = squared_error * is_alive_seq

#compute average of squared error sums per session
session_mse_loss = squared_error.sum(axis = 1).mean()

# %%
#regularize network weights

from lasagne.regularization import regularize_network_params, l2
reg_l2 = regularize_network_params(resolver,l2)*10**-3

# %%
loss = session_mse_loss + reg_l2

# %% [markdown]
# #### Compute weight updates

# %%
updates = lasagne.updates.nesterov_momentum(loss,
                                             weights,learning_rate=0.05,momentum=0.5)

# %% [markdown]
# #### Some auxilary evaluation metrics

# %%
mean_session_reward = rewards_seq.sum(axis=1).mean()
#...

# %% [markdown]
# # Compile train and evaluation functions

# %%
train_fun = theano.function([],[loss,mean_session_reward],updates=updates)

evaluation_fun = theano.function([],[loss,session_mse_loss,reg_l2,mean_session_reward])

# %% [markdown]
# # Training loop

# %%
from AgentNet.utils.persistence import save,load

# %%
from AgentNet.display import Metrics
score_log = Metrics()

# %%
#starting epoch
epoch_counter = 1

#moving average estimation
alpha = 0.1
ma_reward_current = 0.
ma_reward_greedy = 0.

# %%
n_epochs = 10000
batch_size=3

for i in range(n_epochs):    
    
    #train
    env.generate_new_data_batch(batch_size)
    loss,avg_reward = train_fun()
    
    
    
    ##update resolver's epsilon (chance of random action instead of optimal one)
    if epoch_counter%10 ==0:
        current_epsilon =  0.05 + 0.95*np.exp(-epoch_counter/2500.)
        resolver.epsilon.set_value(np.float32(current_epsilon))
    
    
    
    ##show current learning progress
    if epoch_counter%100 ==0:

        ##update learning curves
        full_loss, q_loss, l2_penalty, avg_reward_current = evaluation_fun()
        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current
        score_log["expected e-greedy reward"][epoch_counter] = ma_reward_current
        
        
        
        #greedy train
        resolver.epsilon.set_value(0)
        avg_reward_greedy = evaluation_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["avg session reward greedy (on training)"][epoch_counter] = ma_reward_greedy
        
        
        #back to epsilon-greedy
        resolver.epsilon.set_value(np.float32(current_epsilon))

        print "epoch %i,loss %.5f, epsilon %.5f, rewards: ( e-greedy %.5f, greedy %.5f) "%(
            epoch_counter,full_loss,current_epsilon,ma_reward_current,ma_reward_greedy)
        print "rec %.3f reg %.3f"%(q_loss,l2_penalty)

        
    if epoch_counter %1000 ==0:
        print "Learning curves:"
        score_log.plot()




        
        
    epoch_counter  +=1
# Out:
# epoch 100,loss 3.12995, epsilon 0.96886, rewards: ( e-greedy 0.13333, greedy 0.10000)
# rec 3.118 reg 0.012
# epoch 200,loss 1.98346, epsilon 0.93873, rewards: ( e-greedy 0.42000, greedy 0.39000)
# rec 1.972 reg 0.011
# epoch 300,loss 0.35718, epsilon 0.90960, rewards: ( e-greedy 0.37800, greedy 0.65100)
# rec 0.348 reg 0.010
# epoch 400,loss 1.12206, epsilon 0.88141, rewards: ( e-greedy 0.17353, greedy 0.88590)
# rec 1.113 reg 0.009
# epoch 500,loss 6.62546, epsilon 0.85416, rewards: ( e-greedy 0.02285, greedy 0.69731)
# rec 6.617 reg 0.008
# epoch 600,loss 1.23923, epsilon 0.82779, rewards: ( e-greedy 0.22056, greedy 0.92758)
# rec 1.232 reg 0.008
# epoch 700,loss 7.58791, epsilon 0.80230, rewards: ( e-greedy 0.23184, greedy 0.93482)
# rec 7.581 reg 0.007
# epoch 800,loss 0.86123, epsilon 0.77763, rewards: ( e-greedy 0.34199, greedy 1.14134)
# rec 0.854 reg 0.007
# epoch 900,loss 1.52331, epsilon 0.75378, rewards: ( e-greedy 0.37446, greedy 1.32721)
# rec 1.517 reg 0.006
# epoch 1000,loss 1.40345, epsilon 0.73070, rewards: ( e-greedy 0.43701, greedy 1.09448)
# rec 1.397 reg 0.006
# Learning curves:
# epoch 1100,loss 0.91317, epsilon 0.70839, rewards: ( e-greedy 0.42664, greedy 1.08504)
# rec 0.907 reg 0.006
# epoch 1200,loss 7.45933, epsilon 0.68680, rewards: ( e-greedy 0.18398, greedy 0.67653)
# rec 7.454 reg 0.006
# epoch 1300,loss 2.39764, epsilon 0.66593, rewards: ( e-greedy 0.33225, greedy 0.90888)
# rec 2.392 reg 0.005
# epoch 1400,loss 1.59758, epsilon 0.64573, rewards: ( e-greedy 0.46569, greedy 0.91799)
# rec 1.593 reg 0.005
# epoch 1500,loss 0.53988, epsilon 0.62620, rewards: ( e-greedy 0.65245, greedy 1.12619)
# rec 0.535 reg 0.005
# epoch 1600,loss 0.87441, epsilon 0.60731, rewards: ( e-greedy 0.65388, greedy 1.31357)
# rec 0.870 reg 0.005
# epoch 1700,loss 6.66410, epsilon 0.58904, rewards: ( e-greedy 0.58849, greedy 1.28222)
# rec 6.660 reg 0.004
# epoch 1800,loss 1.08981, epsilon 0.57137, rewards: ( e-greedy 0.82964, greedy 1.45399)
# rec 1.086 reg 0.004
# epoch 1900,loss 7.83778, epsilon 0.55428, rewards: ( e-greedy 0.71334, greedy 1.40859)
# rec 7.834 reg 0.004
# epoch 2000,loss 8.91733, epsilon 0.53775, rewards: ( e-greedy 0.64201, greedy 1.16774)
# rec 8.914 reg 0.004
# Learning curves:
# epoch 2100,loss 2.27984, epsilon 0.52176, rewards: ( e-greedy 0.71114, greedy 1.35096)
# rec 2.276 reg 0.004
# epoch 2200,loss 2.23584, epsilon 0.50629, rewards: ( e-greedy 0.50669, greedy 1.31587)
# rec 2.232 reg 0.003
# epoch 2300,loss 3.64728, epsilon 0.49133, rewards: ( e-greedy 0.52269, greedy 1.48428)
# rec 3.644 reg 0.003
# epoch 2400,loss 8.35796, epsilon 0.47686, rewards: ( e-greedy 0.57042, greedy 1.43585)
# rec 8.355 reg 0.003
# epoch 2500,loss 2.04957, epsilon 0.46287, rewards: ( e-greedy 0.58005, greedy 1.39227)
# rec 2.047 reg 0.003
# epoch 2600,loss 14.21513, epsilon 0.44933, rewards: ( e-greedy 0.28871, greedy 1.15304)
# rec 14.212 reg 0.003
# epoch 2700,loss 7.97031, epsilon 0.43624, rewards: ( e-greedy 0.15984, greedy 1.13774)
# rec 7.968 reg 0.003
# epoch 2800,loss 8.63467, epsilon 0.42358, rewards: ( e-greedy 0.27719, greedy 1.12396)
# rec 8.632 reg 0.003
# epoch 2900,loss 0.83330, epsilon 0.41133, rewards: ( e-greedy 0.31613, greedy 1.11157)
# rec 0.831 reg 0.003
# epoch 3000,loss 1.99008, epsilon 0.39949, rewards: ( e-greedy 0.18452, greedy 1.10041)
# rec 1.988 reg 0.002
# Learning curves:
# epoch 3100,loss 3.11623, epsilon 0.38803, rewards: ( e-greedy 0.29940, greedy 1.29037)
# rec 3.114 reg 0.002
# epoch 3200,loss 8.00864, epsilon 0.37695, rewards: ( e-greedy 0.16946, greedy 1.26133)
# rec 8.006 reg 0.002
# epoch 3300,loss 8.94405, epsilon 0.36623, rewards: ( e-greedy 0.28585, greedy 1.23520)
# rec 8.942 reg 0.002
# epoch 3400,loss 0.40095, epsilon 0.35586, rewards: ( e-greedy 0.22393, greedy 1.11168)
# rec 0.399 reg 0.002
# epoch 3500,loss 6.98570, epsilon 0.34583, rewards: ( e-greedy 0.16820, greedy 0.90051)
# rec 6.984 reg 0.002
# epoch 3600,loss 1.94294, epsilon 0.33613, rewards: ( e-greedy 0.21805, greedy 1.11046)
# rec 1.941 reg 0.002
# epoch 3700,loss 1.32831, epsilon 0.32675, rewards: ( e-greedy 0.12958, greedy 1.09941)
# rec 1.327 reg 0.002
# epoch 3800,loss 8.02450, epsilon 0.31768, rewards: ( e-greedy 0.34995, greedy 1.08947)
# rec 8.023 reg 0.002
# epoch 3900,loss 0.79839, epsilon 0.30891, rewards: ( e-greedy 0.48163, greedy 1.28052)
# rec 0.797 reg 0.002
# epoch 4000,loss 1.14401, epsilon 0.30042, rewards: ( e-greedy 0.63346, greedy 1.45247)
# rec 1.142 reg 0.002
# Learning curves:
# epoch 4100,loss 1.72837, epsilon 0.29221, rewards: ( e-greedy 0.63678, greedy 1.60723)
# rec 1.727 reg 0.001
# epoch 4200,loss 1.75087, epsilon 0.28427, rewards: ( e-greedy 0.77311, greedy 1.74650)
# rec 1.749 reg 0.001
# epoch 4300,loss 5.18327, epsilon 0.27659, rewards: ( e-greedy 0.96246, greedy 1.87185)
# rec 5.182 reg 0.001
# epoch 4400,loss 3.26445, epsilon 0.26916, rewards: ( e-greedy 0.96622, greedy 1.98467)
# rec 3.263 reg 0.001
# epoch 4500,loss 0.63789, epsilon 0.26197, rewards: ( e-greedy 1.03626, greedy 1.88620)
# rec 0.637 reg 0.001
# epoch 4600,loss 0.81809, epsilon 0.25502, rewards: ( e-greedy 1.23263, greedy 1.99758)
# rec 0.817 reg 0.001
# epoch 4700,loss 8.67254, epsilon 0.24830, rewards: ( e-greedy 1.14270, greedy 1.89782)
# rec 8.671 reg 0.001
# epoch 4800,loss 0.39190, epsilon 0.24180, rewards: ( e-greedy 1.19510, greedy 2.00804)
# rec 0.391 reg 0.001
# epoch 4900,loss 8.01449, epsilon 0.23551, rewards: ( e-greedy 1.30892, greedy 1.90724)
# rec 8.013 reg 0.001
# epoch 5000,loss 8.04679, epsilon 0.22943, rewards: ( e-greedy 1.31136, greedy 1.81651)
# rec 8.046 reg 0.001
# Learning curves:
# epoch 5100,loss 11.68318, epsilon 0.22355, rewards: ( e-greedy 1.14689, greedy 1.53486)
# rec 11.682 reg 0.001
# epoch 5200,loss 0.87454, epsilon 0.21786, rewards: ( e-greedy 1.13221, greedy 1.48138)
# rec 0.874 reg 0.001
# epoch 5300,loss 6.97687, epsilon 0.21236, rewards: ( e-greedy 1.05232, greedy 1.43324)
# rec 6.976 reg 0.001
# epoch 5400,loss 1.33300, epsilon 0.20703, rewards: ( e-greedy 1.08042, greedy 1.58991)
# rec 1.332 reg 0.001
# epoch 5500,loss 19.70828, epsilon 0.20189, rewards: ( e-greedy 0.83904, greedy 1.13092)
# rec 19.707 reg 0.001
# epoch 5600,loss 11.73850, epsilon 0.19691, rewards: ( e-greedy 0.62181, greedy 0.91783)
# rec 11.738 reg 0.001
# epoch 5700,loss 8.51567, epsilon 0.19209, rewards: ( e-greedy 0.65963, greedy 0.92605)
# rec 8.515 reg 0.001
# epoch 5800,loss 9.03228, epsilon 0.18743, rewards: ( e-greedy 0.72700, greedy 0.93344)
# rec 9.032 reg 0.001
# epoch 5900,loss 8.01247, epsilon 0.18293, rewards: ( e-greedy 0.62096, greedy 0.94010)
# rec 8.012 reg 0.001
# epoch 6000,loss 6.59140, epsilon 0.17857, rewards: ( e-greedy 0.69220, greedy 0.94609)
# rec 6.591 reg 0.001
# Learning curves:
# epoch 6100,loss 10.26698, epsilon 0.17435, rewards: ( e-greedy 0.58965, greedy 0.95148)
# rec 10.266 reg 0.001
# epoch 6200,loss 2.42093, epsilon 0.17028, rewards: ( e-greedy 0.43068, greedy 0.85633)
# rec 2.420 reg 0.001
# epoch 6300,loss 2.35342, epsilon 0.16633, rewards: ( e-greedy 0.62095, greedy 1.07070)
# rec 2.353 reg 0.001
# epoch 6400,loss 7.28298, epsilon 0.16252, rewards: ( e-greedy 0.65885, greedy 1.06363)
# rec 7.282 reg 0.001
# epoch 6500,loss 1.69958, epsilon 0.15883, rewards: ( e-greedy 0.95963, greedy 1.25727)
# rec 1.699 reg 0.001
# epoch 6600,loss 2.46411, epsilon 0.15526, rewards: ( e-greedy 1.13034, greedy 1.43154)
# rec 2.464 reg 0.001
# epoch 6700,loss 8.79273, epsilon 0.15181, rewards: ( e-greedy 1.15064, greedy 1.38839)
# rec 8.792 reg 0.001
# epoch 6800,loss 9.20300, epsilon 0.14847, rewards: ( e-greedy 1.10224, greedy 1.34955)
# rec 9.203 reg 0.000
# epoch 6900,loss 0.79598, epsilon 0.14525, rewards: ( e-greedy 1.19202, greedy 1.51459)
# rec 0.795 reg 0.000
# epoch 7000,loss 7.42467, epsilon 0.14212, rewards: ( e-greedy 1.07281, greedy 1.46313)
# rec 7.424 reg 0.000
# Learning curves:
# epoch 7100,loss 8.00113, epsilon 0.13910, rewards: ( e-greedy 0.89887, greedy 1.41682)
# rec 8.001 reg 0.000
# epoch 7200,loss 2.58803, epsilon 0.13618, rewards: ( e-greedy 1.10898, greedy 1.57514)
# rec 2.588 reg 0.000
# epoch 7300,loss 4.22976, epsilon 0.13336, rewards: ( e-greedy 1.33142, greedy 1.71762)
# rec 4.229 reg 0.000
# epoch 7400,loss 8.11879, epsilon 0.13062, rewards: ( e-greedy 1.29827, greedy 1.64586)
# rec 8.118 reg 0.000
# epoch 7500,loss 0.60015, epsilon 0.12798, rewards: ( e-greedy 1.20178, greedy 1.78128)
# rec 0.600 reg 0.000
# epoch 7600,loss 15.86852, epsilon 0.12542, rewards: ( e-greedy 0.98160, greedy 1.50315)
# rec 15.868 reg 0.000
# epoch 7700,loss 8.02859, epsilon 0.12295, rewards: ( e-greedy 0.88344, greedy 1.45283)
# rec 8.028 reg 0.000
# epoch 7800,loss 4.66619, epsilon 0.12056, rewards: ( e-greedy 1.09510, greedy 1.60755)
# rec 4.666 reg 0.000
# epoch 7900,loss 12.60844, epsilon 0.11825, rewards: ( e-greedy 0.88559, greedy 1.34679)
# rec 12.608 reg 0.000
# epoch 8000,loss 2.57216, epsilon 0.11601, rewards: ( e-greedy 0.96370, greedy 1.51212)
# rec 2.572 reg 0.000
# Learning curves:
# epoch 8100,loss 9.42534, epsilon 0.11385, rewards: ( e-greedy 0.96733, greedy 1.46090)
# rec 9.425 reg 0.000
# epoch 8200,loss 1.96900, epsilon 0.11175, rewards: ( e-greedy 1.10393, greedy 1.61481)
# rec 1.969 reg 0.000
# epoch 8300,loss 11.97588, epsilon 0.10973, rewards: ( e-greedy 0.99353, greedy 1.35333)
# rec 11.976 reg 0.000
# epoch 8400,loss 8.21194, epsilon 0.10777, rewards: ( e-greedy 0.99418, greedy 1.31800)
# rec 8.212 reg 0.000
# epoch 8500,loss 3.36408, epsilon 0.10588, rewards: ( e-greedy 1.16143, greedy 1.48620)
# rec 3.364 reg 0.000
# epoch 8600,loss 1.73571, epsilon 0.10404, rewards: ( e-greedy 1.24529, greedy 1.63758)
# rec 1.735 reg 0.000
# epoch 8700,loss 8.31400, epsilon 0.10227, rewards: ( e-greedy 1.22076, greedy 1.57382)
# rec 8.314 reg 0.000
# epoch 8800,loss 8.24113, epsilon 0.10056, rewards: ( e-greedy 1.23202, greedy 1.51644)
# rec 8.241 reg 0.000
# epoch 8900,loss 8.84268, epsilon 0.09890, rewards: ( e-greedy 1.30881, greedy 1.46480)
# rec 8.842 reg 0.000
# epoch 9000,loss 8.26031, epsilon 0.09730, rewards: ( e-greedy 1.34460, greedy 1.41832)
# rec 8.260 reg 0.000
# Learning curves:
# epoch 9100,loss 1.82926, epsilon 0.09575, rewards: ( e-greedy 1.31014, greedy 1.57648)
# rec 1.829 reg 0.000
# epoch 9200,loss 0.00019, epsilon 0.09425, rewards: ( e-greedy 1.17913, greedy 1.41884)
# rec 0.000 reg 0.000
# epoch 9300,loss 2.86255, epsilon 0.09280, rewards: ( e-greedy 1.36121, greedy 1.57695)
# rec 2.862 reg 0.000
# epoch 9400,loss 8.56109, epsilon 0.09139, rewards: ( e-greedy 1.35842, greedy 1.51926)
# rec 8.561 reg 0.000
# epoch 9500,loss 0.84612, epsilon 0.09004, rewards: ( e-greedy 1.52258, greedy 1.66733)
# rec 0.846 reg 0.000
# epoch 9600,loss 1.47020, epsilon 0.08872, rewards: ( e-greedy 1.67032, greedy 1.80060)
# rec 1.470 reg 0.000
# epoch 9700,loss 1.24649, epsilon 0.08745, rewards: ( e-greedy 1.83662, greedy 1.92054)
# rec 1.246 reg 0.000
# epoch 9800,loss 0.00015, epsilon 0.08623, rewards: ( e-greedy 1.65296, greedy 1.72848)
# rec 0.000 reg 0.000
# epoch 9900,loss 0.00014, epsilon 0.08504, rewards: ( e-greedy 1.48767, greedy 1.55564)
# rec 0.000 reg 0.000
# epoch 10000,loss 0.24990, epsilon 0.08389, rewards: ( e-greedy 1.33890, greedy 1.40007)
# rec 0.250 reg 0.000
# Learning curves:

# %%
score_log.plot("final")

# %%
#under construction

# %%
print_session(3,display=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-72d458161821> in <module>()
# ----> 1 print_session(3,display=True)
#
# NameError: name 'print_session' is not defined

# %%
evaluation_fun = theano.function([],[action_ids_ravel,action_Qvalues_ravel,immediate_rewards_ravel,
                                     reference_Qvalues_ravel,is_end_ravel,
                                     hidden_seq,qvalues_seq,action_seq])

feature_names = env.feature_names
def print_session(n_sessions = 3,display=False):
    
    a_lot_of_data = evaluation_fun()    
    actions,qvalues,rewards,ref_qvalues,end_sel = a_lot_of_data[:5]
    hidden_log,qvalues_log,action_log = a_lot_of_data[5:]
    
    
    
    b_i = 0 #batch iter ~ session iter
    t_i = 0 #time iter
    

    for a,q,r,q_ref,is_end in zip(actions,qvalues,rewards,ref_qvalues,end_sel):
        print "#%i: %s (%.3f) -> %s |"%(a,feature_names[a],q, r,),
        
        
        t_i +=1
        if is_end ==1:
            
            print '<end>'
            print 'true:',
            for cat in env.categories.get_value()[b_i].nonzero()[0]:
                print feature_names[cat+env.attributes.shape[1].eval()],
            print
                
            #plot qvalues
            if display:
                plt.figure(figsize=[16,8])

                q_values = qvalues_log[b_i].T
                
                for i in range(q_values.shape[0]):
                    plt.plot(q_values[i],label=feature_names[i])

                hidden_activity =  hidden_log[b_i].T
                for i, hh in enumerate(hidden_activity):
                    plt.plot(hh,'--',label='n'+str(i))
                    
                session_actions = action_log[b_i,:t_i]
                action_range = np.arange(len(session_actions))
                plt.scatter(action_range, qvalues_log[b_i][action_range, session_actions])


                #session end
                plt.plot(np.repeat(t_i-1,2),np.linspace(-0.5,0.5,2))
                plt.xlim(0,max(t_i*1.1,2))
                plt.xticks(np.arange(t_i))
                plt.grid()
                plt.legend()
                plt.show()
                
            print
            #/
            b_i +=1
            t_i = 0

            if b_i >= n_sessions:
                break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-2b5ad57f4d25> in <module>()
# ----> 1 evaluation_fun = theano.function([],[action_ids_ravel,action_Qvalues_ravel,immediate_rewards_ravel,
#       2                                      reference_Qvalues_ravel,is_end_ravel,
#       3                                      hidden_seq,qvalues_seq,action_seq])
#       4
#       5 feature_names = env.feature_names
#
# NameError: name 'action_ids_ravel' is not defined
