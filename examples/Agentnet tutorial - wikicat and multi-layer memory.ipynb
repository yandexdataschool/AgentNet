# %%
#experiment name and snapshot folder (used for model persistence)
experiment_setup_name = "tutorial.wikicat.multilayer"

# %%
#instead of installing library...
from config import library_path,snapshot_path
# Out:
# AgentNet examples will store and seek thier snapshots at /home/jheuristic/yozhik/agentnet_snapshots/

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline


#theano imports
#the problem is too simple to be run on GPU. Seriously.
# %env THEANO_FLAGS='device=cpu'
import theano
import theano.tensor as T
floatX = theano.config.floatX

import lasagne
# Out:
# env: THEANO_FLAGS='device=cpu'
# /home/jheuristic/thenv/local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # This tutorial follows the basic experiment pipeline and shows how to use arbitrary agent architectures

# %% [markdown]
# # Experiment setup
# * Here we load an experiment environment (description below)
# * Designing one from scratch is explained in later tutorials

# %%
import AgentNet.experiments.wikicat as experiment
print experiment.__doc__
# Out:
# This experiment Wikipedia data sample on musicians, scraped via the scripts present in this directory.
# For each musician, we know a number of boolean features (factors) on various topics like
#  * whether or not he/she was active in 1990's, 2000's, etc.
#  * whether or not he/she plays guitar, piano, etc
#  * whether or not he/she was born in 50's, 60's, etc.
#  * what wikipedia categories does he/she belong to
#  etc.
#
#
#
# In the initial moment of time, agent knows nothing about any of them.
# At each turn, agent may decide to
#  - "open" one of the hidden factors.
#    - if the factor turns out to be 1, agent receives +3 reward for Wikipedia categories, +1 for other categories,
#    - Otherwise, the reward equals -1 for Wikipedia categories, -1 for other categores
#    - all these rewards are parameterisable during environment creation
#  - decide to quit session
#    - yields reward of 0 and ends the interaction.
#    - all farther actions will have no effect until next session
#
# It is expected, that in order to maximize it's expected reward, the agent
# will converge to a strategy of polling several key features and then utilizing learned
# dependencies between these factors and other ones. For example, if a particular genre was
# popular during particular decays, it makes sense to poll genres and than "open" the corresponding
# most probable years.
#
# The experiment setup contains a single class WikicatEnvironment that
# implements both BaseEnvironment and BaseObjective.

# %%
#Create an environment with all default parameters
env = experiment.WikicatEnvironment()

# %%
from sklearn.cross_validation import train_test_split
attrs, categories, feature_names = env.get_dataset()

train_attrs,test_attrs,train_cats,test_cats = train_test_split(attrs,categories,test_size=0.99,random_state=32)

print "train size:", train_attrs.shape,train_cats.shape
print "train size:", test_attrs.shape,test_cats.shape

print "features:",feature_names[::20]
# Out:
# train size: (85, 300) (85, 93)
# train size: (8509, 300) (8509, 93)
# features: ['Children:is_known', 'Instruments:vocals', 'Genres:electronic', 'Origin:scotland', 'Genres:jazz', 'Genres:electric', 'Occupation:bassist', 'Instruments:violin', 'Genres:instrumental', 'Occupation:entrepreneur', 'Instruments:mandolin', 'Instruments:vocalist', 'Genres:synthpop', 'decades_active:1990', 'Occupation:remixer', 'category:List_of_musical_artists_from_Japan', 'category:List_of_ambient_music_artists', 'category:List_of_crooners', 'category:List_of_country_music_performers', 'category:List_of_bass_guitarists']

# %%
env.load_random_batch(train_attrs,train_cats,5)

# %% [markdown]
# # agent setup
# * An agent implementation has to contain three parts:
#  * Memory layer(s)
#   * in this case, we train two GRU layers [details below]
#  * Q-values evaluation layers
#   * in this case, a lasagne dense layer based on memory layer
#  * Resolver - acton picker layer
#   * in this case, the resolver has epsilon-greedy policy
#
#
# ### two-layer memory architecture
# We train two memory states:
#   * first one, based on observations,
#   * second one, based on first one;
#
# Note that here we update the second memory layer based on the CURRENT state
# of the first one. Instead, you can try to feed it with a previous state.
#
# The q-values are estimated on a concatenated state, effectively on both memory
# states together, but there is no problem with limiting q-evaluator to only one:
# just pass the correct gru layer as an incoming layer to the q-evaluator.
#
# ### Implementation:
# We concatenate both memories into 1 state to pass it through the session loop.
#
# To perform memory update, we need to slice the concatenated state back into
# two memory states.
#
# We do so by defining an input map function and passing it into agent.
#
# We than concatenate two new states back to form a new memory state.

# %%
from AgentNet.resolver import EpsilonGreedyResolver
from AgentNet.memory import GRUMemoryLayer
from AgentNet.agent import Agent

# %%
import lasagne
n_hid_1=128 #first GRU memory
n_hid_2=64 #second GRU memory


_observation_layer = lasagne.layers.InputLayer([None,env.observation_size],name="obs_input")

_prev_gru1_layer = lasagne.layers.InputLayer([None,n_hid_1],name="prev_gru1_state_input")
_prev_gru2_layer = lasagne.layers.InputLayer([None,n_hid_2],name="prev_gru2_state_input")

#memory
gru1 = GRUMemoryLayer(n_hid_1,
                     _observation_layer,
                     _prev_gru1_layer,
                     name="gru1")

gru2 = GRUMemoryLayer(n_hid_2,
                     gru1,        #note that it takes CURRENT gru1 output as input.
                                  #replacing that with _prev_gru1_state would imply taking previous one.
                     _prev_gru2_layer,
                     name="gru2")

concatenated_memory = lasagne.layers.concat([gru1,gru2])

#q_eval
n_actions = len(feature_names)
q_eval = lasagne.layers.DenseLayer(concatenated_memory, #taking both memories. 
                                                        #Replacing with gru1 or gru2 would mean taking one
                                   num_units = n_actions,
                                   nonlinearity=lasagne.nonlinearities.linear,name="QEvaluator")
#resolver
epsilon = theano.shared(np.float32(0.9),"e-greedy.epsilon")

resolver = EpsilonGreedyResolver(q_eval,epsilon=epsilon,name="resolver")



#we need to define the new input map because concatenated_memory is a ConcatLayer and does not have default one

def custom_input_map(last_hidden,observation):
    """just a function that maps memory states to respective inputs"""
    return {
        _prev_gru1_layer:last_hidden[:,0:n_hid_1],
        _prev_gru2_layer:last_hidden[:,n_hid_1:n_hid_1+n_hid_2],
        _observation_layer:observation
    }

#all together
agent = Agent(concatenated_memory,q_eval,resolver,input_map=custom_input_map
             )

# %%
#Since it's a single lasagne network, one can get it's weights, output, etc
weights = lasagne.layers.get_all_params(resolver,trainable=True)
weights
# Out:
# [gru1.W_in_to_updategate,
#  gru1.W_hid_to_updategate,
#  gru1.b_updategate,
#  gru1.W_in_to_resetgate,
#  gru1.W_hid_to_resetgate,
#  gru1.b_resetgate,
#  gru1.W_in_to_hidden_update,
#  gru1.W_hid_to_hidden_update,
#  gru1.b_hidden_update,
#  gru2.W_in_to_updategate,
#  gru2.W_hid_to_updategate,
#  gru2.b_updategate,
#  gru2.W_in_to_resetgate,
#  gru2.W_hid_to_resetgate,
#  gru2.b_resetgate,
#  gru2.W_in_to_hidden_update,
#  gru2.W_hid_to_hidden_update,
#  gru2.b_hidden_update,
#  QEvaluator.W,
#  QEvaluator.b]

# %% [markdown]
# ## Agent setup in detail
# * __Memory layers__
#  * One-step recurrent layer
#      * takes input and one's previous state
#      * returns new memory state
#    * Can be arbitrary lasagne layer
#    * Several one-step recurrent units are implemented in __agentnet.memory__
#    * Note that lasagne's default recurrent networks roll for several steps at once
#      * in other words, __using lasagne recurrent units as memory means recurrence inside recurrence__
#  * Using more than one memory layer is explained in farther tutorials
#
#
# * __Q-values evaluation layer__
#  * Can be arbitrary lasagne network
#  * returns predicted Q-values for each action
#  * Usually depends on memory as an input
#
#
# * __Resolver__ - action picker
#  * Decides on what action is taken
#  * Normally takes Q-values as input
#  * Currently all experiments require integer output
#  * Several resolver layers are implemented in __agentnet.resolver__

# %% [markdown]
# # Interacting with environment
# * an agent has a method that produces symbolic environment interaction sessions
# * interactions result in sequences of observations, actions, q-values,etc
# * one has to pre-define maximum session length.
#  * in this case, environment implements an indicator of whether session has ended by current tick
# * Since this environment also implements Objective methods, it can evaluate rewards for each [batch, time_tick]

# %%
#produce interaction sequences of length <= 10
history = agent.get_sessions(env,session_length=10,
                       batch_size=env.batch_size,)

state_seq,observation_seq,hidden_seq,qvalues_seq,action_seq = history

#get rewards for all actions
rewards_seq = env.get_reward_sequences(state_seq,action_seq)

#get indicator whether session is still active
is_alive_seq = env.get_whether_alive(observation_seq)

# %%
#Let us compile a function that returns all interaction logs
get_history = theano.function([],history+(is_alive_seq,rewards_seq,),mode=theano.compile.mode.FAST_RUN)

# %% [markdown]
# # Evaluating loss function
# * In this case, we want to
#  * first get pairs of (predicted Qvalue, reference Qvalue) for all actions commited
#  * second, define loss function
#  * third, compute grad and update weights
#
#
#  #### Get (prediction,reference) pairs

# %%
#get pairs of corresponding [predicted Qvalues, reference Qvalues] to train on

#gamma - delayed reward coefficient - what fraction of reward is retained if it is obtained one tick later
gamma = theano.shared(np.float32(0.95),name = 'q_learning_gamma')

ref_tuples = env.get_reference(qvalues_seq,
                               action_seq,
                               rewards_seq,
                               is_alive_seq,
                               gamma_or_gammas=gamma,)


action_Qvalues, reference_Qvalues,_ = ref_tuples

# %%
#prevent gradient updates over reference Qvalues (since they depend on predicted Qvalues)
from AgentNet.utils import consider_constant
reference_Qvalues = consider_constant(reference_Qvalues)

# %% [markdown]
# #### Define loss functions

# %%
#tensor of elementwise squared errors
squared_error = lasagne.objectives.squared_error(reference_Qvalues,action_Qvalues)

#zero-out ticks after session ended
squared_error = squared_error * is_alive_seq

#compute average of squared error sums per session
mse_loss = squared_error.sum() / is_alive_seq.sum()

# %%
#regularize network weights

from lasagne.regularization import regularize_network_params, l2
reg_l2 = regularize_network_params(resolver,l2)*10**-4

# %%
loss = mse_loss + reg_l2

# %% [markdown]
# #### Compute weight updates

# %%
updates = lasagne.updates.adadelta(loss,
                                             weights,learning_rate=0.05)

# %% [markdown]
# #### Some auxilary evaluation metrics

# %%
mean_session_reward = rewards_seq.sum(axis=1).mean()
#...

# %% [markdown]
# # Compile train and evaluation functions

# %%
train_fun = theano.function([],[loss,mean_session_reward],updates=updates)

evaluation_fun = theano.function([],[loss,mse_loss,reg_l2,mean_session_reward])

# %% [markdown]
# # session visualization tools
#
#
# * this is a completely optional step of visualizing agent's sessions as chains of actions
# * usually useful to get insight on what worked and what din't
# * in this case, we print strings following pattern
#   * [action_name] ([predicted action qvalue]) -> reward [reference qvalue] | next iteration
#
# * plot shows
#     * time ticks over X, abstract values over Y
#     * bold lines are Qvalues for actions
#     * dots on bold lines represent what actions were taken at each moment of time
#     * dashed lines are agent's hidden state neurons
#     * blue vertical line - session end
#
#
# __Warning! the visualization tools are underdeveloped and only allow simple operations.__
#
# if you found yourself struggling to make it do what you want for 5 minutes, go write your own tool [and contribute it :)]

# %%
from AgentNet.display.sessions import print_sessions
get_printables = theano.function([], [
        hidden_seq,qvalues_seq, action_seq,rewards_seq,reference_Qvalues,is_alive_seq
    ])

def display_sessions(with_plots = False):
        
    hidden_log,qvalues_log,actions_log,reward_log, reference_qv_log, is_alive_log = get_printables()
    
    
    print_sessions(qvalues_log,actions_log,reward_log,
                   is_alive_seq = is_alive_log,
                   #hidden_seq=hidden_log, #do not plot hidden since there's too many actions already
                   reference_qvalues_seq = reference_qv_log,
                   action_names=feature_names,
                   legend = False, #do not show legend since there's too many labeled objects
                  plot_qvalues = with_plots)

# %%
#visualize untrained network performance (which is mostly random)
env.load_random_batch(train_attrs,train_cats,1)
display_sessions(with_plots=True)
# Out:
# session # 0
#  Genres:heavy(qv = 0.0) -> -1.0(ref = -0.920281052589) |  Occupation:bandleader(qv = 0.0316718220711) -> -1.0(ref = -0.857592999935) |  Political party:is_known(qv = -0.0226185321808) -> -1.0(ref = -0.852698028088) |  Label(s):is_known(qv = 0.0291070193052) -> -1.0(ref = -0.869660973549) |  category:List_of_music_arrangers(qv = 0.137198939919) -> -1.0(ref = -0.869278967381) |  category:List_of_gospel_musicians(qv = -0.00589582696557) -> -1.0(ref = -0.852341413498) |  Genres:contemporary(qv = -0.0794397294521) -> -1.0(ref = -0.803845703602) |  category:List_of_blues_musicians(qv = 0.206478223205) -> -1.0(ref = -0.824491381645) |  last_activity:1989(qv = 0.031904540956) -> -1.0(ref = -0.851975739002) |  category:List_of_lead_guitarists(qv = -0.0388116389513) -> 0.0(ref = 0.0) |

# %% [markdown]
# # Training loop

# %%
from AgentNet.utils.persistence import save,load

# %%
from AgentNet.display import Metrics
score_log = Metrics()

# %%
#starting epoch
epoch_counter = 1

#moving average estimation
alpha = 0.1
ma_reward_current = -7.
ma_reward_greedy = -7.

# %%
n_epochs = 150000
batch_size= 10

for i in range(n_epochs):    
    
    #train
    env.load_random_batch(train_attrs,train_cats,batch_size)
    loss,avg_reward = train_fun()
    
    
    
    ##update resolver's epsilon (chance of random action instead of optimal one)
    if epoch_counter%10 ==0:
        current_epsilon =  0.05 + 0.95*np.exp(-epoch_counter/10000.)
        resolver.epsilon.set_value(np.float32(current_epsilon))
    
    
    
    ##record current learning progress and show learning curves
    if epoch_counter%100 ==0:

        ##update learning curves
        full_loss, q_loss, l2_penalty, avg_reward_current = evaluation_fun()
        ma_reward_current = (1-alpha)*ma_reward_current + alpha*avg_reward_current
        score_log["expected e-greedy reward"][epoch_counter] = ma_reward_current
        
        
        
        #greedy train
        resolver.epsilon.set_value(0)
        avg_reward_greedy = evaluation_fun()[-1]
        ma_reward_greedy = (1-alpha)*ma_reward_greedy + alpha*avg_reward_greedy
        score_log["expected greedy reward"][epoch_counter] = ma_reward_greedy
        
        
        #back to epsilon-greedy
        resolver.epsilon.set_value(np.float32(current_epsilon))

        print "epoch %i,loss %.5f, epsilon %.5f, rewards: ( e-greedy %.5f, greedy %.5f) "%(
            epoch_counter,full_loss,current_epsilon,ma_reward_current,ma_reward_greedy)
        print "rec %.3f reg %.3f"%(q_loss,l2_penalty)

        
    if epoch_counter %1000 ==0:
        print "Learning curves:"
        score_log.plot()


        print "Random session examples"
        env.load_random_batch(train_attrs,train_cats,3)
        display_sessions(with_plots=False)


        
        
    epoch_counter  +=1
# Out:
# epoch 100,loss 0.94982, epsilon 0.99055, rewards: ( e-greedy -7.14000, greedy -6.88500)
# rec 0.686 reg 0.264
# epoch 200,loss 0.94633, epsilon 0.98119, rewards: ( e-greedy -7.28600, greedy -6.67150)
# rec 0.683 reg 0.264
# epoch 300,loss 0.93154, epsilon 0.97192, rewards: ( e-greedy -7.34740, greedy -6.53435)
# rec 0.668 reg 0.263
# epoch 400,loss 0.86610, epsilon 0.96275, rewards: ( e-greedy -7.39266, greedy -6.27592)
# rec 0.604 reg 0.263
# epoch 500,loss 0.79795, epsilon 0.95367, rewards: ( e-greedy -7.30839, greedy -5.90832)
# rec 0.536 reg 0.262
# epoch 600,loss 0.87313, epsilon 0.94468, rewards: ( e-greedy -7.25255, greedy -5.63749)
# rec 0.611 reg 0.262
# epoch 700,loss 0.53146, epsilon 0.93577, rewards: ( e-greedy -7.24230, greedy -5.41374)
# rec 0.270 reg 0.261
# epoch 800,loss 0.65721, epsilon 0.92696, rewards: ( e-greedy -7.19307, greedy -5.19237)
# rec 0.397 reg 0.261
# epoch 900,loss 0.53546, epsilon 0.91823, rewards: ( e-greedy -7.22876, greedy -5.05313)
# rec 0.275 reg 0.260
# epoch 1000,loss 0.41612, epsilon 0.90960, rewards: ( e-greedy -7.25089, greedy -4.71782)
# rec 0.157 reg 0.260
# Learning curves:
# Random session examples
# session # 0
#  category:List_of_performers_on_Top_of_the_Pops(qv = 0.0137187875807) -> 3.0(ref = 3.49204993248) |  Labels:is_known(qv = 0.517947375774) -> 1.0(ref = 1.54206228256) |  decades_active:2000(qv = 0.213891983032) -> 1.0(ref = 1.71951520443) |  first_activity:1995(qv = -0.161854803562) -> -1.0(ref = -0.266914486885) |  first_activity:1989(qv = -0.246095359325) -> -1.0(ref = -0.222081661224) |  first_activity:1959(qv = -0.184392601252) -> -1.0(ref = -0.241461336613) |  Genres:garage(qv = -0.210824385285) -> -1.0(ref = -0.248906672001) |  Instruments:synthesizer(qv = -0.085341796279) -> -1.0(ref = -0.220413088799) |  Labels:is_known(qv = 0.820617794991) -> -0.5(ref = 0.189531564713) |  first_activity:1953(qv = -0.101809173822) -> 0.0(ref = 0.0) | session # 1
#  Labels:is_known(qv = 0.33192756772) -> 1.0(ref = 1.39616823196) |  Genres:trance(qv = -0.268230050802) -> -1.0(ref = -0.491812169552) |  Genres:[1](qv = -0.0285650826991) -> -1.0(ref = -0.38377404213) |  Genres:wave(qv = -0.193660825491) -> -1.0(ref = -0.301729559898) |  Labels:is_known(qv = 0.735021531582) -> -0.5(ref = 0.144840180874) |  category:List_of_Latin_pop_artists(qv = 0.0374090075493) -> -1.0(ref = -0.322641372681) |  Occupation:instrumentalist(qv = -0.414199948311) -> -1.0(ref = -0.272985041142) |  Genres:trip(qv = -0.0534441061318) -> -1.0(ref = -0.21716940403) |  Instruments:drums(qv = -0.202019751072) -> -1.0(ref = -0.229883909225) |  Instruments:vocalist(qv = -0.198495790362) -> 0.0(ref = 0.0) | session # 2
#  Origin:kingston(qv = -0.0573375076056) -> -1.0(ref = -0.55165708065) |  Genres:swing(qv = -0.11328060925) -> -1.0(ref = -0.410512268543) |  Genres:contemporary(qv = -0.162346854806) -> -1.0(ref = -0.299808204174) |  category:List_of_female_heavy_metal_singers(qv = 0.0186843015254) -> -1.0(ref = -0.338119029999) |  Genres:black(qv = -0.197128817439) -> -1.0(ref = -0.352486908436) |  Genres:ska(qv = -0.195809006691) -> -1.0(ref = -0.327078402042) |  decades_active:2000(qv = 0.212082654238) -> -1.0(ref = -0.22112596035) |  category:List_of_Polish_musicians_and_musical_groups(qv = -0.204736307263) -> -1.0(ref = -0.245867967606) |  Labels:is_known(qv = 0.793823182583) -> 1.0(ref = 1.67156863213) |  Occupation:poet(qv = -0.0857415124774) -> 0.0(ref = 0.0) | epoch 1100,loss 0.46054, epsilon 0.90104, rewards: ( e-greedy -7.29580, greedy -4.38604)
# rec 0.201 reg 0.259
# epoch 1200,loss 0.45017, epsilon 0.89257, rewards: ( e-greedy -7.30622, greedy -4.15743)
# rec 0.192 reg 0.259
# epoch 1300,loss 0.59818, epsilon 0.88419, rewards: ( e-greedy -7.23560, greedy -3.99169)
# rec 0.340 reg 0.258
# epoch 1400,loss 0.57164, epsilon 0.87589, rewards: ( e-greedy -7.17704, greedy -3.80252)
# rec 0.314 reg 0.258
# epoch 1500,loss 0.47177, epsilon 0.86767, rewards: ( e-greedy -7.11433, greedy -3.63227)
# rec 0.215 reg 0.257
# epoch 1600,loss 0.54168, epsilon 0.85954, rewards: ( e-greedy -6.95290, greedy -3.52904)
# rec 0.285 reg 0.257
# epoch 1700,loss 0.52115, epsilon 0.85148, rewards: ( e-greedy -6.84761, greedy -3.29614)
# rec 0.265 reg 0.256
# epoch 1800,loss 0.56876, epsilon 0.84351, rewards: ( e-greedy -6.70285, greedy -3.06652)
# rec 0.313 reg 0.256
# epoch 1900,loss 0.66333, epsilon 0.83561, rewards: ( e-greedy -6.66256, greedy -2.93987)
# rec 0.408 reg 0.255
# epoch 2000,loss 0.73040, epsilon 0.82779, rewards: ( e-greedy -6.46131, greedy -2.70588)
# rec 0.476 reg 0.255
# Learning curves:
# Random session examples
# session # 0
#  last_activity:2007(qv = -0.0943467766047) -> -1.0(ref = -0.0390173792839) |  category:List_of_Arabic_pop_musicians(qv = -0.178003922105) -> -1.0(ref = 0.0743689537048) |  category:List_of_musicians_who_play_left-handed(qv = -0.143572449684) -> -1.0(ref = 0.0814771652222) |  decades_active:1920(qv = -0.211508929729) -> -1.0(ref = 0.0538268089294) |  Occupation:entrepreneur(qv = -0.191234230995) -> -1.0(ref = 0.0205059051514) |  first_activity:1962(qv = -0.166775718331) -> -1.0(ref = -0.0348741412163) |  Genres:urban(qv = -0.11044896394) -> -1.0(ref = -0.0791739821434) |  category:List_of_jazz_musicians(qv = -0.259778410196) -> -1.0(ref = -0.199766635895) |  Cause of death:is_known(qv = -0.188184797764) -> -1.0(ref = -0.256268978119) |  Origin:louisiana(qv = -0.193069845438) -> 0.0(ref = 0.0) | session # 1
#  Genres:dancehall(qv = -0.0809422582388) -> -1.0(ref = -0.140600025654) |  Labels:is_known(qv = 0.90463155508) -> -1.0(ref = -0.293140292168) |  decades_active:1970(qv = 0.0948119089007) -> 1.0(ref = 1.71973896027) |  category:List_of_Nigerian_musicians(qv = -0.218580290675) -> -1.0(ref = -0.230755031109) |  Labels:is_known(qv = 0.809731543064) -> -0.5(ref = 0.326325893402) |  first_activity:1944(qv = -0.203613221645) -> -1.0(ref = -0.281954526901) |  Genres:wave(qv = -0.150843188167) -> -1.0(ref = -0.319217443466) |  category:List_of_Chicago_blues_musicians(qv = -0.225901141763) -> -1.0(ref = -0.296839058399) |  Origin:us(qv = -0.261575698853) -> -1.0(ref = -0.331581413746) |  Occupation:vocalist(qv = -0.252139151096) -> 0.0(ref = 0.0) | session # 2
#  Genres:music(qv = -0.0722358897328) -> -1.0(ref = 0.00988030433655) |  Labels:is_known(qv = 1.06303191185) -> 1.0(ref = 1.73680257797) |  last_activity:1998(qv = -0.223834574223) -> -1.0(ref = -0.262268960476) |  category:List_of_folk_rock_artists(qv = -0.159953266382) -> -1.0(ref = -0.287939548492) |  Labels:is_known(qv = 0.749537348747) -> -0.5(ref = 0.400172173977) |  category:List_of_electric_blues_musicians(qv = -0.167403623462) -> -1.0(ref = -0.233674347401) |  Instruments:banjo(qv = -0.359136164188) -> -1.0(ref = -0.297822117805) |  Genres:art(qv = -0.161527499557) -> -1.0(ref = -0.30833953619) |  Occupation:director(qv = -0.113618835807) -> -1.0(ref = -0.336691975594) |  Genres:gospel(qv = -0.277425289154) -> 0.0(ref = 0.0) | epoch 2100,loss 0.60700, epsilon 0.82006, rewards: ( e-greedy -6.34518, greedy -2.57530)
# rec 0.353 reg 0.254
# epoch 2200,loss 0.49207, epsilon 0.81239, rewards: ( e-greedy -6.27566, greedy -2.39777)
# rec 0.238 reg 0.254
# epoch 2300,loss 0.75471, epsilon 0.80481, rewards: ( e-greedy -6.23809, greedy -2.33799)
# rec 0.502 reg 0.253
# epoch 2400,loss 0.76898, epsilon 0.79730, rewards: ( e-greedy -6.19428, greedy -2.16419)
# rec 0.516 reg 0.253
# epoch 2500,loss 1.05418, epsilon 0.78986, rewards: ( e-greedy -6.15986, greedy -2.04777)
# rec 0.802 reg 0.252
# epoch 2600,loss 0.92122, epsilon 0.78250, rewards: ( e-greedy -6.08887, greedy -1.98299)
# rec 0.669 reg 0.252
# epoch 2700,loss 1.30521, epsilon 0.77521, rewards: ( e-greedy -5.94998, greedy -1.84469)
# rec 1.054 reg 0.252
# epoch 2800,loss 1.11312, epsilon 0.76799, rewards: ( e-greedy -5.75498, greedy -1.73023)
# rec 0.862 reg 0.251
# epoch 2900,loss 1.51611, epsilon 0.76085, rewards: ( e-greedy -5.86449, greedy -1.47720)
# rec 1.265 reg 0.251
# epoch 3000,loss 1.98678, epsilon 0.75378, rewards: ( e-greedy -5.78304, greedy -1.48448)
# rec 1.736 reg 0.251
# Learning curves:
# Random session examples
# session # 0
#  Occupation:singer(qv = 0.198507755995) -> -1.0(ref = 1.74058103561) |  category:List_of_Christian_hip_hop_and_rap_artists(qv = 0.168315038085) -> -1.0(ref = 2.37189340591) |  Origin:jamaica(qv = 0.130813673139) -> -1.0(ref = 2.4613032341) |  Genres:coast(qv = 0.0659037455916) -> -1.0(ref = 2.03029084206) |  Genres:art(qv = 0.0977931693196) -> -1.0(ref = 1.37173056602) |  Genres:new(qv = 0.482930749655) -> -1.0(ref = 0.834654569626) |  Occupation:writer(qv = 0.38972401619) -> -1.0(ref = 0.556217074394) |  category:List_of_Indian_film_music_directors(qv = 0.225051641464) -> -1.0(ref = 0.345747590065) |  Genres:americana(qv = 0.521249711514) -> -1.0(ref = -0.105679273605) |  decades_active:2000(qv = 0.941390275955) -> 0.0(ref = 0.0) | session # 1
#  Labels:is_known(qv = 1.88797581196) -> -1.0(ref = 1.27748179436) |  category:List_of_Maryland_music_people(qv = 0.283116340637) -> -1.0(ref = 1.69303202629) |  Genres:electric(qv = 0.109428651631) -> -1.0(ref = 1.47395777702) |  Labels:is_known(qv = 2.60416603088) -> -0.5(ref = 1.85976290703) |  Instruments:accordion(qv = 0.0398454070091) -> -1.0(ref = 0.917502403259) |  last_activity:still_active(qv = 2.01842355728) -> 1.0(ref = 2.62566709518) |  Home town:is_known(qv = 0.0402491316199) -> -1.0(ref = 0.172189712524) |  decades_active:1990(qv = 0.928908586502) -> 1.0(ref = 1.88447773457) |  category:List_of_Canadian_musicians(qv = -0.0865892991424) -> -1.0(ref = -0.357945740223) |  last_activity:1998(qv = 0.0816324427724) -> 0.0(ref = 0.0) | session # 2
#  Genres:country(qv = 0.0609812438488) -> -1.0(ref = 1.72026538849) |  Genres:progressive(qv = 0.114908874035) -> -1.0(ref = 2.37972784042) |  Labels:is_known(qv = 3.55760836601) -> -1.0(ref = 1.85646915436) |  Origin:jamaica(qv = 0.176915243268) -> -1.0(ref = 1.52251458168) |  Genres:swing(qv = 0.54934746027) -> -1.0(ref = 1.22100996971) |  decades_active:2000(qv = 2.33790516853) -> 1.0(ref = 2.7394990921) |  Instruments:bass(qv = 0.468102931976) -> -1.0(ref = 0.253250598907) |  category:List_of_saxophonists(qv = 0.141237065196) -> -1.0(ref = -0.129722297192) |  Occupation:tv(qv = 0.302842825651) -> -1.0(ref = -0.335036218166) |  Occupation:bassist(qv = 0.453574746847) -> 0.0(ref = 0.0) | epoch 3100,loss 1.77805, epsilon 0.74677, rewards: ( e-greedy -5.83973, greedy -1.37603)
# rec 1.527 reg 0.251
# epoch 3200,loss 1.45748, epsilon 0.73984, rewards: ( e-greedy -5.69576, greedy -1.39843)
# rec 1.207 reg 0.250
# epoch 3300,loss 1.19314, epsilon 0.73298, rewards: ( e-greedy -5.65118, greedy -1.43859)
# rec 0.943 reg 0.250
# epoch 3400,loss 0.87819, epsilon 0.72618, rewards: ( e-greedy -5.56607, greedy -1.44473)
# rec 0.628 reg 0.250
# epoch 3500,loss 0.90152, epsilon 0.71945, rewards: ( e-greedy -5.62946, greedy -1.49026)
# rec 0.651 reg 0.250
# epoch 3600,loss 0.78297, epsilon 0.71279, rewards: ( e-greedy -5.70151, greedy -1.33123)
# rec 0.533 reg 0.250
# epoch 3700,loss 0.73242, epsilon 0.70620, rewards: ( e-greedy -5.54136, greedy -1.28811)
# rec 0.483 reg 0.250
# epoch 3800,loss 0.54499, epsilon 0.69967, rewards: ( e-greedy -5.50223, greedy -1.28930)
# rec 0.296 reg 0.249
# epoch 3900,loss 0.70343, epsilon 0.69320, rewards: ( e-greedy -5.45200, greedy -1.24537)
# rec 0.455 reg 0.248
# epoch 4000,loss 0.62876, epsilon 0.68680, rewards: ( e-greedy -5.35180, greedy -1.17583)
# rec 0.381 reg 0.248
# Learning curves:
# Random session examples
# session # 0
#  Instruments:drum(qv = 0.210187986493) -> -1.0(ref = 1.20321965218) |  category:List_of_Indian_film_music_directors(qv = 0.20150744915) -> -1.0(ref = 0.574733376503) |  decades_active:2010(qv = 1.6576141119) -> 1.0(ref = 2.15112495422) |  category:List_of_adult_alternative_artists(qv = -0.136430263519) -> -1.0(ref = -0.202700436115) |  decades_active:1990(qv = 0.839262723923) -> 1.0(ref = 1.43503344059) |  category:List_of_saxophonists(qv = -0.583539247513) -> -1.0(ref = -0.665685176849) |  decades_active:1990(qv = 0.351910322905) -> -0.5(ref = -0.132560789585) |  category:List_of_Polish_musicians_and_musical_groups(qv = -0.551514923573) -> -1.0(ref = -0.620864033699) |  Genres:and(qv = -0.392988830805) -> -1.0(ref = -0.597711920738) |  Instruments:guitar(qv = 0.4234611094) -> 0.0(ref = 0.0) | session # 1
#  Genres:electronic(qv = 0.25563454628) -> -1.0(ref = 1.41101670265) |  category:List_of_Canadian_composers(qv = 0.127027645707) -> -1.0(ref = 0.574847221375) |  Genres:rockabilly(qv = 0.0148376282305) -> -1.0(ref = 0.0613721609116) |  decades_active:2010(qv = 1.11723387241) -> 1.0(ref = 1.7522790432) |  decades_active:1990(qv = 0.791872739792) -> 1.0(ref = 1.40152525902) |  Origin:angeles(qv = -0.577039778233) -> -1.0(ref = -0.65593111515) |  Occupation:bassist(qv = -0.727438569069) -> -1.0(ref = -0.686507105827) |  Occupation:educator(qv = -0.418455004692) -> -1.0(ref = -0.729877591133) |  decades_active:1980(qv = 0.284339368343) -> -1.0(ref = -0.628538429737) |  category:List_of_Israeli_musical_artists(qv = -0.223689883947) -> 0.0(ref = 0.0) | session # 2
#  Labels:is_known(qv = 2.00881266594) -> 1.0(ref = 2.64701318741) |  decades_active:2010(qv = 1.73369824886) -> 1.0(ref = 2.37218236923) |  category:List_of_musical_artists_from_Japan(qv = -0.107791550457) -> -1.0(ref = -0.12548071146) |  decades_active:1990(qv = 0.920546650887) -> 1.0(ref = 1.49211275578) |  decades_active:1990(qv = 0.518013477325) -> -0.5(ref = -0.150316208601) |  Occupation:tv(qv = -0.939111232758) -> -1.0(ref = -0.625556468964) |  last_activity:2001(qv = -0.713500678539) -> -1.0(ref = -0.651412725449) |  Died:is_known(qv = -0.274132192135) -> -1.0(ref = -0.688744425774) |  Instruments:saxophone(qv = -0.355273604393) -> -1.0(ref = -0.542768597603) |  Birth name:is_known(qv = 0.481296211481) -> 0.0(ref = 0.0) | epoch 4100,loss 0.96204, epsilon 0.68047, rewards: ( e-greedy -5.27162, greedy -1.13325)
# rec 0.715 reg 0.247
# epoch 4200,loss 1.26345, epsilon 0.67419, rewards: ( e-greedy -5.11446, greedy -1.10492)
# rec 1.017 reg 0.247
# epoch 4300,loss 1.00837, epsilon 0.66798, rewards: ( e-greedy -4.88801, greedy -0.70943)
# rec 0.762 reg 0.246
# epoch 4400,loss 0.79048, epsilon 0.66183, rewards: ( e-greedy -4.68421, greedy -0.35349)
# rec 0.545 reg 0.246
# epoch 4500,loss 0.76007, epsilon 0.65575, rewards: ( e-greedy -4.50579, greedy -0.03314)
# rec 0.515 reg 0.245
# epoch 4600,loss 0.89710, epsilon 0.64972, rewards: ( e-greedy -4.35021, greedy 0.24518)
# rec 0.652 reg 0.245
# epoch 4700,loss 1.15207, epsilon 0.64375, rewards: ( e-greedy -4.45519, greedy 0.30566)
# rec 0.907 reg 0.245
# epoch 4800,loss 1.28945, epsilon 0.63784, rewards: ( e-greedy -4.33967, greedy 0.54009)
# rec 1.045 reg 0.245
# epoch 4900,loss 0.68795, epsilon 0.63200, rewards: ( e-greedy -4.40070, greedy 0.64608)
# rec 0.443 reg 0.245
# epoch 5000,loss 0.75495, epsilon 0.62620, rewards: ( e-greedy -4.26563, greedy 0.75647)
# rec 0.511 reg 0.244
# Learning curves:
# Random session examples
# session # 0
#  Genres:death(qv = 0.580387353897) -> -1.0(ref = 2.17882084846) |  category:List_of_jazz_vocalists(qv = 0.829348623753) -> -1.0(ref = 1.50315642357) |  decades_active:2000(qv = 2.63490152359) -> -1.0(ref = 0.915330410004) |  decades_active:2010(qv = 2.01613736153) -> -1.0(ref = 0.223859906197) |  Occupation:educator(qv = -0.0686017274857) -> -1.0(ref = -0.117360949516) |  Genres:urban(qv = -0.388951301575) -> -1.0(ref = -0.282880663872) |  decades_active:1990(qv = 0.754862487316) -> -1.0(ref = -0.646583676338) |  Website:is_known(qv = 0.372017145157) -> -1.0(ref = -0.854496002197) |  Genres:[1](qv = -0.538547635078) -> -1.0(ref = -0.839976489544) |  Origin:canada(qv = -0.563399016857) -> 0.0(ref = 0.0) | session # 1
#  last_activity:still_active(qv = 1.55324220657) -> 1.0(ref = 3.86614847183) |  Labels:is_known(qv = 3.01699852943) -> -1.0(ref = 1.44602131844) |  Genres:chicago(qv = 0.777356684208) -> -1.0(ref = 0.864436984062) |  Genres:dancehall(qv = 0.296951293945) -> -1.0(ref = 0.213078260422) |  decades_active:2010(qv = 1.27692449093) -> 1.0(ref = 1.87000846863) |  decades_active:1990(qv = 0.91579836607) -> 1.0(ref = 1.49439918995) |  category:List_of_musicians_from_Chicago(qv = -0.633426368237) -> -1.0(ref = -0.622631311417) |  category:List_of_ambient_music_artists(qv = -0.491357296705) -> -1.0(ref = -0.666373372078) |  Instruments:tenor(qv = -0.389722794294) -> -1.0(ref = -0.672402083874) |  Nationality:is_known(qv = -0.0694364830852) -> 0.0(ref = 0.0) | session # 2
#  last_activity:2007(qv = 0.539558589458) -> -1.0(ref = 2.09520721436) |  Labels:is_known(qv = 3.25811290741) -> 1.0(ref = 3.56412148476) |  category:List_of_musicians_who_play_left-handed(qv = 0.808592915535) -> -1.0(ref = 0.946181297302) |  decades_active:2010(qv = 2.04861187935) -> 1.0(ref = 2.32466030121) |  Genres:symphonic(qv = -0.0315951183438) -> -1.0(ref = 0.0445599555969) |  Genres:country(qv = -0.417033731937) -> -1.0(ref = -0.164349019527) |  category:List_of_saxophonists(qv = -0.537964999676) -> -1.0(ref = -0.342485189438) |  decades_active:1990(qv = 0.692120850086) -> 1.0(ref = 1.32355213165) |  Genres:traditional(qv = -0.485111474991) -> -1.0(ref = -0.711115598679) |  Ethnicity:is_known(qv = -0.313310116529) -> 0.0(ref = 0.0) | epoch 5100,loss 0.75372, epsilon 0.62047, rewards: ( e-greedy -4.18407, greedy 0.95083)
# rec 0.510 reg 0.244
# epoch 5200,loss 0.89669, epsilon 0.61479, rewards: ( e-greedy -4.00066, greedy 1.03574)
# rec 0.653 reg 0.244
# epoch 5300,loss 0.70292, epsilon 0.60917, rewards: ( e-greedy -3.85060, greedy 1.23717)
# rec 0.460 reg 0.243
# epoch 5400,loss 0.88997, epsilon 0.60361, rewards: ( e-greedy -3.69054, greedy 1.40345)
# rec 0.647 reg 0.243
# epoch 5500,loss 0.81159, epsilon 0.59810, rewards: ( e-greedy -3.48648, greedy 1.61811)
# rec 0.569 reg 0.243
# epoch 5600,loss 0.87842, epsilon 0.59265, rewards: ( e-greedy -3.29784, greedy 1.66130)
# rec 0.636 reg 0.243
# epoch 5700,loss 0.64902, epsilon 0.58725, rewards: ( e-greedy -3.30805, greedy 1.67517)
# rec 0.407 reg 0.242
# epoch 5800,loss 0.56789, epsilon 0.58190, rewards: ( e-greedy -3.10225, greedy 1.74265)
# rec 0.326 reg 0.242
# epoch 5900,loss 0.69232, epsilon 0.57661, rewards: ( e-greedy -3.01202, greedy 1.67339)
# rec 0.451 reg 0.241
# epoch 6000,loss 0.84143, epsilon 0.57137, rewards: ( e-greedy -2.84082, greedy 1.60105)
# rec 0.600 reg 0.241
# Learning curves:
# Random session examples
# session # 0
#  Labels:is_known(qv = 3.29311180115) -> 1.0(ref = 3.95171689987) |  Origin:kingston(qv = 1.16245949268) -> -1.0(ref = 1.77368068695) |  Genres:electropop(qv = 1.34855127335) -> -1.0(ref = 1.24112343788) |  Origin:korea(qv = 0.820824205875) -> -1.0(ref = 0.851038455963) |  category:List_of_guitarists(qv = 0.363449603319) -> -1.0(ref = 0.555779576302) |  category:List_of_Scottish_musicians(qv = 0.125874921679) -> -1.0(ref = 0.21994304657) |  decades_active:2010(qv = 1.28415060043) -> -1.0(ref = -0.14468973875) |  category:List_of_alternative_country_musicians(qv = -0.256565779448) -> -1.0(ref = -0.453215003014) |  Genres:electro(qv = -0.440067350864) -> -1.0(ref = -0.648709535599) |  Instruments:synthesizer(qv = -0.393059790134) -> 0.0(ref = 0.0) | session # 1
#  category:List_of_folk_musicians(qv = 0.824380993843) -> -1.0(ref = 2.03306055069) |  Resting place:is_known(qv = 1.26157069206) -> -1.0(ref = 1.70072507858) |  Genres:rhythm(qv = 1.25834715366) -> -1.0(ref = 1.08831787109) |  Occupation:recording(qv = 0.969680190086) -> -1.0(ref = 0.76748752594) |  Occupation:music(qv = 0.490259021521) -> -1.0(ref = 0.539076447487) |  category:List_of_classical_pianists(qv = -0.0283976960927) -> -1.0(ref = 0.239232778549) |  Genres:pop(qv = 0.75059312582) -> -1.0(ref = -0.00609856843948) |  decades_active:2010(qv = 1.04621207714) -> 1.0(ref = 1.71037113667) |  decades_active:1990(qv = 0.747759103775) -> 1.0(ref = 1.4523485899) |  last_activity:still_active(qv = 0.476156413555) -> 0.0(ref = 0.0) | session # 2
#  Genres:instrumental(qv = 0.805320620537) -> -1.0(ref = 2.05107092857) |  Genres:celtic(qv = 1.28039908409) -> -1.0(ref = 1.53356432915) |  decades_active:2000(qv = 2.66690993309) -> 1.0(ref = 3.07760572433) |  Origin:angeles(qv = 0.90093511343) -> -1.0(ref = 0.913636088371) |  decades_active:2010(qv = 2.01435375214) -> 1.0(ref = 2.45640039444) |  decades_active:1990(qv = 1.5330529213) -> 1.0(ref = 2.05677986145) |  Origin:tennessee(qv = -0.285247206688) -> -1.0(ref = -0.173054277897) |  last_activity:still_active(qv = 0.870469212532) -> 1.0(ref = 1.60919594765) |  Occupation:instrumentalist(qv = -0.102291107178) -> -1.0(ref = -0.446952521801) |  Genres:symphonic(qv = -0.174138188362) -> 0.0(ref = 0.0) | epoch 6100,loss 0.75460, epsilon 0.56618, rewards: ( e-greedy -2.69674, greedy 1.89094)
# rec 0.514 reg 0.241
# epoch 6200,loss 0.77647, epsilon 0.56105, rewards: ( e-greedy -2.65206, greedy 1.82685)
# rec 0.536 reg 0.241
# epoch 6300,loss 0.65719, epsilon 0.55596, rewards: ( e-greedy -2.66186, greedy 1.68416)
# rec 0.417 reg 0.240
# epoch 6400,loss 0.58434, epsilon 0.55093, rewards: ( e-greedy -2.51067, greedy 1.80575)
# rec 0.344 reg 0.240
# epoch 6500,loss 0.99508, epsilon 0.54594, rewards: ( e-greedy -2.37460, greedy 1.81517)
# rec 0.755 reg 0.240
# epoch 6600,loss 0.87954, epsilon 0.54101, rewards: ( e-greedy -2.29714, greedy 1.72865)
# rec 0.640 reg 0.239
# epoch 6700,loss 0.96734, epsilon 0.53612, rewards: ( e-greedy -2.25743, greedy 1.73079)
# rec 0.728 reg 0.239
# epoch 6800,loss 0.93205, epsilon 0.53129, rewards: ( e-greedy -2.33669, greedy 1.60771)
# rec 0.693 reg 0.239
# epoch 6900,loss 0.63414, epsilon 0.52650, rewards: ( e-greedy -2.19802, greedy 1.70194)
# rec 0.396 reg 0.238
# epoch 7000,loss 0.71628, epsilon 0.52176, rewards: ( e-greedy -2.10822, greedy 1.66675)
# rec 0.478 reg 0.238
# Learning curves:
# Random session examples
# session # 0
#  Occupation:vocalist(qv = 1.0603710413) -> -1.0(ref = 2.01728987694) |  Agent:is_known(qv = 1.35188663006) -> -1.0(ref = 1.35747623444) |  decades_active:2000(qv = 2.48155403137) -> 1.0(ref = 3.04754161835) |  decades_active:2010(qv = 2.15530705452) -> 1.0(ref = 2.64997148514) |  last_activity:still_active(qv = 1.73681223392) -> 1.0(ref = 2.19641947746) |  end_session_now(qv = 0.988087177277) -> 0.0(ref = 0.92774784565) |  Genres:rap(qv = -0.389652937651) -> 0.0(ref = 0.0) |
#
# session # 1
#  Genres:score(qv = 0.921925783157) -> -1.0(ref = 1.89160013199) |  Labels:is_known(qv = 3.04378962517) -> 1.0(ref = 3.72151184082) |  category:List_of_deaths_in_rock_and_roll(qv = 1.22092938423) -> -1.0(ref = 1.20377159119) |  decades_active:2010(qv = 2.31975960732) -> 1.0(ref = 2.7416510582) |  last_activity:still_active(qv = 1.83331680298) -> 1.0(ref = 2.28029441833) |  category:List_of_deaths_in_rock_and_roll(qv = 0.13116158545) -> -0.5(ref = 0.597577810287) |  decades_active:2010(qv = 1.15534508228) -> -0.5(ref = 0.353977441788) |  Genres:heavy(qv = -0.189312532544) -> -1.0(ref = -0.425394117832) |  Origin:pennsylvania(qv = -0.395371347666) -> -1.0(ref = -0.4642624259) |  decades_active:1990(qv = 0.563934326172) -> 0.0(ref = 0.0) | session # 2
#  decades_active:1920(qv = 0.857525408268) -> -1.0(ref = 1.92109251022) |  category:List_of_nicknames_of_jazz_musicians(qv = 1.49875330925) -> -1.0(ref = 1.48369312286) |  Instruments:ukulele(qv = 1.15036714077) -> -1.0(ref = 0.842178821564) |  Genres:roots(qv = 0.49864295125) -> -1.0(ref = 0.323845863342) |  Instruments:and(qv = 0.0581114664674) -> -1.0(ref = 0.174463748932) |  decades_active:2010(qv = 1.23627769947) -> 1.0(ref = 1.88032162189) |  Occupation:songwriter(qv = -0.0388668179512) -> 1.0(ref = 1.93363308907) |  decades_active:1990(qv = 0.982771635056) -> 1.0(ref = 1.62755560875) |  last_activity:still_active(qv = 0.660584867001) -> 1.0(ref = 1.52978301048) |  Occupation:dancer(qv = -0.122887946665) -> 0.0(ref = 0.0) | epoch 7100,loss 0.59739, epsilon 0.51706, rewards: ( e-greedy -2.09739, greedy 1.72507)
# rec 0.360 reg 0.238
# epoch 7200,loss 0.78444, epsilon 0.51241, rewards: ( e-greedy -2.08766, greedy 1.71256)
# rec 0.547 reg 0.238
# epoch 7300,loss 0.64569, epsilon 0.50781, rewards: ( e-greedy -2.10889, greedy 1.77131)
# rec 0.409 reg 0.237
# epoch 7400,loss 0.91394, epsilon 0.50326, rewards: ( e-greedy -2.22800, greedy 1.53418)
# rec 0.677 reg 0.237
# epoch 7500,loss 0.91222, epsilon 0.49875, rewards: ( e-greedy -2.21520, greedy 1.52076)
# rec 0.676 reg 0.236
# epoch 7600,loss 0.66622, epsilon 0.49428, rewards: ( e-greedy -2.24868, greedy 1.64868)
# rec 0.430 reg 0.236
# epoch 7700,loss 0.80838, epsilon 0.48986, rewards: ( e-greedy -2.28881, greedy 1.74381)
# rec 0.573 reg 0.236
# epoch 7800,loss 0.79556, epsilon 0.48549, rewards: ( e-greedy -2.23993, greedy 1.94443)
# rec 0.560 reg 0.235
# epoch 7900,loss 1.01501, epsilon 0.48115, rewards: ( e-greedy -2.21594, greedy 1.93999)
# rec 0.780 reg 0.235

# %% [markdown]
# # Evaluating results

# %%
score_log.plot("final")

# %%
print "Random session examples"
env.load_random_batch(train_attrs,train_cats,10)
display_sessions(with_plots=True)
